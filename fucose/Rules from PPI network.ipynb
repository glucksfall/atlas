# %%
import numpy, pandas, re

# %%
with open('./ppi_network.txt', 'r') as infile:
    data = pandas.read_csv(infile, delimiter = '\t', header = None)
data
# Out:
#                            0                                                 1
# 0                       fucU                                              fucU
# 1               [fucU, fucU]                                      [fucU, fucU]
# 2               [fucU, fucU]                          [fucU, fucU, fucU, fucU]
# 3               [fucU, fucU]              [fucU, fucU, fucU, fucU, fucU, fucU]
# 4               [fucU, fucU]  [fucU, fucU, fucU, fucU, fucU, fucU, fucU, fucU]
# 5   [fucU, fucU, fucU, fucU]                          [fucU, fucU, fucU, fucU]
# 6   [fucU, fucU, fucU, fucU]              [fucU, fucU, fucU, fucU, fucU, fucU]
# 7                       fucI                                              fucI
# 8               [fucI, fucI]                                      [fucI, fucI]
# 9               [fucI, fucI]                          [fucI, fucI, fucI, fucI]
# 10                      fucA                                              fucA
# 11              [fucA, fucA]                                      [fucA, fucA]
# 12                      fucO                                              fucO
# 13                      aldA                                              aldA
# 14              [aldA, aldA]                                      [aldA, aldA]

# %%
for i in data.index:
    ## write LHS (problematic because we need to find complexes in the LHS)
    agents = (data.iloc[i, 0] + ', ' + data.iloc[i, 1])
    names = agents.split(', ')
    
    LHS = []
    next_in_complex = False
    for molecule in names:
        if molecule[0] == '[': # we are dealing with the first monomer of a complex
            next_in_complex = True
            LHS.append('prot(name = \'{:s}\', up = {{:s}}, dw = {{:s}})'.format(molecule[1:]))
        elif molecule[-1] == ']': # we are dealing with the last monomer of a complex
            next_in_complex = False            
            LHS.append('prot(name = \'{:s}\', up = {{:s}}, dw = {{:s}})'.format(molecule[:-1]))
        elif next_in_complex:
            LHS.append('prot(name = \'{:s}\', up = {{:s}}, dw = {{:s}})'.format(molecule))
        else: # we have a monomer
            LHS.append('prot(name = \'{:s}\', up = None, dw = None)'.format(molecule))
            
    ## look for where starts and ends a complex in the LHS
    monomers = [(m.start(), m.end()) for m in re.finditer(r'[A-Za-z-_]+', agents)]
    complexes = [(m.start()+1, m.end()-1) for m in re.finditer(r'\[[A-Za-z-_, ]+\]', agents)]
    
    positions = []
    for cplx_pos in reversed(complexes):
        pos_i = None
        pos_f = None
        for index, kmer_pos in enumerate(monomers):
            if cplx_pos[0] == kmer_pos[0]:
                pos_i = index
            if cplx_pos[1] == kmer_pos[1]:
                pos_f = index
                positions.append((pos_i, pos_f))
                break

    ## join complexes following start and end positions
    for position in positions:
        count_monomers = len(LHS[position[0]:position[1]+1])
        dw = list(range(1, count_monomers+1))
        up = [dw[-1]] + dw[:-1]
        up[0] = 'None'
        dw[-1] = 'None'
        
        for index, sub_position in enumerate(range(position[0], position[1]+1)):
            LHS[sub_position] = LHS[sub_position].format(str(up[index]), str(dw[index]))

        ## join agents and remove from LHS list because they were joined into one
        LHS[position[0]] = ' %\n    '.join(LHS[position[0]:position[1]+1])
        for index in reversed(range(position[0]+1, position[1]+1)):
            LHS.pop(index)

    ## final join
    LHS = ' +\n    '.join(LHS)
    
    ## write RHS (no problem, always bind molecules in a chain)
    agents = (data.iloc[i, 0] + ', ' + data.iloc[i, 1])
    agents = agents.replace('[', '').replace(']', '')
    agents = agents.split(', ')
    
    RHS = []
    # numbering links
    dw = list(range(1, len(agents)+1))
    up = [dw[-1]] + dw[:-1]
    up[0] = 'None'
    dw[-1] = 'None'

    for index, molecule in enumerate(agents):
        RHS.append('prot(name = \'{:s}\', up = {:s}, dw = {:s})' \
                   .format(molecule, str(up[index]), str(dw[index])))
    RHS = ' %\n    '.join(RHS)
    
    ## print complete rule
    name = 'prot.prot_assembly.rule_' + str(i+1)
    print('Rule(\'{:s}\', \n' \
          '    {:s} |\n' \
          '    {:s}, \n' \
          '    Parameter(\'fwd_{:s}\', 0),\n' \
          '    Parameter(\'rvs_{:s}\', 0))' \
          .format(name, LHS, RHS, name, name).replace('-', '_'))
    print()
# Out:
# Rule('prot.prot_assembly.rule_1',
#     prot(name = 'fucU', up = None, dw = None) +
#     prot(name = 'fucU', up = None, dw = None) |
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_1', 0),
#     Parameter('rvs_prot.prot_assembly.rule_1', 0))
#
# Rule('prot.prot_assembly.rule_2',
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = None) +
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = None) |
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_2', 0),
#     Parameter('rvs_prot.prot_assembly.rule_2', 0))
#
# Rule('prot.prot_assembly.rule_3',
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = None) +
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = None) |
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = 4) %
#     prot(name = 'fucU', up = 4, dw = 5) %
#     prot(name = 'fucU', up = 5, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_3', 0),
#     Parameter('rvs_prot.prot_assembly.rule_3', 0))
#
# Rule('prot.prot_assembly.rule_4',
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = None) +
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = 4) %
#     prot(name = 'fucU', up = 4, dw = 5) %
#     prot(name = 'fucU', up = 5, dw = None) |
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = 4) %
#     prot(name = 'fucU', up = 4, dw = 5) %
#     prot(name = 'fucU', up = 5, dw = 6) %
#     prot(name = 'fucU', up = 6, dw = 7) %
#     prot(name = 'fucU', up = 7, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_4', 0),
#     Parameter('rvs_prot.prot_assembly.rule_4', 0))
#
# Rule('prot.prot_assembly.rule_5',
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = None) +
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = 4) %
#     prot(name = 'fucU', up = 4, dw = 5) %
#     prot(name = 'fucU', up = 5, dw = 6) %
#     prot(name = 'fucU', up = 6, dw = 7) %
#     prot(name = 'fucU', up = 7, dw = None) |
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = 4) %
#     prot(name = 'fucU', up = 4, dw = 5) %
#     prot(name = 'fucU', up = 5, dw = 6) %
#     prot(name = 'fucU', up = 6, dw = 7) %
#     prot(name = 'fucU', up = 7, dw = 8) %
#     prot(name = 'fucU', up = 8, dw = 9) %
#     prot(name = 'fucU', up = 9, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_5', 0),
#     Parameter('rvs_prot.prot_assembly.rule_5', 0))
#
# Rule('prot.prot_assembly.rule_6',
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = None) +
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = None) |
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = 4) %
#     prot(name = 'fucU', up = 4, dw = 5) %
#     prot(name = 'fucU', up = 5, dw = 6) %
#     prot(name = 'fucU', up = 6, dw = 7) %
#     prot(name = 'fucU', up = 7, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_6', 0),
#     Parameter('rvs_prot.prot_assembly.rule_6', 0))
#
# Rule('prot.prot_assembly.rule_7',
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = None) +
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = 4) %
#     prot(name = 'fucU', up = 4, dw = 5) %
#     prot(name = 'fucU', up = 5, dw = None) |
#     prot(name = 'fucU', up = None, dw = 1) %
#     prot(name = 'fucU', up = 1, dw = 2) %
#     prot(name = 'fucU', up = 2, dw = 3) %
#     prot(name = 'fucU', up = 3, dw = 4) %
#     prot(name = 'fucU', up = 4, dw = 5) %
#     prot(name = 'fucU', up = 5, dw = 6) %
#     prot(name = 'fucU', up = 6, dw = 7) %
#     prot(name = 'fucU', up = 7, dw = 8) %
#     prot(name = 'fucU', up = 8, dw = 9) %
#     prot(name = 'fucU', up = 9, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_7', 0),
#     Parameter('rvs_prot.prot_assembly.rule_7', 0))
#
# Rule('prot.prot_assembly.rule_8',
#     prot(name = 'fucI', up = None, dw = None) +
#     prot(name = 'fucI', up = None, dw = None) |
#     prot(name = 'fucI', up = None, dw = 1) %
#     prot(name = 'fucI', up = 1, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_8', 0),
#     Parameter('rvs_prot.prot_assembly.rule_8', 0))
#
# Rule('prot.prot_assembly.rule_9',
#     prot(name = 'fucI', up = None, dw = 1) %
#     prot(name = 'fucI', up = 1, dw = None) +
#     prot(name = 'fucI', up = None, dw = 1) %
#     prot(name = 'fucI', up = 1, dw = None) |
#     prot(name = 'fucI', up = None, dw = 1) %
#     prot(name = 'fucI', up = 1, dw = 2) %
#     prot(name = 'fucI', up = 2, dw = 3) %
#     prot(name = 'fucI', up = 3, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_9', 0),
#     Parameter('rvs_prot.prot_assembly.rule_9', 0))
#
# Rule('prot.prot_assembly.rule_10',
#     prot(name = 'fucI', up = None, dw = 1) %
#     prot(name = 'fucI', up = 1, dw = None) +
#     prot(name = 'fucI', up = None, dw = 1) %
#     prot(name = 'fucI', up = 1, dw = 2) %
#     prot(name = 'fucI', up = 2, dw = 3) %
#     prot(name = 'fucI', up = 3, dw = None) |
#     prot(name = 'fucI', up = None, dw = 1) %
#     prot(name = 'fucI', up = 1, dw = 2) %
#     prot(name = 'fucI', up = 2, dw = 3) %
#     prot(name = 'fucI', up = 3, dw = 4) %
#     prot(name = 'fucI', up = 4, dw = 5) %
#     prot(name = 'fucI', up = 5, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_10', 0),
#     Parameter('rvs_prot.prot_assembly.rule_10', 0))
#
# Rule('prot.prot_assembly.rule_11',
#     prot(name = 'fucA', up = None, dw = None) +
#     prot(name = 'fucA', up = None, dw = None) |
#     prot(name = 'fucA', up = None, dw = 1) %
#     prot(name = 'fucA', up = 1, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_11', 0),
#     Parameter('rvs_prot.prot_assembly.rule_11', 0))
#
# Rule('prot.prot_assembly.rule_12',
#     prot(name = 'fucA', up = None, dw = 1) %
#     prot(name = 'fucA', up = 1, dw = None) +
#     prot(name = 'fucA', up = None, dw = 1) %
#     prot(name = 'fucA', up = 1, dw = None) |
#     prot(name = 'fucA', up = None, dw = 1) %
#     prot(name = 'fucA', up = 1, dw = 2) %
#     prot(name = 'fucA', up = 2, dw = 3) %
#     prot(name = 'fucA', up = 3, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_12', 0),
#     Parameter('rvs_prot.prot_assembly.rule_12', 0))
#
# Rule('prot.prot_assembly.rule_13',
#     prot(name = 'fucO', up = None, dw = None) +
#     prot(name = 'fucO', up = None, dw = None) |
#     prot(name = 'fucO', up = None, dw = 1) %
#     prot(name = 'fucO', up = 1, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_13', 0),
#     Parameter('rvs_prot.prot_assembly.rule_13', 0))
#
# Rule('prot.prot_assembly.rule_14',
#     prot(name = 'aldA', up = None, dw = None) +
#     prot(name = 'aldA', up = None, dw = None) |
#     prot(name = 'aldA', up = None, dw = 1) %
#     prot(name = 'aldA', up = 1, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_14', 0),
#     Parameter('rvs_prot.prot_assembly.rule_14', 0))
#
# Rule('prot.prot_assembly.rule_15',
#     prot(name = 'aldA', up = None, dw = 1) %
#     prot(name = 'aldA', up = 1, dw = None) +
#     prot(name = 'aldA', up = None, dw = 1) %
#     prot(name = 'aldA', up = 1, dw = None) |
#     prot(name = 'aldA', up = None, dw = 1) %
#     prot(name = 'aldA', up = 1, dw = 2) %
#     prot(name = 'aldA', up = 2, dw = 3) %
#     prot(name = 'aldA', up = 3, dw = None),
#     Parameter('fwd_prot.prot_assembly.rule_15', 0),
#     Parameter('rvs_prot.prot_assembly.rule_15', 0))
