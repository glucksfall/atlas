# %% [markdown]
# ### Section 0: Import

# %%
from pysb import *
from pysb.export import export
from pysb.simulator import BngSimulator, KappaSimulator

import matplotlib.pyplot as plt
from pylab import linspace

import seaborn
palette = seaborn.color_palette('colorblind')

from pysb.pathfinder import set_path
set_path('bng', '/opt/git-repositories/bionetgen.RuleWorld/bng2/') # path to bng2 folder (BNG2.pl executable)
set_path('kasim', '/opt/git-repositories/KaSim4.Kappa-Dev/') # path to KaSim executable (v4 or newer)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width: 95% !important; }</style>"))
# Out:
# <style>.container { width: 95% !important; }</style>

# %% [markdown]
# ### Section 1: Define Model

# %%
Model()
# Out:
# <Model '_interactive_' (monomers: 0, rules: 0, parameters: 0, expressions: 0, compartments: 0) at 0x7effbb5ead68>

# %%
# Define model components

# paste inside brackets the common names for metabolites
metabolites = ['ACET', 'ACETALD', 'ACETYL_COA', 'ACETYL_P', 'ADENINE', 'ADENOSINE', 
    'ADENOSINE5TRIPHOSPHO5ADENOSINE', 'ADENYLOSUCC', 'ADP', 'AICAR', 'ALLO_THR', 
    'AMINO_OXOBUT', 'AMMONIUM', 'AMP', 'ANTHRANILATE', 'ASN', 'ATP', 'Acceptor', 
    'Alcohols', 'Alpha_D_aldose_1_phosphates', 'Amino_Acids_20', 
    'Aromatic_Amino_Acids', 'Aromatic_Oxoacids', 'CARBAMATE', 'CARBAMOYL_P', 
    'CARBAMYUL_L_ASPARTATE', 'CARBON_DIOXIDE', 'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P', 
    'CDP', 'CHOLINE', 'CHORISMATE', 'CIS_ACONITATE', 'CIT', 'CMP', 'CO_A', 
    'CPD_1136', 'CPD_12991', 'CPD_1301', 'CPD_1302', 'CPD_13025', 'CPD_13357', 
    'CPD_13927', 'CPD_13930', 'CPD_14443', 'CPD_14736', 'CPD_15317', 'CPD_15390', 
    'CPD_15391', 'CPD_15392', 'CPD_15393', 'CPD_15818', 'CPD_16009', 'CPD_16619', 
    'CPD_194', 'CPD_239', 'CPD_2961', 'CPD_3582', 'CPD_3705', 'CPD_3706', 
    'CPD_3710', 'CPD_3711', 'CPD_3721', 'CPD_3723', 'CPD_3724', 'CPD_3728', 
    'CPD_381', 'CPD_4544', 'CPD_469', 'CPD_476', 'CPD_536', 'CPD_606', 'CPD_618', 
    'CPD_66', 'CPD_660', 'CPD_67', 'CPD0_181', 'CPD0_2189', 'CPD0_2331', 
    'CPD0_2338', 'CPD0_2339', 'CPD0_2340', 'CPD0_2461', 'CPD0_881', 'CREATINE', 
    'CREATINE_P', 'CTP', 'CYS', 'CYTIDINE', 'CYTOSINE', 
    'D_6_P_GLUCONO_DELTA_LACTONE', 'D_ALANINE', 'D_ALLOSE_6_PHOSPHATE', 
    'D_ALLULOSE_6_PHOSPHATE', 'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P', 'D_GLUCOSAMINE_6_P', 
    'D_Ribofuranose', 'D_SEDOHEPTULOSE_1_7_P2', 'D_SEDOHEPTULOSE_7_P', 'D_TARTRATE', 
    'D_glucopyranose_6_phosphate', 'D_glucose_1_phosphates', 'DADP', 'DAMP', 'DATP', 
    'DCDP', 'DCMP', 'DCTP', 'DEAMIDO_NAD', 'DEHYDROQUINATE', 
    'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE', 'DEOXY_D_RIBOSE_1_PHOSPHATE', 
    'DEOXY_RIBOSE_5P', 'DEOXYADENOSINE', 'DEOXYCYTIDINE', 'DEOXYGUANOSINE', 
    'DEOXYINOSINE', 'DEOXYURIDINE', 'DGDP', 'DGMP', 'DGTP', 'DI_H_OROTATE', 
    'DIHYDROFOLATE_GLU_N', 'DIHYDROLIPOYL_GCVH', 'DIHYDROXY_ACETONE_PHOSPHATE', 
    'DIHYDROXYACETONE', 'DPG', 'DUDP', 'DUMP', 'DUTP', 'Deoxy_Ribonucleoside_3P', 
    'Deoxy_Ribonucleoside_Monophosphates', 'Deoxy_Ribonucleoside_Triphosphates', 
    'Deoxy_Ribonucleosides', 'Dihydro_Lipoyl_Proteins', 'Donor_H2', 
    'ENOL_OXALOACETATE', 'ERYTHROSE_4P', 'ETHANOL_AMINE', 'ETR_Quinols', 
    'ETR_Quinones', 'FMN', 'FMNH2', 'FORMATE', 'FORMYL_THF_GLU_N', 
    'FRUCTOSE_16_DIPHOSPHATE', 'FRUCTOSE_6P', 'FUM', 'G3P', 'GAP', 'GDP', 'GLN', 
    'GLT', 'GLUCONATE', 'GLUCOSAMINE', 'GLY', 'GLYCERALD', 'GLYCERATE', 'GLYCEROL', 
    'GLYCEROL_3P', 'GLYCOLLATE', 'GLYOX', 'GMP', 'GTP', 'GUANINE', 'GUANOSINE', 
    'Glucopyranose', 'HCO3', 'HIS', 'HISTIDINAL', 'HISTIDINOL', 'HOMO_CYS', 
    'HOMO_SER', 'HS', 'HYPOXANTHINE', 'ILE', 'IMIDAZOLE_ACETOL_P', 'IMP', 'INDOLE', 
    'INDOLE_3_GLYCEROL_P', 'INOSINE', 'L_ALLO_THREONINE', 'L_ASPARTATE', 
    'L_ASPARTATE_SEMIALDEHYDE', 'L_BETA_ASPARTYL_P', 'L_CYSTATHIONINE', 
    'L_GLYCERALDEHYDE', 'L_GLYCERALDEHYDE_3_PHOSPHATE', 'L_HISTIDINOL_P', 
    'L_PANTOATE', 'L_THREONINE_O_3_PHOSPHATE', 'LEU', 'LL_DIAMINOPIMELATE', 'LYS', 
    'Lipoyl_Protein_N6_lipoyllysine', 'MAL', 'MALONATE_S_ALD', 'MANNOSE', 
    'MANNOSE_1P', 'MESO_DIAMINOPIMELATE', 'MET', 'METHYLENE_THF_GLU_N', 
    'Mannose_6_phosphate', 'Menaquinols', 'Menaquinones', 
    'N_5_PHOSPHORIBOSYL_ANTHRANILATE', 'N_ALPHA_ACETYLORNITHINE', 
    'N_SUCCINYL_2_AMINO_6_KETOPIMELATE', 'N_SUCCINYLLL_2_6_DIAMINOPIMELATE', 
    'N5_Formyl_THF_Glu_N', 'NACMUR', 'NAD', 'NAD_P_OR_NOP', 'NADH', 'NADH_P_OR_NOP', 
    'NADP', 'NADPH', 'NIACINAMIDE', 'NIACINE', 'NICOTINAMIDE_NUCLEOTIDE', 
    'NICOTINAMIDE_RIBOSE', 'NICOTINATE_NUCLEOTIDE', 'Nucleoside_Diphosphates', 
    'Nucleoside_Monophosphates', 'Nucleoside_Triphosphates', 'Nucleosides', 
    'O_PHOSPHO_L_HOMOSERINE', 'O_SUCCINYL_L_HOMOSERINE', 'OROTATE', 
    'OROTIDINE_5_PHOSPHATE', 'OXALACETIC_ACID', 'OXYGEN_MOLECULE', 
    'Orthophosphoric_Monoesters', 'Oxo_glutarate_dehydro_suc_DH_lipoyl', 
    'Oxo_glutarate_dehydrogenase_DH_lipoyl', 'Oxo_glutarate_dehydrogenase_lipoyl', 
    'P_HYDROXY_PHENYLPYRUVATE', 'P_NITROPHENOL', 
    'P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE', 'P3I', 'PHE', 'PHENYL_PYRUVATE', 
    'PHOSPHO_ENOL_PYRUVATE', 'PHOSPHORIBOSYL_AMP', 'PHOSPHORIBOSYL_ATP', 
    'PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE', 'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE', 
    'PHOSPHORIBOSYL_FORMIMINO_AICAR_P', 'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P', 
    'PHOSPHORYL_CHOLINE', 'PHOSPHORYL_ETHANOLAMINE', 'PPI', 'PREPHENATE', 
    'PROTEIN_LIPOYLLYSINE', 'PROTON', 'PRPP', 'PTSH_MONOMER', 'PTSH_PHOSPHORYLATED', 
    'PYRAZINAMIDE', 'PYRAZINOIC_ACID', 'PYRIDOXAL', 'PYRIDOXAL_PHOSPHATE', 
    'PYRIDOXAMINE_5P', 'PYRIDOXINE', 'PYRIDOXINE_5P', 'PYRUVATE', 'Pi', 
    'Purine_Bases', 'Purine_Ribonucleosides', 'Pyrimidine_Bases', 
    'Pyrimidine_Nucleosides', 'Pyrimidine_ribonucleotides', 
    'Pyruvate_dehydrogenase_acetylDHlipoyl', 
    'Pyruvate_dehydrogenase_dihydrolipoate', 'Pyruvate_dehydrogenase_lipoate', 
    'R_2_HYDROXYGLUTARATE', 'RIBOFLAVIN', 'RIBOSE_1P', 'RIBOSE_5P', 'RIBULOSE_5P', 
    'Ribonucleoside_Monophosphates', 'Ribonucleoside_Triphosphates', 
    'Ribonucleosides', 'SER', 'SHIKIMATE', 'SHIKIMATE_5P', 'SUC', 'SUC_COA', 
    'Sugar', 'Sugar_Phosphate', 'TAGATOSE_1_6_DIPHOSPHATE', 'TAGATOSE_6_PHOSPHATE', 
    'TARTRATE', 'TDP', 'THF_GLU_N', 'THR', 'THREO_DS_ISO_CITRATE', 'THYMIDINE', 
    'THYMINE', 'TMP', 'TREHALOSE', 'TREHALOSE_6P', 'TRP', 'TTP', 'TYR', 'UDP', 
    'UDP_sugar', 'UMP', 'URACIL', 'URATE', 'URIDINE', 'UTP', 'Ubiquinols', 
    'Ubiquinones', 'VAL', 'WATER', 'XANTHINE', 'XANTHOSINE', 
    'XANTHOSINE_5_PHOSPHATE', 'XYLULOSE_5_PHOSPHATE', '_1_KETO_2_METHYLVALERATE', 
    '_2_ACETO_2_HYDROXY_BUTYRATE', '_2_ACETO_LACTATE', 
    '_2_AMINOMALONATE_SEMIALDEHYDE', '_2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE', 
    '_2_DEHYDROPANTOATE', '_2_DEOXY_D_GLUCOSE', '_2_DEOXY_D_GLUCOSE_6_PHOSPHATE', 
    '_2_KETO_3_METHYL_VALERATE', '_2_KETO_ISOVALERATE', '_2_KETOGLUTARATE', 
    '_2_OXOBUTANOATE', '_2_PG', '_2K_4CH3_PENTANOATE', 
    '_3_CARBOXY_3_HYDROXY_ISOCAPROATE', '_3_DEHYDRO_SHIKIMATE', 
    '_3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P', '_3_ENOLPYRUVYL_SHIKIMATE_5P', 
    '_3_HYDROXY_PROPIONATE', '_3_MERCAPTO_PYRUVATE', '_3_P_HYDROXYPYRUVATE', 
    '_3_P_SERINE', '_3_Phosphomonucleotides', '_3OH_4P_OH_ALPHA_KETOBUTYRATE', 
    '_4_PHOSPHONOOXY_THREONINE', '_5_10_METHENYL_THF_GLU_N', '_5_METHYL_THF_GLU_N', 
    '_5_P_BETA_D_RIBOSYL_AMINE', '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', 
    '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', '_5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE', 
    '_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE']

# paste inside brackets the common names for genes
genes = ['aceA', 'aceB', 'aceE', 'aceF', 'acnA', 'acnB', 'add', 'adk', 'amn', 'ansA', 
    'ansB', 'aphA', 'apt', 'argD', 'aroA', 'aroB', 'aroC', 'aroD', 'aroE', 'aroF', 
    'aroG', 'aroH', 'aroK', 'aroL', 'asd', 'asnA', 'asnB', 'aspA', 'aspC', 'carA', 
    'carB', 'cdd', 'cmk', 'codA', 'crr', 'dapA', 'dapB', 'dapD', 'dapE', 'dapF', 
    'dcd', 'deoA', 'deoB', 'deoD', 'dmlA', 'dut', 'eno', 'fbaA', 'fbaB', 'fbp', 
    'fumA', 'fumB', 'fumC', 'fumD', 'fumE', 'gapA', 'glpX', 'gltA', 'glyA', 'gmk', 
    'gnd', 'gpmA', 'gpmM', 'gpt', 'gsk', 'guaA', 'guaB', 'guaD', 'hisA', 'hisB', 
    'hisC', 'hisD', 'hisF', 'hisG', 'hisH', 'hisI', 'hpt', 'iaaA', 'icd', 'ilvA', 
    'ilvB', 'ilvC', 'ilvD', 'ilvE', 'ilvH', 'ilvI', 'ilvM', 'ilvN', 'leuA', 'leuB', 
    'leuC', 'leuD', 'lpd', 'lysA', 'lysC', 'maeA', 'maeB', 'malY', 'mazG', 'mdh', 
    'metA', 'metB', 'metC', 'metE', 'metH', 'metL', 'mqo', 'nadD', 'nadE', 'nadR', 
    'ndk', 'nrdD', 'nudI', 'nupC', 'nupG', 'pck', 'pfkA', 'pfkB', 'pgi', 'pgk', 
    'pheA', 'phoA', 'pncA', 'pncB', 'ppnN', 'ppnP', 'ppsA', 'prs', 'ptsG', 'purA', 
    'purB', 'purC', 'purD', 'purE', 'purF', 'purH', 'purK', 'purL', 'purM', 'purN', 
    'purT', 'pykA', 'pykF', 'pyrC', 'pyrD', 'pyrE', 'pyrF', 'pyrG', 'pyrH', 'rihA', 
    'rihB', 'rihC', 'rpe', 'rpiA', 'rpiB', 'rutA', 'rutB', 'rutD', 'rutE', 'rutG', 
    'serA', 'serB', 'serC', 'sucA', 'sucB', 'sucC', 'sucD', 'talA', 'talB', 'tdk', 
    'thrA', 'thrB', 'thrC', 'thyA', 'tktA', 'tktB', 'tmk', 'tpiA', 'trpA', 'trpB', 
    'trpC', 'trpD', 'trpE', 'tyrA', 'tyrB', 'udk', 'udp', 'umpG', 'umpH', 'upp', 
    'ushA', 'xapA', 'xdhA', 'xdhB', 'xdhC', 'ybhA', 'ydfG', 'yggF', 'yrfG', 'zwf']

# paste inside brackets the DNA binding sites: BS- followed by genomic coordinates
binding_sites = []

Monomer('met', ['name', 'loc', 'prot'], 
    { 'name' : metabolites, 
      'loc' : ['cyt', 'per', 'ex']})

Monomer('dna', ['name', 'type', 'prot', 'rna', 'up', 'dw'], 
    { 'name' : genes + binding_sites, 
      'type' : ['BS', 'pro1', 'pro2', 'pro3', 'pro4', 'rbs', 'cds', 'ter1', 'ter2']})

Monomer('rna', ['name', 'type', 'dna', 'prot'], 
    { 'name' : genes + binding_sites, 
      'type' : ['BS', 'pro1', 'pro2', 'pro3', 'pro4', 'rbs', 'cds', 'ter1', 'ter2']})

Monomer('prot', ['name', 'loc', 'dna', 'met', 'rna', 'up', 'dw'],
    { 'name' : genes, # we name proteins with their gene common names (aka, first letter lowercase) 
      'loc' : ['cyt', 'per', 'ex']})
# Out:
# Monomer('prot', ['name', 'loc', 'dna', 'met', 'rna', 'up', 'dw'], {'name': ['aceA', 'aceB', 'aceE', 'aceF', 'acnA', 'acnB', 'add', 'adk', 'amn', 'ansA', 'ansB', 'aphA', 'apt', 'argD', 'aroA', 'aroB', 'aroC', 'aroD', 'aroE', 'aroF', 'aroG', 'aroH', 'aroK', 'aroL', 'asd', 'asnA', 'asnB', 'aspA', 'aspC', 'carA', 'carB', 'cdd', 'cmk', 'codA', 'crr', 'dapA', 'dapB', 'dapD', 'dapE', 'dapF', 'dcd', 'deoA', 'deoB', 'deoD', 'dmlA', 'dut', 'eno', 'fbaA', 'fbaB', 'fbp', 'fumA', 'fumB', 'fumC', 'fumD', 'fumE', 'gapA', 'glpX', 'gltA', 'glyA', 'gmk', 'gnd', 'gpmA', 'gpmM', 'gpt', 'gsk', 'guaA', 'guaB', 'guaD', 'hisA', 'hisB', 'hisC', 'hisD', 'hisF', 'hisG', 'hisH', 'hisI', 'hpt', 'iaaA', 'icd', 'ilvA', 'ilvB', 'ilvC', 'ilvD', 'ilvE', 'ilvH', 'ilvI', 'ilvM', 'ilvN', 'leuA', 'leuB', 'leuC', 'leuD', 'lpd', 'lysA', 'lysC', 'maeA', 'maeB', 'malY', 'mazG', 'mdh', 'metA', 'metB', 'metC', 'metE', 'metH', 'metL', 'mqo', 'nadD', 'nadE', 'nadR', 'ndk', 'nrdD', 'nudI', 'nupC', 'nupG', 'pck', 'pfkA', 'pfkB', '
# ...

# %%
## paste here the result of "Monomer+Initials+Observables from metabolic network"
# Define observables and initials for metabolites
Observable('obs_ACET_cyt', met(name = 'ACET', loc = 'cyt', prot = None))
Observable('obs_ACET_per', met(name = 'ACET', loc = 'per', prot = None))
Observable('obs_ACET_ex', met(name = 'ACET', loc = 'ex', prot = None))
Observable('obs_ACETALD_cyt', met(name = 'ACETALD', loc = 'cyt', prot = None))
Observable('obs_ACETALD_per', met(name = 'ACETALD', loc = 'per', prot = None))
Observable('obs_ACETALD_ex', met(name = 'ACETALD', loc = 'ex', prot = None))
Observable('obs_ACETYL_COA_cyt', met(name = 'ACETYL_COA', loc = 'cyt', prot = None))
Observable('obs_ACETYL_COA_per', met(name = 'ACETYL_COA', loc = 'per', prot = None))
Observable('obs_ACETYL_COA_ex', met(name = 'ACETYL_COA', loc = 'ex', prot = None))
Observable('obs_ACETYL_P_cyt', met(name = 'ACETYL_P', loc = 'cyt', prot = None))
Observable('obs_ACETYL_P_per', met(name = 'ACETYL_P', loc = 'per', prot = None))
Observable('obs_ACETYL_P_ex', met(name = 'ACETYL_P', loc = 'ex', prot = None))
Observable('obs_ADENINE_cyt', met(name = 'ADENINE', loc = 'cyt', prot = None))
Observable('obs_ADENINE_per', met(name = 'ADENINE', loc = 'per', prot = None))
Observable('obs_ADENINE_ex', met(name = 'ADENINE', loc = 'ex', prot = None))
Observable('obs_ADENOSINE_cyt', met(name = 'ADENOSINE', loc = 'cyt', prot = None))
Observable('obs_ADENOSINE_per', met(name = 'ADENOSINE', loc = 'per', prot = None))
Observable('obs_ADENOSINE_ex', met(name = 'ADENOSINE', loc = 'ex', prot = None))
Observable('obs_ADENOSINE5TRIPHOSPHO5ADENOSINE_cyt', met(name = 'ADENOSINE5TRIPHOSPHO5ADENOSINE', loc = 'cyt', prot = None))
Observable('obs_ADENOSINE5TRIPHOSPHO5ADENOSINE_per', met(name = 'ADENOSINE5TRIPHOSPHO5ADENOSINE', loc = 'per', prot = None))
Observable('obs_ADENOSINE5TRIPHOSPHO5ADENOSINE_ex', met(name = 'ADENOSINE5TRIPHOSPHO5ADENOSINE', loc = 'ex', prot = None))
Observable('obs_ADENYLOSUCC_cyt', met(name = 'ADENYLOSUCC', loc = 'cyt', prot = None))
Observable('obs_ADENYLOSUCC_per', met(name = 'ADENYLOSUCC', loc = 'per', prot = None))
Observable('obs_ADENYLOSUCC_ex', met(name = 'ADENYLOSUCC', loc = 'ex', prot = None))
Observable('obs_ADP_cyt', met(name = 'ADP', loc = 'cyt', prot = None))
Observable('obs_ADP_per', met(name = 'ADP', loc = 'per', prot = None))
Observable('obs_ADP_ex', met(name = 'ADP', loc = 'ex', prot = None))
Observable('obs_AICAR_cyt', met(name = 'AICAR', loc = 'cyt', prot = None))
Observable('obs_AICAR_per', met(name = 'AICAR', loc = 'per', prot = None))
Observable('obs_AICAR_ex', met(name = 'AICAR', loc = 'ex', prot = None))
Observable('obs_ALLO_THR_cyt', met(name = 'ALLO_THR', loc = 'cyt', prot = None))
Observable('obs_ALLO_THR_per', met(name = 'ALLO_THR', loc = 'per', prot = None))
Observable('obs_ALLO_THR_ex', met(name = 'ALLO_THR', loc = 'ex', prot = None))
Observable('obs_AMINO_OXOBUT_cyt', met(name = 'AMINO_OXOBUT', loc = 'cyt', prot = None))
Observable('obs_AMINO_OXOBUT_per', met(name = 'AMINO_OXOBUT', loc = 'per', prot = None))
Observable('obs_AMINO_OXOBUT_ex', met(name = 'AMINO_OXOBUT', loc = 'ex', prot = None))
Observable('obs_AMMONIUM_cyt', met(name = 'AMMONIUM', loc = 'cyt', prot = None))
Observable('obs_AMMONIUM_per', met(name = 'AMMONIUM', loc = 'per', prot = None))
Observable('obs_AMMONIUM_ex', met(name = 'AMMONIUM', loc = 'ex', prot = None))
Observable('obs_AMP_cyt', met(name = 'AMP', loc = 'cyt', prot = None))
Observable('obs_AMP_per', met(name = 'AMP', loc = 'per', prot = None))
Observable('obs_AMP_ex', met(name = 'AMP', loc = 'ex', prot = None))
Observable('obs_ANTHRANILATE_cyt', met(name = 'ANTHRANILATE', loc = 'cyt', prot = None))
Observable('obs_ANTHRANILATE_per', met(name = 'ANTHRANILATE', loc = 'per', prot = None))
Observable('obs_ANTHRANILATE_ex', met(name = 'ANTHRANILATE', loc = 'ex', prot = None))
Observable('obs_ASN_cyt', met(name = 'ASN', loc = 'cyt', prot = None))
Observable('obs_ASN_per', met(name = 'ASN', loc = 'per', prot = None))
Observable('obs_ASN_ex', met(name = 'ASN', loc = 'ex', prot = None))
Observable('obs_ATP_cyt', met(name = 'ATP', loc = 'cyt', prot = None))
Observable('obs_ATP_per', met(name = 'ATP', loc = 'per', prot = None))
Observable('obs_ATP_ex', met(name = 'ATP', loc = 'ex', prot = None))
Observable('obs_Acceptor_cyt', met(name = 'Acceptor', loc = 'cyt', prot = None))
Observable('obs_Acceptor_per', met(name = 'Acceptor', loc = 'per', prot = None))
Observable('obs_Acceptor_ex', met(name = 'Acceptor', loc = 'ex', prot = None))
Observable('obs_Alcohols_cyt', met(name = 'Alcohols', loc = 'cyt', prot = None))
Observable('obs_Alcohols_per', met(name = 'Alcohols', loc = 'per', prot = None))
Observable('obs_Alcohols_ex', met(name = 'Alcohols', loc = 'ex', prot = None))
Observable('obs_Alpha_D_aldose_1_phosphates_cyt', met(name = 'Alpha_D_aldose_1_phosphates', loc = 'cyt', prot = None))
Observable('obs_Alpha_D_aldose_1_phosphates_per', met(name = 'Alpha_D_aldose_1_phosphates', loc = 'per', prot = None))
Observable('obs_Alpha_D_aldose_1_phosphates_ex', met(name = 'Alpha_D_aldose_1_phosphates', loc = 'ex', prot = None))
Observable('obs_Amino_Acids_20_cyt', met(name = 'Amino_Acids_20', loc = 'cyt', prot = None))
Observable('obs_Amino_Acids_20_per', met(name = 'Amino_Acids_20', loc = 'per', prot = None))
Observable('obs_Amino_Acids_20_ex', met(name = 'Amino_Acids_20', loc = 'ex', prot = None))
Observable('obs_Aromatic_Amino_Acids_cyt', met(name = 'Aromatic_Amino_Acids', loc = 'cyt', prot = None))
Observable('obs_Aromatic_Amino_Acids_per', met(name = 'Aromatic_Amino_Acids', loc = 'per', prot = None))
Observable('obs_Aromatic_Amino_Acids_ex', met(name = 'Aromatic_Amino_Acids', loc = 'ex', prot = None))
Observable('obs_Aromatic_Oxoacids_cyt', met(name = 'Aromatic_Oxoacids', loc = 'cyt', prot = None))
Observable('obs_Aromatic_Oxoacids_per', met(name = 'Aromatic_Oxoacids', loc = 'per', prot = None))
Observable('obs_Aromatic_Oxoacids_ex', met(name = 'Aromatic_Oxoacids', loc = 'ex', prot = None))
Observable('obs_CARBAMATE_cyt', met(name = 'CARBAMATE', loc = 'cyt', prot = None))
Observable('obs_CARBAMATE_per', met(name = 'CARBAMATE', loc = 'per', prot = None))
Observable('obs_CARBAMATE_ex', met(name = 'CARBAMATE', loc = 'ex', prot = None))
Observable('obs_CARBAMOYL_P_cyt', met(name = 'CARBAMOYL_P', loc = 'cyt', prot = None))
Observable('obs_CARBAMOYL_P_per', met(name = 'CARBAMOYL_P', loc = 'per', prot = None))
Observable('obs_CARBAMOYL_P_ex', met(name = 'CARBAMOYL_P', loc = 'ex', prot = None))
Observable('obs_CARBAMYUL_L_ASPARTATE_cyt', met(name = 'CARBAMYUL_L_ASPARTATE', loc = 'cyt', prot = None))
Observable('obs_CARBAMYUL_L_ASPARTATE_per', met(name = 'CARBAMYUL_L_ASPARTATE', loc = 'per', prot = None))
Observable('obs_CARBAMYUL_L_ASPARTATE_ex', met(name = 'CARBAMYUL_L_ASPARTATE', loc = 'ex', prot = None))
Observable('obs_CARBON_DIOXIDE_cyt', met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None))
Observable('obs_CARBON_DIOXIDE_per', met(name = 'CARBON_DIOXIDE', loc = 'per', prot = None))
Observable('obs_CARBON_DIOXIDE_ex', met(name = 'CARBON_DIOXIDE', loc = 'ex', prot = None))
Observable('obs_CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P_cyt', met(name = 'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P', loc = 'cyt', prot = None))
Observable('obs_CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P_per', met(name = 'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P', loc = 'per', prot = None))
Observable('obs_CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P_ex', met(name = 'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P', loc = 'ex', prot = None))
Observable('obs_CDP_cyt', met(name = 'CDP', loc = 'cyt', prot = None))
Observable('obs_CDP_per', met(name = 'CDP', loc = 'per', prot = None))
Observable('obs_CDP_ex', met(name = 'CDP', loc = 'ex', prot = None))
Observable('obs_CHOLINE_cyt', met(name = 'CHOLINE', loc = 'cyt', prot = None))
Observable('obs_CHOLINE_per', met(name = 'CHOLINE', loc = 'per', prot = None))
Observable('obs_CHOLINE_ex', met(name = 'CHOLINE', loc = 'ex', prot = None))
Observable('obs_CHORISMATE_cyt', met(name = 'CHORISMATE', loc = 'cyt', prot = None))
Observable('obs_CHORISMATE_per', met(name = 'CHORISMATE', loc = 'per', prot = None))
Observable('obs_CHORISMATE_ex', met(name = 'CHORISMATE', loc = 'ex', prot = None))
Observable('obs_CIS_ACONITATE_cyt', met(name = 'CIS_ACONITATE', loc = 'cyt', prot = None))
Observable('obs_CIS_ACONITATE_per', met(name = 'CIS_ACONITATE', loc = 'per', prot = None))
Observable('obs_CIS_ACONITATE_ex', met(name = 'CIS_ACONITATE', loc = 'ex', prot = None))
Observable('obs_CIT_cyt', met(name = 'CIT', loc = 'cyt', prot = None))
Observable('obs_CIT_per', met(name = 'CIT', loc = 'per', prot = None))
Observable('obs_CIT_ex', met(name = 'CIT', loc = 'ex', prot = None))
Observable('obs_CMP_cyt', met(name = 'CMP', loc = 'cyt', prot = None))
Observable('obs_CMP_per', met(name = 'CMP', loc = 'per', prot = None))
Observable('obs_CMP_ex', met(name = 'CMP', loc = 'ex', prot = None))
Observable('obs_CO_A_cyt', met(name = 'CO_A', loc = 'cyt', prot = None))
Observable('obs_CO_A_per', met(name = 'CO_A', loc = 'per', prot = None))
Observable('obs_CO_A_ex', met(name = 'CO_A', loc = 'ex', prot = None))
Observable('obs_CPD_1136_cyt', met(name = 'CPD_1136', loc = 'cyt', prot = None))
Observable('obs_CPD_1136_per', met(name = 'CPD_1136', loc = 'per', prot = None))
Observable('obs_CPD_1136_ex', met(name = 'CPD_1136', loc = 'ex', prot = None))
Observable('obs_CPD_12991_cyt', met(name = 'CPD_12991', loc = 'cyt', prot = None))
Observable('obs_CPD_12991_per', met(name = 'CPD_12991', loc = 'per', prot = None))
Observable('obs_CPD_12991_ex', met(name = 'CPD_12991', loc = 'ex', prot = None))
Observable('obs_CPD_1301_cyt', met(name = 'CPD_1301', loc = 'cyt', prot = None))
Observable('obs_CPD_1301_per', met(name = 'CPD_1301', loc = 'per', prot = None))
Observable('obs_CPD_1301_ex', met(name = 'CPD_1301', loc = 'ex', prot = None))
Observable('obs_CPD_1302_cyt', met(name = 'CPD_1302', loc = 'cyt', prot = None))
Observable('obs_CPD_1302_per', met(name = 'CPD_1302', loc = 'per', prot = None))
Observable('obs_CPD_1302_ex', met(name = 'CPD_1302', loc = 'ex', prot = None))
Observable('obs_CPD_13025_cyt', met(name = 'CPD_13025', loc = 'cyt', prot = None))
Observable('obs_CPD_13025_per', met(name = 'CPD_13025', loc = 'per', prot = None))
Observable('obs_CPD_13025_ex', met(name = 'CPD_13025', loc = 'ex', prot = None))
Observable('obs_CPD_13357_cyt', met(name = 'CPD_13357', loc = 'cyt', prot = None))
Observable('obs_CPD_13357_per', met(name = 'CPD_13357', loc = 'per', prot = None))
Observable('obs_CPD_13357_ex', met(name = 'CPD_13357', loc = 'ex', prot = None))
Observable('obs_CPD_13927_cyt', met(name = 'CPD_13927', loc = 'cyt', prot = None))
Observable('obs_CPD_13927_per', met(name = 'CPD_13927', loc = 'per', prot = None))
Observable('obs_CPD_13927_ex', met(name = 'CPD_13927', loc = 'ex', prot = None))
Observable('obs_CPD_13930_cyt', met(name = 'CPD_13930', loc = 'cyt', prot = None))
Observable('obs_CPD_13930_per', met(name = 'CPD_13930', loc = 'per', prot = None))
Observable('obs_CPD_13930_ex', met(name = 'CPD_13930', loc = 'ex', prot = None))
Observable('obs_CPD_14443_cyt', met(name = 'CPD_14443', loc = 'cyt', prot = None))
Observable('obs_CPD_14443_per', met(name = 'CPD_14443', loc = 'per', prot = None))
Observable('obs_CPD_14443_ex', met(name = 'CPD_14443', loc = 'ex', prot = None))
Observable('obs_CPD_14736_cyt', met(name = 'CPD_14736', loc = 'cyt', prot = None))
Observable('obs_CPD_14736_per', met(name = 'CPD_14736', loc = 'per', prot = None))
Observable('obs_CPD_14736_ex', met(name = 'CPD_14736', loc = 'ex', prot = None))
Observable('obs_CPD_15317_cyt', met(name = 'CPD_15317', loc = 'cyt', prot = None))
Observable('obs_CPD_15317_per', met(name = 'CPD_15317', loc = 'per', prot = None))
Observable('obs_CPD_15317_ex', met(name = 'CPD_15317', loc = 'ex', prot = None))
Observable('obs_CPD_15390_cyt', met(name = 'CPD_15390', loc = 'cyt', prot = None))
Observable('obs_CPD_15390_per', met(name = 'CPD_15390', loc = 'per', prot = None))
Observable('obs_CPD_15390_ex', met(name = 'CPD_15390', loc = 'ex', prot = None))
Observable('obs_CPD_15391_cyt', met(name = 'CPD_15391', loc = 'cyt', prot = None))
Observable('obs_CPD_15391_per', met(name = 'CPD_15391', loc = 'per', prot = None))
Observable('obs_CPD_15391_ex', met(name = 'CPD_15391', loc = 'ex', prot = None))
Observable('obs_CPD_15392_cyt', met(name = 'CPD_15392', loc = 'cyt', prot = None))
Observable('obs_CPD_15392_per', met(name = 'CPD_15392', loc = 'per', prot = None))
Observable('obs_CPD_15392_ex', met(name = 'CPD_15392', loc = 'ex', prot = None))
Observable('obs_CPD_15393_cyt', met(name = 'CPD_15393', loc = 'cyt', prot = None))
Observable('obs_CPD_15393_per', met(name = 'CPD_15393', loc = 'per', prot = None))
Observable('obs_CPD_15393_ex', met(name = 'CPD_15393', loc = 'ex', prot = None))
Observable('obs_CPD_15818_cyt', met(name = 'CPD_15818', loc = 'cyt', prot = None))
Observable('obs_CPD_15818_per', met(name = 'CPD_15818', loc = 'per', prot = None))
Observable('obs_CPD_15818_ex', met(name = 'CPD_15818', loc = 'ex', prot = None))
Observable('obs_CPD_16009_cyt', met(name = 'CPD_16009', loc = 'cyt', prot = None))
Observable('obs_CPD_16009_per', met(name = 'CPD_16009', loc = 'per', prot = None))
Observable('obs_CPD_16009_ex', met(name = 'CPD_16009', loc = 'ex', prot = None))
Observable('obs_CPD_16619_cyt', met(name = 'CPD_16619', loc = 'cyt', prot = None))
Observable('obs_CPD_16619_per', met(name = 'CPD_16619', loc = 'per', prot = None))
Observable('obs_CPD_16619_ex', met(name = 'CPD_16619', loc = 'ex', prot = None))
Observable('obs_CPD_194_cyt', met(name = 'CPD_194', loc = 'cyt', prot = None))
Observable('obs_CPD_194_per', met(name = 'CPD_194', loc = 'per', prot = None))
Observable('obs_CPD_194_ex', met(name = 'CPD_194', loc = 'ex', prot = None))
Observable('obs_CPD_239_cyt', met(name = 'CPD_239', loc = 'cyt', prot = None))
Observable('obs_CPD_239_per', met(name = 'CPD_239', loc = 'per', prot = None))
Observable('obs_CPD_239_ex', met(name = 'CPD_239', loc = 'ex', prot = None))
Observable('obs_CPD_2961_cyt', met(name = 'CPD_2961', loc = 'cyt', prot = None))
Observable('obs_CPD_2961_per', met(name = 'CPD_2961', loc = 'per', prot = None))
Observable('obs_CPD_2961_ex', met(name = 'CPD_2961', loc = 'ex', prot = None))
Observable('obs_CPD_3582_cyt', met(name = 'CPD_3582', loc = 'cyt', prot = None))
Observable('obs_CPD_3582_per', met(name = 'CPD_3582', loc = 'per', prot = None))
Observable('obs_CPD_3582_ex', met(name = 'CPD_3582', loc = 'ex', prot = None))
Observable('obs_CPD_3705_cyt', met(name = 'CPD_3705', loc = 'cyt', prot = None))
Observable('obs_CPD_3705_per', met(name = 'CPD_3705', loc = 'per', prot = None))
Observable('obs_CPD_3705_ex', met(name = 'CPD_3705', loc = 'ex', prot = None))
Observable('obs_CPD_3706_cyt', met(name = 'CPD_3706', loc = 'cyt', prot = None))
Observable('obs_CPD_3706_per', met(name = 'CPD_3706', loc = 'per', prot = None))
Observable('obs_CPD_3706_ex', met(name = 'CPD_3706', loc = 'ex', prot = None))
Observable('obs_CPD_3710_cyt', met(name = 'CPD_3710', loc = 'cyt', prot = None))
Observable('obs_CPD_3710_per', met(name = 'CPD_3710', loc = 'per', prot = None))
Observable('obs_CPD_3710_ex', met(name = 'CPD_3710', loc = 'ex', prot = None))
Observable('obs_CPD_3711_cyt', met(name = 'CPD_3711', loc = 'cyt', prot = None))
Observable('obs_CPD_3711_per', met(name = 'CPD_3711', loc = 'per', prot = None))
Observable('obs_CPD_3711_ex', met(name = 'CPD_3711', loc = 'ex', prot = None))
Observable('obs_CPD_3721_cyt', met(name = 'CPD_3721', loc = 'cyt', prot = None))
Observable('obs_CPD_3721_per', met(name = 'CPD_3721', loc = 'per', prot = None))
Observable('obs_CPD_3721_ex', met(name = 'CPD_3721', loc = 'ex', prot = None))
Observable('obs_CPD_3723_cyt', met(name = 'CPD_3723', loc = 'cyt', prot = None))
Observable('obs_CPD_3723_per', met(name = 'CPD_3723', loc = 'per', prot = None))
Observable('obs_CPD_3723_ex', met(name = 'CPD_3723', loc = 'ex', prot = None))
Observable('obs_CPD_3724_cyt', met(name = 'CPD_3724', loc = 'cyt', prot = None))
Observable('obs_CPD_3724_per', met(name = 'CPD_3724', loc = 'per', prot = None))
Observable('obs_CPD_3724_ex', met(name = 'CPD_3724', loc = 'ex', prot = None))
Observable('obs_CPD_3728_cyt', met(name = 'CPD_3728', loc = 'cyt', prot = None))
Observable('obs_CPD_3728_per', met(name = 'CPD_3728', loc = 'per', prot = None))
Observable('obs_CPD_3728_ex', met(name = 'CPD_3728', loc = 'ex', prot = None))
Observable('obs_CPD_381_cyt', met(name = 'CPD_381', loc = 'cyt', prot = None))
Observable('obs_CPD_381_per', met(name = 'CPD_381', loc = 'per', prot = None))
Observable('obs_CPD_381_ex', met(name = 'CPD_381', loc = 'ex', prot = None))
Observable('obs_CPD_4544_cyt', met(name = 'CPD_4544', loc = 'cyt', prot = None))
Observable('obs_CPD_4544_per', met(name = 'CPD_4544', loc = 'per', prot = None))
Observable('obs_CPD_4544_ex', met(name = 'CPD_4544', loc = 'ex', prot = None))
Observable('obs_CPD_469_cyt', met(name = 'CPD_469', loc = 'cyt', prot = None))
Observable('obs_CPD_469_per', met(name = 'CPD_469', loc = 'per', prot = None))
Observable('obs_CPD_469_ex', met(name = 'CPD_469', loc = 'ex', prot = None))
Observable('obs_CPD_476_cyt', met(name = 'CPD_476', loc = 'cyt', prot = None))
Observable('obs_CPD_476_per', met(name = 'CPD_476', loc = 'per', prot = None))
Observable('obs_CPD_476_ex', met(name = 'CPD_476', loc = 'ex', prot = None))
Observable('obs_CPD_536_cyt', met(name = 'CPD_536', loc = 'cyt', prot = None))
Observable('obs_CPD_536_per', met(name = 'CPD_536', loc = 'per', prot = None))
Observable('obs_CPD_536_ex', met(name = 'CPD_536', loc = 'ex', prot = None))
Observable('obs_CPD_606_cyt', met(name = 'CPD_606', loc = 'cyt', prot = None))
Observable('obs_CPD_606_per', met(name = 'CPD_606', loc = 'per', prot = None))
Observable('obs_CPD_606_ex', met(name = 'CPD_606', loc = 'ex', prot = None))
Observable('obs_CPD_618_cyt', met(name = 'CPD_618', loc = 'cyt', prot = None))
Observable('obs_CPD_618_per', met(name = 'CPD_618', loc = 'per', prot = None))
Observable('obs_CPD_618_ex', met(name = 'CPD_618', loc = 'ex', prot = None))
Observable('obs_CPD_66_cyt', met(name = 'CPD_66', loc = 'cyt', prot = None))
Observable('obs_CPD_66_per', met(name = 'CPD_66', loc = 'per', prot = None))
Observable('obs_CPD_66_ex', met(name = 'CPD_66', loc = 'ex', prot = None))
Observable('obs_CPD_660_cyt', met(name = 'CPD_660', loc = 'cyt', prot = None))
Observable('obs_CPD_660_per', met(name = 'CPD_660', loc = 'per', prot = None))
Observable('obs_CPD_660_ex', met(name = 'CPD_660', loc = 'ex', prot = None))
Observable('obs_CPD_67_cyt', met(name = 'CPD_67', loc = 'cyt', prot = None))
Observable('obs_CPD_67_per', met(name = 'CPD_67', loc = 'per', prot = None))
Observable('obs_CPD_67_ex', met(name = 'CPD_67', loc = 'ex', prot = None))
Observable('obs_CPD0_181_cyt', met(name = 'CPD0_181', loc = 'cyt', prot = None))
Observable('obs_CPD0_181_per', met(name = 'CPD0_181', loc = 'per', prot = None))
Observable('obs_CPD0_181_ex', met(name = 'CPD0_181', loc = 'ex', prot = None))
Observable('obs_CPD0_2189_cyt', met(name = 'CPD0_2189', loc = 'cyt', prot = None))
Observable('obs_CPD0_2189_per', met(name = 'CPD0_2189', loc = 'per', prot = None))
Observable('obs_CPD0_2189_ex', met(name = 'CPD0_2189', loc = 'ex', prot = None))
Observable('obs_CPD0_2331_cyt', met(name = 'CPD0_2331', loc = 'cyt', prot = None))
Observable('obs_CPD0_2331_per', met(name = 'CPD0_2331', loc = 'per', prot = None))
Observable('obs_CPD0_2331_ex', met(name = 'CPD0_2331', loc = 'ex', prot = None))
Observable('obs_CPD0_2338_cyt', met(name = 'CPD0_2338', loc = 'cyt', prot = None))
Observable('obs_CPD0_2338_per', met(name = 'CPD0_2338', loc = 'per', prot = None))
Observable('obs_CPD0_2338_ex', met(name = 'CPD0_2338', loc = 'ex', prot = None))
Observable('obs_CPD0_2339_cyt', met(name = 'CPD0_2339', loc = 'cyt', prot = None))
Observable('obs_CPD0_2339_per', met(name = 'CPD0_2339', loc = 'per', prot = None))
Observable('obs_CPD0_2339_ex', met(name = 'CPD0_2339', loc = 'ex', prot = None))
Observable('obs_CPD0_2340_cyt', met(name = 'CPD0_2340', loc = 'cyt', prot = None))
Observable('obs_CPD0_2340_per', met(name = 'CPD0_2340', loc = 'per', prot = None))
Observable('obs_CPD0_2340_ex', met(name = 'CPD0_2340', loc = 'ex', prot = None))
Observable('obs_CPD0_2461_cyt', met(name = 'CPD0_2461', loc = 'cyt', prot = None))
Observable('obs_CPD0_2461_per', met(name = 'CPD0_2461', loc = 'per', prot = None))
Observable('obs_CPD0_2461_ex', met(name = 'CPD0_2461', loc = 'ex', prot = None))
Observable('obs_CPD0_881_cyt', met(name = 'CPD0_881', loc = 'cyt', prot = None))
Observable('obs_CPD0_881_per', met(name = 'CPD0_881', loc = 'per', prot = None))
Observable('obs_CPD0_881_ex', met(name = 'CPD0_881', loc = 'ex', prot = None))
Observable('obs_CREATINE_cyt', met(name = 'CREATINE', loc = 'cyt', prot = None))
Observable('obs_CREATINE_per', met(name = 'CREATINE', loc = 'per', prot = None))
Observable('obs_CREATINE_ex', met(name = 'CREATINE', loc = 'ex', prot = None))
Observable('obs_CREATINE_P_cyt', met(name = 'CREATINE_P', loc = 'cyt', prot = None))
Observable('obs_CREATINE_P_per', met(name = 'CREATINE_P', loc = 'per', prot = None))
Observable('obs_CREATINE_P_ex', met(name = 'CREATINE_P', loc = 'ex', prot = None))
Observable('obs_CTP_cyt', met(name = 'CTP', loc = 'cyt', prot = None))
Observable('obs_CTP_per', met(name = 'CTP', loc = 'per', prot = None))
Observable('obs_CTP_ex', met(name = 'CTP', loc = 'ex', prot = None))
Observable('obs_CYS_cyt', met(name = 'CYS', loc = 'cyt', prot = None))
Observable('obs_CYS_per', met(name = 'CYS', loc = 'per', prot = None))
Observable('obs_CYS_ex', met(name = 'CYS', loc = 'ex', prot = None))
Observable('obs_CYTIDINE_cyt', met(name = 'CYTIDINE', loc = 'cyt', prot = None))
Observable('obs_CYTIDINE_per', met(name = 'CYTIDINE', loc = 'per', prot = None))
Observable('obs_CYTIDINE_ex', met(name = 'CYTIDINE', loc = 'ex', prot = None))
Observable('obs_CYTOSINE_cyt', met(name = 'CYTOSINE', loc = 'cyt', prot = None))
Observable('obs_CYTOSINE_per', met(name = 'CYTOSINE', loc = 'per', prot = None))
Observable('obs_CYTOSINE_ex', met(name = 'CYTOSINE', loc = 'ex', prot = None))
Observable('obs_D_6_P_GLUCONO_DELTA_LACTONE_cyt', met(name = 'D_6_P_GLUCONO_DELTA_LACTONE', loc = 'cyt', prot = None))
Observable('obs_D_6_P_GLUCONO_DELTA_LACTONE_per', met(name = 'D_6_P_GLUCONO_DELTA_LACTONE', loc = 'per', prot = None))
Observable('obs_D_6_P_GLUCONO_DELTA_LACTONE_ex', met(name = 'D_6_P_GLUCONO_DELTA_LACTONE', loc = 'ex', prot = None))
Observable('obs_D_ALANINE_cyt', met(name = 'D_ALANINE', loc = 'cyt', prot = None))
Observable('obs_D_ALANINE_per', met(name = 'D_ALANINE', loc = 'per', prot = None))
Observable('obs_D_ALANINE_ex', met(name = 'D_ALANINE', loc = 'ex', prot = None))
Observable('obs_D_ALLOSE_6_PHOSPHATE_cyt', met(name = 'D_ALLOSE_6_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_D_ALLOSE_6_PHOSPHATE_per', met(name = 'D_ALLOSE_6_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_D_ALLOSE_6_PHOSPHATE_ex', met(name = 'D_ALLOSE_6_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_D_ALLULOSE_6_PHOSPHATE_cyt', met(name = 'D_ALLULOSE_6_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_D_ALLULOSE_6_PHOSPHATE_per', met(name = 'D_ALLULOSE_6_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_D_ALLULOSE_6_PHOSPHATE_ex', met(name = 'D_ALLULOSE_6_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_D_ERYTHRO_IMIDAZOLE_GLYCEROL_P_cyt', met(name = 'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P', loc = 'cyt', prot = None))
Observable('obs_D_ERYTHRO_IMIDAZOLE_GLYCEROL_P_per', met(name = 'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P', loc = 'per', prot = None))
Observable('obs_D_ERYTHRO_IMIDAZOLE_GLYCEROL_P_ex', met(name = 'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P', loc = 'ex', prot = None))
Observable('obs_D_GLUCOSAMINE_6_P_cyt', met(name = 'D_GLUCOSAMINE_6_P', loc = 'cyt', prot = None))
Observable('obs_D_GLUCOSAMINE_6_P_per', met(name = 'D_GLUCOSAMINE_6_P', loc = 'per', prot = None))
Observable('obs_D_GLUCOSAMINE_6_P_ex', met(name = 'D_GLUCOSAMINE_6_P', loc = 'ex', prot = None))
Observable('obs_D_Ribofuranose_cyt', met(name = 'D_Ribofuranose', loc = 'cyt', prot = None))
Observable('obs_D_Ribofuranose_per', met(name = 'D_Ribofuranose', loc = 'per', prot = None))
Observable('obs_D_Ribofuranose_ex', met(name = 'D_Ribofuranose', loc = 'ex', prot = None))
Observable('obs_D_SEDOHEPTULOSE_1_7_P2_cyt', met(name = 'D_SEDOHEPTULOSE_1_7_P2', loc = 'cyt', prot = None))
Observable('obs_D_SEDOHEPTULOSE_1_7_P2_per', met(name = 'D_SEDOHEPTULOSE_1_7_P2', loc = 'per', prot = None))
Observable('obs_D_SEDOHEPTULOSE_1_7_P2_ex', met(name = 'D_SEDOHEPTULOSE_1_7_P2', loc = 'ex', prot = None))
Observable('obs_D_SEDOHEPTULOSE_7_P_cyt', met(name = 'D_SEDOHEPTULOSE_7_P', loc = 'cyt', prot = None))
Observable('obs_D_SEDOHEPTULOSE_7_P_per', met(name = 'D_SEDOHEPTULOSE_7_P', loc = 'per', prot = None))
Observable('obs_D_SEDOHEPTULOSE_7_P_ex', met(name = 'D_SEDOHEPTULOSE_7_P', loc = 'ex', prot = None))
Observable('obs_D_TARTRATE_cyt', met(name = 'D_TARTRATE', loc = 'cyt', prot = None))
Observable('obs_D_TARTRATE_per', met(name = 'D_TARTRATE', loc = 'per', prot = None))
Observable('obs_D_TARTRATE_ex', met(name = 'D_TARTRATE', loc = 'ex', prot = None))
Observable('obs_D_glucopyranose_6_phosphate_cyt', met(name = 'D_glucopyranose_6_phosphate', loc = 'cyt', prot = None))
Observable('obs_D_glucopyranose_6_phosphate_per', met(name = 'D_glucopyranose_6_phosphate', loc = 'per', prot = None))
Observable('obs_D_glucopyranose_6_phosphate_ex', met(name = 'D_glucopyranose_6_phosphate', loc = 'ex', prot = None))
Observable('obs_D_glucose_1_phosphates_cyt', met(name = 'D_glucose_1_phosphates', loc = 'cyt', prot = None))
Observable('obs_D_glucose_1_phosphates_per', met(name = 'D_glucose_1_phosphates', loc = 'per', prot = None))
Observable('obs_D_glucose_1_phosphates_ex', met(name = 'D_glucose_1_phosphates', loc = 'ex', prot = None))
Observable('obs_DADP_cyt', met(name = 'DADP', loc = 'cyt', prot = None))
Observable('obs_DADP_per', met(name = 'DADP', loc = 'per', prot = None))
Observable('obs_DADP_ex', met(name = 'DADP', loc = 'ex', prot = None))
Observable('obs_DAMP_cyt', met(name = 'DAMP', loc = 'cyt', prot = None))
Observable('obs_DAMP_per', met(name = 'DAMP', loc = 'per', prot = None))
Observable('obs_DAMP_ex', met(name = 'DAMP', loc = 'ex', prot = None))
Observable('obs_DATP_cyt', met(name = 'DATP', loc = 'cyt', prot = None))
Observable('obs_DATP_per', met(name = 'DATP', loc = 'per', prot = None))
Observable('obs_DATP_ex', met(name = 'DATP', loc = 'ex', prot = None))
Observable('obs_DCDP_cyt', met(name = 'DCDP', loc = 'cyt', prot = None))
Observable('obs_DCDP_per', met(name = 'DCDP', loc = 'per', prot = None))
Observable('obs_DCDP_ex', met(name = 'DCDP', loc = 'ex', prot = None))
Observable('obs_DCMP_cyt', met(name = 'DCMP', loc = 'cyt', prot = None))
Observable('obs_DCMP_per', met(name = 'DCMP', loc = 'per', prot = None))
Observable('obs_DCMP_ex', met(name = 'DCMP', loc = 'ex', prot = None))
Observable('obs_DCTP_cyt', met(name = 'DCTP', loc = 'cyt', prot = None))
Observable('obs_DCTP_per', met(name = 'DCTP', loc = 'per', prot = None))
Observable('obs_DCTP_ex', met(name = 'DCTP', loc = 'ex', prot = None))
Observable('obs_DEAMIDO_NAD_cyt', met(name = 'DEAMIDO_NAD', loc = 'cyt', prot = None))
Observable('obs_DEAMIDO_NAD_per', met(name = 'DEAMIDO_NAD', loc = 'per', prot = None))
Observable('obs_DEAMIDO_NAD_ex', met(name = 'DEAMIDO_NAD', loc = 'ex', prot = None))
Observable('obs_DEHYDROQUINATE_cyt', met(name = 'DEHYDROQUINATE', loc = 'cyt', prot = None))
Observable('obs_DEHYDROQUINATE_per', met(name = 'DEHYDROQUINATE', loc = 'per', prot = None))
Observable('obs_DEHYDROQUINATE_ex', met(name = 'DEHYDROQUINATE', loc = 'ex', prot = None))
Observable('obs_DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_cyt', met(name = 'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE', loc = 'cyt', prot = None))
Observable('obs_DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_per', met(name = 'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE', loc = 'per', prot = None))
Observable('obs_DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_ex', met(name = 'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE', loc = 'ex', prot = None))
Observable('obs_DEOXY_D_RIBOSE_1_PHOSPHATE_cyt', met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_DEOXY_D_RIBOSE_1_PHOSPHATE_per', met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_DEOXY_D_RIBOSE_1_PHOSPHATE_ex', met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_DEOXY_RIBOSE_5P_cyt', met(name = 'DEOXY_RIBOSE_5P', loc = 'cyt', prot = None))
Observable('obs_DEOXY_RIBOSE_5P_per', met(name = 'DEOXY_RIBOSE_5P', loc = 'per', prot = None))
Observable('obs_DEOXY_RIBOSE_5P_ex', met(name = 'DEOXY_RIBOSE_5P', loc = 'ex', prot = None))
Observable('obs_DEOXYADENOSINE_cyt', met(name = 'DEOXYADENOSINE', loc = 'cyt', prot = None))
Observable('obs_DEOXYADENOSINE_per', met(name = 'DEOXYADENOSINE', loc = 'per', prot = None))
Observable('obs_DEOXYADENOSINE_ex', met(name = 'DEOXYADENOSINE', loc = 'ex', prot = None))
Observable('obs_DEOXYCYTIDINE_cyt', met(name = 'DEOXYCYTIDINE', loc = 'cyt', prot = None))
Observable('obs_DEOXYCYTIDINE_per', met(name = 'DEOXYCYTIDINE', loc = 'per', prot = None))
Observable('obs_DEOXYCYTIDINE_ex', met(name = 'DEOXYCYTIDINE', loc = 'ex', prot = None))
Observable('obs_DEOXYGUANOSINE_cyt', met(name = 'DEOXYGUANOSINE', loc = 'cyt', prot = None))
Observable('obs_DEOXYGUANOSINE_per', met(name = 'DEOXYGUANOSINE', loc = 'per', prot = None))
Observable('obs_DEOXYGUANOSINE_ex', met(name = 'DEOXYGUANOSINE', loc = 'ex', prot = None))
Observable('obs_DEOXYINOSINE_cyt', met(name = 'DEOXYINOSINE', loc = 'cyt', prot = None))
Observable('obs_DEOXYINOSINE_per', met(name = 'DEOXYINOSINE', loc = 'per', prot = None))
Observable('obs_DEOXYINOSINE_ex', met(name = 'DEOXYINOSINE', loc = 'ex', prot = None))
Observable('obs_DEOXYURIDINE_cyt', met(name = 'DEOXYURIDINE', loc = 'cyt', prot = None))
Observable('obs_DEOXYURIDINE_per', met(name = 'DEOXYURIDINE', loc = 'per', prot = None))
Observable('obs_DEOXYURIDINE_ex', met(name = 'DEOXYURIDINE', loc = 'ex', prot = None))
Observable('obs_DGDP_cyt', met(name = 'DGDP', loc = 'cyt', prot = None))
Observable('obs_DGDP_per', met(name = 'DGDP', loc = 'per', prot = None))
Observable('obs_DGDP_ex', met(name = 'DGDP', loc = 'ex', prot = None))
Observable('obs_DGMP_cyt', met(name = 'DGMP', loc = 'cyt', prot = None))
Observable('obs_DGMP_per', met(name = 'DGMP', loc = 'per', prot = None))
Observable('obs_DGMP_ex', met(name = 'DGMP', loc = 'ex', prot = None))
Observable('obs_DGTP_cyt', met(name = 'DGTP', loc = 'cyt', prot = None))
Observable('obs_DGTP_per', met(name = 'DGTP', loc = 'per', prot = None))
Observable('obs_DGTP_ex', met(name = 'DGTP', loc = 'ex', prot = None))
Observable('obs_DI_H_OROTATE_cyt', met(name = 'DI_H_OROTATE', loc = 'cyt', prot = None))
Observable('obs_DI_H_OROTATE_per', met(name = 'DI_H_OROTATE', loc = 'per', prot = None))
Observable('obs_DI_H_OROTATE_ex', met(name = 'DI_H_OROTATE', loc = 'ex', prot = None))
Observable('obs_DIHYDROFOLATE_GLU_N_cyt', met(name = 'DIHYDROFOLATE_GLU_N', loc = 'cyt', prot = None))
Observable('obs_DIHYDROFOLATE_GLU_N_per', met(name = 'DIHYDROFOLATE_GLU_N', loc = 'per', prot = None))
Observable('obs_DIHYDROFOLATE_GLU_N_ex', met(name = 'DIHYDROFOLATE_GLU_N', loc = 'ex', prot = None))
Observable('obs_DIHYDROLIPOYL_GCVH_cyt', met(name = 'DIHYDROLIPOYL_GCVH', loc = 'cyt', prot = None))
Observable('obs_DIHYDROLIPOYL_GCVH_per', met(name = 'DIHYDROLIPOYL_GCVH', loc = 'per', prot = None))
Observable('obs_DIHYDROLIPOYL_GCVH_ex', met(name = 'DIHYDROLIPOYL_GCVH', loc = 'ex', prot = None))
Observable('obs_DIHYDROXY_ACETONE_PHOSPHATE_cyt', met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_DIHYDROXY_ACETONE_PHOSPHATE_per', met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_DIHYDROXY_ACETONE_PHOSPHATE_ex', met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_DIHYDROXYACETONE_cyt', met(name = 'DIHYDROXYACETONE', loc = 'cyt', prot = None))
Observable('obs_DIHYDROXYACETONE_per', met(name = 'DIHYDROXYACETONE', loc = 'per', prot = None))
Observable('obs_DIHYDROXYACETONE_ex', met(name = 'DIHYDROXYACETONE', loc = 'ex', prot = None))
Observable('obs_DPG_cyt', met(name = 'DPG', loc = 'cyt', prot = None))
Observable('obs_DPG_per', met(name = 'DPG', loc = 'per', prot = None))
Observable('obs_DPG_ex', met(name = 'DPG', loc = 'ex', prot = None))
Observable('obs_DUDP_cyt', met(name = 'DUDP', loc = 'cyt', prot = None))
Observable('obs_DUDP_per', met(name = 'DUDP', loc = 'per', prot = None))
Observable('obs_DUDP_ex', met(name = 'DUDP', loc = 'ex', prot = None))
Observable('obs_DUMP_cyt', met(name = 'DUMP', loc = 'cyt', prot = None))
Observable('obs_DUMP_per', met(name = 'DUMP', loc = 'per', prot = None))
Observable('obs_DUMP_ex', met(name = 'DUMP', loc = 'ex', prot = None))
Observable('obs_DUTP_cyt', met(name = 'DUTP', loc = 'cyt', prot = None))
Observable('obs_DUTP_per', met(name = 'DUTP', loc = 'per', prot = None))
Observable('obs_DUTP_ex', met(name = 'DUTP', loc = 'ex', prot = None))
Observable('obs_Deoxy_Ribonucleoside_3P_cyt', met(name = 'Deoxy_Ribonucleoside_3P', loc = 'cyt', prot = None))
Observable('obs_Deoxy_Ribonucleoside_3P_per', met(name = 'Deoxy_Ribonucleoside_3P', loc = 'per', prot = None))
Observable('obs_Deoxy_Ribonucleoside_3P_ex', met(name = 'Deoxy_Ribonucleoside_3P', loc = 'ex', prot = None))
Observable('obs_Deoxy_Ribonucleoside_Monophosphates_cyt', met(name = 'Deoxy_Ribonucleoside_Monophosphates', loc = 'cyt', prot = None))
Observable('obs_Deoxy_Ribonucleoside_Monophosphates_per', met(name = 'Deoxy_Ribonucleoside_Monophosphates', loc = 'per', prot = None))
Observable('obs_Deoxy_Ribonucleoside_Monophosphates_ex', met(name = 'Deoxy_Ribonucleoside_Monophosphates', loc = 'ex', prot = None))
Observable('obs_Deoxy_Ribonucleoside_Triphosphates_cyt', met(name = 'Deoxy_Ribonucleoside_Triphosphates', loc = 'cyt', prot = None))
Observable('obs_Deoxy_Ribonucleoside_Triphosphates_per', met(name = 'Deoxy_Ribonucleoside_Triphosphates', loc = 'per', prot = None))
Observable('obs_Deoxy_Ribonucleoside_Triphosphates_ex', met(name = 'Deoxy_Ribonucleoside_Triphosphates', loc = 'ex', prot = None))
Observable('obs_Deoxy_Ribonucleosides_cyt', met(name = 'Deoxy_Ribonucleosides', loc = 'cyt', prot = None))
Observable('obs_Deoxy_Ribonucleosides_per', met(name = 'Deoxy_Ribonucleosides', loc = 'per', prot = None))
Observable('obs_Deoxy_Ribonucleosides_ex', met(name = 'Deoxy_Ribonucleosides', loc = 'ex', prot = None))
Observable('obs_Dihydro_Lipoyl_Proteins_cyt', met(name = 'Dihydro_Lipoyl_Proteins', loc = 'cyt', prot = None))
Observable('obs_Dihydro_Lipoyl_Proteins_per', met(name = 'Dihydro_Lipoyl_Proteins', loc = 'per', prot = None))
Observable('obs_Dihydro_Lipoyl_Proteins_ex', met(name = 'Dihydro_Lipoyl_Proteins', loc = 'ex', prot = None))
Observable('obs_Donor_H2_cyt', met(name = 'Donor_H2', loc = 'cyt', prot = None))
Observable('obs_Donor_H2_per', met(name = 'Donor_H2', loc = 'per', prot = None))
Observable('obs_Donor_H2_ex', met(name = 'Donor_H2', loc = 'ex', prot = None))
Observable('obs_ENOL_OXALOACETATE_cyt', met(name = 'ENOL_OXALOACETATE', loc = 'cyt', prot = None))
Observable('obs_ENOL_OXALOACETATE_per', met(name = 'ENOL_OXALOACETATE', loc = 'per', prot = None))
Observable('obs_ENOL_OXALOACETATE_ex', met(name = 'ENOL_OXALOACETATE', loc = 'ex', prot = None))
Observable('obs_ERYTHROSE_4P_cyt', met(name = 'ERYTHROSE_4P', loc = 'cyt', prot = None))
Observable('obs_ERYTHROSE_4P_per', met(name = 'ERYTHROSE_4P', loc = 'per', prot = None))
Observable('obs_ERYTHROSE_4P_ex', met(name = 'ERYTHROSE_4P', loc = 'ex', prot = None))
Observable('obs_ETHANOL_AMINE_cyt', met(name = 'ETHANOL_AMINE', loc = 'cyt', prot = None))
Observable('obs_ETHANOL_AMINE_per', met(name = 'ETHANOL_AMINE', loc = 'per', prot = None))
Observable('obs_ETHANOL_AMINE_ex', met(name = 'ETHANOL_AMINE', loc = 'ex', prot = None))
Observable('obs_ETR_Quinols_cyt', met(name = 'ETR_Quinols', loc = 'cyt', prot = None))
Observable('obs_ETR_Quinols_per', met(name = 'ETR_Quinols', loc = 'per', prot = None))
Observable('obs_ETR_Quinols_ex', met(name = 'ETR_Quinols', loc = 'ex', prot = None))
Observable('obs_ETR_Quinones_cyt', met(name = 'ETR_Quinones', loc = 'cyt', prot = None))
Observable('obs_ETR_Quinones_per', met(name = 'ETR_Quinones', loc = 'per', prot = None))
Observable('obs_ETR_Quinones_ex', met(name = 'ETR_Quinones', loc = 'ex', prot = None))
Observable('obs_FMN_cyt', met(name = 'FMN', loc = 'cyt', prot = None))
Observable('obs_FMN_per', met(name = 'FMN', loc = 'per', prot = None))
Observable('obs_FMN_ex', met(name = 'FMN', loc = 'ex', prot = None))
Observable('obs_FMNH2_cyt', met(name = 'FMNH2', loc = 'cyt', prot = None))
Observable('obs_FMNH2_per', met(name = 'FMNH2', loc = 'per', prot = None))
Observable('obs_FMNH2_ex', met(name = 'FMNH2', loc = 'ex', prot = None))
Observable('obs_FORMATE_cyt', met(name = 'FORMATE', loc = 'cyt', prot = None))
Observable('obs_FORMATE_per', met(name = 'FORMATE', loc = 'per', prot = None))
Observable('obs_FORMATE_ex', met(name = 'FORMATE', loc = 'ex', prot = None))
Observable('obs_FORMYL_THF_GLU_N_cyt', met(name = 'FORMYL_THF_GLU_N', loc = 'cyt', prot = None))
Observable('obs_FORMYL_THF_GLU_N_per', met(name = 'FORMYL_THF_GLU_N', loc = 'per', prot = None))
Observable('obs_FORMYL_THF_GLU_N_ex', met(name = 'FORMYL_THF_GLU_N', loc = 'ex', prot = None))
Observable('obs_FRUCTOSE_16_DIPHOSPHATE_cyt', met(name = 'FRUCTOSE_16_DIPHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_FRUCTOSE_16_DIPHOSPHATE_per', met(name = 'FRUCTOSE_16_DIPHOSPHATE', loc = 'per', prot = None))
Observable('obs_FRUCTOSE_16_DIPHOSPHATE_ex', met(name = 'FRUCTOSE_16_DIPHOSPHATE', loc = 'ex', prot = None))
Observable('obs_FRUCTOSE_6P_cyt', met(name = 'FRUCTOSE_6P', loc = 'cyt', prot = None))
Observable('obs_FRUCTOSE_6P_per', met(name = 'FRUCTOSE_6P', loc = 'per', prot = None))
Observable('obs_FRUCTOSE_6P_ex', met(name = 'FRUCTOSE_6P', loc = 'ex', prot = None))
Observable('obs_FUM_cyt', met(name = 'FUM', loc = 'cyt', prot = None))
Observable('obs_FUM_per', met(name = 'FUM', loc = 'per', prot = None))
Observable('obs_FUM_ex', met(name = 'FUM', loc = 'ex', prot = None))
Observable('obs_G3P_cyt', met(name = 'G3P', loc = 'cyt', prot = None))
Observable('obs_G3P_per', met(name = 'G3P', loc = 'per', prot = None))
Observable('obs_G3P_ex', met(name = 'G3P', loc = 'ex', prot = None))
Observable('obs_GAP_cyt', met(name = 'GAP', loc = 'cyt', prot = None))
Observable('obs_GAP_per', met(name = 'GAP', loc = 'per', prot = None))
Observable('obs_GAP_ex', met(name = 'GAP', loc = 'ex', prot = None))
Observable('obs_GDP_cyt', met(name = 'GDP', loc = 'cyt', prot = None))
Observable('obs_GDP_per', met(name = 'GDP', loc = 'per', prot = None))
Observable('obs_GDP_ex', met(name = 'GDP', loc = 'ex', prot = None))
Observable('obs_GLN_cyt', met(name = 'GLN', loc = 'cyt', prot = None))
Observable('obs_GLN_per', met(name = 'GLN', loc = 'per', prot = None))
Observable('obs_GLN_ex', met(name = 'GLN', loc = 'ex', prot = None))
Observable('obs_GLT_cyt', met(name = 'GLT', loc = 'cyt', prot = None))
Observable('obs_GLT_per', met(name = 'GLT', loc = 'per', prot = None))
Observable('obs_GLT_ex', met(name = 'GLT', loc = 'ex', prot = None))
Observable('obs_GLUCONATE_cyt', met(name = 'GLUCONATE', loc = 'cyt', prot = None))
Observable('obs_GLUCONATE_per', met(name = 'GLUCONATE', loc = 'per', prot = None))
Observable('obs_GLUCONATE_ex', met(name = 'GLUCONATE', loc = 'ex', prot = None))
Observable('obs_GLUCOSAMINE_cyt', met(name = 'GLUCOSAMINE', loc = 'cyt', prot = None))
Observable('obs_GLUCOSAMINE_per', met(name = 'GLUCOSAMINE', loc = 'per', prot = None))
Observable('obs_GLUCOSAMINE_ex', met(name = 'GLUCOSAMINE', loc = 'ex', prot = None))
Observable('obs_GLY_cyt', met(name = 'GLY', loc = 'cyt', prot = None))
Observable('obs_GLY_per', met(name = 'GLY', loc = 'per', prot = None))
Observable('obs_GLY_ex', met(name = 'GLY', loc = 'ex', prot = None))
Observable('obs_GLYCERALD_cyt', met(name = 'GLYCERALD', loc = 'cyt', prot = None))
Observable('obs_GLYCERALD_per', met(name = 'GLYCERALD', loc = 'per', prot = None))
Observable('obs_GLYCERALD_ex', met(name = 'GLYCERALD', loc = 'ex', prot = None))
Observable('obs_GLYCERATE_cyt', met(name = 'GLYCERATE', loc = 'cyt', prot = None))
Observable('obs_GLYCERATE_per', met(name = 'GLYCERATE', loc = 'per', prot = None))
Observable('obs_GLYCERATE_ex', met(name = 'GLYCERATE', loc = 'ex', prot = None))
Observable('obs_GLYCEROL_cyt', met(name = 'GLYCEROL', loc = 'cyt', prot = None))
Observable('obs_GLYCEROL_per', met(name = 'GLYCEROL', loc = 'per', prot = None))
Observable('obs_GLYCEROL_ex', met(name = 'GLYCEROL', loc = 'ex', prot = None))
Observable('obs_GLYCEROL_3P_cyt', met(name = 'GLYCEROL_3P', loc = 'cyt', prot = None))
Observable('obs_GLYCEROL_3P_per', met(name = 'GLYCEROL_3P', loc = 'per', prot = None))
Observable('obs_GLYCEROL_3P_ex', met(name = 'GLYCEROL_3P', loc = 'ex', prot = None))
Observable('obs_GLYCOLLATE_cyt', met(name = 'GLYCOLLATE', loc = 'cyt', prot = None))
Observable('obs_GLYCOLLATE_per', met(name = 'GLYCOLLATE', loc = 'per', prot = None))
Observable('obs_GLYCOLLATE_ex', met(name = 'GLYCOLLATE', loc = 'ex', prot = None))
Observable('obs_GLYOX_cyt', met(name = 'GLYOX', loc = 'cyt', prot = None))
Observable('obs_GLYOX_per', met(name = 'GLYOX', loc = 'per', prot = None))
Observable('obs_GLYOX_ex', met(name = 'GLYOX', loc = 'ex', prot = None))
Observable('obs_GMP_cyt', met(name = 'GMP', loc = 'cyt', prot = None))
Observable('obs_GMP_per', met(name = 'GMP', loc = 'per', prot = None))
Observable('obs_GMP_ex', met(name = 'GMP', loc = 'ex', prot = None))
Observable('obs_GTP_cyt', met(name = 'GTP', loc = 'cyt', prot = None))
Observable('obs_GTP_per', met(name = 'GTP', loc = 'per', prot = None))
Observable('obs_GTP_ex', met(name = 'GTP', loc = 'ex', prot = None))
Observable('obs_GUANINE_cyt', met(name = 'GUANINE', loc = 'cyt', prot = None))
Observable('obs_GUANINE_per', met(name = 'GUANINE', loc = 'per', prot = None))
Observable('obs_GUANINE_ex', met(name = 'GUANINE', loc = 'ex', prot = None))
Observable('obs_GUANOSINE_cyt', met(name = 'GUANOSINE', loc = 'cyt', prot = None))
Observable('obs_GUANOSINE_per', met(name = 'GUANOSINE', loc = 'per', prot = None))
Observable('obs_GUANOSINE_ex', met(name = 'GUANOSINE', loc = 'ex', prot = None))
Observable('obs_Glucopyranose_cyt', met(name = 'Glucopyranose', loc = 'cyt', prot = None))
Observable('obs_Glucopyranose_per', met(name = 'Glucopyranose', loc = 'per', prot = None))
Observable('obs_Glucopyranose_ex', met(name = 'Glucopyranose', loc = 'ex', prot = None))
Observable('obs_HCO3_cyt', met(name = 'HCO3', loc = 'cyt', prot = None))
Observable('obs_HCO3_per', met(name = 'HCO3', loc = 'per', prot = None))
Observable('obs_HCO3_ex', met(name = 'HCO3', loc = 'ex', prot = None))
Observable('obs_HIS_cyt', met(name = 'HIS', loc = 'cyt', prot = None))
Observable('obs_HIS_per', met(name = 'HIS', loc = 'per', prot = None))
Observable('obs_HIS_ex', met(name = 'HIS', loc = 'ex', prot = None))
Observable('obs_HISTIDINAL_cyt', met(name = 'HISTIDINAL', loc = 'cyt', prot = None))
Observable('obs_HISTIDINAL_per', met(name = 'HISTIDINAL', loc = 'per', prot = None))
Observable('obs_HISTIDINAL_ex', met(name = 'HISTIDINAL', loc = 'ex', prot = None))
Observable('obs_HISTIDINOL_cyt', met(name = 'HISTIDINOL', loc = 'cyt', prot = None))
Observable('obs_HISTIDINOL_per', met(name = 'HISTIDINOL', loc = 'per', prot = None))
Observable('obs_HISTIDINOL_ex', met(name = 'HISTIDINOL', loc = 'ex', prot = None))
Observable('obs_HOMO_CYS_cyt', met(name = 'HOMO_CYS', loc = 'cyt', prot = None))
Observable('obs_HOMO_CYS_per', met(name = 'HOMO_CYS', loc = 'per', prot = None))
Observable('obs_HOMO_CYS_ex', met(name = 'HOMO_CYS', loc = 'ex', prot = None))
Observable('obs_HOMO_SER_cyt', met(name = 'HOMO_SER', loc = 'cyt', prot = None))
Observable('obs_HOMO_SER_per', met(name = 'HOMO_SER', loc = 'per', prot = None))
Observable('obs_HOMO_SER_ex', met(name = 'HOMO_SER', loc = 'ex', prot = None))
Observable('obs_HS_cyt', met(name = 'HS', loc = 'cyt', prot = None))
Observable('obs_HS_per', met(name = 'HS', loc = 'per', prot = None))
Observable('obs_HS_ex', met(name = 'HS', loc = 'ex', prot = None))
Observable('obs_HYPOXANTHINE_cyt', met(name = 'HYPOXANTHINE', loc = 'cyt', prot = None))
Observable('obs_HYPOXANTHINE_per', met(name = 'HYPOXANTHINE', loc = 'per', prot = None))
Observable('obs_HYPOXANTHINE_ex', met(name = 'HYPOXANTHINE', loc = 'ex', prot = None))
Observable('obs_ILE_cyt', met(name = 'ILE', loc = 'cyt', prot = None))
Observable('obs_ILE_per', met(name = 'ILE', loc = 'per', prot = None))
Observable('obs_ILE_ex', met(name = 'ILE', loc = 'ex', prot = None))
Observable('obs_IMIDAZOLE_ACETOL_P_cyt', met(name = 'IMIDAZOLE_ACETOL_P', loc = 'cyt', prot = None))
Observable('obs_IMIDAZOLE_ACETOL_P_per', met(name = 'IMIDAZOLE_ACETOL_P', loc = 'per', prot = None))
Observable('obs_IMIDAZOLE_ACETOL_P_ex', met(name = 'IMIDAZOLE_ACETOL_P', loc = 'ex', prot = None))
Observable('obs_IMP_cyt', met(name = 'IMP', loc = 'cyt', prot = None))
Observable('obs_IMP_per', met(name = 'IMP', loc = 'per', prot = None))
Observable('obs_IMP_ex', met(name = 'IMP', loc = 'ex', prot = None))
Observable('obs_INDOLE_cyt', met(name = 'INDOLE', loc = 'cyt', prot = None))
Observable('obs_INDOLE_per', met(name = 'INDOLE', loc = 'per', prot = None))
Observable('obs_INDOLE_ex', met(name = 'INDOLE', loc = 'ex', prot = None))
Observable('obs_INDOLE_3_GLYCEROL_P_cyt', met(name = 'INDOLE_3_GLYCEROL_P', loc = 'cyt', prot = None))
Observable('obs_INDOLE_3_GLYCEROL_P_per', met(name = 'INDOLE_3_GLYCEROL_P', loc = 'per', prot = None))
Observable('obs_INDOLE_3_GLYCEROL_P_ex', met(name = 'INDOLE_3_GLYCEROL_P', loc = 'ex', prot = None))
Observable('obs_INOSINE_cyt', met(name = 'INOSINE', loc = 'cyt', prot = None))
Observable('obs_INOSINE_per', met(name = 'INOSINE', loc = 'per', prot = None))
Observable('obs_INOSINE_ex', met(name = 'INOSINE', loc = 'ex', prot = None))
Observable('obs_L_ALLO_THREONINE_cyt', met(name = 'L_ALLO_THREONINE', loc = 'cyt', prot = None))
Observable('obs_L_ALLO_THREONINE_per', met(name = 'L_ALLO_THREONINE', loc = 'per', prot = None))
Observable('obs_L_ALLO_THREONINE_ex', met(name = 'L_ALLO_THREONINE', loc = 'ex', prot = None))
Observable('obs_L_ASPARTATE_cyt', met(name = 'L_ASPARTATE', loc = 'cyt', prot = None))
Observable('obs_L_ASPARTATE_per', met(name = 'L_ASPARTATE', loc = 'per', prot = None))
Observable('obs_L_ASPARTATE_ex', met(name = 'L_ASPARTATE', loc = 'ex', prot = None))
Observable('obs_L_ASPARTATE_SEMIALDEHYDE_cyt', met(name = 'L_ASPARTATE_SEMIALDEHYDE', loc = 'cyt', prot = None))
Observable('obs_L_ASPARTATE_SEMIALDEHYDE_per', met(name = 'L_ASPARTATE_SEMIALDEHYDE', loc = 'per', prot = None))
Observable('obs_L_ASPARTATE_SEMIALDEHYDE_ex', met(name = 'L_ASPARTATE_SEMIALDEHYDE', loc = 'ex', prot = None))
Observable('obs_L_BETA_ASPARTYL_P_cyt', met(name = 'L_BETA_ASPARTYL_P', loc = 'cyt', prot = None))
Observable('obs_L_BETA_ASPARTYL_P_per', met(name = 'L_BETA_ASPARTYL_P', loc = 'per', prot = None))
Observable('obs_L_BETA_ASPARTYL_P_ex', met(name = 'L_BETA_ASPARTYL_P', loc = 'ex', prot = None))
Observable('obs_L_CYSTATHIONINE_cyt', met(name = 'L_CYSTATHIONINE', loc = 'cyt', prot = None))
Observable('obs_L_CYSTATHIONINE_per', met(name = 'L_CYSTATHIONINE', loc = 'per', prot = None))
Observable('obs_L_CYSTATHIONINE_ex', met(name = 'L_CYSTATHIONINE', loc = 'ex', prot = None))
Observable('obs_L_GLYCERALDEHYDE_cyt', met(name = 'L_GLYCERALDEHYDE', loc = 'cyt', prot = None))
Observable('obs_L_GLYCERALDEHYDE_per', met(name = 'L_GLYCERALDEHYDE', loc = 'per', prot = None))
Observable('obs_L_GLYCERALDEHYDE_ex', met(name = 'L_GLYCERALDEHYDE', loc = 'ex', prot = None))
Observable('obs_L_GLYCERALDEHYDE_3_PHOSPHATE_cyt', met(name = 'L_GLYCERALDEHYDE_3_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_L_GLYCERALDEHYDE_3_PHOSPHATE_per', met(name = 'L_GLYCERALDEHYDE_3_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_L_GLYCERALDEHYDE_3_PHOSPHATE_ex', met(name = 'L_GLYCERALDEHYDE_3_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_L_HISTIDINOL_P_cyt', met(name = 'L_HISTIDINOL_P', loc = 'cyt', prot = None))
Observable('obs_L_HISTIDINOL_P_per', met(name = 'L_HISTIDINOL_P', loc = 'per', prot = None))
Observable('obs_L_HISTIDINOL_P_ex', met(name = 'L_HISTIDINOL_P', loc = 'ex', prot = None))
Observable('obs_L_PANTOATE_cyt', met(name = 'L_PANTOATE', loc = 'cyt', prot = None))
Observable('obs_L_PANTOATE_per', met(name = 'L_PANTOATE', loc = 'per', prot = None))
Observable('obs_L_PANTOATE_ex', met(name = 'L_PANTOATE', loc = 'ex', prot = None))
Observable('obs_L_THREONINE_O_3_PHOSPHATE_cyt', met(name = 'L_THREONINE_O_3_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_L_THREONINE_O_3_PHOSPHATE_per', met(name = 'L_THREONINE_O_3_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_L_THREONINE_O_3_PHOSPHATE_ex', met(name = 'L_THREONINE_O_3_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_LEU_cyt', met(name = 'LEU', loc = 'cyt', prot = None))
Observable('obs_LEU_per', met(name = 'LEU', loc = 'per', prot = None))
Observable('obs_LEU_ex', met(name = 'LEU', loc = 'ex', prot = None))
Observable('obs_LL_DIAMINOPIMELATE_cyt', met(name = 'LL_DIAMINOPIMELATE', loc = 'cyt', prot = None))
Observable('obs_LL_DIAMINOPIMELATE_per', met(name = 'LL_DIAMINOPIMELATE', loc = 'per', prot = None))
Observable('obs_LL_DIAMINOPIMELATE_ex', met(name = 'LL_DIAMINOPIMELATE', loc = 'ex', prot = None))
Observable('obs_LYS_cyt', met(name = 'LYS', loc = 'cyt', prot = None))
Observable('obs_LYS_per', met(name = 'LYS', loc = 'per', prot = None))
Observable('obs_LYS_ex', met(name = 'LYS', loc = 'ex', prot = None))
Observable('obs_Lipoyl_Protein_N6_lipoyllysine_cyt', met(name = 'Lipoyl_Protein_N6_lipoyllysine', loc = 'cyt', prot = None))
Observable('obs_Lipoyl_Protein_N6_lipoyllysine_per', met(name = 'Lipoyl_Protein_N6_lipoyllysine', loc = 'per', prot = None))
Observable('obs_Lipoyl_Protein_N6_lipoyllysine_ex', met(name = 'Lipoyl_Protein_N6_lipoyllysine', loc = 'ex', prot = None))
Observable('obs_MAL_cyt', met(name = 'MAL', loc = 'cyt', prot = None))
Observable('obs_MAL_per', met(name = 'MAL', loc = 'per', prot = None))
Observable('obs_MAL_ex', met(name = 'MAL', loc = 'ex', prot = None))
Observable('obs_MALONATE_S_ALD_cyt', met(name = 'MALONATE_S_ALD', loc = 'cyt', prot = None))
Observable('obs_MALONATE_S_ALD_per', met(name = 'MALONATE_S_ALD', loc = 'per', prot = None))
Observable('obs_MALONATE_S_ALD_ex', met(name = 'MALONATE_S_ALD', loc = 'ex', prot = None))
Observable('obs_MANNOSE_cyt', met(name = 'MANNOSE', loc = 'cyt', prot = None))
Observable('obs_MANNOSE_per', met(name = 'MANNOSE', loc = 'per', prot = None))
Observable('obs_MANNOSE_ex', met(name = 'MANNOSE', loc = 'ex', prot = None))
Observable('obs_MANNOSE_1P_cyt', met(name = 'MANNOSE_1P', loc = 'cyt', prot = None))
Observable('obs_MANNOSE_1P_per', met(name = 'MANNOSE_1P', loc = 'per', prot = None))
Observable('obs_MANNOSE_1P_ex', met(name = 'MANNOSE_1P', loc = 'ex', prot = None))
Observable('obs_MESO_DIAMINOPIMELATE_cyt', met(name = 'MESO_DIAMINOPIMELATE', loc = 'cyt', prot = None))
Observable('obs_MESO_DIAMINOPIMELATE_per', met(name = 'MESO_DIAMINOPIMELATE', loc = 'per', prot = None))
Observable('obs_MESO_DIAMINOPIMELATE_ex', met(name = 'MESO_DIAMINOPIMELATE', loc = 'ex', prot = None))
Observable('obs_MET_cyt', met(name = 'MET', loc = 'cyt', prot = None))
Observable('obs_MET_per', met(name = 'MET', loc = 'per', prot = None))
Observable('obs_MET_ex', met(name = 'MET', loc = 'ex', prot = None))
Observable('obs_METHYLENE_THF_GLU_N_cyt', met(name = 'METHYLENE_THF_GLU_N', loc = 'cyt', prot = None))
Observable('obs_METHYLENE_THF_GLU_N_per', met(name = 'METHYLENE_THF_GLU_N', loc = 'per', prot = None))
Observable('obs_METHYLENE_THF_GLU_N_ex', met(name = 'METHYLENE_THF_GLU_N', loc = 'ex', prot = None))
Observable('obs_Mannose_6_phosphate_cyt', met(name = 'Mannose_6_phosphate', loc = 'cyt', prot = None))
Observable('obs_Mannose_6_phosphate_per', met(name = 'Mannose_6_phosphate', loc = 'per', prot = None))
Observable('obs_Mannose_6_phosphate_ex', met(name = 'Mannose_6_phosphate', loc = 'ex', prot = None))
Observable('obs_Menaquinols_cyt', met(name = 'Menaquinols', loc = 'cyt', prot = None))
Observable('obs_Menaquinols_per', met(name = 'Menaquinols', loc = 'per', prot = None))
Observable('obs_Menaquinols_ex', met(name = 'Menaquinols', loc = 'ex', prot = None))
Observable('obs_Menaquinones_cyt', met(name = 'Menaquinones', loc = 'cyt', prot = None))
Observable('obs_Menaquinones_per', met(name = 'Menaquinones', loc = 'per', prot = None))
Observable('obs_Menaquinones_ex', met(name = 'Menaquinones', loc = 'ex', prot = None))
Observable('obs_N_5_PHOSPHORIBOSYL_ANTHRANILATE_cyt', met(name = 'N_5_PHOSPHORIBOSYL_ANTHRANILATE', loc = 'cyt', prot = None))
Observable('obs_N_5_PHOSPHORIBOSYL_ANTHRANILATE_per', met(name = 'N_5_PHOSPHORIBOSYL_ANTHRANILATE', loc = 'per', prot = None))
Observable('obs_N_5_PHOSPHORIBOSYL_ANTHRANILATE_ex', met(name = 'N_5_PHOSPHORIBOSYL_ANTHRANILATE', loc = 'ex', prot = None))
Observable('obs_N_ALPHA_ACETYLORNITHINE_cyt', met(name = 'N_ALPHA_ACETYLORNITHINE', loc = 'cyt', prot = None))
Observable('obs_N_ALPHA_ACETYLORNITHINE_per', met(name = 'N_ALPHA_ACETYLORNITHINE', loc = 'per', prot = None))
Observable('obs_N_ALPHA_ACETYLORNITHINE_ex', met(name = 'N_ALPHA_ACETYLORNITHINE', loc = 'ex', prot = None))
Observable('obs_N_SUCCINYL_2_AMINO_6_KETOPIMELATE_cyt', met(name = 'N_SUCCINYL_2_AMINO_6_KETOPIMELATE', loc = 'cyt', prot = None))
Observable('obs_N_SUCCINYL_2_AMINO_6_KETOPIMELATE_per', met(name = 'N_SUCCINYL_2_AMINO_6_KETOPIMELATE', loc = 'per', prot = None))
Observable('obs_N_SUCCINYL_2_AMINO_6_KETOPIMELATE_ex', met(name = 'N_SUCCINYL_2_AMINO_6_KETOPIMELATE', loc = 'ex', prot = None))
Observable('obs_N_SUCCINYLLL_2_6_DIAMINOPIMELATE_cyt', met(name = 'N_SUCCINYLLL_2_6_DIAMINOPIMELATE', loc = 'cyt', prot = None))
Observable('obs_N_SUCCINYLLL_2_6_DIAMINOPIMELATE_per', met(name = 'N_SUCCINYLLL_2_6_DIAMINOPIMELATE', loc = 'per', prot = None))
Observable('obs_N_SUCCINYLLL_2_6_DIAMINOPIMELATE_ex', met(name = 'N_SUCCINYLLL_2_6_DIAMINOPIMELATE', loc = 'ex', prot = None))
Observable('obs_N5_Formyl_THF_Glu_N_cyt', met(name = 'N5_Formyl_THF_Glu_N', loc = 'cyt', prot = None))
Observable('obs_N5_Formyl_THF_Glu_N_per', met(name = 'N5_Formyl_THF_Glu_N', loc = 'per', prot = None))
Observable('obs_N5_Formyl_THF_Glu_N_ex', met(name = 'N5_Formyl_THF_Glu_N', loc = 'ex', prot = None))
Observable('obs_NACMUR_cyt', met(name = 'NACMUR', loc = 'cyt', prot = None))
Observable('obs_NACMUR_per', met(name = 'NACMUR', loc = 'per', prot = None))
Observable('obs_NACMUR_ex', met(name = 'NACMUR', loc = 'ex', prot = None))
Observable('obs_NAD_cyt', met(name = 'NAD', loc = 'cyt', prot = None))
Observable('obs_NAD_per', met(name = 'NAD', loc = 'per', prot = None))
Observable('obs_NAD_ex', met(name = 'NAD', loc = 'ex', prot = None))
Observable('obs_NAD_P_OR_NOP_cyt', met(name = 'NAD_P_OR_NOP', loc = 'cyt', prot = None))
Observable('obs_NAD_P_OR_NOP_per', met(name = 'NAD_P_OR_NOP', loc = 'per', prot = None))
Observable('obs_NAD_P_OR_NOP_ex', met(name = 'NAD_P_OR_NOP', loc = 'ex', prot = None))
Observable('obs_NADH_cyt', met(name = 'NADH', loc = 'cyt', prot = None))
Observable('obs_NADH_per', met(name = 'NADH', loc = 'per', prot = None))
Observable('obs_NADH_ex', met(name = 'NADH', loc = 'ex', prot = None))
Observable('obs_NADH_P_OR_NOP_cyt', met(name = 'NADH_P_OR_NOP', loc = 'cyt', prot = None))
Observable('obs_NADH_P_OR_NOP_per', met(name = 'NADH_P_OR_NOP', loc = 'per', prot = None))
Observable('obs_NADH_P_OR_NOP_ex', met(name = 'NADH_P_OR_NOP', loc = 'ex', prot = None))
Observable('obs_NADP_cyt', met(name = 'NADP', loc = 'cyt', prot = None))
Observable('obs_NADP_per', met(name = 'NADP', loc = 'per', prot = None))
Observable('obs_NADP_ex', met(name = 'NADP', loc = 'ex', prot = None))
Observable('obs_NADPH_cyt', met(name = 'NADPH', loc = 'cyt', prot = None))
Observable('obs_NADPH_per', met(name = 'NADPH', loc = 'per', prot = None))
Observable('obs_NADPH_ex', met(name = 'NADPH', loc = 'ex', prot = None))
Observable('obs_NIACINAMIDE_cyt', met(name = 'NIACINAMIDE', loc = 'cyt', prot = None))
Observable('obs_NIACINAMIDE_per', met(name = 'NIACINAMIDE', loc = 'per', prot = None))
Observable('obs_NIACINAMIDE_ex', met(name = 'NIACINAMIDE', loc = 'ex', prot = None))
Observable('obs_NIACINE_cyt', met(name = 'NIACINE', loc = 'cyt', prot = None))
Observable('obs_NIACINE_per', met(name = 'NIACINE', loc = 'per', prot = None))
Observable('obs_NIACINE_ex', met(name = 'NIACINE', loc = 'ex', prot = None))
Observable('obs_NICOTINAMIDE_NUCLEOTIDE_cyt', met(name = 'NICOTINAMIDE_NUCLEOTIDE', loc = 'cyt', prot = None))
Observable('obs_NICOTINAMIDE_NUCLEOTIDE_per', met(name = 'NICOTINAMIDE_NUCLEOTIDE', loc = 'per', prot = None))
Observable('obs_NICOTINAMIDE_NUCLEOTIDE_ex', met(name = 'NICOTINAMIDE_NUCLEOTIDE', loc = 'ex', prot = None))
Observable('obs_NICOTINAMIDE_RIBOSE_cyt', met(name = 'NICOTINAMIDE_RIBOSE', loc = 'cyt', prot = None))
Observable('obs_NICOTINAMIDE_RIBOSE_per', met(name = 'NICOTINAMIDE_RIBOSE', loc = 'per', prot = None))
Observable('obs_NICOTINAMIDE_RIBOSE_ex', met(name = 'NICOTINAMIDE_RIBOSE', loc = 'ex', prot = None))
Observable('obs_NICOTINATE_NUCLEOTIDE_cyt', met(name = 'NICOTINATE_NUCLEOTIDE', loc = 'cyt', prot = None))
Observable('obs_NICOTINATE_NUCLEOTIDE_per', met(name = 'NICOTINATE_NUCLEOTIDE', loc = 'per', prot = None))
Observable('obs_NICOTINATE_NUCLEOTIDE_ex', met(name = 'NICOTINATE_NUCLEOTIDE', loc = 'ex', prot = None))
Observable('obs_Nucleoside_Diphosphates_cyt', met(name = 'Nucleoside_Diphosphates', loc = 'cyt', prot = None))
Observable('obs_Nucleoside_Diphosphates_per', met(name = 'Nucleoside_Diphosphates', loc = 'per', prot = None))
Observable('obs_Nucleoside_Diphosphates_ex', met(name = 'Nucleoside_Diphosphates', loc = 'ex', prot = None))
Observable('obs_Nucleoside_Monophosphates_cyt', met(name = 'Nucleoside_Monophosphates', loc = 'cyt', prot = None))
Observable('obs_Nucleoside_Monophosphates_per', met(name = 'Nucleoside_Monophosphates', loc = 'per', prot = None))
Observable('obs_Nucleoside_Monophosphates_ex', met(name = 'Nucleoside_Monophosphates', loc = 'ex', prot = None))
Observable('obs_Nucleoside_Triphosphates_cyt', met(name = 'Nucleoside_Triphosphates', loc = 'cyt', prot = None))
Observable('obs_Nucleoside_Triphosphates_per', met(name = 'Nucleoside_Triphosphates', loc = 'per', prot = None))
Observable('obs_Nucleoside_Triphosphates_ex', met(name = 'Nucleoside_Triphosphates', loc = 'ex', prot = None))
Observable('obs_Nucleosides_cyt', met(name = 'Nucleosides', loc = 'cyt', prot = None))
Observable('obs_Nucleosides_per', met(name = 'Nucleosides', loc = 'per', prot = None))
Observable('obs_Nucleosides_ex', met(name = 'Nucleosides', loc = 'ex', prot = None))
Observable('obs_O_PHOSPHO_L_HOMOSERINE_cyt', met(name = 'O_PHOSPHO_L_HOMOSERINE', loc = 'cyt', prot = None))
Observable('obs_O_PHOSPHO_L_HOMOSERINE_per', met(name = 'O_PHOSPHO_L_HOMOSERINE', loc = 'per', prot = None))
Observable('obs_O_PHOSPHO_L_HOMOSERINE_ex', met(name = 'O_PHOSPHO_L_HOMOSERINE', loc = 'ex', prot = None))
Observable('obs_O_SUCCINYL_L_HOMOSERINE_cyt', met(name = 'O_SUCCINYL_L_HOMOSERINE', loc = 'cyt', prot = None))
Observable('obs_O_SUCCINYL_L_HOMOSERINE_per', met(name = 'O_SUCCINYL_L_HOMOSERINE', loc = 'per', prot = None))
Observable('obs_O_SUCCINYL_L_HOMOSERINE_ex', met(name = 'O_SUCCINYL_L_HOMOSERINE', loc = 'ex', prot = None))
Observable('obs_OROTATE_cyt', met(name = 'OROTATE', loc = 'cyt', prot = None))
Observable('obs_OROTATE_per', met(name = 'OROTATE', loc = 'per', prot = None))
Observable('obs_OROTATE_ex', met(name = 'OROTATE', loc = 'ex', prot = None))
Observable('obs_OROTIDINE_5_PHOSPHATE_cyt', met(name = 'OROTIDINE_5_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_OROTIDINE_5_PHOSPHATE_per', met(name = 'OROTIDINE_5_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_OROTIDINE_5_PHOSPHATE_ex', met(name = 'OROTIDINE_5_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_OXALACETIC_ACID_cyt', met(name = 'OXALACETIC_ACID', loc = 'cyt', prot = None))
Observable('obs_OXALACETIC_ACID_per', met(name = 'OXALACETIC_ACID', loc = 'per', prot = None))
Observable('obs_OXALACETIC_ACID_ex', met(name = 'OXALACETIC_ACID', loc = 'ex', prot = None))
Observable('obs_OXYGEN_MOLECULE_cyt', met(name = 'OXYGEN_MOLECULE', loc = 'cyt', prot = None))
Observable('obs_OXYGEN_MOLECULE_per', met(name = 'OXYGEN_MOLECULE', loc = 'per', prot = None))
Observable('obs_OXYGEN_MOLECULE_ex', met(name = 'OXYGEN_MOLECULE', loc = 'ex', prot = None))
Observable('obs_Orthophosphoric_Monoesters_cyt', met(name = 'Orthophosphoric_Monoesters', loc = 'cyt', prot = None))
Observable('obs_Orthophosphoric_Monoesters_per', met(name = 'Orthophosphoric_Monoesters', loc = 'per', prot = None))
Observable('obs_Orthophosphoric_Monoesters_ex', met(name = 'Orthophosphoric_Monoesters', loc = 'ex', prot = None))
Observable('obs_Oxo_glutarate_dehydro_suc_DH_lipoyl_cyt', met(name = 'Oxo_glutarate_dehydro_suc_DH_lipoyl', loc = 'cyt', prot = None))
Observable('obs_Oxo_glutarate_dehydro_suc_DH_lipoyl_per', met(name = 'Oxo_glutarate_dehydro_suc_DH_lipoyl', loc = 'per', prot = None))
Observable('obs_Oxo_glutarate_dehydro_suc_DH_lipoyl_ex', met(name = 'Oxo_glutarate_dehydro_suc_DH_lipoyl', loc = 'ex', prot = None))
Observable('obs_Oxo_glutarate_dehydrogenase_DH_lipoyl_cyt', met(name = 'Oxo_glutarate_dehydrogenase_DH_lipoyl', loc = 'cyt', prot = None))
Observable('obs_Oxo_glutarate_dehydrogenase_DH_lipoyl_per', met(name = 'Oxo_glutarate_dehydrogenase_DH_lipoyl', loc = 'per', prot = None))
Observable('obs_Oxo_glutarate_dehydrogenase_DH_lipoyl_ex', met(name = 'Oxo_glutarate_dehydrogenase_DH_lipoyl', loc = 'ex', prot = None))
Observable('obs_Oxo_glutarate_dehydrogenase_lipoyl_cyt', met(name = 'Oxo_glutarate_dehydrogenase_lipoyl', loc = 'cyt', prot = None))
Observable('obs_Oxo_glutarate_dehydrogenase_lipoyl_per', met(name = 'Oxo_glutarate_dehydrogenase_lipoyl', loc = 'per', prot = None))
Observable('obs_Oxo_glutarate_dehydrogenase_lipoyl_ex', met(name = 'Oxo_glutarate_dehydrogenase_lipoyl', loc = 'ex', prot = None))
Observable('obs_P_HYDROXY_PHENYLPYRUVATE_cyt', met(name = 'P_HYDROXY_PHENYLPYRUVATE', loc = 'cyt', prot = None))
Observable('obs_P_HYDROXY_PHENYLPYRUVATE_per', met(name = 'P_HYDROXY_PHENYLPYRUVATE', loc = 'per', prot = None))
Observable('obs_P_HYDROXY_PHENYLPYRUVATE_ex', met(name = 'P_HYDROXY_PHENYLPYRUVATE', loc = 'ex', prot = None))
Observable('obs_P_NITROPHENOL_cyt', met(name = 'P_NITROPHENOL', loc = 'cyt', prot = None))
Observable('obs_P_NITROPHENOL_per', met(name = 'P_NITROPHENOL', loc = 'per', prot = None))
Observable('obs_P_NITROPHENOL_ex', met(name = 'P_NITROPHENOL', loc = 'ex', prot = None))
Observable('obs_P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE_cyt', met(name = 'P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE', loc = 'cyt', prot = None))
Observable('obs_P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE_per', met(name = 'P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE', loc = 'per', prot = None))
Observable('obs_P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE_ex', met(name = 'P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE', loc = 'ex', prot = None))
Observable('obs_P3I_cyt', met(name = 'P3I', loc = 'cyt', prot = None))
Observable('obs_P3I_per', met(name = 'P3I', loc = 'per', prot = None))
Observable('obs_P3I_ex', met(name = 'P3I', loc = 'ex', prot = None))
Observable('obs_PHE_cyt', met(name = 'PHE', loc = 'cyt', prot = None))
Observable('obs_PHE_per', met(name = 'PHE', loc = 'per', prot = None))
Observable('obs_PHE_ex', met(name = 'PHE', loc = 'ex', prot = None))
Observable('obs_PHENYL_PYRUVATE_cyt', met(name = 'PHENYL_PYRUVATE', loc = 'cyt', prot = None))
Observable('obs_PHENYL_PYRUVATE_per', met(name = 'PHENYL_PYRUVATE', loc = 'per', prot = None))
Observable('obs_PHENYL_PYRUVATE_ex', met(name = 'PHENYL_PYRUVATE', loc = 'ex', prot = None))
Observable('obs_PHOSPHO_ENOL_PYRUVATE_cyt', met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'cyt', prot = None))
Observable('obs_PHOSPHO_ENOL_PYRUVATE_per', met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'per', prot = None))
Observable('obs_PHOSPHO_ENOL_PYRUVATE_ex', met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'ex', prot = None))
Observable('obs_PHOSPHORIBOSYL_AMP_cyt', met(name = 'PHOSPHORIBOSYL_AMP', loc = 'cyt', prot = None))
Observable('obs_PHOSPHORIBOSYL_AMP_per', met(name = 'PHOSPHORIBOSYL_AMP', loc = 'per', prot = None))
Observable('obs_PHOSPHORIBOSYL_AMP_ex', met(name = 'PHOSPHORIBOSYL_AMP', loc = 'ex', prot = None))
Observable('obs_PHOSPHORIBOSYL_ATP_cyt', met(name = 'PHOSPHORIBOSYL_ATP', loc = 'cyt', prot = None))
Observable('obs_PHOSPHORIBOSYL_ATP_per', met(name = 'PHOSPHORIBOSYL_ATP', loc = 'per', prot = None))
Observable('obs_PHOSPHORIBOSYL_ATP_ex', met(name = 'PHOSPHORIBOSYL_ATP', loc = 'ex', prot = None))
Observable('obs_PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE_cyt', met(name = 'PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE', loc = 'cyt', prot = None))
Observable('obs_PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE_per', met(name = 'PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE', loc = 'per', prot = None))
Observable('obs_PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE_ex', met(name = 'PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE', loc = 'ex', prot = None))
Observable('obs_PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE_cyt', met(name = 'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE', loc = 'cyt', prot = None))
Observable('obs_PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE_per', met(name = 'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE', loc = 'per', prot = None))
Observable('obs_PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE_ex', met(name = 'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE', loc = 'ex', prot = None))
Observable('obs_PHOSPHORIBOSYL_FORMIMINO_AICAR_P_cyt', met(name = 'PHOSPHORIBOSYL_FORMIMINO_AICAR_P', loc = 'cyt', prot = None))
Observable('obs_PHOSPHORIBOSYL_FORMIMINO_AICAR_P_per', met(name = 'PHOSPHORIBOSYL_FORMIMINO_AICAR_P', loc = 'per', prot = None))
Observable('obs_PHOSPHORIBOSYL_FORMIMINO_AICAR_P_ex', met(name = 'PHOSPHORIBOSYL_FORMIMINO_AICAR_P', loc = 'ex', prot = None))
Observable('obs_PHOSPHORIBULOSYL_FORMIMINO_AICAR_P_cyt', met(name = 'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P', loc = 'cyt', prot = None))
Observable('obs_PHOSPHORIBULOSYL_FORMIMINO_AICAR_P_per', met(name = 'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P', loc = 'per', prot = None))
Observable('obs_PHOSPHORIBULOSYL_FORMIMINO_AICAR_P_ex', met(name = 'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P', loc = 'ex', prot = None))
Observable('obs_PHOSPHORYL_CHOLINE_cyt', met(name = 'PHOSPHORYL_CHOLINE', loc = 'cyt', prot = None))
Observable('obs_PHOSPHORYL_CHOLINE_per', met(name = 'PHOSPHORYL_CHOLINE', loc = 'per', prot = None))
Observable('obs_PHOSPHORYL_CHOLINE_ex', met(name = 'PHOSPHORYL_CHOLINE', loc = 'ex', prot = None))
Observable('obs_PHOSPHORYL_ETHANOLAMINE_cyt', met(name = 'PHOSPHORYL_ETHANOLAMINE', loc = 'cyt', prot = None))
Observable('obs_PHOSPHORYL_ETHANOLAMINE_per', met(name = 'PHOSPHORYL_ETHANOLAMINE', loc = 'per', prot = None))
Observable('obs_PHOSPHORYL_ETHANOLAMINE_ex', met(name = 'PHOSPHORYL_ETHANOLAMINE', loc = 'ex', prot = None))
Observable('obs_PPI_cyt', met(name = 'PPI', loc = 'cyt', prot = None))
Observable('obs_PPI_per', met(name = 'PPI', loc = 'per', prot = None))
Observable('obs_PPI_ex', met(name = 'PPI', loc = 'ex', prot = None))
Observable('obs_PREPHENATE_cyt', met(name = 'PREPHENATE', loc = 'cyt', prot = None))
Observable('obs_PREPHENATE_per', met(name = 'PREPHENATE', loc = 'per', prot = None))
Observable('obs_PREPHENATE_ex', met(name = 'PREPHENATE', loc = 'ex', prot = None))
Observable('obs_PROTEIN_LIPOYLLYSINE_cyt', met(name = 'PROTEIN_LIPOYLLYSINE', loc = 'cyt', prot = None))
Observable('obs_PROTEIN_LIPOYLLYSINE_per', met(name = 'PROTEIN_LIPOYLLYSINE', loc = 'per', prot = None))
Observable('obs_PROTEIN_LIPOYLLYSINE_ex', met(name = 'PROTEIN_LIPOYLLYSINE', loc = 'ex', prot = None))
Observable('obs_PROTON_cyt', met(name = 'PROTON', loc = 'cyt', prot = None))
Observable('obs_PROTON_per', met(name = 'PROTON', loc = 'per', prot = None))
Observable('obs_PROTON_ex', met(name = 'PROTON', loc = 'ex', prot = None))
Observable('obs_PRPP_cyt', met(name = 'PRPP', loc = 'cyt', prot = None))
Observable('obs_PRPP_per', met(name = 'PRPP', loc = 'per', prot = None))
Observable('obs_PRPP_ex', met(name = 'PRPP', loc = 'ex', prot = None))
Observable('obs_PTSH_MONOMER_cyt', met(name = 'PTSH_MONOMER', loc = 'cyt', prot = None))
Observable('obs_PTSH_MONOMER_per', met(name = 'PTSH_MONOMER', loc = 'per', prot = None))
Observable('obs_PTSH_MONOMER_ex', met(name = 'PTSH_MONOMER', loc = 'ex', prot = None))
Observable('obs_PTSH_PHOSPHORYLATED_cyt', met(name = 'PTSH_PHOSPHORYLATED', loc = 'cyt', prot = None))
Observable('obs_PTSH_PHOSPHORYLATED_per', met(name = 'PTSH_PHOSPHORYLATED', loc = 'per', prot = None))
Observable('obs_PTSH_PHOSPHORYLATED_ex', met(name = 'PTSH_PHOSPHORYLATED', loc = 'ex', prot = None))
Observable('obs_PYRAZINAMIDE_cyt', met(name = 'PYRAZINAMIDE', loc = 'cyt', prot = None))
Observable('obs_PYRAZINAMIDE_per', met(name = 'PYRAZINAMIDE', loc = 'per', prot = None))
Observable('obs_PYRAZINAMIDE_ex', met(name = 'PYRAZINAMIDE', loc = 'ex', prot = None))
Observable('obs_PYRAZINOIC_ACID_cyt', met(name = 'PYRAZINOIC_ACID', loc = 'cyt', prot = None))
Observable('obs_PYRAZINOIC_ACID_per', met(name = 'PYRAZINOIC_ACID', loc = 'per', prot = None))
Observable('obs_PYRAZINOIC_ACID_ex', met(name = 'PYRAZINOIC_ACID', loc = 'ex', prot = None))
Observable('obs_PYRIDOXAL_cyt', met(name = 'PYRIDOXAL', loc = 'cyt', prot = None))
Observable('obs_PYRIDOXAL_per', met(name = 'PYRIDOXAL', loc = 'per', prot = None))
Observable('obs_PYRIDOXAL_ex', met(name = 'PYRIDOXAL', loc = 'ex', prot = None))
Observable('obs_PYRIDOXAL_PHOSPHATE_cyt', met(name = 'PYRIDOXAL_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_PYRIDOXAL_PHOSPHATE_per', met(name = 'PYRIDOXAL_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_PYRIDOXAL_PHOSPHATE_ex', met(name = 'PYRIDOXAL_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_PYRIDOXAMINE_5P_cyt', met(name = 'PYRIDOXAMINE_5P', loc = 'cyt', prot = None))
Observable('obs_PYRIDOXAMINE_5P_per', met(name = 'PYRIDOXAMINE_5P', loc = 'per', prot = None))
Observable('obs_PYRIDOXAMINE_5P_ex', met(name = 'PYRIDOXAMINE_5P', loc = 'ex', prot = None))
Observable('obs_PYRIDOXINE_cyt', met(name = 'PYRIDOXINE', loc = 'cyt', prot = None))
Observable('obs_PYRIDOXINE_per', met(name = 'PYRIDOXINE', loc = 'per', prot = None))
Observable('obs_PYRIDOXINE_ex', met(name = 'PYRIDOXINE', loc = 'ex', prot = None))
Observable('obs_PYRIDOXINE_5P_cyt', met(name = 'PYRIDOXINE_5P', loc = 'cyt', prot = None))
Observable('obs_PYRIDOXINE_5P_per', met(name = 'PYRIDOXINE_5P', loc = 'per', prot = None))
Observable('obs_PYRIDOXINE_5P_ex', met(name = 'PYRIDOXINE_5P', loc = 'ex', prot = None))
Observable('obs_PYRUVATE_cyt', met(name = 'PYRUVATE', loc = 'cyt', prot = None))
Observable('obs_PYRUVATE_per', met(name = 'PYRUVATE', loc = 'per', prot = None))
Observable('obs_PYRUVATE_ex', met(name = 'PYRUVATE', loc = 'ex', prot = None))
Observable('obs_Pi_cyt', met(name = 'Pi', loc = 'cyt', prot = None))
Observable('obs_Pi_per', met(name = 'Pi', loc = 'per', prot = None))
Observable('obs_Pi_ex', met(name = 'Pi', loc = 'ex', prot = None))
Observable('obs_Purine_Bases_cyt', met(name = 'Purine_Bases', loc = 'cyt', prot = None))
Observable('obs_Purine_Bases_per', met(name = 'Purine_Bases', loc = 'per', prot = None))
Observable('obs_Purine_Bases_ex', met(name = 'Purine_Bases', loc = 'ex', prot = None))
Observable('obs_Purine_Ribonucleosides_cyt', met(name = 'Purine_Ribonucleosides', loc = 'cyt', prot = None))
Observable('obs_Purine_Ribonucleosides_per', met(name = 'Purine_Ribonucleosides', loc = 'per', prot = None))
Observable('obs_Purine_Ribonucleosides_ex', met(name = 'Purine_Ribonucleosides', loc = 'ex', prot = None))
Observable('obs_Pyrimidine_Bases_cyt', met(name = 'Pyrimidine_Bases', loc = 'cyt', prot = None))
Observable('obs_Pyrimidine_Bases_per', met(name = 'Pyrimidine_Bases', loc = 'per', prot = None))
Observable('obs_Pyrimidine_Bases_ex', met(name = 'Pyrimidine_Bases', loc = 'ex', prot = None))
Observable('obs_Pyrimidine_Nucleosides_cyt', met(name = 'Pyrimidine_Nucleosides', loc = 'cyt', prot = None))
Observable('obs_Pyrimidine_Nucleosides_per', met(name = 'Pyrimidine_Nucleosides', loc = 'per', prot = None))
Observable('obs_Pyrimidine_Nucleosides_ex', met(name = 'Pyrimidine_Nucleosides', loc = 'ex', prot = None))
Observable('obs_Pyrimidine_ribonucleotides_cyt', met(name = 'Pyrimidine_ribonucleotides', loc = 'cyt', prot = None))
Observable('obs_Pyrimidine_ribonucleotides_per', met(name = 'Pyrimidine_ribonucleotides', loc = 'per', prot = None))
Observable('obs_Pyrimidine_ribonucleotides_ex', met(name = 'Pyrimidine_ribonucleotides', loc = 'ex', prot = None))
Observable('obs_Pyruvate_dehydrogenase_acetylDHlipoyl_cyt', met(name = 'Pyruvate_dehydrogenase_acetylDHlipoyl', loc = 'cyt', prot = None))
Observable('obs_Pyruvate_dehydrogenase_acetylDHlipoyl_per', met(name = 'Pyruvate_dehydrogenase_acetylDHlipoyl', loc = 'per', prot = None))
Observable('obs_Pyruvate_dehydrogenase_acetylDHlipoyl_ex', met(name = 'Pyruvate_dehydrogenase_acetylDHlipoyl', loc = 'ex', prot = None))
Observable('obs_Pyruvate_dehydrogenase_dihydrolipoate_cyt', met(name = 'Pyruvate_dehydrogenase_dihydrolipoate', loc = 'cyt', prot = None))
Observable('obs_Pyruvate_dehydrogenase_dihydrolipoate_per', met(name = 'Pyruvate_dehydrogenase_dihydrolipoate', loc = 'per', prot = None))
Observable('obs_Pyruvate_dehydrogenase_dihydrolipoate_ex', met(name = 'Pyruvate_dehydrogenase_dihydrolipoate', loc = 'ex', prot = None))
Observable('obs_Pyruvate_dehydrogenase_lipoate_cyt', met(name = 'Pyruvate_dehydrogenase_lipoate', loc = 'cyt', prot = None))
Observable('obs_Pyruvate_dehydrogenase_lipoate_per', met(name = 'Pyruvate_dehydrogenase_lipoate', loc = 'per', prot = None))
Observable('obs_Pyruvate_dehydrogenase_lipoate_ex', met(name = 'Pyruvate_dehydrogenase_lipoate', loc = 'ex', prot = None))
Observable('obs_R_2_HYDROXYGLUTARATE_cyt', met(name = 'R_2_HYDROXYGLUTARATE', loc = 'cyt', prot = None))
Observable('obs_R_2_HYDROXYGLUTARATE_per', met(name = 'R_2_HYDROXYGLUTARATE', loc = 'per', prot = None))
Observable('obs_R_2_HYDROXYGLUTARATE_ex', met(name = 'R_2_HYDROXYGLUTARATE', loc = 'ex', prot = None))
Observable('obs_RIBOFLAVIN_cyt', met(name = 'RIBOFLAVIN', loc = 'cyt', prot = None))
Observable('obs_RIBOFLAVIN_per', met(name = 'RIBOFLAVIN', loc = 'per', prot = None))
Observable('obs_RIBOFLAVIN_ex', met(name = 'RIBOFLAVIN', loc = 'ex', prot = None))
Observable('obs_RIBOSE_1P_cyt', met(name = 'RIBOSE_1P', loc = 'cyt', prot = None))
Observable('obs_RIBOSE_1P_per', met(name = 'RIBOSE_1P', loc = 'per', prot = None))
Observable('obs_RIBOSE_1P_ex', met(name = 'RIBOSE_1P', loc = 'ex', prot = None))
Observable('obs_RIBOSE_5P_cyt', met(name = 'RIBOSE_5P', loc = 'cyt', prot = None))
Observable('obs_RIBOSE_5P_per', met(name = 'RIBOSE_5P', loc = 'per', prot = None))
Observable('obs_RIBOSE_5P_ex', met(name = 'RIBOSE_5P', loc = 'ex', prot = None))
Observable('obs_RIBULOSE_5P_cyt', met(name = 'RIBULOSE_5P', loc = 'cyt', prot = None))
Observable('obs_RIBULOSE_5P_per', met(name = 'RIBULOSE_5P', loc = 'per', prot = None))
Observable('obs_RIBULOSE_5P_ex', met(name = 'RIBULOSE_5P', loc = 'ex', prot = None))
Observable('obs_Ribonucleoside_Monophosphates_cyt', met(name = 'Ribonucleoside_Monophosphates', loc = 'cyt', prot = None))
Observable('obs_Ribonucleoside_Monophosphates_per', met(name = 'Ribonucleoside_Monophosphates', loc = 'per', prot = None))
Observable('obs_Ribonucleoside_Monophosphates_ex', met(name = 'Ribonucleoside_Monophosphates', loc = 'ex', prot = None))
Observable('obs_Ribonucleoside_Triphosphates_cyt', met(name = 'Ribonucleoside_Triphosphates', loc = 'cyt', prot = None))
Observable('obs_Ribonucleoside_Triphosphates_per', met(name = 'Ribonucleoside_Triphosphates', loc = 'per', prot = None))
Observable('obs_Ribonucleoside_Triphosphates_ex', met(name = 'Ribonucleoside_Triphosphates', loc = 'ex', prot = None))
Observable('obs_Ribonucleosides_cyt', met(name = 'Ribonucleosides', loc = 'cyt', prot = None))
Observable('obs_Ribonucleosides_per', met(name = 'Ribonucleosides', loc = 'per', prot = None))
Observable('obs_Ribonucleosides_ex', met(name = 'Ribonucleosides', loc = 'ex', prot = None))
Observable('obs_SER_cyt', met(name = 'SER', loc = 'cyt', prot = None))
Observable('obs_SER_per', met(name = 'SER', loc = 'per', prot = None))
Observable('obs_SER_ex', met(name = 'SER', loc = 'ex', prot = None))
Observable('obs_SHIKIMATE_cyt', met(name = 'SHIKIMATE', loc = 'cyt', prot = None))
Observable('obs_SHIKIMATE_per', met(name = 'SHIKIMATE', loc = 'per', prot = None))
Observable('obs_SHIKIMATE_ex', met(name = 'SHIKIMATE', loc = 'ex', prot = None))
Observable('obs_SHIKIMATE_5P_cyt', met(name = 'SHIKIMATE_5P', loc = 'cyt', prot = None))
Observable('obs_SHIKIMATE_5P_per', met(name = 'SHIKIMATE_5P', loc = 'per', prot = None))
Observable('obs_SHIKIMATE_5P_ex', met(name = 'SHIKIMATE_5P', loc = 'ex', prot = None))
Observable('obs_SUC_cyt', met(name = 'SUC', loc = 'cyt', prot = None))
Observable('obs_SUC_per', met(name = 'SUC', loc = 'per', prot = None))
Observable('obs_SUC_ex', met(name = 'SUC', loc = 'ex', prot = None))
Observable('obs_SUC_COA_cyt', met(name = 'SUC_COA', loc = 'cyt', prot = None))
Observable('obs_SUC_COA_per', met(name = 'SUC_COA', loc = 'per', prot = None))
Observable('obs_SUC_COA_ex', met(name = 'SUC_COA', loc = 'ex', prot = None))
Observable('obs_Sugar_cyt', met(name = 'Sugar', loc = 'cyt', prot = None))
Observable('obs_Sugar_per', met(name = 'Sugar', loc = 'per', prot = None))
Observable('obs_Sugar_ex', met(name = 'Sugar', loc = 'ex', prot = None))
Observable('obs_Sugar_Phosphate_cyt', met(name = 'Sugar_Phosphate', loc = 'cyt', prot = None))
Observable('obs_Sugar_Phosphate_per', met(name = 'Sugar_Phosphate', loc = 'per', prot = None))
Observable('obs_Sugar_Phosphate_ex', met(name = 'Sugar_Phosphate', loc = 'ex', prot = None))
Observable('obs_TAGATOSE_1_6_DIPHOSPHATE_cyt', met(name = 'TAGATOSE_1_6_DIPHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_TAGATOSE_1_6_DIPHOSPHATE_per', met(name = 'TAGATOSE_1_6_DIPHOSPHATE', loc = 'per', prot = None))
Observable('obs_TAGATOSE_1_6_DIPHOSPHATE_ex', met(name = 'TAGATOSE_1_6_DIPHOSPHATE', loc = 'ex', prot = None))
Observable('obs_TAGATOSE_6_PHOSPHATE_cyt', met(name = 'TAGATOSE_6_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_TAGATOSE_6_PHOSPHATE_per', met(name = 'TAGATOSE_6_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_TAGATOSE_6_PHOSPHATE_ex', met(name = 'TAGATOSE_6_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_TARTRATE_cyt', met(name = 'TARTRATE', loc = 'cyt', prot = None))
Observable('obs_TARTRATE_per', met(name = 'TARTRATE', loc = 'per', prot = None))
Observable('obs_TARTRATE_ex', met(name = 'TARTRATE', loc = 'ex', prot = None))
Observable('obs_TDP_cyt', met(name = 'TDP', loc = 'cyt', prot = None))
Observable('obs_TDP_per', met(name = 'TDP', loc = 'per', prot = None))
Observable('obs_TDP_ex', met(name = 'TDP', loc = 'ex', prot = None))
Observable('obs_THF_GLU_N_cyt', met(name = 'THF_GLU_N', loc = 'cyt', prot = None))
Observable('obs_THF_GLU_N_per', met(name = 'THF_GLU_N', loc = 'per', prot = None))
Observable('obs_THF_GLU_N_ex', met(name = 'THF_GLU_N', loc = 'ex', prot = None))
Observable('obs_THR_cyt', met(name = 'THR', loc = 'cyt', prot = None))
Observable('obs_THR_per', met(name = 'THR', loc = 'per', prot = None))
Observable('obs_THR_ex', met(name = 'THR', loc = 'ex', prot = None))
Observable('obs_THREO_DS_ISO_CITRATE_cyt', met(name = 'THREO_DS_ISO_CITRATE', loc = 'cyt', prot = None))
Observable('obs_THREO_DS_ISO_CITRATE_per', met(name = 'THREO_DS_ISO_CITRATE', loc = 'per', prot = None))
Observable('obs_THREO_DS_ISO_CITRATE_ex', met(name = 'THREO_DS_ISO_CITRATE', loc = 'ex', prot = None))
Observable('obs_THYMIDINE_cyt', met(name = 'THYMIDINE', loc = 'cyt', prot = None))
Observable('obs_THYMIDINE_per', met(name = 'THYMIDINE', loc = 'per', prot = None))
Observable('obs_THYMIDINE_ex', met(name = 'THYMIDINE', loc = 'ex', prot = None))
Observable('obs_THYMINE_cyt', met(name = 'THYMINE', loc = 'cyt', prot = None))
Observable('obs_THYMINE_per', met(name = 'THYMINE', loc = 'per', prot = None))
Observable('obs_THYMINE_ex', met(name = 'THYMINE', loc = 'ex', prot = None))
Observable('obs_TMP_cyt', met(name = 'TMP', loc = 'cyt', prot = None))
Observable('obs_TMP_per', met(name = 'TMP', loc = 'per', prot = None))
Observable('obs_TMP_ex', met(name = 'TMP', loc = 'ex', prot = None))
Observable('obs_TREHALOSE_cyt', met(name = 'TREHALOSE', loc = 'cyt', prot = None))
Observable('obs_TREHALOSE_per', met(name = 'TREHALOSE', loc = 'per', prot = None))
Observable('obs_TREHALOSE_ex', met(name = 'TREHALOSE', loc = 'ex', prot = None))
Observable('obs_TREHALOSE_6P_cyt', met(name = 'TREHALOSE_6P', loc = 'cyt', prot = None))
Observable('obs_TREHALOSE_6P_per', met(name = 'TREHALOSE_6P', loc = 'per', prot = None))
Observable('obs_TREHALOSE_6P_ex', met(name = 'TREHALOSE_6P', loc = 'ex', prot = None))
Observable('obs_TRP_cyt', met(name = 'TRP', loc = 'cyt', prot = None))
Observable('obs_TRP_per', met(name = 'TRP', loc = 'per', prot = None))
Observable('obs_TRP_ex', met(name = 'TRP', loc = 'ex', prot = None))
Observable('obs_TTP_cyt', met(name = 'TTP', loc = 'cyt', prot = None))
Observable('obs_TTP_per', met(name = 'TTP', loc = 'per', prot = None))
Observable('obs_TTP_ex', met(name = 'TTP', loc = 'ex', prot = None))
Observable('obs_TYR_cyt', met(name = 'TYR', loc = 'cyt', prot = None))
Observable('obs_TYR_per', met(name = 'TYR', loc = 'per', prot = None))
Observable('obs_TYR_ex', met(name = 'TYR', loc = 'ex', prot = None))
Observable('obs_UDP_cyt', met(name = 'UDP', loc = 'cyt', prot = None))
Observable('obs_UDP_per', met(name = 'UDP', loc = 'per', prot = None))
Observable('obs_UDP_ex', met(name = 'UDP', loc = 'ex', prot = None))
Observable('obs_UDP_sugar_cyt', met(name = 'UDP_sugar', loc = 'cyt', prot = None))
Observable('obs_UDP_sugar_per', met(name = 'UDP_sugar', loc = 'per', prot = None))
Observable('obs_UDP_sugar_ex', met(name = 'UDP_sugar', loc = 'ex', prot = None))
Observable('obs_UMP_cyt', met(name = 'UMP', loc = 'cyt', prot = None))
Observable('obs_UMP_per', met(name = 'UMP', loc = 'per', prot = None))
Observable('obs_UMP_ex', met(name = 'UMP', loc = 'ex', prot = None))
Observable('obs_URACIL_cyt', met(name = 'URACIL', loc = 'cyt', prot = None))
Observable('obs_URACIL_per', met(name = 'URACIL', loc = 'per', prot = None))
Observable('obs_URACIL_ex', met(name = 'URACIL', loc = 'ex', prot = None))
Observable('obs_URATE_cyt', met(name = 'URATE', loc = 'cyt', prot = None))
Observable('obs_URATE_per', met(name = 'URATE', loc = 'per', prot = None))
Observable('obs_URATE_ex', met(name = 'URATE', loc = 'ex', prot = None))
Observable('obs_URIDINE_cyt', met(name = 'URIDINE', loc = 'cyt', prot = None))
Observable('obs_URIDINE_per', met(name = 'URIDINE', loc = 'per', prot = None))
Observable('obs_URIDINE_ex', met(name = 'URIDINE', loc = 'ex', prot = None))
Observable('obs_UTP_cyt', met(name = 'UTP', loc = 'cyt', prot = None))
Observable('obs_UTP_per', met(name = 'UTP', loc = 'per', prot = None))
Observable('obs_UTP_ex', met(name = 'UTP', loc = 'ex', prot = None))
Observable('obs_Ubiquinols_cyt', met(name = 'Ubiquinols', loc = 'cyt', prot = None))
Observable('obs_Ubiquinols_per', met(name = 'Ubiquinols', loc = 'per', prot = None))
Observable('obs_Ubiquinols_ex', met(name = 'Ubiquinols', loc = 'ex', prot = None))
Observable('obs_Ubiquinones_cyt', met(name = 'Ubiquinones', loc = 'cyt', prot = None))
Observable('obs_Ubiquinones_per', met(name = 'Ubiquinones', loc = 'per', prot = None))
Observable('obs_Ubiquinones_ex', met(name = 'Ubiquinones', loc = 'ex', prot = None))
Observable('obs_VAL_cyt', met(name = 'VAL', loc = 'cyt', prot = None))
Observable('obs_VAL_per', met(name = 'VAL', loc = 'per', prot = None))
Observable('obs_VAL_ex', met(name = 'VAL', loc = 'ex', prot = None))
Observable('obs_WATER_cyt', met(name = 'WATER', loc = 'cyt', prot = None))
Observable('obs_WATER_per', met(name = 'WATER', loc = 'per', prot = None))
Observable('obs_WATER_ex', met(name = 'WATER', loc = 'ex', prot = None))
Observable('obs_XANTHINE_cyt', met(name = 'XANTHINE', loc = 'cyt', prot = None))
Observable('obs_XANTHINE_per', met(name = 'XANTHINE', loc = 'per', prot = None))
Observable('obs_XANTHINE_ex', met(name = 'XANTHINE', loc = 'ex', prot = None))
Observable('obs_XANTHOSINE_cyt', met(name = 'XANTHOSINE', loc = 'cyt', prot = None))
Observable('obs_XANTHOSINE_per', met(name = 'XANTHOSINE', loc = 'per', prot = None))
Observable('obs_XANTHOSINE_ex', met(name = 'XANTHOSINE', loc = 'ex', prot = None))
Observable('obs_XANTHOSINE_5_PHOSPHATE_cyt', met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_XANTHOSINE_5_PHOSPHATE_per', met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_XANTHOSINE_5_PHOSPHATE_ex', met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs_XYLULOSE_5_PHOSPHATE_cyt', met(name = 'XYLULOSE_5_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs_XYLULOSE_5_PHOSPHATE_per', met(name = 'XYLULOSE_5_PHOSPHATE', loc = 'per', prot = None))
Observable('obs_XYLULOSE_5_PHOSPHATE_ex', met(name = 'XYLULOSE_5_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs__1_KETO_2_METHYLVALERATE_cyt', met(name = '_1_KETO_2_METHYLVALERATE', loc = 'cyt', prot = None))
Observable('obs__1_KETO_2_METHYLVALERATE_per', met(name = '_1_KETO_2_METHYLVALERATE', loc = 'per', prot = None))
Observable('obs__1_KETO_2_METHYLVALERATE_ex', met(name = '_1_KETO_2_METHYLVALERATE', loc = 'ex', prot = None))
Observable('obs__2_ACETO_2_HYDROXY_BUTYRATE_cyt', met(name = '_2_ACETO_2_HYDROXY_BUTYRATE', loc = 'cyt', prot = None))
Observable('obs__2_ACETO_2_HYDROXY_BUTYRATE_per', met(name = '_2_ACETO_2_HYDROXY_BUTYRATE', loc = 'per', prot = None))
Observable('obs__2_ACETO_2_HYDROXY_BUTYRATE_ex', met(name = '_2_ACETO_2_HYDROXY_BUTYRATE', loc = 'ex', prot = None))
Observable('obs__2_ACETO_LACTATE_cyt', met(name = '_2_ACETO_LACTATE', loc = 'cyt', prot = None))
Observable('obs__2_ACETO_LACTATE_per', met(name = '_2_ACETO_LACTATE', loc = 'per', prot = None))
Observable('obs__2_ACETO_LACTATE_ex', met(name = '_2_ACETO_LACTATE', loc = 'ex', prot = None))
Observable('obs__2_AMINOMALONATE_SEMIALDEHYDE_cyt', met(name = '_2_AMINOMALONATE_SEMIALDEHYDE', loc = 'cyt', prot = None))
Observable('obs__2_AMINOMALONATE_SEMIALDEHYDE_per', met(name = '_2_AMINOMALONATE_SEMIALDEHYDE', loc = 'per', prot = None))
Observable('obs__2_AMINOMALONATE_SEMIALDEHYDE_ex', met(name = '_2_AMINOMALONATE_SEMIALDEHYDE', loc = 'ex', prot = None))
Observable('obs__2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE_cyt', met(name = '_2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE', loc = 'cyt', prot = None))
Observable('obs__2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE_per', met(name = '_2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE', loc = 'per', prot = None))
Observable('obs__2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE_ex', met(name = '_2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE', loc = 'ex', prot = None))
Observable('obs__2_DEHYDROPANTOATE_cyt', met(name = '_2_DEHYDROPANTOATE', loc = 'cyt', prot = None))
Observable('obs__2_DEHYDROPANTOATE_per', met(name = '_2_DEHYDROPANTOATE', loc = 'per', prot = None))
Observable('obs__2_DEHYDROPANTOATE_ex', met(name = '_2_DEHYDROPANTOATE', loc = 'ex', prot = None))
Observable('obs__2_DEOXY_D_GLUCOSE_cyt', met(name = '_2_DEOXY_D_GLUCOSE', loc = 'cyt', prot = None))
Observable('obs__2_DEOXY_D_GLUCOSE_per', met(name = '_2_DEOXY_D_GLUCOSE', loc = 'per', prot = None))
Observable('obs__2_DEOXY_D_GLUCOSE_ex', met(name = '_2_DEOXY_D_GLUCOSE', loc = 'ex', prot = None))
Observable('obs__2_DEOXY_D_GLUCOSE_6_PHOSPHATE_cyt', met(name = '_2_DEOXY_D_GLUCOSE_6_PHOSPHATE', loc = 'cyt', prot = None))
Observable('obs__2_DEOXY_D_GLUCOSE_6_PHOSPHATE_per', met(name = '_2_DEOXY_D_GLUCOSE_6_PHOSPHATE', loc = 'per', prot = None))
Observable('obs__2_DEOXY_D_GLUCOSE_6_PHOSPHATE_ex', met(name = '_2_DEOXY_D_GLUCOSE_6_PHOSPHATE', loc = 'ex', prot = None))
Observable('obs__2_KETO_3_METHYL_VALERATE_cyt', met(name = '_2_KETO_3_METHYL_VALERATE', loc = 'cyt', prot = None))
Observable('obs__2_KETO_3_METHYL_VALERATE_per', met(name = '_2_KETO_3_METHYL_VALERATE', loc = 'per', prot = None))
Observable('obs__2_KETO_3_METHYL_VALERATE_ex', met(name = '_2_KETO_3_METHYL_VALERATE', loc = 'ex', prot = None))
Observable('obs__2_KETO_ISOVALERATE_cyt', met(name = '_2_KETO_ISOVALERATE', loc = 'cyt', prot = None))
Observable('obs__2_KETO_ISOVALERATE_per', met(name = '_2_KETO_ISOVALERATE', loc = 'per', prot = None))
Observable('obs__2_KETO_ISOVALERATE_ex', met(name = '_2_KETO_ISOVALERATE', loc = 'ex', prot = None))
Observable('obs__2_KETOGLUTARATE_cyt', met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None))
Observable('obs__2_KETOGLUTARATE_per', met(name = '_2_KETOGLUTARATE', loc = 'per', prot = None))
Observable('obs__2_KETOGLUTARATE_ex', met(name = '_2_KETOGLUTARATE', loc = 'ex', prot = None))
Observable('obs__2_OXOBUTANOATE_cyt', met(name = '_2_OXOBUTANOATE', loc = 'cyt', prot = None))
Observable('obs__2_OXOBUTANOATE_per', met(name = '_2_OXOBUTANOATE', loc = 'per', prot = None))
Observable('obs__2_OXOBUTANOATE_ex', met(name = '_2_OXOBUTANOATE', loc = 'ex', prot = None))
Observable('obs__2_PG_cyt', met(name = '_2_PG', loc = 'cyt', prot = None))
Observable('obs__2_PG_per', met(name = '_2_PG', loc = 'per', prot = None))
Observable('obs__2_PG_ex', met(name = '_2_PG', loc = 'ex', prot = None))
Observable('obs__2K_4CH3_PENTANOATE_cyt', met(name = '_2K_4CH3_PENTANOATE', loc = 'cyt', prot = None))
Observable('obs__2K_4CH3_PENTANOATE_per', met(name = '_2K_4CH3_PENTANOATE', loc = 'per', prot = None))
Observable('obs__2K_4CH3_PENTANOATE_ex', met(name = '_2K_4CH3_PENTANOATE', loc = 'ex', prot = None))
Observable('obs__3_CARBOXY_3_HYDROXY_ISOCAPROATE_cyt', met(name = '_3_CARBOXY_3_HYDROXY_ISOCAPROATE', loc = 'cyt', prot = None))
Observable('obs__3_CARBOXY_3_HYDROXY_ISOCAPROATE_per', met(name = '_3_CARBOXY_3_HYDROXY_ISOCAPROATE', loc = 'per', prot = None))
Observable('obs__3_CARBOXY_3_HYDROXY_ISOCAPROATE_ex', met(name = '_3_CARBOXY_3_HYDROXY_ISOCAPROATE', loc = 'ex', prot = None))
Observable('obs__3_DEHYDRO_SHIKIMATE_cyt', met(name = '_3_DEHYDRO_SHIKIMATE', loc = 'cyt', prot = None))
Observable('obs__3_DEHYDRO_SHIKIMATE_per', met(name = '_3_DEHYDRO_SHIKIMATE', loc = 'per', prot = None))
Observable('obs__3_DEHYDRO_SHIKIMATE_ex', met(name = '_3_DEHYDRO_SHIKIMATE', loc = 'ex', prot = None))
Observable('obs__3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P_cyt', met(name = '_3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P', loc = 'cyt', prot = None))
Observable('obs__3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P_per', met(name = '_3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P', loc = 'per', prot = None))
Observable('obs__3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P_ex', met(name = '_3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P', loc = 'ex', prot = None))
Observable('obs__3_ENOLPYRUVYL_SHIKIMATE_5P_cyt', met(name = '_3_ENOLPYRUVYL_SHIKIMATE_5P', loc = 'cyt', prot = None))
Observable('obs__3_ENOLPYRUVYL_SHIKIMATE_5P_per', met(name = '_3_ENOLPYRUVYL_SHIKIMATE_5P', loc = 'per', prot = None))
Observable('obs__3_ENOLPYRUVYL_SHIKIMATE_5P_ex', met(name = '_3_ENOLPYRUVYL_SHIKIMATE_5P', loc = 'ex', prot = None))
Observable('obs__3_HYDROXY_PROPIONATE_cyt', met(name = '_3_HYDROXY_PROPIONATE', loc = 'cyt', prot = None))
Observable('obs__3_HYDROXY_PROPIONATE_per', met(name = '_3_HYDROXY_PROPIONATE', loc = 'per', prot = None))
Observable('obs__3_HYDROXY_PROPIONATE_ex', met(name = '_3_HYDROXY_PROPIONATE', loc = 'ex', prot = None))
Observable('obs__3_MERCAPTO_PYRUVATE_cyt', met(name = '_3_MERCAPTO_PYRUVATE', loc = 'cyt', prot = None))
Observable('obs__3_MERCAPTO_PYRUVATE_per', met(name = '_3_MERCAPTO_PYRUVATE', loc = 'per', prot = None))
Observable('obs__3_MERCAPTO_PYRUVATE_ex', met(name = '_3_MERCAPTO_PYRUVATE', loc = 'ex', prot = None))
Observable('obs__3_P_HYDROXYPYRUVATE_cyt', met(name = '_3_P_HYDROXYPYRUVATE', loc = 'cyt', prot = None))
Observable('obs__3_P_HYDROXYPYRUVATE_per', met(name = '_3_P_HYDROXYPYRUVATE', loc = 'per', prot = None))
Observable('obs__3_P_HYDROXYPYRUVATE_ex', met(name = '_3_P_HYDROXYPYRUVATE', loc = 'ex', prot = None))
Observable('obs__3_P_SERINE_cyt', met(name = '_3_P_SERINE', loc = 'cyt', prot = None))
Observable('obs__3_P_SERINE_per', met(name = '_3_P_SERINE', loc = 'per', prot = None))
Observable('obs__3_P_SERINE_ex', met(name = '_3_P_SERINE', loc = 'ex', prot = None))
Observable('obs__3_Phosphomonucleotides_cyt', met(name = '_3_Phosphomonucleotides', loc = 'cyt', prot = None))
Observable('obs__3_Phosphomonucleotides_per', met(name = '_3_Phosphomonucleotides', loc = 'per', prot = None))
Observable('obs__3_Phosphomonucleotides_ex', met(name = '_3_Phosphomonucleotides', loc = 'ex', prot = None))
Observable('obs__3OH_4P_OH_ALPHA_KETOBUTYRATE_cyt', met(name = '_3OH_4P_OH_ALPHA_KETOBUTYRATE', loc = 'cyt', prot = None))
Observable('obs__3OH_4P_OH_ALPHA_KETOBUTYRATE_per', met(name = '_3OH_4P_OH_ALPHA_KETOBUTYRATE', loc = 'per', prot = None))
Observable('obs__3OH_4P_OH_ALPHA_KETOBUTYRATE_ex', met(name = '_3OH_4P_OH_ALPHA_KETOBUTYRATE', loc = 'ex', prot = None))
Observable('obs__4_PHOSPHONOOXY_THREONINE_cyt', met(name = '_4_PHOSPHONOOXY_THREONINE', loc = 'cyt', prot = None))
Observable('obs__4_PHOSPHONOOXY_THREONINE_per', met(name = '_4_PHOSPHONOOXY_THREONINE', loc = 'per', prot = None))
Observable('obs__4_PHOSPHONOOXY_THREONINE_ex', met(name = '_4_PHOSPHONOOXY_THREONINE', loc = 'ex', prot = None))
Observable('obs__5_10_METHENYL_THF_GLU_N_cyt', met(name = '_5_10_METHENYL_THF_GLU_N', loc = 'cyt', prot = None))
Observable('obs__5_10_METHENYL_THF_GLU_N_per', met(name = '_5_10_METHENYL_THF_GLU_N', loc = 'per', prot = None))
Observable('obs__5_10_METHENYL_THF_GLU_N_ex', met(name = '_5_10_METHENYL_THF_GLU_N', loc = 'ex', prot = None))
Observable('obs__5_METHYL_THF_GLU_N_cyt', met(name = '_5_METHYL_THF_GLU_N', loc = 'cyt', prot = None))
Observable('obs__5_METHYL_THF_GLU_N_per', met(name = '_5_METHYL_THF_GLU_N', loc = 'per', prot = None))
Observable('obs__5_METHYL_THF_GLU_N_ex', met(name = '_5_METHYL_THF_GLU_N', loc = 'ex', prot = None))
Observable('obs__5_P_BETA_D_RIBOSYL_AMINE_cyt', met(name = '_5_P_BETA_D_RIBOSYL_AMINE', loc = 'cyt', prot = None))
Observable('obs__5_P_BETA_D_RIBOSYL_AMINE_per', met(name = '_5_P_BETA_D_RIBOSYL_AMINE', loc = 'per', prot = None))
Observable('obs__5_P_BETA_D_RIBOSYL_AMINE_ex', met(name = '_5_P_BETA_D_RIBOSYL_AMINE', loc = 'ex', prot = None))
Observable('obs__5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE_cyt', met(name = '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', loc = 'cyt', prot = None))
Observable('obs__5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE_per', met(name = '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', loc = 'per', prot = None))
Observable('obs__5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE_ex', met(name = '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', loc = 'ex', prot = None))
Observable('obs__5_PHOSPHO_RIBOSYL_GLYCINEAMIDE_cyt', met(name = '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', loc = 'cyt', prot = None))
Observable('obs__5_PHOSPHO_RIBOSYL_GLYCINEAMIDE_per', met(name = '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', loc = 'per', prot = None))
Observable('obs__5_PHOSPHO_RIBOSYL_GLYCINEAMIDE_ex', met(name = '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', loc = 'ex', prot = None))
Observable('obs__5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE_cyt', met(name = '_5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE', loc = 'cyt', prot = None))
Observable('obs__5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE_per', met(name = '_5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE', loc = 'per', prot = None))
Observable('obs__5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE_ex', met(name = '_5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE', loc = 'ex', prot = None))
Observable('obs__5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE_cyt', met(name = '_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE', loc = 'cyt', prot = None))
Observable('obs__5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE_per', met(name = '_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE', loc = 'per', prot = None))
Observable('obs__5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE_ex', met(name = '_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE', loc = 'ex', prot = None))

Initial(met(name = 'ACET', loc = 'cyt', prot = None), Parameter('t0_ACET_cyt', 0))
Initial(met(name = 'ACET', loc = 'per', prot = None), Parameter('t0_ACET_per', 0))
Initial(met(name = 'ACET', loc = 'ex', prot = None), Parameter('t0_ACET_ex', 0))
Initial(met(name = 'ACETALD', loc = 'cyt', prot = None), Parameter('t0_ACETALD_cyt', 0))
Initial(met(name = 'ACETALD', loc = 'per', prot = None), Parameter('t0_ACETALD_per', 0))
Initial(met(name = 'ACETALD', loc = 'ex', prot = None), Parameter('t0_ACETALD_ex', 0))
Initial(met(name = 'ACETYL_COA', loc = 'cyt', prot = None), Parameter('t0_ACETYL_COA_cyt', 0))
Initial(met(name = 'ACETYL_COA', loc = 'per', prot = None), Parameter('t0_ACETYL_COA_per', 0))
Initial(met(name = 'ACETYL_COA', loc = 'ex', prot = None), Parameter('t0_ACETYL_COA_ex', 0))
Initial(met(name = 'ACETYL_P', loc = 'cyt', prot = None), Parameter('t0_ACETYL_P_cyt', 0))
Initial(met(name = 'ACETYL_P', loc = 'per', prot = None), Parameter('t0_ACETYL_P_per', 0))
Initial(met(name = 'ACETYL_P', loc = 'ex', prot = None), Parameter('t0_ACETYL_P_ex', 0))
Initial(met(name = 'ADENINE', loc = 'cyt', prot = None), Parameter('t0_ADENINE_cyt', 0))
Initial(met(name = 'ADENINE', loc = 'per', prot = None), Parameter('t0_ADENINE_per', 0))
Initial(met(name = 'ADENINE', loc = 'ex', prot = None), Parameter('t0_ADENINE_ex', 0))
Initial(met(name = 'ADENOSINE', loc = 'cyt', prot = None), Parameter('t0_ADENOSINE_cyt', 0))
Initial(met(name = 'ADENOSINE', loc = 'per', prot = None), Parameter('t0_ADENOSINE_per', 0))
Initial(met(name = 'ADENOSINE', loc = 'ex', prot = None), Parameter('t0_ADENOSINE_ex', 0))
Initial(met(name = 'ADENOSINE5TRIPHOSPHO5ADENOSINE', loc = 'cyt', prot = None), Parameter('t0_ADENOSINE5TRIPHOSPHO5ADENOSINE_cyt', 0))
Initial(met(name = 'ADENOSINE5TRIPHOSPHO5ADENOSINE', loc = 'per', prot = None), Parameter('t0_ADENOSINE5TRIPHOSPHO5ADENOSINE_per', 0))
Initial(met(name = 'ADENOSINE5TRIPHOSPHO5ADENOSINE', loc = 'ex', prot = None), Parameter('t0_ADENOSINE5TRIPHOSPHO5ADENOSINE_ex', 0))
Initial(met(name = 'ADENYLOSUCC', loc = 'cyt', prot = None), Parameter('t0_ADENYLOSUCC_cyt', 0))
Initial(met(name = 'ADENYLOSUCC', loc = 'per', prot = None), Parameter('t0_ADENYLOSUCC_per', 0))
Initial(met(name = 'ADENYLOSUCC', loc = 'ex', prot = None), Parameter('t0_ADENYLOSUCC_ex', 0))
Initial(met(name = 'ADP', loc = 'cyt', prot = None), Parameter('t0_ADP_cyt', 0))
Initial(met(name = 'ADP', loc = 'per', prot = None), Parameter('t0_ADP_per', 0))
Initial(met(name = 'ADP', loc = 'ex', prot = None), Parameter('t0_ADP_ex', 0))
Initial(met(name = 'AICAR', loc = 'cyt', prot = None), Parameter('t0_AICAR_cyt', 0))
Initial(met(name = 'AICAR', loc = 'per', prot = None), Parameter('t0_AICAR_per', 0))
Initial(met(name = 'AICAR', loc = 'ex', prot = None), Parameter('t0_AICAR_ex', 0))
Initial(met(name = 'ALLO_THR', loc = 'cyt', prot = None), Parameter('t0_ALLO_THR_cyt', 0))
Initial(met(name = 'ALLO_THR', loc = 'per', prot = None), Parameter('t0_ALLO_THR_per', 0))
Initial(met(name = 'ALLO_THR', loc = 'ex', prot = None), Parameter('t0_ALLO_THR_ex', 0))
Initial(met(name = 'AMINO_OXOBUT', loc = 'cyt', prot = None), Parameter('t0_AMINO_OXOBUT_cyt', 0))
Initial(met(name = 'AMINO_OXOBUT', loc = 'per', prot = None), Parameter('t0_AMINO_OXOBUT_per', 0))
Initial(met(name = 'AMINO_OXOBUT', loc = 'ex', prot = None), Parameter('t0_AMINO_OXOBUT_ex', 0))
Initial(met(name = 'AMMONIUM', loc = 'cyt', prot = None), Parameter('t0_AMMONIUM_cyt', 0))
Initial(met(name = 'AMMONIUM', loc = 'per', prot = None), Parameter('t0_AMMONIUM_per', 0))
Initial(met(name = 'AMMONIUM', loc = 'ex', prot = None), Parameter('t0_AMMONIUM_ex', 0))
Initial(met(name = 'AMP', loc = 'cyt', prot = None), Parameter('t0_AMP_cyt', 0))
Initial(met(name = 'AMP', loc = 'per', prot = None), Parameter('t0_AMP_per', 0))
Initial(met(name = 'AMP', loc = 'ex', prot = None), Parameter('t0_AMP_ex', 0))
Initial(met(name = 'ANTHRANILATE', loc = 'cyt', prot = None), Parameter('t0_ANTHRANILATE_cyt', 0))
Initial(met(name = 'ANTHRANILATE', loc = 'per', prot = None), Parameter('t0_ANTHRANILATE_per', 0))
Initial(met(name = 'ANTHRANILATE', loc = 'ex', prot = None), Parameter('t0_ANTHRANILATE_ex', 0))
Initial(met(name = 'ASN', loc = 'cyt', prot = None), Parameter('t0_ASN_cyt', 0))
Initial(met(name = 'ASN', loc = 'per', prot = None), Parameter('t0_ASN_per', 0))
Initial(met(name = 'ASN', loc = 'ex', prot = None), Parameter('t0_ASN_ex', 0))
Initial(met(name = 'ATP', loc = 'cyt', prot = None), Parameter('t0_ATP_cyt', 0))
Initial(met(name = 'ATP', loc = 'per', prot = None), Parameter('t0_ATP_per', 0))
Initial(met(name = 'ATP', loc = 'ex', prot = None), Parameter('t0_ATP_ex', 0))
Initial(met(name = 'Acceptor', loc = 'cyt', prot = None), Parameter('t0_Acceptor_cyt', 0))
Initial(met(name = 'Acceptor', loc = 'per', prot = None), Parameter('t0_Acceptor_per', 0))
Initial(met(name = 'Acceptor', loc = 'ex', prot = None), Parameter('t0_Acceptor_ex', 0))
Initial(met(name = 'Alcohols', loc = 'cyt', prot = None), Parameter('t0_Alcohols_cyt', 0))
Initial(met(name = 'Alcohols', loc = 'per', prot = None), Parameter('t0_Alcohols_per', 0))
Initial(met(name = 'Alcohols', loc = 'ex', prot = None), Parameter('t0_Alcohols_ex', 0))
Initial(met(name = 'Alpha_D_aldose_1_phosphates', loc = 'cyt', prot = None), Parameter('t0_Alpha_D_aldose_1_phosphates_cyt', 0))
Initial(met(name = 'Alpha_D_aldose_1_phosphates', loc = 'per', prot = None), Parameter('t0_Alpha_D_aldose_1_phosphates_per', 0))
Initial(met(name = 'Alpha_D_aldose_1_phosphates', loc = 'ex', prot = None), Parameter('t0_Alpha_D_aldose_1_phosphates_ex', 0))
Initial(met(name = 'Amino_Acids_20', loc = 'cyt', prot = None), Parameter('t0_Amino_Acids_20_cyt', 0))
Initial(met(name = 'Amino_Acids_20', loc = 'per', prot = None), Parameter('t0_Amino_Acids_20_per', 0))
Initial(met(name = 'Amino_Acids_20', loc = 'ex', prot = None), Parameter('t0_Amino_Acids_20_ex', 0))
Initial(met(name = 'Aromatic_Amino_Acids', loc = 'cyt', prot = None), Parameter('t0_Aromatic_Amino_Acids_cyt', 0))
Initial(met(name = 'Aromatic_Amino_Acids', loc = 'per', prot = None), Parameter('t0_Aromatic_Amino_Acids_per', 0))
Initial(met(name = 'Aromatic_Amino_Acids', loc = 'ex', prot = None), Parameter('t0_Aromatic_Amino_Acids_ex', 0))
Initial(met(name = 'Aromatic_Oxoacids', loc = 'cyt', prot = None), Parameter('t0_Aromatic_Oxoacids_cyt', 0))
Initial(met(name = 'Aromatic_Oxoacids', loc = 'per', prot = None), Parameter('t0_Aromatic_Oxoacids_per', 0))
Initial(met(name = 'Aromatic_Oxoacids', loc = 'ex', prot = None), Parameter('t0_Aromatic_Oxoacids_ex', 0))
Initial(met(name = 'CARBAMATE', loc = 'cyt', prot = None), Parameter('t0_CARBAMATE_cyt', 0))
Initial(met(name = 'CARBAMATE', loc = 'per', prot = None), Parameter('t0_CARBAMATE_per', 0))
Initial(met(name = 'CARBAMATE', loc = 'ex', prot = None), Parameter('t0_CARBAMATE_ex', 0))
Initial(met(name = 'CARBAMOYL_P', loc = 'cyt', prot = None), Parameter('t0_CARBAMOYL_P_cyt', 0))
Initial(met(name = 'CARBAMOYL_P', loc = 'per', prot = None), Parameter('t0_CARBAMOYL_P_per', 0))
Initial(met(name = 'CARBAMOYL_P', loc = 'ex', prot = None), Parameter('t0_CARBAMOYL_P_ex', 0))
Initial(met(name = 'CARBAMYUL_L_ASPARTATE', loc = 'cyt', prot = None), Parameter('t0_CARBAMYUL_L_ASPARTATE_cyt', 0))
Initial(met(name = 'CARBAMYUL_L_ASPARTATE', loc = 'per', prot = None), Parameter('t0_CARBAMYUL_L_ASPARTATE_per', 0))
Initial(met(name = 'CARBAMYUL_L_ASPARTATE', loc = 'ex', prot = None), Parameter('t0_CARBAMYUL_L_ASPARTATE_ex', 0))
Initial(met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None), Parameter('t0_CARBON_DIOXIDE_cyt', 0))
Initial(met(name = 'CARBON_DIOXIDE', loc = 'per', prot = None), Parameter('t0_CARBON_DIOXIDE_per', 0))
Initial(met(name = 'CARBON_DIOXIDE', loc = 'ex', prot = None), Parameter('t0_CARBON_DIOXIDE_ex', 0))
Initial(met(name = 'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P', loc = 'cyt', prot = None), Parameter('t0_CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P_cyt', 0))
Initial(met(name = 'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P', loc = 'per', prot = None), Parameter('t0_CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P_per', 0))
Initial(met(name = 'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P', loc = 'ex', prot = None), Parameter('t0_CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P_ex', 0))
Initial(met(name = 'CDP', loc = 'cyt', prot = None), Parameter('t0_CDP_cyt', 0))
Initial(met(name = 'CDP', loc = 'per', prot = None), Parameter('t0_CDP_per', 0))
Initial(met(name = 'CDP', loc = 'ex', prot = None), Parameter('t0_CDP_ex', 0))
Initial(met(name = 'CHOLINE', loc = 'cyt', prot = None), Parameter('t0_CHOLINE_cyt', 0))
Initial(met(name = 'CHOLINE', loc = 'per', prot = None), Parameter('t0_CHOLINE_per', 0))
Initial(met(name = 'CHOLINE', loc = 'ex', prot = None), Parameter('t0_CHOLINE_ex', 0))
Initial(met(name = 'CHORISMATE', loc = 'cyt', prot = None), Parameter('t0_CHORISMATE_cyt', 0))
Initial(met(name = 'CHORISMATE', loc = 'per', prot = None), Parameter('t0_CHORISMATE_per', 0))
Initial(met(name = 'CHORISMATE', loc = 'ex', prot = None), Parameter('t0_CHORISMATE_ex', 0))
Initial(met(name = 'CIS_ACONITATE', loc = 'cyt', prot = None), Parameter('t0_CIS_ACONITATE_cyt', 0))
Initial(met(name = 'CIS_ACONITATE', loc = 'per', prot = None), Parameter('t0_CIS_ACONITATE_per', 0))
Initial(met(name = 'CIS_ACONITATE', loc = 'ex', prot = None), Parameter('t0_CIS_ACONITATE_ex', 0))
Initial(met(name = 'CIT', loc = 'cyt', prot = None), Parameter('t0_CIT_cyt', 0))
Initial(met(name = 'CIT', loc = 'per', prot = None), Parameter('t0_CIT_per', 0))
Initial(met(name = 'CIT', loc = 'ex', prot = None), Parameter('t0_CIT_ex', 0))
Initial(met(name = 'CMP', loc = 'cyt', prot = None), Parameter('t0_CMP_cyt', 0))
Initial(met(name = 'CMP', loc = 'per', prot = None), Parameter('t0_CMP_per', 0))
Initial(met(name = 'CMP', loc = 'ex', prot = None), Parameter('t0_CMP_ex', 0))
Initial(met(name = 'CO_A', loc = 'cyt', prot = None), Parameter('t0_CO_A_cyt', 0))
Initial(met(name = 'CO_A', loc = 'per', prot = None), Parameter('t0_CO_A_per', 0))
Initial(met(name = 'CO_A', loc = 'ex', prot = None), Parameter('t0_CO_A_ex', 0))
Initial(met(name = 'CPD_1136', loc = 'cyt', prot = None), Parameter('t0_CPD_1136_cyt', 0))
Initial(met(name = 'CPD_1136', loc = 'per', prot = None), Parameter('t0_CPD_1136_per', 0))
Initial(met(name = 'CPD_1136', loc = 'ex', prot = None), Parameter('t0_CPD_1136_ex', 0))
Initial(met(name = 'CPD_12991', loc = 'cyt', prot = None), Parameter('t0_CPD_12991_cyt', 0))
Initial(met(name = 'CPD_12991', loc = 'per', prot = None), Parameter('t0_CPD_12991_per', 0))
Initial(met(name = 'CPD_12991', loc = 'ex', prot = None), Parameter('t0_CPD_12991_ex', 0))
Initial(met(name = 'CPD_1301', loc = 'cyt', prot = None), Parameter('t0_CPD_1301_cyt', 0))
Initial(met(name = 'CPD_1301', loc = 'per', prot = None), Parameter('t0_CPD_1301_per', 0))
Initial(met(name = 'CPD_1301', loc = 'ex', prot = None), Parameter('t0_CPD_1301_ex', 0))
Initial(met(name = 'CPD_1302', loc = 'cyt', prot = None), Parameter('t0_CPD_1302_cyt', 0))
Initial(met(name = 'CPD_1302', loc = 'per', prot = None), Parameter('t0_CPD_1302_per', 0))
Initial(met(name = 'CPD_1302', loc = 'ex', prot = None), Parameter('t0_CPD_1302_ex', 0))
Initial(met(name = 'CPD_13025', loc = 'cyt', prot = None), Parameter('t0_CPD_13025_cyt', 0))
Initial(met(name = 'CPD_13025', loc = 'per', prot = None), Parameter('t0_CPD_13025_per', 0))
Initial(met(name = 'CPD_13025', loc = 'ex', prot = None), Parameter('t0_CPD_13025_ex', 0))
Initial(met(name = 'CPD_13357', loc = 'cyt', prot = None), Parameter('t0_CPD_13357_cyt', 0))
Initial(met(name = 'CPD_13357', loc = 'per', prot = None), Parameter('t0_CPD_13357_per', 0))
Initial(met(name = 'CPD_13357', loc = 'ex', prot = None), Parameter('t0_CPD_13357_ex', 0))
Initial(met(name = 'CPD_13927', loc = 'cyt', prot = None), Parameter('t0_CPD_13927_cyt', 0))
Initial(met(name = 'CPD_13927', loc = 'per', prot = None), Parameter('t0_CPD_13927_per', 0))
Initial(met(name = 'CPD_13927', loc = 'ex', prot = None), Parameter('t0_CPD_13927_ex', 0))
Initial(met(name = 'CPD_13930', loc = 'cyt', prot = None), Parameter('t0_CPD_13930_cyt', 0))
Initial(met(name = 'CPD_13930', loc = 'per', prot = None), Parameter('t0_CPD_13930_per', 0))
Initial(met(name = 'CPD_13930', loc = 'ex', prot = None), Parameter('t0_CPD_13930_ex', 0))
Initial(met(name = 'CPD_14443', loc = 'cyt', prot = None), Parameter('t0_CPD_14443_cyt', 0))
Initial(met(name = 'CPD_14443', loc = 'per', prot = None), Parameter('t0_CPD_14443_per', 0))
Initial(met(name = 'CPD_14443', loc = 'ex', prot = None), Parameter('t0_CPD_14443_ex', 0))
Initial(met(name = 'CPD_14736', loc = 'cyt', prot = None), Parameter('t0_CPD_14736_cyt', 0))
Initial(met(name = 'CPD_14736', loc = 'per', prot = None), Parameter('t0_CPD_14736_per', 0))
Initial(met(name = 'CPD_14736', loc = 'ex', prot = None), Parameter('t0_CPD_14736_ex', 0))
Initial(met(name = 'CPD_15317', loc = 'cyt', prot = None), Parameter('t0_CPD_15317_cyt', 0))
Initial(met(name = 'CPD_15317', loc = 'per', prot = None), Parameter('t0_CPD_15317_per', 0))
Initial(met(name = 'CPD_15317', loc = 'ex', prot = None), Parameter('t0_CPD_15317_ex', 0))
Initial(met(name = 'CPD_15390', loc = 'cyt', prot = None), Parameter('t0_CPD_15390_cyt', 0))
Initial(met(name = 'CPD_15390', loc = 'per', prot = None), Parameter('t0_CPD_15390_per', 0))
Initial(met(name = 'CPD_15390', loc = 'ex', prot = None), Parameter('t0_CPD_15390_ex', 0))
Initial(met(name = 'CPD_15391', loc = 'cyt', prot = None), Parameter('t0_CPD_15391_cyt', 0))
Initial(met(name = 'CPD_15391', loc = 'per', prot = None), Parameter('t0_CPD_15391_per', 0))
Initial(met(name = 'CPD_15391', loc = 'ex', prot = None), Parameter('t0_CPD_15391_ex', 0))
Initial(met(name = 'CPD_15392', loc = 'cyt', prot = None), Parameter('t0_CPD_15392_cyt', 0))
Initial(met(name = 'CPD_15392', loc = 'per', prot = None), Parameter('t0_CPD_15392_per', 0))
Initial(met(name = 'CPD_15392', loc = 'ex', prot = None), Parameter('t0_CPD_15392_ex', 0))
Initial(met(name = 'CPD_15393', loc = 'cyt', prot = None), Parameter('t0_CPD_15393_cyt', 0))
Initial(met(name = 'CPD_15393', loc = 'per', prot = None), Parameter('t0_CPD_15393_per', 0))
Initial(met(name = 'CPD_15393', loc = 'ex', prot = None), Parameter('t0_CPD_15393_ex', 0))
Initial(met(name = 'CPD_15818', loc = 'cyt', prot = None), Parameter('t0_CPD_15818_cyt', 0))
Initial(met(name = 'CPD_15818', loc = 'per', prot = None), Parameter('t0_CPD_15818_per', 0))
Initial(met(name = 'CPD_15818', loc = 'ex', prot = None), Parameter('t0_CPD_15818_ex', 0))
Initial(met(name = 'CPD_16009', loc = 'cyt', prot = None), Parameter('t0_CPD_16009_cyt', 0))
Initial(met(name = 'CPD_16009', loc = 'per', prot = None), Parameter('t0_CPD_16009_per', 0))
Initial(met(name = 'CPD_16009', loc = 'ex', prot = None), Parameter('t0_CPD_16009_ex', 0))
Initial(met(name = 'CPD_16619', loc = 'cyt', prot = None), Parameter('t0_CPD_16619_cyt', 0))
Initial(met(name = 'CPD_16619', loc = 'per', prot = None), Parameter('t0_CPD_16619_per', 0))
Initial(met(name = 'CPD_16619', loc = 'ex', prot = None), Parameter('t0_CPD_16619_ex', 0))
Initial(met(name = 'CPD_194', loc = 'cyt', prot = None), Parameter('t0_CPD_194_cyt', 0))
Initial(met(name = 'CPD_194', loc = 'per', prot = None), Parameter('t0_CPD_194_per', 0))
Initial(met(name = 'CPD_194', loc = 'ex', prot = None), Parameter('t0_CPD_194_ex', 0))
Initial(met(name = 'CPD_239', loc = 'cyt', prot = None), Parameter('t0_CPD_239_cyt', 0))
Initial(met(name = 'CPD_239', loc = 'per', prot = None), Parameter('t0_CPD_239_per', 0))
Initial(met(name = 'CPD_239', loc = 'ex', prot = None), Parameter('t0_CPD_239_ex', 0))
Initial(met(name = 'CPD_2961', loc = 'cyt', prot = None), Parameter('t0_CPD_2961_cyt', 0))
Initial(met(name = 'CPD_2961', loc = 'per', prot = None), Parameter('t0_CPD_2961_per', 0))
Initial(met(name = 'CPD_2961', loc = 'ex', prot = None), Parameter('t0_CPD_2961_ex', 0))
Initial(met(name = 'CPD_3582', loc = 'cyt', prot = None), Parameter('t0_CPD_3582_cyt', 0))
Initial(met(name = 'CPD_3582', loc = 'per', prot = None), Parameter('t0_CPD_3582_per', 0))
Initial(met(name = 'CPD_3582', loc = 'ex', prot = None), Parameter('t0_CPD_3582_ex', 0))
Initial(met(name = 'CPD_3705', loc = 'cyt', prot = None), Parameter('t0_CPD_3705_cyt', 0))
Initial(met(name = 'CPD_3705', loc = 'per', prot = None), Parameter('t0_CPD_3705_per', 0))
Initial(met(name = 'CPD_3705', loc = 'ex', prot = None), Parameter('t0_CPD_3705_ex', 0))
Initial(met(name = 'CPD_3706', loc = 'cyt', prot = None), Parameter('t0_CPD_3706_cyt', 0))
Initial(met(name = 'CPD_3706', loc = 'per', prot = None), Parameter('t0_CPD_3706_per', 0))
Initial(met(name = 'CPD_3706', loc = 'ex', prot = None), Parameter('t0_CPD_3706_ex', 0))
Initial(met(name = 'CPD_3710', loc = 'cyt', prot = None), Parameter('t0_CPD_3710_cyt', 0))
Initial(met(name = 'CPD_3710', loc = 'per', prot = None), Parameter('t0_CPD_3710_per', 0))
Initial(met(name = 'CPD_3710', loc = 'ex', prot = None), Parameter('t0_CPD_3710_ex', 0))
Initial(met(name = 'CPD_3711', loc = 'cyt', prot = None), Parameter('t0_CPD_3711_cyt', 0))
Initial(met(name = 'CPD_3711', loc = 'per', prot = None), Parameter('t0_CPD_3711_per', 0))
Initial(met(name = 'CPD_3711', loc = 'ex', prot = None), Parameter('t0_CPD_3711_ex', 0))
Initial(met(name = 'CPD_3721', loc = 'cyt', prot = None), Parameter('t0_CPD_3721_cyt', 0))
Initial(met(name = 'CPD_3721', loc = 'per', prot = None), Parameter('t0_CPD_3721_per', 0))
Initial(met(name = 'CPD_3721', loc = 'ex', prot = None), Parameter('t0_CPD_3721_ex', 0))
Initial(met(name = 'CPD_3723', loc = 'cyt', prot = None), Parameter('t0_CPD_3723_cyt', 0))
Initial(met(name = 'CPD_3723', loc = 'per', prot = None), Parameter('t0_CPD_3723_per', 0))
Initial(met(name = 'CPD_3723', loc = 'ex', prot = None), Parameter('t0_CPD_3723_ex', 0))
Initial(met(name = 'CPD_3724', loc = 'cyt', prot = None), Parameter('t0_CPD_3724_cyt', 0))
Initial(met(name = 'CPD_3724', loc = 'per', prot = None), Parameter('t0_CPD_3724_per', 0))
Initial(met(name = 'CPD_3724', loc = 'ex', prot = None), Parameter('t0_CPD_3724_ex', 0))
Initial(met(name = 'CPD_3728', loc = 'cyt', prot = None), Parameter('t0_CPD_3728_cyt', 0))
Initial(met(name = 'CPD_3728', loc = 'per', prot = None), Parameter('t0_CPD_3728_per', 0))
Initial(met(name = 'CPD_3728', loc = 'ex', prot = None), Parameter('t0_CPD_3728_ex', 0))
Initial(met(name = 'CPD_381', loc = 'cyt', prot = None), Parameter('t0_CPD_381_cyt', 0))
Initial(met(name = 'CPD_381', loc = 'per', prot = None), Parameter('t0_CPD_381_per', 0))
Initial(met(name = 'CPD_381', loc = 'ex', prot = None), Parameter('t0_CPD_381_ex', 0))
Initial(met(name = 'CPD_4544', loc = 'cyt', prot = None), Parameter('t0_CPD_4544_cyt', 0))
Initial(met(name = 'CPD_4544', loc = 'per', prot = None), Parameter('t0_CPD_4544_per', 0))
Initial(met(name = 'CPD_4544', loc = 'ex', prot = None), Parameter('t0_CPD_4544_ex', 0))
Initial(met(name = 'CPD_469', loc = 'cyt', prot = None), Parameter('t0_CPD_469_cyt', 0))
Initial(met(name = 'CPD_469', loc = 'per', prot = None), Parameter('t0_CPD_469_per', 0))
Initial(met(name = 'CPD_469', loc = 'ex', prot = None), Parameter('t0_CPD_469_ex', 0))
Initial(met(name = 'CPD_476', loc = 'cyt', prot = None), Parameter('t0_CPD_476_cyt', 0))
Initial(met(name = 'CPD_476', loc = 'per', prot = None), Parameter('t0_CPD_476_per', 0))
Initial(met(name = 'CPD_476', loc = 'ex', prot = None), Parameter('t0_CPD_476_ex', 0))
Initial(met(name = 'CPD_536', loc = 'cyt', prot = None), Parameter('t0_CPD_536_cyt', 0))
Initial(met(name = 'CPD_536', loc = 'per', prot = None), Parameter('t0_CPD_536_per', 0))
Initial(met(name = 'CPD_536', loc = 'ex', prot = None), Parameter('t0_CPD_536_ex', 0))
Initial(met(name = 'CPD_606', loc = 'cyt', prot = None), Parameter('t0_CPD_606_cyt', 0))
Initial(met(name = 'CPD_606', loc = 'per', prot = None), Parameter('t0_CPD_606_per', 0))
Initial(met(name = 'CPD_606', loc = 'ex', prot = None), Parameter('t0_CPD_606_ex', 0))
Initial(met(name = 'CPD_618', loc = 'cyt', prot = None), Parameter('t0_CPD_618_cyt', 0))
Initial(met(name = 'CPD_618', loc = 'per', prot = None), Parameter('t0_CPD_618_per', 0))
Initial(met(name = 'CPD_618', loc = 'ex', prot = None), Parameter('t0_CPD_618_ex', 0))
Initial(met(name = 'CPD_66', loc = 'cyt', prot = None), Parameter('t0_CPD_66_cyt', 0))
Initial(met(name = 'CPD_66', loc = 'per', prot = None), Parameter('t0_CPD_66_per', 0))
Initial(met(name = 'CPD_66', loc = 'ex', prot = None), Parameter('t0_CPD_66_ex', 0))
Initial(met(name = 'CPD_660', loc = 'cyt', prot = None), Parameter('t0_CPD_660_cyt', 0))
Initial(met(name = 'CPD_660', loc = 'per', prot = None), Parameter('t0_CPD_660_per', 0))
Initial(met(name = 'CPD_660', loc = 'ex', prot = None), Parameter('t0_CPD_660_ex', 0))
Initial(met(name = 'CPD_67', loc = 'cyt', prot = None), Parameter('t0_CPD_67_cyt', 0))
Initial(met(name = 'CPD_67', loc = 'per', prot = None), Parameter('t0_CPD_67_per', 0))
Initial(met(name = 'CPD_67', loc = 'ex', prot = None), Parameter('t0_CPD_67_ex', 0))
Initial(met(name = 'CPD0_181', loc = 'cyt', prot = None), Parameter('t0_CPD0_181_cyt', 0))
Initial(met(name = 'CPD0_181', loc = 'per', prot = None), Parameter('t0_CPD0_181_per', 0))
Initial(met(name = 'CPD0_181', loc = 'ex', prot = None), Parameter('t0_CPD0_181_ex', 0))
Initial(met(name = 'CPD0_2189', loc = 'cyt', prot = None), Parameter('t0_CPD0_2189_cyt', 0))
Initial(met(name = 'CPD0_2189', loc = 'per', prot = None), Parameter('t0_CPD0_2189_per', 0))
Initial(met(name = 'CPD0_2189', loc = 'ex', prot = None), Parameter('t0_CPD0_2189_ex', 0))
Initial(met(name = 'CPD0_2331', loc = 'cyt', prot = None), Parameter('t0_CPD0_2331_cyt', 0))
Initial(met(name = 'CPD0_2331', loc = 'per', prot = None), Parameter('t0_CPD0_2331_per', 0))
Initial(met(name = 'CPD0_2331', loc = 'ex', prot = None), Parameter('t0_CPD0_2331_ex', 0))
Initial(met(name = 'CPD0_2338', loc = 'cyt', prot = None), Parameter('t0_CPD0_2338_cyt', 0))
Initial(met(name = 'CPD0_2338', loc = 'per', prot = None), Parameter('t0_CPD0_2338_per', 0))
Initial(met(name = 'CPD0_2338', loc = 'ex', prot = None), Parameter('t0_CPD0_2338_ex', 0))
Initial(met(name = 'CPD0_2339', loc = 'cyt', prot = None), Parameter('t0_CPD0_2339_cyt', 0))
Initial(met(name = 'CPD0_2339', loc = 'per', prot = None), Parameter('t0_CPD0_2339_per', 0))
Initial(met(name = 'CPD0_2339', loc = 'ex', prot = None), Parameter('t0_CPD0_2339_ex', 0))
Initial(met(name = 'CPD0_2340', loc = 'cyt', prot = None), Parameter('t0_CPD0_2340_cyt', 0))
Initial(met(name = 'CPD0_2340', loc = 'per', prot = None), Parameter('t0_CPD0_2340_per', 0))
Initial(met(name = 'CPD0_2340', loc = 'ex', prot = None), Parameter('t0_CPD0_2340_ex', 0))
Initial(met(name = 'CPD0_2461', loc = 'cyt', prot = None), Parameter('t0_CPD0_2461_cyt', 0))
Initial(met(name = 'CPD0_2461', loc = 'per', prot = None), Parameter('t0_CPD0_2461_per', 0))
Initial(met(name = 'CPD0_2461', loc = 'ex', prot = None), Parameter('t0_CPD0_2461_ex', 0))
Initial(met(name = 'CPD0_881', loc = 'cyt', prot = None), Parameter('t0_CPD0_881_cyt', 0))
Initial(met(name = 'CPD0_881', loc = 'per', prot = None), Parameter('t0_CPD0_881_per', 0))
Initial(met(name = 'CPD0_881', loc = 'ex', prot = None), Parameter('t0_CPD0_881_ex', 0))
Initial(met(name = 'CREATINE', loc = 'cyt', prot = None), Parameter('t0_CREATINE_cyt', 0))
Initial(met(name = 'CREATINE', loc = 'per', prot = None), Parameter('t0_CREATINE_per', 0))
Initial(met(name = 'CREATINE', loc = 'ex', prot = None), Parameter('t0_CREATINE_ex', 0))
Initial(met(name = 'CREATINE_P', loc = 'cyt', prot = None), Parameter('t0_CREATINE_P_cyt', 0))
Initial(met(name = 'CREATINE_P', loc = 'per', prot = None), Parameter('t0_CREATINE_P_per', 0))
Initial(met(name = 'CREATINE_P', loc = 'ex', prot = None), Parameter('t0_CREATINE_P_ex', 0))
Initial(met(name = 'CTP', loc = 'cyt', prot = None), Parameter('t0_CTP_cyt', 0))
Initial(met(name = 'CTP', loc = 'per', prot = None), Parameter('t0_CTP_per', 0))
Initial(met(name = 'CTP', loc = 'ex', prot = None), Parameter('t0_CTP_ex', 0))
Initial(met(name = 'CYS', loc = 'cyt', prot = None), Parameter('t0_CYS_cyt', 0))
Initial(met(name = 'CYS', loc = 'per', prot = None), Parameter('t0_CYS_per', 0))
Initial(met(name = 'CYS', loc = 'ex', prot = None), Parameter('t0_CYS_ex', 0))
Initial(met(name = 'CYTIDINE', loc = 'cyt', prot = None), Parameter('t0_CYTIDINE_cyt', 0))
Initial(met(name = 'CYTIDINE', loc = 'per', prot = None), Parameter('t0_CYTIDINE_per', 0))
Initial(met(name = 'CYTIDINE', loc = 'ex', prot = None), Parameter('t0_CYTIDINE_ex', 0))
Initial(met(name = 'CYTOSINE', loc = 'cyt', prot = None), Parameter('t0_CYTOSINE_cyt', 0))
Initial(met(name = 'CYTOSINE', loc = 'per', prot = None), Parameter('t0_CYTOSINE_per', 0))
Initial(met(name = 'CYTOSINE', loc = 'ex', prot = None), Parameter('t0_CYTOSINE_ex', 0))
Initial(met(name = 'D_6_P_GLUCONO_DELTA_LACTONE', loc = 'cyt', prot = None), Parameter('t0_D_6_P_GLUCONO_DELTA_LACTONE_cyt', 0))
Initial(met(name = 'D_6_P_GLUCONO_DELTA_LACTONE', loc = 'per', prot = None), Parameter('t0_D_6_P_GLUCONO_DELTA_LACTONE_per', 0))
Initial(met(name = 'D_6_P_GLUCONO_DELTA_LACTONE', loc = 'ex', prot = None), Parameter('t0_D_6_P_GLUCONO_DELTA_LACTONE_ex', 0))
Initial(met(name = 'D_ALANINE', loc = 'cyt', prot = None), Parameter('t0_D_ALANINE_cyt', 0))
Initial(met(name = 'D_ALANINE', loc = 'per', prot = None), Parameter('t0_D_ALANINE_per', 0))
Initial(met(name = 'D_ALANINE', loc = 'ex', prot = None), Parameter('t0_D_ALANINE_ex', 0))
Initial(met(name = 'D_ALLOSE_6_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_D_ALLOSE_6_PHOSPHATE_cyt', 0))
Initial(met(name = 'D_ALLOSE_6_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_D_ALLOSE_6_PHOSPHATE_per', 0))
Initial(met(name = 'D_ALLOSE_6_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_D_ALLOSE_6_PHOSPHATE_ex', 0))
Initial(met(name = 'D_ALLULOSE_6_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_D_ALLULOSE_6_PHOSPHATE_cyt', 0))
Initial(met(name = 'D_ALLULOSE_6_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_D_ALLULOSE_6_PHOSPHATE_per', 0))
Initial(met(name = 'D_ALLULOSE_6_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_D_ALLULOSE_6_PHOSPHATE_ex', 0))
Initial(met(name = 'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P', loc = 'cyt', prot = None), Parameter('t0_D_ERYTHRO_IMIDAZOLE_GLYCEROL_P_cyt', 0))
Initial(met(name = 'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P', loc = 'per', prot = None), Parameter('t0_D_ERYTHRO_IMIDAZOLE_GLYCEROL_P_per', 0))
Initial(met(name = 'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P', loc = 'ex', prot = None), Parameter('t0_D_ERYTHRO_IMIDAZOLE_GLYCEROL_P_ex', 0))
Initial(met(name = 'D_GLUCOSAMINE_6_P', loc = 'cyt', prot = None), Parameter('t0_D_GLUCOSAMINE_6_P_cyt', 0))
Initial(met(name = 'D_GLUCOSAMINE_6_P', loc = 'per', prot = None), Parameter('t0_D_GLUCOSAMINE_6_P_per', 0))
Initial(met(name = 'D_GLUCOSAMINE_6_P', loc = 'ex', prot = None), Parameter('t0_D_GLUCOSAMINE_6_P_ex', 0))
Initial(met(name = 'D_Ribofuranose', loc = 'cyt', prot = None), Parameter('t0_D_Ribofuranose_cyt', 0))
Initial(met(name = 'D_Ribofuranose', loc = 'per', prot = None), Parameter('t0_D_Ribofuranose_per', 0))
Initial(met(name = 'D_Ribofuranose', loc = 'ex', prot = None), Parameter('t0_D_Ribofuranose_ex', 0))
Initial(met(name = 'D_SEDOHEPTULOSE_1_7_P2', loc = 'cyt', prot = None), Parameter('t0_D_SEDOHEPTULOSE_1_7_P2_cyt', 0))
Initial(met(name = 'D_SEDOHEPTULOSE_1_7_P2', loc = 'per', prot = None), Parameter('t0_D_SEDOHEPTULOSE_1_7_P2_per', 0))
Initial(met(name = 'D_SEDOHEPTULOSE_1_7_P2', loc = 'ex', prot = None), Parameter('t0_D_SEDOHEPTULOSE_1_7_P2_ex', 0))
Initial(met(name = 'D_SEDOHEPTULOSE_7_P', loc = 'cyt', prot = None), Parameter('t0_D_SEDOHEPTULOSE_7_P_cyt', 0))
Initial(met(name = 'D_SEDOHEPTULOSE_7_P', loc = 'per', prot = None), Parameter('t0_D_SEDOHEPTULOSE_7_P_per', 0))
Initial(met(name = 'D_SEDOHEPTULOSE_7_P', loc = 'ex', prot = None), Parameter('t0_D_SEDOHEPTULOSE_7_P_ex', 0))
Initial(met(name = 'D_TARTRATE', loc = 'cyt', prot = None), Parameter('t0_D_TARTRATE_cyt', 0))
Initial(met(name = 'D_TARTRATE', loc = 'per', prot = None), Parameter('t0_D_TARTRATE_per', 0))
Initial(met(name = 'D_TARTRATE', loc = 'ex', prot = None), Parameter('t0_D_TARTRATE_ex', 0))
Initial(met(name = 'D_glucopyranose_6_phosphate', loc = 'cyt', prot = None), Parameter('t0_D_glucopyranose_6_phosphate_cyt', 0))
Initial(met(name = 'D_glucopyranose_6_phosphate', loc = 'per', prot = None), Parameter('t0_D_glucopyranose_6_phosphate_per', 0))
Initial(met(name = 'D_glucopyranose_6_phosphate', loc = 'ex', prot = None), Parameter('t0_D_glucopyranose_6_phosphate_ex', 0))
Initial(met(name = 'D_glucose_1_phosphates', loc = 'cyt', prot = None), Parameter('t0_D_glucose_1_phosphates_cyt', 0))
Initial(met(name = 'D_glucose_1_phosphates', loc = 'per', prot = None), Parameter('t0_D_glucose_1_phosphates_per', 0))
Initial(met(name = 'D_glucose_1_phosphates', loc = 'ex', prot = None), Parameter('t0_D_glucose_1_phosphates_ex', 0))
Initial(met(name = 'DADP', loc = 'cyt', prot = None), Parameter('t0_DADP_cyt', 0))
Initial(met(name = 'DADP', loc = 'per', prot = None), Parameter('t0_DADP_per', 0))
Initial(met(name = 'DADP', loc = 'ex', prot = None), Parameter('t0_DADP_ex', 0))
Initial(met(name = 'DAMP', loc = 'cyt', prot = None), Parameter('t0_DAMP_cyt', 0))
Initial(met(name = 'DAMP', loc = 'per', prot = None), Parameter('t0_DAMP_per', 0))
Initial(met(name = 'DAMP', loc = 'ex', prot = None), Parameter('t0_DAMP_ex', 0))
Initial(met(name = 'DATP', loc = 'cyt', prot = None), Parameter('t0_DATP_cyt', 0))
Initial(met(name = 'DATP', loc = 'per', prot = None), Parameter('t0_DATP_per', 0))
Initial(met(name = 'DATP', loc = 'ex', prot = None), Parameter('t0_DATP_ex', 0))
Initial(met(name = 'DCDP', loc = 'cyt', prot = None), Parameter('t0_DCDP_cyt', 0))
Initial(met(name = 'DCDP', loc = 'per', prot = None), Parameter('t0_DCDP_per', 0))
Initial(met(name = 'DCDP', loc = 'ex', prot = None), Parameter('t0_DCDP_ex', 0))
Initial(met(name = 'DCMP', loc = 'cyt', prot = None), Parameter('t0_DCMP_cyt', 0))
Initial(met(name = 'DCMP', loc = 'per', prot = None), Parameter('t0_DCMP_per', 0))
Initial(met(name = 'DCMP', loc = 'ex', prot = None), Parameter('t0_DCMP_ex', 0))
Initial(met(name = 'DCTP', loc = 'cyt', prot = None), Parameter('t0_DCTP_cyt', 0))
Initial(met(name = 'DCTP', loc = 'per', prot = None), Parameter('t0_DCTP_per', 0))
Initial(met(name = 'DCTP', loc = 'ex', prot = None), Parameter('t0_DCTP_ex', 0))
Initial(met(name = 'DEAMIDO_NAD', loc = 'cyt', prot = None), Parameter('t0_DEAMIDO_NAD_cyt', 0))
Initial(met(name = 'DEAMIDO_NAD', loc = 'per', prot = None), Parameter('t0_DEAMIDO_NAD_per', 0))
Initial(met(name = 'DEAMIDO_NAD', loc = 'ex', prot = None), Parameter('t0_DEAMIDO_NAD_ex', 0))
Initial(met(name = 'DEHYDROQUINATE', loc = 'cyt', prot = None), Parameter('t0_DEHYDROQUINATE_cyt', 0))
Initial(met(name = 'DEHYDROQUINATE', loc = 'per', prot = None), Parameter('t0_DEHYDROQUINATE_per', 0))
Initial(met(name = 'DEHYDROQUINATE', loc = 'ex', prot = None), Parameter('t0_DEHYDROQUINATE_ex', 0))
Initial(met(name = 'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE', loc = 'cyt', prot = None), Parameter('t0_DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_cyt', 0))
Initial(met(name = 'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE', loc = 'per', prot = None), Parameter('t0_DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_per', 0))
Initial(met(name = 'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE', loc = 'ex', prot = None), Parameter('t0_DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE_ex', 0))
Initial(met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_DEOXY_D_RIBOSE_1_PHOSPHATE_cyt', 0))
Initial(met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_DEOXY_D_RIBOSE_1_PHOSPHATE_per', 0))
Initial(met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_DEOXY_D_RIBOSE_1_PHOSPHATE_ex', 0))
Initial(met(name = 'DEOXY_RIBOSE_5P', loc = 'cyt', prot = None), Parameter('t0_DEOXY_RIBOSE_5P_cyt', 0))
Initial(met(name = 'DEOXY_RIBOSE_5P', loc = 'per', prot = None), Parameter('t0_DEOXY_RIBOSE_5P_per', 0))
Initial(met(name = 'DEOXY_RIBOSE_5P', loc = 'ex', prot = None), Parameter('t0_DEOXY_RIBOSE_5P_ex', 0))
Initial(met(name = 'DEOXYADENOSINE', loc = 'cyt', prot = None), Parameter('t0_DEOXYADENOSINE_cyt', 0))
Initial(met(name = 'DEOXYADENOSINE', loc = 'per', prot = None), Parameter('t0_DEOXYADENOSINE_per', 0))
Initial(met(name = 'DEOXYADENOSINE', loc = 'ex', prot = None), Parameter('t0_DEOXYADENOSINE_ex', 0))
Initial(met(name = 'DEOXYCYTIDINE', loc = 'cyt', prot = None), Parameter('t0_DEOXYCYTIDINE_cyt', 0))
Initial(met(name = 'DEOXYCYTIDINE', loc = 'per', prot = None), Parameter('t0_DEOXYCYTIDINE_per', 0))
Initial(met(name = 'DEOXYCYTIDINE', loc = 'ex', prot = None), Parameter('t0_DEOXYCYTIDINE_ex', 0))
Initial(met(name = 'DEOXYGUANOSINE', loc = 'cyt', prot = None), Parameter('t0_DEOXYGUANOSINE_cyt', 0))
Initial(met(name = 'DEOXYGUANOSINE', loc = 'per', prot = None), Parameter('t0_DEOXYGUANOSINE_per', 0))
Initial(met(name = 'DEOXYGUANOSINE', loc = 'ex', prot = None), Parameter('t0_DEOXYGUANOSINE_ex', 0))
Initial(met(name = 'DEOXYINOSINE', loc = 'cyt', prot = None), Parameter('t0_DEOXYINOSINE_cyt', 0))
Initial(met(name = 'DEOXYINOSINE', loc = 'per', prot = None), Parameter('t0_DEOXYINOSINE_per', 0))
Initial(met(name = 'DEOXYINOSINE', loc = 'ex', prot = None), Parameter('t0_DEOXYINOSINE_ex', 0))
Initial(met(name = 'DEOXYURIDINE', loc = 'cyt', prot = None), Parameter('t0_DEOXYURIDINE_cyt', 0))
Initial(met(name = 'DEOXYURIDINE', loc = 'per', prot = None), Parameter('t0_DEOXYURIDINE_per', 0))
Initial(met(name = 'DEOXYURIDINE', loc = 'ex', prot = None), Parameter('t0_DEOXYURIDINE_ex', 0))
Initial(met(name = 'DGDP', loc = 'cyt', prot = None), Parameter('t0_DGDP_cyt', 0))
Initial(met(name = 'DGDP', loc = 'per', prot = None), Parameter('t0_DGDP_per', 0))
Initial(met(name = 'DGDP', loc = 'ex', prot = None), Parameter('t0_DGDP_ex', 0))
Initial(met(name = 'DGMP', loc = 'cyt', prot = None), Parameter('t0_DGMP_cyt', 0))
Initial(met(name = 'DGMP', loc = 'per', prot = None), Parameter('t0_DGMP_per', 0))
Initial(met(name = 'DGMP', loc = 'ex', prot = None), Parameter('t0_DGMP_ex', 0))
Initial(met(name = 'DGTP', loc = 'cyt', prot = None), Parameter('t0_DGTP_cyt', 0))
Initial(met(name = 'DGTP', loc = 'per', prot = None), Parameter('t0_DGTP_per', 0))
Initial(met(name = 'DGTP', loc = 'ex', prot = None), Parameter('t0_DGTP_ex', 0))
Initial(met(name = 'DI_H_OROTATE', loc = 'cyt', prot = None), Parameter('t0_DI_H_OROTATE_cyt', 0))
Initial(met(name = 'DI_H_OROTATE', loc = 'per', prot = None), Parameter('t0_DI_H_OROTATE_per', 0))
Initial(met(name = 'DI_H_OROTATE', loc = 'ex', prot = None), Parameter('t0_DI_H_OROTATE_ex', 0))
Initial(met(name = 'DIHYDROFOLATE_GLU_N', loc = 'cyt', prot = None), Parameter('t0_DIHYDROFOLATE_GLU_N_cyt', 0))
Initial(met(name = 'DIHYDROFOLATE_GLU_N', loc = 'per', prot = None), Parameter('t0_DIHYDROFOLATE_GLU_N_per', 0))
Initial(met(name = 'DIHYDROFOLATE_GLU_N', loc = 'ex', prot = None), Parameter('t0_DIHYDROFOLATE_GLU_N_ex', 0))
Initial(met(name = 'DIHYDROLIPOYL_GCVH', loc = 'cyt', prot = None), Parameter('t0_DIHYDROLIPOYL_GCVH_cyt', 0))
Initial(met(name = 'DIHYDROLIPOYL_GCVH', loc = 'per', prot = None), Parameter('t0_DIHYDROLIPOYL_GCVH_per', 0))
Initial(met(name = 'DIHYDROLIPOYL_GCVH', loc = 'ex', prot = None), Parameter('t0_DIHYDROLIPOYL_GCVH_ex', 0))
Initial(met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_DIHYDROXY_ACETONE_PHOSPHATE_cyt', 0))
Initial(met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_DIHYDROXY_ACETONE_PHOSPHATE_per', 0))
Initial(met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_DIHYDROXY_ACETONE_PHOSPHATE_ex', 0))
Initial(met(name = 'DIHYDROXYACETONE', loc = 'cyt', prot = None), Parameter('t0_DIHYDROXYACETONE_cyt', 0))
Initial(met(name = 'DIHYDROXYACETONE', loc = 'per', prot = None), Parameter('t0_DIHYDROXYACETONE_per', 0))
Initial(met(name = 'DIHYDROXYACETONE', loc = 'ex', prot = None), Parameter('t0_DIHYDROXYACETONE_ex', 0))
Initial(met(name = 'DPG', loc = 'cyt', prot = None), Parameter('t0_DPG_cyt', 0))
Initial(met(name = 'DPG', loc = 'per', prot = None), Parameter('t0_DPG_per', 0))
Initial(met(name = 'DPG', loc = 'ex', prot = None), Parameter('t0_DPG_ex', 0))
Initial(met(name = 'DUDP', loc = 'cyt', prot = None), Parameter('t0_DUDP_cyt', 0))
Initial(met(name = 'DUDP', loc = 'per', prot = None), Parameter('t0_DUDP_per', 0))
Initial(met(name = 'DUDP', loc = 'ex', prot = None), Parameter('t0_DUDP_ex', 0))
Initial(met(name = 'DUMP', loc = 'cyt', prot = None), Parameter('t0_DUMP_cyt', 0))
Initial(met(name = 'DUMP', loc = 'per', prot = None), Parameter('t0_DUMP_per', 0))
Initial(met(name = 'DUMP', loc = 'ex', prot = None), Parameter('t0_DUMP_ex', 0))
Initial(met(name = 'DUTP', loc = 'cyt', prot = None), Parameter('t0_DUTP_cyt', 0))
Initial(met(name = 'DUTP', loc = 'per', prot = None), Parameter('t0_DUTP_per', 0))
Initial(met(name = 'DUTP', loc = 'ex', prot = None), Parameter('t0_DUTP_ex', 0))
Initial(met(name = 'Deoxy_Ribonucleoside_3P', loc = 'cyt', prot = None), Parameter('t0_Deoxy_Ribonucleoside_3P_cyt', 0))
Initial(met(name = 'Deoxy_Ribonucleoside_3P', loc = 'per', prot = None), Parameter('t0_Deoxy_Ribonucleoside_3P_per', 0))
Initial(met(name = 'Deoxy_Ribonucleoside_3P', loc = 'ex', prot = None), Parameter('t0_Deoxy_Ribonucleoside_3P_ex', 0))
Initial(met(name = 'Deoxy_Ribonucleoside_Monophosphates', loc = 'cyt', prot = None), Parameter('t0_Deoxy_Ribonucleoside_Monophosphates_cyt', 0))
Initial(met(name = 'Deoxy_Ribonucleoside_Monophosphates', loc = 'per', prot = None), Parameter('t0_Deoxy_Ribonucleoside_Monophosphates_per', 0))
Initial(met(name = 'Deoxy_Ribonucleoside_Monophosphates', loc = 'ex', prot = None), Parameter('t0_Deoxy_Ribonucleoside_Monophosphates_ex', 0))
Initial(met(name = 'Deoxy_Ribonucleoside_Triphosphates', loc = 'cyt', prot = None), Parameter('t0_Deoxy_Ribonucleoside_Triphosphates_cyt', 0))
Initial(met(name = 'Deoxy_Ribonucleoside_Triphosphates', loc = 'per', prot = None), Parameter('t0_Deoxy_Ribonucleoside_Triphosphates_per', 0))
Initial(met(name = 'Deoxy_Ribonucleoside_Triphosphates', loc = 'ex', prot = None), Parameter('t0_Deoxy_Ribonucleoside_Triphosphates_ex', 0))
Initial(met(name = 'Deoxy_Ribonucleosides', loc = 'cyt', prot = None), Parameter('t0_Deoxy_Ribonucleosides_cyt', 0))
Initial(met(name = 'Deoxy_Ribonucleosides', loc = 'per', prot = None), Parameter('t0_Deoxy_Ribonucleosides_per', 0))
Initial(met(name = 'Deoxy_Ribonucleosides', loc = 'ex', prot = None), Parameter('t0_Deoxy_Ribonucleosides_ex', 0))
Initial(met(name = 'Dihydro_Lipoyl_Proteins', loc = 'cyt', prot = None), Parameter('t0_Dihydro_Lipoyl_Proteins_cyt', 0))
Initial(met(name = 'Dihydro_Lipoyl_Proteins', loc = 'per', prot = None), Parameter('t0_Dihydro_Lipoyl_Proteins_per', 0))
Initial(met(name = 'Dihydro_Lipoyl_Proteins', loc = 'ex', prot = None), Parameter('t0_Dihydro_Lipoyl_Proteins_ex', 0))
Initial(met(name = 'Donor_H2', loc = 'cyt', prot = None), Parameter('t0_Donor_H2_cyt', 0))
Initial(met(name = 'Donor_H2', loc = 'per', prot = None), Parameter('t0_Donor_H2_per', 0))
Initial(met(name = 'Donor_H2', loc = 'ex', prot = None), Parameter('t0_Donor_H2_ex', 0))
Initial(met(name = 'ENOL_OXALOACETATE', loc = 'cyt', prot = None), Parameter('t0_ENOL_OXALOACETATE_cyt', 0))
Initial(met(name = 'ENOL_OXALOACETATE', loc = 'per', prot = None), Parameter('t0_ENOL_OXALOACETATE_per', 0))
Initial(met(name = 'ENOL_OXALOACETATE', loc = 'ex', prot = None), Parameter('t0_ENOL_OXALOACETATE_ex', 0))

Initial(met(name = 'ERYTHROSE_4P', loc = 'cyt', prot = None), Parameter('t0_ERYTHROSE_4P_cyt', 0))
Initial(met(name = 'ERYTHROSE_4P', loc = 'per', prot = None), Parameter('t0_ERYTHROSE_4P_per', 0))
Initial(met(name = 'ERYTHROSE_4P', loc = 'ex', prot = None), Parameter('t0_ERYTHROSE_4P_ex', 0))
Initial(met(name = 'ETHANOL_AMINE', loc = 'cyt', prot = None), Parameter('t0_ETHANOL_AMINE_cyt', 0))
Initial(met(name = 'ETHANOL_AMINE', loc = 'per', prot = None), Parameter('t0_ETHANOL_AMINE_per', 0))
Initial(met(name = 'ETHANOL_AMINE', loc = 'ex', prot = None), Parameter('t0_ETHANOL_AMINE_ex', 0))
Initial(met(name = 'ETR_Quinols', loc = 'cyt', prot = None), Parameter('t0_ETR_Quinols_cyt', 0))
Initial(met(name = 'ETR_Quinols', loc = 'per', prot = None), Parameter('t0_ETR_Quinols_per', 0))
Initial(met(name = 'ETR_Quinols', loc = 'ex', prot = None), Parameter('t0_ETR_Quinols_ex', 0))
Initial(met(name = 'ETR_Quinones', loc = 'cyt', prot = None), Parameter('t0_ETR_Quinones_cyt', 0))
Initial(met(name = 'ETR_Quinones', loc = 'per', prot = None), Parameter('t0_ETR_Quinones_per', 0))
Initial(met(name = 'ETR_Quinones', loc = 'ex', prot = None), Parameter('t0_ETR_Quinones_ex', 0))
Initial(met(name = 'FMN', loc = 'cyt', prot = None), Parameter('t0_FMN_cyt', 0))
Initial(met(name = 'FMN', loc = 'per', prot = None), Parameter('t0_FMN_per', 0))
Initial(met(name = 'FMN', loc = 'ex', prot = None), Parameter('t0_FMN_ex', 0))
Initial(met(name = 'FMNH2', loc = 'cyt', prot = None), Parameter('t0_FMNH2_cyt', 0))
Initial(met(name = 'FMNH2', loc = 'per', prot = None), Parameter('t0_FMNH2_per', 0))
Initial(met(name = 'FMNH2', loc = 'ex', prot = None), Parameter('t0_FMNH2_ex', 0))
Initial(met(name = 'FORMATE', loc = 'cyt', prot = None), Parameter('t0_FORMATE_cyt', 0))
Initial(met(name = 'FORMATE', loc = 'per', prot = None), Parameter('t0_FORMATE_per', 0))
Initial(met(name = 'FORMATE', loc = 'ex', prot = None), Parameter('t0_FORMATE_ex', 0))
Initial(met(name = 'FORMYL_THF_GLU_N', loc = 'cyt', prot = None), Parameter('t0_FORMYL_THF_GLU_N_cyt', 0))
Initial(met(name = 'FORMYL_THF_GLU_N', loc = 'per', prot = None), Parameter('t0_FORMYL_THF_GLU_N_per', 0))
Initial(met(name = 'FORMYL_THF_GLU_N', loc = 'ex', prot = None), Parameter('t0_FORMYL_THF_GLU_N_ex', 0))
Initial(met(name = 'FRUCTOSE_16_DIPHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_FRUCTOSE_16_DIPHOSPHATE_cyt', 0))
Initial(met(name = 'FRUCTOSE_16_DIPHOSPHATE', loc = 'per', prot = None), Parameter('t0_FRUCTOSE_16_DIPHOSPHATE_per', 0))
Initial(met(name = 'FRUCTOSE_16_DIPHOSPHATE', loc = 'ex', prot = None), Parameter('t0_FRUCTOSE_16_DIPHOSPHATE_ex', 0))
Initial(met(name = 'FRUCTOSE_6P', loc = 'cyt', prot = None), Parameter('t0_FRUCTOSE_6P_cyt', 0))
Initial(met(name = 'FRUCTOSE_6P', loc = 'per', prot = None), Parameter('t0_FRUCTOSE_6P_per', 0))
Initial(met(name = 'FRUCTOSE_6P', loc = 'ex', prot = None), Parameter('t0_FRUCTOSE_6P_ex', 0))
Initial(met(name = 'FUM', loc = 'cyt', prot = None), Parameter('t0_FUM_cyt', 0))
Initial(met(name = 'FUM', loc = 'per', prot = None), Parameter('t0_FUM_per', 0))
Initial(met(name = 'FUM', loc = 'ex', prot = None), Parameter('t0_FUM_ex', 0))
Initial(met(name = 'G3P', loc = 'cyt', prot = None), Parameter('t0_G3P_cyt', 0))
Initial(met(name = 'G3P', loc = 'per', prot = None), Parameter('t0_G3P_per', 0))
Initial(met(name = 'G3P', loc = 'ex', prot = None), Parameter('t0_G3P_ex', 0))
Initial(met(name = 'GAP', loc = 'cyt', prot = None), Parameter('t0_GAP_cyt', 0))
Initial(met(name = 'GAP', loc = 'per', prot = None), Parameter('t0_GAP_per', 0))
Initial(met(name = 'GAP', loc = 'ex', prot = None), Parameter('t0_GAP_ex', 0))
Initial(met(name = 'GDP', loc = 'cyt', prot = None), Parameter('t0_GDP_cyt', 0))
Initial(met(name = 'GDP', loc = 'per', prot = None), Parameter('t0_GDP_per', 0))
Initial(met(name = 'GDP', loc = 'ex', prot = None), Parameter('t0_GDP_ex', 0))
Initial(met(name = 'GLN', loc = 'cyt', prot = None), Parameter('t0_GLN_cyt', 0))
Initial(met(name = 'GLN', loc = 'per', prot = None), Parameter('t0_GLN_per', 0))
Initial(met(name = 'GLN', loc = 'ex', prot = None), Parameter('t0_GLN_ex', 0))
Initial(met(name = 'GLT', loc = 'cyt', prot = None), Parameter('t0_GLT_cyt', 0))
Initial(met(name = 'GLT', loc = 'per', prot = None), Parameter('t0_GLT_per', 0))
Initial(met(name = 'GLT', loc = 'ex', prot = None), Parameter('t0_GLT_ex', 0))
Initial(met(name = 'GLUCONATE', loc = 'cyt', prot = None), Parameter('t0_GLUCONATE_cyt', 0))
Initial(met(name = 'GLUCONATE', loc = 'per', prot = None), Parameter('t0_GLUCONATE_per', 0))
Initial(met(name = 'GLUCONATE', loc = 'ex', prot = None), Parameter('t0_GLUCONATE_ex', 0))
Initial(met(name = 'GLUCOSAMINE', loc = 'cyt', prot = None), Parameter('t0_GLUCOSAMINE_cyt', 0))
Initial(met(name = 'GLUCOSAMINE', loc = 'per', prot = None), Parameter('t0_GLUCOSAMINE_per', 0))
Initial(met(name = 'GLUCOSAMINE', loc = 'ex', prot = None), Parameter('t0_GLUCOSAMINE_ex', 0))
Initial(met(name = 'GLY', loc = 'cyt', prot = None), Parameter('t0_GLY_cyt', 0))
Initial(met(name = 'GLY', loc = 'per', prot = None), Parameter('t0_GLY_per', 0))
Initial(met(name = 'GLY', loc = 'ex', prot = None), Parameter('t0_GLY_ex', 0))
Initial(met(name = 'GLYCERALD', loc = 'cyt', prot = None), Parameter('t0_GLYCERALD_cyt', 0))
Initial(met(name = 'GLYCERALD', loc = 'per', prot = None), Parameter('t0_GLYCERALD_per', 0))
Initial(met(name = 'GLYCERALD', loc = 'ex', prot = None), Parameter('t0_GLYCERALD_ex', 0))
Initial(met(name = 'GLYCERATE', loc = 'cyt', prot = None), Parameter('t0_GLYCERATE_cyt', 0))
Initial(met(name = 'GLYCERATE', loc = 'per', prot = None), Parameter('t0_GLYCERATE_per', 0))
Initial(met(name = 'GLYCERATE', loc = 'ex', prot = None), Parameter('t0_GLYCERATE_ex', 0))
Initial(met(name = 'GLYCEROL', loc = 'cyt', prot = None), Parameter('t0_GLYCEROL_cyt', 0))
Initial(met(name = 'GLYCEROL', loc = 'per', prot = None), Parameter('t0_GLYCEROL_per', 0))
Initial(met(name = 'GLYCEROL', loc = 'ex', prot = None), Parameter('t0_GLYCEROL_ex', 0))
Initial(met(name = 'GLYCEROL_3P', loc = 'cyt', prot = None), Parameter('t0_GLYCEROL_3P_cyt', 0))
Initial(met(name = 'GLYCEROL_3P', loc = 'per', prot = None), Parameter('t0_GLYCEROL_3P_per', 0))
Initial(met(name = 'GLYCEROL_3P', loc = 'ex', prot = None), Parameter('t0_GLYCEROL_3P_ex', 0))
Initial(met(name = 'GLYCOLLATE', loc = 'cyt', prot = None), Parameter('t0_GLYCOLLATE_cyt', 0))
Initial(met(name = 'GLYCOLLATE', loc = 'per', prot = None), Parameter('t0_GLYCOLLATE_per', 0))
Initial(met(name = 'GLYCOLLATE', loc = 'ex', prot = None), Parameter('t0_GLYCOLLATE_ex', 0))
Initial(met(name = 'GLYOX', loc = 'cyt', prot = None), Parameter('t0_GLYOX_cyt', 0))
Initial(met(name = 'GLYOX', loc = 'per', prot = None), Parameter('t0_GLYOX_per', 0))
Initial(met(name = 'GLYOX', loc = 'ex', prot = None), Parameter('t0_GLYOX_ex', 0))
Initial(met(name = 'GMP', loc = 'cyt', prot = None), Parameter('t0_GMP_cyt', 0))
Initial(met(name = 'GMP', loc = 'per', prot = None), Parameter('t0_GMP_per', 0))
Initial(met(name = 'GMP', loc = 'ex', prot = None), Parameter('t0_GMP_ex', 0))
Initial(met(name = 'GTP', loc = 'cyt', prot = None), Parameter('t0_GTP_cyt', 0))
Initial(met(name = 'GTP', loc = 'per', prot = None), Parameter('t0_GTP_per', 0))
Initial(met(name = 'GTP', loc = 'ex', prot = None), Parameter('t0_GTP_ex', 0))
Initial(met(name = 'GUANINE', loc = 'cyt', prot = None), Parameter('t0_GUANINE_cyt', 0))
Initial(met(name = 'GUANINE', loc = 'per', prot = None), Parameter('t0_GUANINE_per', 0))
Initial(met(name = 'GUANINE', loc = 'ex', prot = None), Parameter('t0_GUANINE_ex', 0))
Initial(met(name = 'GUANOSINE', loc = 'cyt', prot = None), Parameter('t0_GUANOSINE_cyt', 0))
Initial(met(name = 'GUANOSINE', loc = 'per', prot = None), Parameter('t0_GUANOSINE_per', 0))
Initial(met(name = 'GUANOSINE', loc = 'ex', prot = None), Parameter('t0_GUANOSINE_ex', 0))
Initial(met(name = 'Glucopyranose', loc = 'cyt', prot = None), Parameter('t0_Glucopyranose_cyt', 0))
Initial(met(name = 'Glucopyranose', loc = 'per', prot = None), Parameter('t0_Glucopyranose_per', 0))
Initial(met(name = 'Glucopyranose', loc = 'ex', prot = None), Parameter('t0_Glucopyranose_ex', 0))
Initial(met(name = 'HCO3', loc = 'cyt', prot = None), Parameter('t0_HCO3_cyt', 0))
Initial(met(name = 'HCO3', loc = 'per', prot = None), Parameter('t0_HCO3_per', 0))
Initial(met(name = 'HCO3', loc = 'ex', prot = None), Parameter('t0_HCO3_ex', 0))
Initial(met(name = 'HIS', loc = 'cyt', prot = None), Parameter('t0_HIS_cyt', 0))
Initial(met(name = 'HIS', loc = 'per', prot = None), Parameter('t0_HIS_per', 0))
Initial(met(name = 'HIS', loc = 'ex', prot = None), Parameter('t0_HIS_ex', 0))
Initial(met(name = 'HISTIDINAL', loc = 'cyt', prot = None), Parameter('t0_HISTIDINAL_cyt', 0))
Initial(met(name = 'HISTIDINAL', loc = 'per', prot = None), Parameter('t0_HISTIDINAL_per', 0))
Initial(met(name = 'HISTIDINAL', loc = 'ex', prot = None), Parameter('t0_HISTIDINAL_ex', 0))
Initial(met(name = 'HISTIDINOL', loc = 'cyt', prot = None), Parameter('t0_HISTIDINOL_cyt', 0))
Initial(met(name = 'HISTIDINOL', loc = 'per', prot = None), Parameter('t0_HISTIDINOL_per', 0))
Initial(met(name = 'HISTIDINOL', loc = 'ex', prot = None), Parameter('t0_HISTIDINOL_ex', 0))
Initial(met(name = 'HOMO_CYS', loc = 'cyt', prot = None), Parameter('t0_HOMO_CYS_cyt', 0))
Initial(met(name = 'HOMO_CYS', loc = 'per', prot = None), Parameter('t0_HOMO_CYS_per', 0))
Initial(met(name = 'HOMO_CYS', loc = 'ex', prot = None), Parameter('t0_HOMO_CYS_ex', 0))
Initial(met(name = 'HOMO_SER', loc = 'cyt', prot = None), Parameter('t0_HOMO_SER_cyt', 0))
Initial(met(name = 'HOMO_SER', loc = 'per', prot = None), Parameter('t0_HOMO_SER_per', 0))
Initial(met(name = 'HOMO_SER', loc = 'ex', prot = None), Parameter('t0_HOMO_SER_ex', 0))
Initial(met(name = 'HS', loc = 'cyt', prot = None), Parameter('t0_HS_cyt', 0))
Initial(met(name = 'HS', loc = 'per', prot = None), Parameter('t0_HS_per', 0))
Initial(met(name = 'HS', loc = 'ex', prot = None), Parameter('t0_HS_ex', 0))
Initial(met(name = 'HYPOXANTHINE', loc = 'cyt', prot = None), Parameter('t0_HYPOXANTHINE_cyt', 0))
Initial(met(name = 'HYPOXANTHINE', loc = 'per', prot = None), Parameter('t0_HYPOXANTHINE_per', 0))
Initial(met(name = 'HYPOXANTHINE', loc = 'ex', prot = None), Parameter('t0_HYPOXANTHINE_ex', 0))
Initial(met(name = 'ILE', loc = 'cyt', prot = None), Parameter('t0_ILE_cyt', 0))
Initial(met(name = 'ILE', loc = 'per', prot = None), Parameter('t0_ILE_per', 0))
Initial(met(name = 'ILE', loc = 'ex', prot = None), Parameter('t0_ILE_ex', 0))
Initial(met(name = 'IMIDAZOLE_ACETOL_P', loc = 'cyt', prot = None), Parameter('t0_IMIDAZOLE_ACETOL_P_cyt', 0))
Initial(met(name = 'IMIDAZOLE_ACETOL_P', loc = 'per', prot = None), Parameter('t0_IMIDAZOLE_ACETOL_P_per', 0))
Initial(met(name = 'IMIDAZOLE_ACETOL_P', loc = 'ex', prot = None), Parameter('t0_IMIDAZOLE_ACETOL_P_ex', 0))
Initial(met(name = 'IMP', loc = 'cyt', prot = None), Parameter('t0_IMP_cyt', 0))
Initial(met(name = 'IMP', loc = 'per', prot = None), Parameter('t0_IMP_per', 0))
Initial(met(name = 'IMP', loc = 'ex', prot = None), Parameter('t0_IMP_ex', 0))
Initial(met(name = 'INDOLE', loc = 'cyt', prot = None), Parameter('t0_INDOLE_cyt', 0))
Initial(met(name = 'INDOLE', loc = 'per', prot = None), Parameter('t0_INDOLE_per', 0))
Initial(met(name = 'INDOLE', loc = 'ex', prot = None), Parameter('t0_INDOLE_ex', 0))
Initial(met(name = 'INDOLE_3_GLYCEROL_P', loc = 'cyt', prot = None), Parameter('t0_INDOLE_3_GLYCEROL_P_cyt', 0))
Initial(met(name = 'INDOLE_3_GLYCEROL_P', loc = 'per', prot = None), Parameter('t0_INDOLE_3_GLYCEROL_P_per', 0))
Initial(met(name = 'INDOLE_3_GLYCEROL_P', loc = 'ex', prot = None), Parameter('t0_INDOLE_3_GLYCEROL_P_ex', 0))
Initial(met(name = 'INOSINE', loc = 'cyt', prot = None), Parameter('t0_INOSINE_cyt', 0))
Initial(met(name = 'INOSINE', loc = 'per', prot = None), Parameter('t0_INOSINE_per', 0))
Initial(met(name = 'INOSINE', loc = 'ex', prot = None), Parameter('t0_INOSINE_ex', 0))
Initial(met(name = 'L_ALLO_THREONINE', loc = 'cyt', prot = None), Parameter('t0_L_ALLO_THREONINE_cyt', 0))
Initial(met(name = 'L_ALLO_THREONINE', loc = 'per', prot = None), Parameter('t0_L_ALLO_THREONINE_per', 0))
Initial(met(name = 'L_ALLO_THREONINE', loc = 'ex', prot = None), Parameter('t0_L_ALLO_THREONINE_ex', 0))
Initial(met(name = 'L_ASPARTATE', loc = 'cyt', prot = None), Parameter('t0_L_ASPARTATE_cyt', 0))
Initial(met(name = 'L_ASPARTATE', loc = 'per', prot = None), Parameter('t0_L_ASPARTATE_per', 0))
Initial(met(name = 'L_ASPARTATE', loc = 'ex', prot = None), Parameter('t0_L_ASPARTATE_ex', 0))
Initial(met(name = 'L_ASPARTATE_SEMIALDEHYDE', loc = 'cyt', prot = None), Parameter('t0_L_ASPARTATE_SEMIALDEHYDE_cyt', 0))
Initial(met(name = 'L_ASPARTATE_SEMIALDEHYDE', loc = 'per', prot = None), Parameter('t0_L_ASPARTATE_SEMIALDEHYDE_per', 0))
Initial(met(name = 'L_ASPARTATE_SEMIALDEHYDE', loc = 'ex', prot = None), Parameter('t0_L_ASPARTATE_SEMIALDEHYDE_ex', 0))
Initial(met(name = 'L_BETA_ASPARTYL_P', loc = 'cyt', prot = None), Parameter('t0_L_BETA_ASPARTYL_P_cyt', 0))
Initial(met(name = 'L_BETA_ASPARTYL_P', loc = 'per', prot = None), Parameter('t0_L_BETA_ASPARTYL_P_per', 0))
Initial(met(name = 'L_BETA_ASPARTYL_P', loc = 'ex', prot = None), Parameter('t0_L_BETA_ASPARTYL_P_ex', 0))
Initial(met(name = 'L_CYSTATHIONINE', loc = 'cyt', prot = None), Parameter('t0_L_CYSTATHIONINE_cyt', 0))
Initial(met(name = 'L_CYSTATHIONINE', loc = 'per', prot = None), Parameter('t0_L_CYSTATHIONINE_per', 0))
Initial(met(name = 'L_CYSTATHIONINE', loc = 'ex', prot = None), Parameter('t0_L_CYSTATHIONINE_ex', 0))
Initial(met(name = 'L_GLYCERALDEHYDE', loc = 'cyt', prot = None), Parameter('t0_L_GLYCERALDEHYDE_cyt', 0))
Initial(met(name = 'L_GLYCERALDEHYDE', loc = 'per', prot = None), Parameter('t0_L_GLYCERALDEHYDE_per', 0))
Initial(met(name = 'L_GLYCERALDEHYDE', loc = 'ex', prot = None), Parameter('t0_L_GLYCERALDEHYDE_ex', 0))
Initial(met(name = 'L_GLYCERALDEHYDE_3_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_L_GLYCERALDEHYDE_3_PHOSPHATE_cyt', 0))
Initial(met(name = 'L_GLYCERALDEHYDE_3_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_L_GLYCERALDEHYDE_3_PHOSPHATE_per', 0))
Initial(met(name = 'L_GLYCERALDEHYDE_3_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_L_GLYCERALDEHYDE_3_PHOSPHATE_ex', 0))
Initial(met(name = 'L_HISTIDINOL_P', loc = 'cyt', prot = None), Parameter('t0_L_HISTIDINOL_P_cyt', 0))
Initial(met(name = 'L_HISTIDINOL_P', loc = 'per', prot = None), Parameter('t0_L_HISTIDINOL_P_per', 0))
Initial(met(name = 'L_HISTIDINOL_P', loc = 'ex', prot = None), Parameter('t0_L_HISTIDINOL_P_ex', 0))
Initial(met(name = 'L_PANTOATE', loc = 'cyt', prot = None), Parameter('t0_L_PANTOATE_cyt', 0))
Initial(met(name = 'L_PANTOATE', loc = 'per', prot = None), Parameter('t0_L_PANTOATE_per', 0))
Initial(met(name = 'L_PANTOATE', loc = 'ex', prot = None), Parameter('t0_L_PANTOATE_ex', 0))
Initial(met(name = 'L_THREONINE_O_3_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_L_THREONINE_O_3_PHOSPHATE_cyt', 0))
Initial(met(name = 'L_THREONINE_O_3_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_L_THREONINE_O_3_PHOSPHATE_per', 0))
Initial(met(name = 'L_THREONINE_O_3_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_L_THREONINE_O_3_PHOSPHATE_ex', 0))
Initial(met(name = 'LEU', loc = 'cyt', prot = None), Parameter('t0_LEU_cyt', 0))
Initial(met(name = 'LEU', loc = 'per', prot = None), Parameter('t0_LEU_per', 0))
Initial(met(name = 'LEU', loc = 'ex', prot = None), Parameter('t0_LEU_ex', 0))
Initial(met(name = 'LL_DIAMINOPIMELATE', loc = 'cyt', prot = None), Parameter('t0_LL_DIAMINOPIMELATE_cyt', 0))
Initial(met(name = 'LL_DIAMINOPIMELATE', loc = 'per', prot = None), Parameter('t0_LL_DIAMINOPIMELATE_per', 0))
Initial(met(name = 'LL_DIAMINOPIMELATE', loc = 'ex', prot = None), Parameter('t0_LL_DIAMINOPIMELATE_ex', 0))
Initial(met(name = 'LYS', loc = 'cyt', prot = None), Parameter('t0_LYS_cyt', 0))
Initial(met(name = 'LYS', loc = 'per', prot = None), Parameter('t0_LYS_per', 0))
Initial(met(name = 'LYS', loc = 'ex', prot = None), Parameter('t0_LYS_ex', 0))
Initial(met(name = 'Lipoyl_Protein_N6_lipoyllysine', loc = 'cyt', prot = None), Parameter('t0_Lipoyl_Protein_N6_lipoyllysine_cyt', 0))
Initial(met(name = 'Lipoyl_Protein_N6_lipoyllysine', loc = 'per', prot = None), Parameter('t0_Lipoyl_Protein_N6_lipoyllysine_per', 0))
Initial(met(name = 'Lipoyl_Protein_N6_lipoyllysine', loc = 'ex', prot = None), Parameter('t0_Lipoyl_Protein_N6_lipoyllysine_ex', 0))
Initial(met(name = 'MAL', loc = 'cyt', prot = None), Parameter('t0_MAL_cyt', 0))
Initial(met(name = 'MAL', loc = 'per', prot = None), Parameter('t0_MAL_per', 0))
Initial(met(name = 'MAL', loc = 'ex', prot = None), Parameter('t0_MAL_ex', 0))
Initial(met(name = 'MALONATE_S_ALD', loc = 'cyt', prot = None), Parameter('t0_MALONATE_S_ALD_cyt', 0))
Initial(met(name = 'MALONATE_S_ALD', loc = 'per', prot = None), Parameter('t0_MALONATE_S_ALD_per', 0))
Initial(met(name = 'MALONATE_S_ALD', loc = 'ex', prot = None), Parameter('t0_MALONATE_S_ALD_ex', 0))
Initial(met(name = 'MANNOSE', loc = 'cyt', prot = None), Parameter('t0_MANNOSE_cyt', 0))
Initial(met(name = 'MANNOSE', loc = 'per', prot = None), Parameter('t0_MANNOSE_per', 0))
Initial(met(name = 'MANNOSE', loc = 'ex', prot = None), Parameter('t0_MANNOSE_ex', 0))
Initial(met(name = 'MANNOSE_1P', loc = 'cyt', prot = None), Parameter('t0_MANNOSE_1P_cyt', 0))
Initial(met(name = 'MANNOSE_1P', loc = 'per', prot = None), Parameter('t0_MANNOSE_1P_per', 0))
Initial(met(name = 'MANNOSE_1P', loc = 'ex', prot = None), Parameter('t0_MANNOSE_1P_ex', 0))
Initial(met(name = 'MESO_DIAMINOPIMELATE', loc = 'cyt', prot = None), Parameter('t0_MESO_DIAMINOPIMELATE_cyt', 0))
Initial(met(name = 'MESO_DIAMINOPIMELATE', loc = 'per', prot = None), Parameter('t0_MESO_DIAMINOPIMELATE_per', 0))
Initial(met(name = 'MESO_DIAMINOPIMELATE', loc = 'ex', prot = None), Parameter('t0_MESO_DIAMINOPIMELATE_ex', 0))
Initial(met(name = 'MET', loc = 'cyt', prot = None), Parameter('t0_MET_cyt', 0))
Initial(met(name = 'MET', loc = 'per', prot = None), Parameter('t0_MET_per', 0))
Initial(met(name = 'MET', loc = 'ex', prot = None), Parameter('t0_MET_ex', 0))
Initial(met(name = 'METHYLENE_THF_GLU_N', loc = 'cyt', prot = None), Parameter('t0_METHYLENE_THF_GLU_N_cyt', 0))
Initial(met(name = 'METHYLENE_THF_GLU_N', loc = 'per', prot = None), Parameter('t0_METHYLENE_THF_GLU_N_per', 0))
Initial(met(name = 'METHYLENE_THF_GLU_N', loc = 'ex', prot = None), Parameter('t0_METHYLENE_THF_GLU_N_ex', 0))
Initial(met(name = 'Mannose_6_phosphate', loc = 'cyt', prot = None), Parameter('t0_Mannose_6_phosphate_cyt', 0))
Initial(met(name = 'Mannose_6_phosphate', loc = 'per', prot = None), Parameter('t0_Mannose_6_phosphate_per', 0))
Initial(met(name = 'Mannose_6_phosphate', loc = 'ex', prot = None), Parameter('t0_Mannose_6_phosphate_ex', 0))
Initial(met(name = 'Menaquinols', loc = 'cyt', prot = None), Parameter('t0_Menaquinols_cyt', 0))
Initial(met(name = 'Menaquinols', loc = 'per', prot = None), Parameter('t0_Menaquinols_per', 0))
Initial(met(name = 'Menaquinols', loc = 'ex', prot = None), Parameter('t0_Menaquinols_ex', 0))
Initial(met(name = 'Menaquinones', loc = 'cyt', prot = None), Parameter('t0_Menaquinones_cyt', 0))
Initial(met(name = 'Menaquinones', loc = 'per', prot = None), Parameter('t0_Menaquinones_per', 0))
Initial(met(name = 'Menaquinones', loc = 'ex', prot = None), Parameter('t0_Menaquinones_ex', 0))
Initial(met(name = 'N_5_PHOSPHORIBOSYL_ANTHRANILATE', loc = 'cyt', prot = None), Parameter('t0_N_5_PHOSPHORIBOSYL_ANTHRANILATE_cyt', 0))
Initial(met(name = 'N_5_PHOSPHORIBOSYL_ANTHRANILATE', loc = 'per', prot = None), Parameter('t0_N_5_PHOSPHORIBOSYL_ANTHRANILATE_per', 0))
Initial(met(name = 'N_5_PHOSPHORIBOSYL_ANTHRANILATE', loc = 'ex', prot = None), Parameter('t0_N_5_PHOSPHORIBOSYL_ANTHRANILATE_ex', 0))
Initial(met(name = 'N_ALPHA_ACETYLORNITHINE', loc = 'cyt', prot = None), Parameter('t0_N_ALPHA_ACETYLORNITHINE_cyt', 0))
Initial(met(name = 'N_ALPHA_ACETYLORNITHINE', loc = 'per', prot = None), Parameter('t0_N_ALPHA_ACETYLORNITHINE_per', 0))
Initial(met(name = 'N_ALPHA_ACETYLORNITHINE', loc = 'ex', prot = None), Parameter('t0_N_ALPHA_ACETYLORNITHINE_ex', 0))
Initial(met(name = 'N_SUCCINYL_2_AMINO_6_KETOPIMELATE', loc = 'cyt', prot = None), Parameter('t0_N_SUCCINYL_2_AMINO_6_KETOPIMELATE_cyt', 0))
Initial(met(name = 'N_SUCCINYL_2_AMINO_6_KETOPIMELATE', loc = 'per', prot = None), Parameter('t0_N_SUCCINYL_2_AMINO_6_KETOPIMELATE_per', 0))
Initial(met(name = 'N_SUCCINYL_2_AMINO_6_KETOPIMELATE', loc = 'ex', prot = None), Parameter('t0_N_SUCCINYL_2_AMINO_6_KETOPIMELATE_ex', 0))
Initial(met(name = 'N_SUCCINYLLL_2_6_DIAMINOPIMELATE', loc = 'cyt', prot = None), Parameter('t0_N_SUCCINYLLL_2_6_DIAMINOPIMELATE_cyt', 0))
Initial(met(name = 'N_SUCCINYLLL_2_6_DIAMINOPIMELATE', loc = 'per', prot = None), Parameter('t0_N_SUCCINYLLL_2_6_DIAMINOPIMELATE_per', 0))
Initial(met(name = 'N_SUCCINYLLL_2_6_DIAMINOPIMELATE', loc = 'ex', prot = None), Parameter('t0_N_SUCCINYLLL_2_6_DIAMINOPIMELATE_ex', 0))
Initial(met(name = 'N5_Formyl_THF_Glu_N', loc = 'cyt', prot = None), Parameter('t0_N5_Formyl_THF_Glu_N_cyt', 0))
Initial(met(name = 'N5_Formyl_THF_Glu_N', loc = 'per', prot = None), Parameter('t0_N5_Formyl_THF_Glu_N_per', 0))
Initial(met(name = 'N5_Formyl_THF_Glu_N', loc = 'ex', prot = None), Parameter('t0_N5_Formyl_THF_Glu_N_ex', 0))
Initial(met(name = 'NACMUR', loc = 'cyt', prot = None), Parameter('t0_NACMUR_cyt', 0))
Initial(met(name = 'NACMUR', loc = 'per', prot = None), Parameter('t0_NACMUR_per', 0))
Initial(met(name = 'NACMUR', loc = 'ex', prot = None), Parameter('t0_NACMUR_ex', 0))
Initial(met(name = 'NAD', loc = 'cyt', prot = None), Parameter('t0_NAD_cyt', 0))
Initial(met(name = 'NAD', loc = 'per', prot = None), Parameter('t0_NAD_per', 0))
Initial(met(name = 'NAD', loc = 'ex', prot = None), Parameter('t0_NAD_ex', 0))
Initial(met(name = 'NAD_P_OR_NOP', loc = 'cyt', prot = None), Parameter('t0_NAD_P_OR_NOP_cyt', 0))
Initial(met(name = 'NAD_P_OR_NOP', loc = 'per', prot = None), Parameter('t0_NAD_P_OR_NOP_per', 0))
Initial(met(name = 'NAD_P_OR_NOP', loc = 'ex', prot = None), Parameter('t0_NAD_P_OR_NOP_ex', 0))
Initial(met(name = 'NADH', loc = 'cyt', prot = None), Parameter('t0_NADH_cyt', 0))
Initial(met(name = 'NADH', loc = 'per', prot = None), Parameter('t0_NADH_per', 0))
Initial(met(name = 'NADH', loc = 'ex', prot = None), Parameter('t0_NADH_ex', 0))
Initial(met(name = 'NADH_P_OR_NOP', loc = 'cyt', prot = None), Parameter('t0_NADH_P_OR_NOP_cyt', 0))
Initial(met(name = 'NADH_P_OR_NOP', loc = 'per', prot = None), Parameter('t0_NADH_P_OR_NOP_per', 0))
Initial(met(name = 'NADH_P_OR_NOP', loc = 'ex', prot = None), Parameter('t0_NADH_P_OR_NOP_ex', 0))
Initial(met(name = 'NADP', loc = 'cyt', prot = None), Parameter('t0_NADP_cyt', 0))
Initial(met(name = 'NADP', loc = 'per', prot = None), Parameter('t0_NADP_per', 0))
Initial(met(name = 'NADP', loc = 'ex', prot = None), Parameter('t0_NADP_ex', 0))
Initial(met(name = 'NADPH', loc = 'cyt', prot = None), Parameter('t0_NADPH_cyt', 0))
Initial(met(name = 'NADPH', loc = 'per', prot = None), Parameter('t0_NADPH_per', 0))
Initial(met(name = 'NADPH', loc = 'ex', prot = None), Parameter('t0_NADPH_ex', 0))
Initial(met(name = 'NIACINAMIDE', loc = 'cyt', prot = None), Parameter('t0_NIACINAMIDE_cyt', 0))
Initial(met(name = 'NIACINAMIDE', loc = 'per', prot = None), Parameter('t0_NIACINAMIDE_per', 0))
Initial(met(name = 'NIACINAMIDE', loc = 'ex', prot = None), Parameter('t0_NIACINAMIDE_ex', 0))
Initial(met(name = 'NIACINE', loc = 'cyt', prot = None), Parameter('t0_NIACINE_cyt', 0))
Initial(met(name = 'NIACINE', loc = 'per', prot = None), Parameter('t0_NIACINE_per', 0))
Initial(met(name = 'NIACINE', loc = 'ex', prot = None), Parameter('t0_NIACINE_ex', 0))
Initial(met(name = 'NICOTINAMIDE_NUCLEOTIDE', loc = 'cyt', prot = None), Parameter('t0_NICOTINAMIDE_NUCLEOTIDE_cyt', 0))
Initial(met(name = 'NICOTINAMIDE_NUCLEOTIDE', loc = 'per', prot = None), Parameter('t0_NICOTINAMIDE_NUCLEOTIDE_per', 0))
Initial(met(name = 'NICOTINAMIDE_NUCLEOTIDE', loc = 'ex', prot = None), Parameter('t0_NICOTINAMIDE_NUCLEOTIDE_ex', 0))
Initial(met(name = 'NICOTINAMIDE_RIBOSE', loc = 'cyt', prot = None), Parameter('t0_NICOTINAMIDE_RIBOSE_cyt', 0))
Initial(met(name = 'NICOTINAMIDE_RIBOSE', loc = 'per', prot = None), Parameter('t0_NICOTINAMIDE_RIBOSE_per', 0))
Initial(met(name = 'NICOTINAMIDE_RIBOSE', loc = 'ex', prot = None), Parameter('t0_NICOTINAMIDE_RIBOSE_ex', 0))
Initial(met(name = 'NICOTINATE_NUCLEOTIDE', loc = 'cyt', prot = None), Parameter('t0_NICOTINATE_NUCLEOTIDE_cyt', 0))
Initial(met(name = 'NICOTINATE_NUCLEOTIDE', loc = 'per', prot = None), Parameter('t0_NICOTINATE_NUCLEOTIDE_per', 0))
Initial(met(name = 'NICOTINATE_NUCLEOTIDE', loc = 'ex', prot = None), Parameter('t0_NICOTINATE_NUCLEOTIDE_ex', 0))
Initial(met(name = 'Nucleoside_Diphosphates', loc = 'cyt', prot = None), Parameter('t0_Nucleoside_Diphosphates_cyt', 0))
Initial(met(name = 'Nucleoside_Diphosphates', loc = 'per', prot = None), Parameter('t0_Nucleoside_Diphosphates_per', 0))
Initial(met(name = 'Nucleoside_Diphosphates', loc = 'ex', prot = None), Parameter('t0_Nucleoside_Diphosphates_ex', 0))
Initial(met(name = 'Nucleoside_Monophosphates', loc = 'cyt', prot = None), Parameter('t0_Nucleoside_Monophosphates_cyt', 0))
Initial(met(name = 'Nucleoside_Monophosphates', loc = 'per', prot = None), Parameter('t0_Nucleoside_Monophosphates_per', 0))
Initial(met(name = 'Nucleoside_Monophosphates', loc = 'ex', prot = None), Parameter('t0_Nucleoside_Monophosphates_ex', 0))
Initial(met(name = 'Nucleoside_Triphosphates', loc = 'cyt', prot = None), Parameter('t0_Nucleoside_Triphosphates_cyt', 0))
Initial(met(name = 'Nucleoside_Triphosphates', loc = 'per', prot = None), Parameter('t0_Nucleoside_Triphosphates_per', 0))
Initial(met(name = 'Nucleoside_Triphosphates', loc = 'ex', prot = None), Parameter('t0_Nucleoside_Triphosphates_ex', 0))
Initial(met(name = 'Nucleosides', loc = 'cyt', prot = None), Parameter('t0_Nucleosides_cyt', 0))
Initial(met(name = 'Nucleosides', loc = 'per', prot = None), Parameter('t0_Nucleosides_per', 0))
Initial(met(name = 'Nucleosides', loc = 'ex', prot = None), Parameter('t0_Nucleosides_ex', 0))
Initial(met(name = 'O_PHOSPHO_L_HOMOSERINE', loc = 'cyt', prot = None), Parameter('t0_O_PHOSPHO_L_HOMOSERINE_cyt', 0))
Initial(met(name = 'O_PHOSPHO_L_HOMOSERINE', loc = 'per', prot = None), Parameter('t0_O_PHOSPHO_L_HOMOSERINE_per', 0))
Initial(met(name = 'O_PHOSPHO_L_HOMOSERINE', loc = 'ex', prot = None), Parameter('t0_O_PHOSPHO_L_HOMOSERINE_ex', 0))
Initial(met(name = 'O_SUCCINYL_L_HOMOSERINE', loc = 'cyt', prot = None), Parameter('t0_O_SUCCINYL_L_HOMOSERINE_cyt', 0))
Initial(met(name = 'O_SUCCINYL_L_HOMOSERINE', loc = 'per', prot = None), Parameter('t0_O_SUCCINYL_L_HOMOSERINE_per', 0))
Initial(met(name = 'O_SUCCINYL_L_HOMOSERINE', loc = 'ex', prot = None), Parameter('t0_O_SUCCINYL_L_HOMOSERINE_ex', 0))
Initial(met(name = 'OROTATE', loc = 'cyt', prot = None), Parameter('t0_OROTATE_cyt', 0))
Initial(met(name = 'OROTATE', loc = 'per', prot = None), Parameter('t0_OROTATE_per', 0))
Initial(met(name = 'OROTATE', loc = 'ex', prot = None), Parameter('t0_OROTATE_ex', 0))
Initial(met(name = 'OROTIDINE_5_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_OROTIDINE_5_PHOSPHATE_cyt', 0))
Initial(met(name = 'OROTIDINE_5_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_OROTIDINE_5_PHOSPHATE_per', 0))
Initial(met(name = 'OROTIDINE_5_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_OROTIDINE_5_PHOSPHATE_ex', 0))
Initial(met(name = 'OXALACETIC_ACID', loc = 'cyt', prot = None), Parameter('t0_OXALACETIC_ACID_cyt', 0))
Initial(met(name = 'OXALACETIC_ACID', loc = 'per', prot = None), Parameter('t0_OXALACETIC_ACID_per', 0))
Initial(met(name = 'OXALACETIC_ACID', loc = 'ex', prot = None), Parameter('t0_OXALACETIC_ACID_ex', 0))
Initial(met(name = 'OXYGEN_MOLECULE', loc = 'cyt', prot = None), Parameter('t0_OXYGEN_MOLECULE_cyt', 0))
Initial(met(name = 'OXYGEN_MOLECULE', loc = 'per', prot = None), Parameter('t0_OXYGEN_MOLECULE_per', 0))
Initial(met(name = 'OXYGEN_MOLECULE', loc = 'ex', prot = None), Parameter('t0_OXYGEN_MOLECULE_ex', 0))
Initial(met(name = 'Orthophosphoric_Monoesters', loc = 'cyt', prot = None), Parameter('t0_Orthophosphoric_Monoesters_cyt', 0))
Initial(met(name = 'Orthophosphoric_Monoesters', loc = 'per', prot = None), Parameter('t0_Orthophosphoric_Monoesters_per', 0))
Initial(met(name = 'Orthophosphoric_Monoesters', loc = 'ex', prot = None), Parameter('t0_Orthophosphoric_Monoesters_ex', 0))
Initial(met(name = 'Oxo_glutarate_dehydro_suc_DH_lipoyl', loc = 'cyt', prot = None), Parameter('t0_Oxo_glutarate_dehydro_suc_DH_lipoyl_cyt', 0))
Initial(met(name = 'Oxo_glutarate_dehydro_suc_DH_lipoyl', loc = 'per', prot = None), Parameter('t0_Oxo_glutarate_dehydro_suc_DH_lipoyl_per', 0))
Initial(met(name = 'Oxo_glutarate_dehydro_suc_DH_lipoyl', loc = 'ex', prot = None), Parameter('t0_Oxo_glutarate_dehydro_suc_DH_lipoyl_ex', 0))
Initial(met(name = 'Oxo_glutarate_dehydrogenase_DH_lipoyl', loc = 'cyt', prot = None), Parameter('t0_Oxo_glutarate_dehydrogenase_DH_lipoyl_cyt', 0))
Initial(met(name = 'Oxo_glutarate_dehydrogenase_DH_lipoyl', loc = 'per', prot = None), Parameter('t0_Oxo_glutarate_dehydrogenase_DH_lipoyl_per', 0))
Initial(met(name = 'Oxo_glutarate_dehydrogenase_DH_lipoyl', loc = 'ex', prot = None), Parameter('t0_Oxo_glutarate_dehydrogenase_DH_lipoyl_ex', 0))
Initial(met(name = 'Oxo_glutarate_dehydrogenase_lipoyl', loc = 'cyt', prot = None), Parameter('t0_Oxo_glutarate_dehydrogenase_lipoyl_cyt', 0))
Initial(met(name = 'Oxo_glutarate_dehydrogenase_lipoyl', loc = 'per', prot = None), Parameter('t0_Oxo_glutarate_dehydrogenase_lipoyl_per', 0))
Initial(met(name = 'Oxo_glutarate_dehydrogenase_lipoyl', loc = 'ex', prot = None), Parameter('t0_Oxo_glutarate_dehydrogenase_lipoyl_ex', 0))
Initial(met(name = 'P_HYDROXY_PHENYLPYRUVATE', loc = 'cyt', prot = None), Parameter('t0_P_HYDROXY_PHENYLPYRUVATE_cyt', 0))
Initial(met(name = 'P_HYDROXY_PHENYLPYRUVATE', loc = 'per', prot = None), Parameter('t0_P_HYDROXY_PHENYLPYRUVATE_per', 0))
Initial(met(name = 'P_HYDROXY_PHENYLPYRUVATE', loc = 'ex', prot = None), Parameter('t0_P_HYDROXY_PHENYLPYRUVATE_ex', 0))
Initial(met(name = 'P_NITROPHENOL', loc = 'cyt', prot = None), Parameter('t0_P_NITROPHENOL_cyt', 0))
Initial(met(name = 'P_NITROPHENOL', loc = 'per', prot = None), Parameter('t0_P_NITROPHENOL_per', 0))
Initial(met(name = 'P_NITROPHENOL', loc = 'ex', prot = None), Parameter('t0_P_NITROPHENOL_ex', 0))
Initial(met(name = 'P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE', loc = 'cyt', prot = None), Parameter('t0_P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE_cyt', 0))
Initial(met(name = 'P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE', loc = 'per', prot = None), Parameter('t0_P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE_per', 0))
Initial(met(name = 'P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE', loc = 'ex', prot = None), Parameter('t0_P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE_ex', 0))
Initial(met(name = 'P3I', loc = 'cyt', prot = None), Parameter('t0_P3I_cyt', 0))
Initial(met(name = 'P3I', loc = 'per', prot = None), Parameter('t0_P3I_per', 0))
Initial(met(name = 'P3I', loc = 'ex', prot = None), Parameter('t0_P3I_ex', 0))
Initial(met(name = 'PHE', loc = 'cyt', prot = None), Parameter('t0_PHE_cyt', 0))
Initial(met(name = 'PHE', loc = 'per', prot = None), Parameter('t0_PHE_per', 0))
Initial(met(name = 'PHE', loc = 'ex', prot = None), Parameter('t0_PHE_ex', 0))
Initial(met(name = 'PHENYL_PYRUVATE', loc = 'cyt', prot = None), Parameter('t0_PHENYL_PYRUVATE_cyt', 0))
Initial(met(name = 'PHENYL_PYRUVATE', loc = 'per', prot = None), Parameter('t0_PHENYL_PYRUVATE_per', 0))
Initial(met(name = 'PHENYL_PYRUVATE', loc = 'ex', prot = None), Parameter('t0_PHENYL_PYRUVATE_ex', 0))
Initial(met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'cyt', prot = None), Parameter('t0_PHOSPHO_ENOL_PYRUVATE_cyt', 0))
Initial(met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'per', prot = None), Parameter('t0_PHOSPHO_ENOL_PYRUVATE_per', 0))
Initial(met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'ex', prot = None), Parameter('t0_PHOSPHO_ENOL_PYRUVATE_ex', 0))
Initial(met(name = 'PHOSPHORIBOSYL_AMP', loc = 'cyt', prot = None), Parameter('t0_PHOSPHORIBOSYL_AMP_cyt', 0))
Initial(met(name = 'PHOSPHORIBOSYL_AMP', loc = 'per', prot = None), Parameter('t0_PHOSPHORIBOSYL_AMP_per', 0))
Initial(met(name = 'PHOSPHORIBOSYL_AMP', loc = 'ex', prot = None), Parameter('t0_PHOSPHORIBOSYL_AMP_ex', 0))
Initial(met(name = 'PHOSPHORIBOSYL_ATP', loc = 'cyt', prot = None), Parameter('t0_PHOSPHORIBOSYL_ATP_cyt', 0))
Initial(met(name = 'PHOSPHORIBOSYL_ATP', loc = 'per', prot = None), Parameter('t0_PHOSPHORIBOSYL_ATP_per', 0))
Initial(met(name = 'PHOSPHORIBOSYL_ATP', loc = 'ex', prot = None), Parameter('t0_PHOSPHORIBOSYL_ATP_ex', 0))
Initial(met(name = 'PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE', loc = 'cyt', prot = None), Parameter('t0_PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE_cyt', 0))
Initial(met(name = 'PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE', loc = 'per', prot = None), Parameter('t0_PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE_per', 0))
Initial(met(name = 'PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE', loc = 'ex', prot = None), Parameter('t0_PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE_ex', 0))
Initial(met(name = 'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE', loc = 'cyt', prot = None), Parameter('t0_PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE_cyt', 0))
Initial(met(name = 'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE', loc = 'per', prot = None), Parameter('t0_PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE_per', 0))
Initial(met(name = 'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE', loc = 'ex', prot = None), Parameter('t0_PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE_ex', 0))
Initial(met(name = 'PHOSPHORIBOSYL_FORMIMINO_AICAR_P', loc = 'cyt', prot = None), Parameter('t0_PHOSPHORIBOSYL_FORMIMINO_AICAR_P_cyt', 0))
Initial(met(name = 'PHOSPHORIBOSYL_FORMIMINO_AICAR_P', loc = 'per', prot = None), Parameter('t0_PHOSPHORIBOSYL_FORMIMINO_AICAR_P_per', 0))
Initial(met(name = 'PHOSPHORIBOSYL_FORMIMINO_AICAR_P', loc = 'ex', prot = None), Parameter('t0_PHOSPHORIBOSYL_FORMIMINO_AICAR_P_ex', 0))
Initial(met(name = 'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P', loc = 'cyt', prot = None), Parameter('t0_PHOSPHORIBULOSYL_FORMIMINO_AICAR_P_cyt', 0))
Initial(met(name = 'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P', loc = 'per', prot = None), Parameter('t0_PHOSPHORIBULOSYL_FORMIMINO_AICAR_P_per', 0))
Initial(met(name = 'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P', loc = 'ex', prot = None), Parameter('t0_PHOSPHORIBULOSYL_FORMIMINO_AICAR_P_ex', 0))
Initial(met(name = 'PHOSPHORYL_CHOLINE', loc = 'cyt', prot = None), Parameter('t0_PHOSPHORYL_CHOLINE_cyt', 0))
Initial(met(name = 'PHOSPHORYL_CHOLINE', loc = 'per', prot = None), Parameter('t0_PHOSPHORYL_CHOLINE_per', 0))
Initial(met(name = 'PHOSPHORYL_CHOLINE', loc = 'ex', prot = None), Parameter('t0_PHOSPHORYL_CHOLINE_ex', 0))
Initial(met(name = 'PHOSPHORYL_ETHANOLAMINE', loc = 'cyt', prot = None), Parameter('t0_PHOSPHORYL_ETHANOLAMINE_cyt', 0))
Initial(met(name = 'PHOSPHORYL_ETHANOLAMINE', loc = 'per', prot = None), Parameter('t0_PHOSPHORYL_ETHANOLAMINE_per', 0))
Initial(met(name = 'PHOSPHORYL_ETHANOLAMINE', loc = 'ex', prot = None), Parameter('t0_PHOSPHORYL_ETHANOLAMINE_ex', 0))
Initial(met(name = 'PPI', loc = 'cyt', prot = None), Parameter('t0_PPI_cyt', 0))
Initial(met(name = 'PPI', loc = 'per', prot = None), Parameter('t0_PPI_per', 0))
Initial(met(name = 'PPI', loc = 'ex', prot = None), Parameter('t0_PPI_ex', 0))
Initial(met(name = 'PREPHENATE', loc = 'cyt', prot = None), Parameter('t0_PREPHENATE_cyt', 0))
Initial(met(name = 'PREPHENATE', loc = 'per', prot = None), Parameter('t0_PREPHENATE_per', 0))
Initial(met(name = 'PREPHENATE', loc = 'ex', prot = None), Parameter('t0_PREPHENATE_ex', 0))
Initial(met(name = 'PROTEIN_LIPOYLLYSINE', loc = 'cyt', prot = None), Parameter('t0_PROTEIN_LIPOYLLYSINE_cyt', 0))
Initial(met(name = 'PROTEIN_LIPOYLLYSINE', loc = 'per', prot = None), Parameter('t0_PROTEIN_LIPOYLLYSINE_per', 0))
Initial(met(name = 'PROTEIN_LIPOYLLYSINE', loc = 'ex', prot = None), Parameter('t0_PROTEIN_LIPOYLLYSINE_ex', 0))
Initial(met(name = 'PROTON', loc = 'cyt', prot = None), Parameter('t0_PROTON_cyt', 0))
Initial(met(name = 'PROTON', loc = 'per', prot = None), Parameter('t0_PROTON_per', 0))
Initial(met(name = 'PROTON', loc = 'ex', prot = None), Parameter('t0_PROTON_ex', 0))
Initial(met(name = 'PRPP', loc = 'cyt', prot = None), Parameter('t0_PRPP_cyt', 0))
Initial(met(name = 'PRPP', loc = 'per', prot = None), Parameter('t0_PRPP_per', 0))
Initial(met(name = 'PRPP', loc = 'ex', prot = None), Parameter('t0_PRPP_ex', 0))
Initial(met(name = 'PTSH_MONOMER', loc = 'cyt', prot = None), Parameter('t0_PTSH_MONOMER_cyt', 0))
Initial(met(name = 'PTSH_MONOMER', loc = 'per', prot = None), Parameter('t0_PTSH_MONOMER_per', 0))
Initial(met(name = 'PTSH_MONOMER', loc = 'ex', prot = None), Parameter('t0_PTSH_MONOMER_ex', 0))
Initial(met(name = 'PTSH_PHOSPHORYLATED', loc = 'cyt', prot = None), Parameter('t0_PTSH_PHOSPHORYLATED_cyt', 0))
Initial(met(name = 'PTSH_PHOSPHORYLATED', loc = 'per', prot = None), Parameter('t0_PTSH_PHOSPHORYLATED_per', 0))
Initial(met(name = 'PTSH_PHOSPHORYLATED', loc = 'ex', prot = None), Parameter('t0_PTSH_PHOSPHORYLATED_ex', 0))
Initial(met(name = 'PYRAZINAMIDE', loc = 'cyt', prot = None), Parameter('t0_PYRAZINAMIDE_cyt', 0))
Initial(met(name = 'PYRAZINAMIDE', loc = 'per', prot = None), Parameter('t0_PYRAZINAMIDE_per', 0))
Initial(met(name = 'PYRAZINAMIDE', loc = 'ex', prot = None), Parameter('t0_PYRAZINAMIDE_ex', 0))
Initial(met(name = 'PYRAZINOIC_ACID', loc = 'cyt', prot = None), Parameter('t0_PYRAZINOIC_ACID_cyt', 0))
Initial(met(name = 'PYRAZINOIC_ACID', loc = 'per', prot = None), Parameter('t0_PYRAZINOIC_ACID_per', 0))
Initial(met(name = 'PYRAZINOIC_ACID', loc = 'ex', prot = None), Parameter('t0_PYRAZINOIC_ACID_ex', 0))
Initial(met(name = 'PYRIDOXAL', loc = 'cyt', prot = None), Parameter('t0_PYRIDOXAL_cyt', 0))
Initial(met(name = 'PYRIDOXAL', loc = 'per', prot = None), Parameter('t0_PYRIDOXAL_per', 0))
Initial(met(name = 'PYRIDOXAL', loc = 'ex', prot = None), Parameter('t0_PYRIDOXAL_ex', 0))
Initial(met(name = 'PYRIDOXAL_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_PYRIDOXAL_PHOSPHATE_cyt', 0))
Initial(met(name = 'PYRIDOXAL_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_PYRIDOXAL_PHOSPHATE_per', 0))
Initial(met(name = 'PYRIDOXAL_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_PYRIDOXAL_PHOSPHATE_ex', 0))
Initial(met(name = 'PYRIDOXAMINE_5P', loc = 'cyt', prot = None), Parameter('t0_PYRIDOXAMINE_5P_cyt', 0))
Initial(met(name = 'PYRIDOXAMINE_5P', loc = 'per', prot = None), Parameter('t0_PYRIDOXAMINE_5P_per', 0))
Initial(met(name = 'PYRIDOXAMINE_5P', loc = 'ex', prot = None), Parameter('t0_PYRIDOXAMINE_5P_ex', 0))
Initial(met(name = 'PYRIDOXINE', loc = 'cyt', prot = None), Parameter('t0_PYRIDOXINE_cyt', 0))
Initial(met(name = 'PYRIDOXINE', loc = 'per', prot = None), Parameter('t0_PYRIDOXINE_per', 0))
Initial(met(name = 'PYRIDOXINE', loc = 'ex', prot = None), Parameter('t0_PYRIDOXINE_ex', 0))
Initial(met(name = 'PYRIDOXINE_5P', loc = 'cyt', prot = None), Parameter('t0_PYRIDOXINE_5P_cyt', 0))
Initial(met(name = 'PYRIDOXINE_5P', loc = 'per', prot = None), Parameter('t0_PYRIDOXINE_5P_per', 0))
Initial(met(name = 'PYRIDOXINE_5P', loc = 'ex', prot = None), Parameter('t0_PYRIDOXINE_5P_ex', 0))
Initial(met(name = 'PYRUVATE', loc = 'cyt', prot = None), Parameter('t0_PYRUVATE_cyt', 0))
Initial(met(name = 'PYRUVATE', loc = 'per', prot = None), Parameter('t0_PYRUVATE_per', 0))
Initial(met(name = 'PYRUVATE', loc = 'ex', prot = None), Parameter('t0_PYRUVATE_ex', 0))
Initial(met(name = 'Pi', loc = 'cyt', prot = None), Parameter('t0_Pi_cyt', 0))
Initial(met(name = 'Pi', loc = 'per', prot = None), Parameter('t0_Pi_per', 0))
Initial(met(name = 'Pi', loc = 'ex', prot = None), Parameter('t0_Pi_ex', 0))
Initial(met(name = 'Purine_Bases', loc = 'cyt', prot = None), Parameter('t0_Purine_Bases_cyt', 0))
Initial(met(name = 'Purine_Bases', loc = 'per', prot = None), Parameter('t0_Purine_Bases_per', 0))
Initial(met(name = 'Purine_Bases', loc = 'ex', prot = None), Parameter('t0_Purine_Bases_ex', 0))
Initial(met(name = 'Purine_Ribonucleosides', loc = 'cyt', prot = None), Parameter('t0_Purine_Ribonucleosides_cyt', 0))
Initial(met(name = 'Purine_Ribonucleosides', loc = 'per', prot = None), Parameter('t0_Purine_Ribonucleosides_per', 0))
Initial(met(name = 'Purine_Ribonucleosides', loc = 'ex', prot = None), Parameter('t0_Purine_Ribonucleosides_ex', 0))
Initial(met(name = 'Pyrimidine_Bases', loc = 'cyt', prot = None), Parameter('t0_Pyrimidine_Bases_cyt', 0))
Initial(met(name = 'Pyrimidine_Bases', loc = 'per', prot = None), Parameter('t0_Pyrimidine_Bases_per', 0))
Initial(met(name = 'Pyrimidine_Bases', loc = 'ex', prot = None), Parameter('t0_Pyrimidine_Bases_ex', 0))
Initial(met(name = 'Pyrimidine_Nucleosides', loc = 'cyt', prot = None), Parameter('t0_Pyrimidine_Nucleosides_cyt', 0))
Initial(met(name = 'Pyrimidine_Nucleosides', loc = 'per', prot = None), Parameter('t0_Pyrimidine_Nucleosides_per', 0))
Initial(met(name = 'Pyrimidine_Nucleosides', loc = 'ex', prot = None), Parameter('t0_Pyrimidine_Nucleosides_ex', 0))
Initial(met(name = 'Pyrimidine_ribonucleotides', loc = 'cyt', prot = None), Parameter('t0_Pyrimidine_ribonucleotides_cyt', 0))
Initial(met(name = 'Pyrimidine_ribonucleotides', loc = 'per', prot = None), Parameter('t0_Pyrimidine_ribonucleotides_per', 0))
Initial(met(name = 'Pyrimidine_ribonucleotides', loc = 'ex', prot = None), Parameter('t0_Pyrimidine_ribonucleotides_ex', 0))
Initial(met(name = 'Pyruvate_dehydrogenase_acetylDHlipoyl', loc = 'cyt', prot = None), Parameter('t0_Pyruvate_dehydrogenase_acetylDHlipoyl_cyt', 0))
Initial(met(name = 'Pyruvate_dehydrogenase_acetylDHlipoyl', loc = 'per', prot = None), Parameter('t0_Pyruvate_dehydrogenase_acetylDHlipoyl_per', 0))
Initial(met(name = 'Pyruvate_dehydrogenase_acetylDHlipoyl', loc = 'ex', prot = None), Parameter('t0_Pyruvate_dehydrogenase_acetylDHlipoyl_ex', 0))
Initial(met(name = 'Pyruvate_dehydrogenase_dihydrolipoate', loc = 'cyt', prot = None), Parameter('t0_Pyruvate_dehydrogenase_dihydrolipoate_cyt', 0))
Initial(met(name = 'Pyruvate_dehydrogenase_dihydrolipoate', loc = 'per', prot = None), Parameter('t0_Pyruvate_dehydrogenase_dihydrolipoate_per', 0))
Initial(met(name = 'Pyruvate_dehydrogenase_dihydrolipoate', loc = 'ex', prot = None), Parameter('t0_Pyruvate_dehydrogenase_dihydrolipoate_ex', 0))
Initial(met(name = 'Pyruvate_dehydrogenase_lipoate', loc = 'cyt', prot = None), Parameter('t0_Pyruvate_dehydrogenase_lipoate_cyt', 0))
Initial(met(name = 'Pyruvate_dehydrogenase_lipoate', loc = 'per', prot = None), Parameter('t0_Pyruvate_dehydrogenase_lipoate_per', 0))
Initial(met(name = 'Pyruvate_dehydrogenase_lipoate', loc = 'ex', prot = None), Parameter('t0_Pyruvate_dehydrogenase_lipoate_ex', 0))
Initial(met(name = 'R_2_HYDROXYGLUTARATE', loc = 'cyt', prot = None), Parameter('t0_R_2_HYDROXYGLUTARATE_cyt', 0))
Initial(met(name = 'R_2_HYDROXYGLUTARATE', loc = 'per', prot = None), Parameter('t0_R_2_HYDROXYGLUTARATE_per', 0))
Initial(met(name = 'R_2_HYDROXYGLUTARATE', loc = 'ex', prot = None), Parameter('t0_R_2_HYDROXYGLUTARATE_ex', 0))
Initial(met(name = 'RIBOFLAVIN', loc = 'cyt', prot = None), Parameter('t0_RIBOFLAVIN_cyt', 0))
Initial(met(name = 'RIBOFLAVIN', loc = 'per', prot = None), Parameter('t0_RIBOFLAVIN_per', 0))
Initial(met(name = 'RIBOFLAVIN', loc = 'ex', prot = None), Parameter('t0_RIBOFLAVIN_ex', 0))
Initial(met(name = 'RIBOSE_1P', loc = 'cyt', prot = None), Parameter('t0_RIBOSE_1P_cyt', 0))
Initial(met(name = 'RIBOSE_1P', loc = 'per', prot = None), Parameter('t0_RIBOSE_1P_per', 0))
Initial(met(name = 'RIBOSE_1P', loc = 'ex', prot = None), Parameter('t0_RIBOSE_1P_ex', 0))
Initial(met(name = 'RIBOSE_5P', loc = 'cyt', prot = None), Parameter('t0_RIBOSE_5P_cyt', 0))
Initial(met(name = 'RIBOSE_5P', loc = 'per', prot = None), Parameter('t0_RIBOSE_5P_per', 0))
Initial(met(name = 'RIBOSE_5P', loc = 'ex', prot = None), Parameter('t0_RIBOSE_5P_ex', 0))
Initial(met(name = 'RIBULOSE_5P', loc = 'cyt', prot = None), Parameter('t0_RIBULOSE_5P_cyt', 0))
Initial(met(name = 'RIBULOSE_5P', loc = 'per', prot = None), Parameter('t0_RIBULOSE_5P_per', 0))
Initial(met(name = 'RIBULOSE_5P', loc = 'ex', prot = None), Parameter('t0_RIBULOSE_5P_ex', 0))
Initial(met(name = 'Ribonucleoside_Monophosphates', loc = 'cyt', prot = None), Parameter('t0_Ribonucleoside_Monophosphates_cyt', 0))
Initial(met(name = 'Ribonucleoside_Monophosphates', loc = 'per', prot = None), Parameter('t0_Ribonucleoside_Monophosphates_per', 0))
Initial(met(name = 'Ribonucleoside_Monophosphates', loc = 'ex', prot = None), Parameter('t0_Ribonucleoside_Monophosphates_ex', 0))
Initial(met(name = 'Ribonucleoside_Triphosphates', loc = 'cyt', prot = None), Parameter('t0_Ribonucleoside_Triphosphates_cyt', 0))
Initial(met(name = 'Ribonucleoside_Triphosphates', loc = 'per', prot = None), Parameter('t0_Ribonucleoside_Triphosphates_per', 0))
Initial(met(name = 'Ribonucleoside_Triphosphates', loc = 'ex', prot = None), Parameter('t0_Ribonucleoside_Triphosphates_ex', 0))
Initial(met(name = 'Ribonucleosides', loc = 'cyt', prot = None), Parameter('t0_Ribonucleosides_cyt', 0))
Initial(met(name = 'Ribonucleosides', loc = 'per', prot = None), Parameter('t0_Ribonucleosides_per', 0))
Initial(met(name = 'Ribonucleosides', loc = 'ex', prot = None), Parameter('t0_Ribonucleosides_ex', 0))
Initial(met(name = 'SER', loc = 'cyt', prot = None), Parameter('t0_SER_cyt', 0))
Initial(met(name = 'SER', loc = 'per', prot = None), Parameter('t0_SER_per', 0))
Initial(met(name = 'SER', loc = 'ex', prot = None), Parameter('t0_SER_ex', 0))
Initial(met(name = 'SHIKIMATE', loc = 'cyt', prot = None), Parameter('t0_SHIKIMATE_cyt', 0))
Initial(met(name = 'SHIKIMATE', loc = 'per', prot = None), Parameter('t0_SHIKIMATE_per', 0))
Initial(met(name = 'SHIKIMATE', loc = 'ex', prot = None), Parameter('t0_SHIKIMATE_ex', 0))
Initial(met(name = 'SHIKIMATE_5P', loc = 'cyt', prot = None), Parameter('t0_SHIKIMATE_5P_cyt', 0))
Initial(met(name = 'SHIKIMATE_5P', loc = 'per', prot = None), Parameter('t0_SHIKIMATE_5P_per', 0))
Initial(met(name = 'SHIKIMATE_5P', loc = 'ex', prot = None), Parameter('t0_SHIKIMATE_5P_ex', 0))
Initial(met(name = 'SUC', loc = 'cyt', prot = None), Parameter('t0_SUC_cyt', 0))
Initial(met(name = 'SUC', loc = 'per', prot = None), Parameter('t0_SUC_per', 0))
Initial(met(name = 'SUC', loc = 'ex', prot = None), Parameter('t0_SUC_ex', 0))
Initial(met(name = 'SUC_COA', loc = 'cyt', prot = None), Parameter('t0_SUC_COA_cyt', 0))
Initial(met(name = 'SUC_COA', loc = 'per', prot = None), Parameter('t0_SUC_COA_per', 0))
Initial(met(name = 'SUC_COA', loc = 'ex', prot = None), Parameter('t0_SUC_COA_ex', 0))
Initial(met(name = 'Sugar', loc = 'cyt', prot = None), Parameter('t0_Sugar_cyt', 0))
Initial(met(name = 'Sugar', loc = 'per', prot = None), Parameter('t0_Sugar_per', 0))
Initial(met(name = 'Sugar', loc = 'ex', prot = None), Parameter('t0_Sugar_ex', 0))
Initial(met(name = 'Sugar_Phosphate', loc = 'cyt', prot = None), Parameter('t0_Sugar_Phosphate_cyt', 0))
Initial(met(name = 'Sugar_Phosphate', loc = 'per', prot = None), Parameter('t0_Sugar_Phosphate_per', 0))
Initial(met(name = 'Sugar_Phosphate', loc = 'ex', prot = None), Parameter('t0_Sugar_Phosphate_ex', 0))
Initial(met(name = 'TAGATOSE_1_6_DIPHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_TAGATOSE_1_6_DIPHOSPHATE_cyt', 0))
Initial(met(name = 'TAGATOSE_1_6_DIPHOSPHATE', loc = 'per', prot = None), Parameter('t0_TAGATOSE_1_6_DIPHOSPHATE_per', 0))
Initial(met(name = 'TAGATOSE_1_6_DIPHOSPHATE', loc = 'ex', prot = None), Parameter('t0_TAGATOSE_1_6_DIPHOSPHATE_ex', 0))
Initial(met(name = 'TAGATOSE_6_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_TAGATOSE_6_PHOSPHATE_cyt', 0))
Initial(met(name = 'TAGATOSE_6_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_TAGATOSE_6_PHOSPHATE_per', 0))
Initial(met(name = 'TAGATOSE_6_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_TAGATOSE_6_PHOSPHATE_ex', 0))
Initial(met(name = 'TARTRATE', loc = 'cyt', prot = None), Parameter('t0_TARTRATE_cyt', 0))
Initial(met(name = 'TARTRATE', loc = 'per', prot = None), Parameter('t0_TARTRATE_per', 0))
Initial(met(name = 'TARTRATE', loc = 'ex', prot = None), Parameter('t0_TARTRATE_ex', 0))
Initial(met(name = 'TDP', loc = 'cyt', prot = None), Parameter('t0_TDP_cyt', 0))
Initial(met(name = 'TDP', loc = 'per', prot = None), Parameter('t0_TDP_per', 0))
Initial(met(name = 'TDP', loc = 'ex', prot = None), Parameter('t0_TDP_ex', 0))
Initial(met(name = 'THF_GLU_N', loc = 'cyt', prot = None), Parameter('t0_THF_GLU_N_cyt', 0))
Initial(met(name = 'THF_GLU_N', loc = 'per', prot = None), Parameter('t0_THF_GLU_N_per', 0))
Initial(met(name = 'THF_GLU_N', loc = 'ex', prot = None), Parameter('t0_THF_GLU_N_ex', 0))
Initial(met(name = 'THR', loc = 'cyt', prot = None), Parameter('t0_THR_cyt', 0))
Initial(met(name = 'THR', loc = 'per', prot = None), Parameter('t0_THR_per', 0))
Initial(met(name = 'THR', loc = 'ex', prot = None), Parameter('t0_THR_ex', 0))
Initial(met(name = 'THREO_DS_ISO_CITRATE', loc = 'cyt', prot = None), Parameter('t0_THREO_DS_ISO_CITRATE_cyt', 0))
Initial(met(name = 'THREO_DS_ISO_CITRATE', loc = 'per', prot = None), Parameter('t0_THREO_DS_ISO_CITRATE_per', 0))
Initial(met(name = 'THREO_DS_ISO_CITRATE', loc = 'ex', prot = None), Parameter('t0_THREO_DS_ISO_CITRATE_ex', 0))
Initial(met(name = 'THYMIDINE', loc = 'cyt', prot = None), Parameter('t0_THYMIDINE_cyt', 0))
Initial(met(name = 'THYMIDINE', loc = 'per', prot = None), Parameter('t0_THYMIDINE_per', 0))
Initial(met(name = 'THYMIDINE', loc = 'ex', prot = None), Parameter('t0_THYMIDINE_ex', 0))
Initial(met(name = 'THYMINE', loc = 'cyt', prot = None), Parameter('t0_THYMINE_cyt', 0))
Initial(met(name = 'THYMINE', loc = 'per', prot = None), Parameter('t0_THYMINE_per', 0))
Initial(met(name = 'THYMINE', loc = 'ex', prot = None), Parameter('t0_THYMINE_ex', 0))
Initial(met(name = 'TMP', loc = 'cyt', prot = None), Parameter('t0_TMP_cyt', 0))
Initial(met(name = 'TMP', loc = 'per', prot = None), Parameter('t0_TMP_per', 0))
Initial(met(name = 'TMP', loc = 'ex', prot = None), Parameter('t0_TMP_ex', 0))
Initial(met(name = 'TREHALOSE', loc = 'cyt', prot = None), Parameter('t0_TREHALOSE_cyt', 0))
Initial(met(name = 'TREHALOSE', loc = 'per', prot = None), Parameter('t0_TREHALOSE_per', 0))
Initial(met(name = 'TREHALOSE', loc = 'ex', prot = None), Parameter('t0_TREHALOSE_ex', 0))
Initial(met(name = 'TREHALOSE_6P', loc = 'cyt', prot = None), Parameter('t0_TREHALOSE_6P_cyt', 0))
Initial(met(name = 'TREHALOSE_6P', loc = 'per', prot = None), Parameter('t0_TREHALOSE_6P_per', 0))
Initial(met(name = 'TREHALOSE_6P', loc = 'ex', prot = None), Parameter('t0_TREHALOSE_6P_ex', 0))
Initial(met(name = 'TRP', loc = 'cyt', prot = None), Parameter('t0_TRP_cyt', 0))
Initial(met(name = 'TRP', loc = 'per', prot = None), Parameter('t0_TRP_per', 0))
Initial(met(name = 'TRP', loc = 'ex', prot = None), Parameter('t0_TRP_ex', 0))
Initial(met(name = 'TTP', loc = 'cyt', prot = None), Parameter('t0_TTP_cyt', 0))
Initial(met(name = 'TTP', loc = 'per', prot = None), Parameter('t0_TTP_per', 0))
Initial(met(name = 'TTP', loc = 'ex', prot = None), Parameter('t0_TTP_ex', 0))
Initial(met(name = 'TYR', loc = 'cyt', prot = None), Parameter('t0_TYR_cyt', 0))
Initial(met(name = 'TYR', loc = 'per', prot = None), Parameter('t0_TYR_per', 0))
Initial(met(name = 'TYR', loc = 'ex', prot = None), Parameter('t0_TYR_ex', 0))
Initial(met(name = 'UDP', loc = 'cyt', prot = None), Parameter('t0_UDP_cyt', 0))
Initial(met(name = 'UDP', loc = 'per', prot = None), Parameter('t0_UDP_per', 0))
Initial(met(name = 'UDP', loc = 'ex', prot = None), Parameter('t0_UDP_ex', 0))
Initial(met(name = 'UDP_sugar', loc = 'cyt', prot = None), Parameter('t0_UDP_sugar_cyt', 0))
Initial(met(name = 'UDP_sugar', loc = 'per', prot = None), Parameter('t0_UDP_sugar_per', 0))
Initial(met(name = 'UDP_sugar', loc = 'ex', prot = None), Parameter('t0_UDP_sugar_ex', 0))
Initial(met(name = 'UMP', loc = 'cyt', prot = None), Parameter('t0_UMP_cyt', 0))
Initial(met(name = 'UMP', loc = 'per', prot = None), Parameter('t0_UMP_per', 0))
Initial(met(name = 'UMP', loc = 'ex', prot = None), Parameter('t0_UMP_ex', 0))
Initial(met(name = 'URACIL', loc = 'cyt', prot = None), Parameter('t0_URACIL_cyt', 0))
Initial(met(name = 'URACIL', loc = 'per', prot = None), Parameter('t0_URACIL_per', 0))
Initial(met(name = 'URACIL', loc = 'ex', prot = None), Parameter('t0_URACIL_ex', 0))
Initial(met(name = 'URATE', loc = 'cyt', prot = None), Parameter('t0_URATE_cyt', 0))
Initial(met(name = 'URATE', loc = 'per', prot = None), Parameter('t0_URATE_per', 0))
Initial(met(name = 'URATE', loc = 'ex', prot = None), Parameter('t0_URATE_ex', 0))
Initial(met(name = 'URIDINE', loc = 'cyt', prot = None), Parameter('t0_URIDINE_cyt', 0))
Initial(met(name = 'URIDINE', loc = 'per', prot = None), Parameter('t0_URIDINE_per', 0))
Initial(met(name = 'URIDINE', loc = 'ex', prot = None), Parameter('t0_URIDINE_ex', 0))
Initial(met(name = 'UTP', loc = 'cyt', prot = None), Parameter('t0_UTP_cyt', 0))
Initial(met(name = 'UTP', loc = 'per', prot = None), Parameter('t0_UTP_per', 0))
Initial(met(name = 'UTP', loc = 'ex', prot = None), Parameter('t0_UTP_ex', 0))
Initial(met(name = 'Ubiquinols', loc = 'cyt', prot = None), Parameter('t0_Ubiquinols_cyt', 0))
Initial(met(name = 'Ubiquinols', loc = 'per', prot = None), Parameter('t0_Ubiquinols_per', 0))
Initial(met(name = 'Ubiquinols', loc = 'ex', prot = None), Parameter('t0_Ubiquinols_ex', 0))
Initial(met(name = 'Ubiquinones', loc = 'cyt', prot = None), Parameter('t0_Ubiquinones_cyt', 0))
Initial(met(name = 'Ubiquinones', loc = 'per', prot = None), Parameter('t0_Ubiquinones_per', 0))
Initial(met(name = 'Ubiquinones', loc = 'ex', prot = None), Parameter('t0_Ubiquinones_ex', 0))
Initial(met(name = 'VAL', loc = 'cyt', prot = None), Parameter('t0_VAL_cyt', 0))
Initial(met(name = 'VAL', loc = 'per', prot = None), Parameter('t0_VAL_per', 0))
Initial(met(name = 'VAL', loc = 'ex', prot = None), Parameter('t0_VAL_ex', 0))
Initial(met(name = 'WATER', loc = 'cyt', prot = None), Parameter('t0_WATER_cyt', 0))
Initial(met(name = 'WATER', loc = 'per', prot = None), Parameter('t0_WATER_per', 0))
Initial(met(name = 'WATER', loc = 'ex', prot = None), Parameter('t0_WATER_ex', 0))
Initial(met(name = 'XANTHINE', loc = 'cyt', prot = None), Parameter('t0_XANTHINE_cyt', 0))
Initial(met(name = 'XANTHINE', loc = 'per', prot = None), Parameter('t0_XANTHINE_per', 0))
Initial(met(name = 'XANTHINE', loc = 'ex', prot = None), Parameter('t0_XANTHINE_ex', 0))
Initial(met(name = 'XANTHOSINE', loc = 'cyt', prot = None), Parameter('t0_XANTHOSINE_cyt', 0))
Initial(met(name = 'XANTHOSINE', loc = 'per', prot = None), Parameter('t0_XANTHOSINE_per', 0))
Initial(met(name = 'XANTHOSINE', loc = 'ex', prot = None), Parameter('t0_XANTHOSINE_ex', 0))
Initial(met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_XANTHOSINE_5_PHOSPHATE_cyt', 0))
Initial(met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_XANTHOSINE_5_PHOSPHATE_per', 0))
Initial(met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_XANTHOSINE_5_PHOSPHATE_ex', 0))
Initial(met(name = 'XYLULOSE_5_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0_XYLULOSE_5_PHOSPHATE_cyt', 0))
Initial(met(name = 'XYLULOSE_5_PHOSPHATE', loc = 'per', prot = None), Parameter('t0_XYLULOSE_5_PHOSPHATE_per', 0))
Initial(met(name = 'XYLULOSE_5_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0_XYLULOSE_5_PHOSPHATE_ex', 0))
Initial(met(name = '_1_KETO_2_METHYLVALERATE', loc = 'cyt', prot = None), Parameter('t0__1_KETO_2_METHYLVALERATE_cyt', 0))
Initial(met(name = '_1_KETO_2_METHYLVALERATE', loc = 'per', prot = None), Parameter('t0__1_KETO_2_METHYLVALERATE_per', 0))
Initial(met(name = '_1_KETO_2_METHYLVALERATE', loc = 'ex', prot = None), Parameter('t0__1_KETO_2_METHYLVALERATE_ex', 0))
Initial(met(name = '_2_ACETO_2_HYDROXY_BUTYRATE', loc = 'cyt', prot = None), Parameter('t0__2_ACETO_2_HYDROXY_BUTYRATE_cyt', 0))
Initial(met(name = '_2_ACETO_2_HYDROXY_BUTYRATE', loc = 'per', prot = None), Parameter('t0__2_ACETO_2_HYDROXY_BUTYRATE_per', 0))
Initial(met(name = '_2_ACETO_2_HYDROXY_BUTYRATE', loc = 'ex', prot = None), Parameter('t0__2_ACETO_2_HYDROXY_BUTYRATE_ex', 0))
Initial(met(name = '_2_ACETO_LACTATE', loc = 'cyt', prot = None), Parameter('t0__2_ACETO_LACTATE_cyt', 0))
Initial(met(name = '_2_ACETO_LACTATE', loc = 'per', prot = None), Parameter('t0__2_ACETO_LACTATE_per', 0))
Initial(met(name = '_2_ACETO_LACTATE', loc = 'ex', prot = None), Parameter('t0__2_ACETO_LACTATE_ex', 0))
Initial(met(name = '_2_AMINOMALONATE_SEMIALDEHYDE', loc = 'cyt', prot = None), Parameter('t0__2_AMINOMALONATE_SEMIALDEHYDE_cyt', 0))
Initial(met(name = '_2_AMINOMALONATE_SEMIALDEHYDE', loc = 'per', prot = None), Parameter('t0__2_AMINOMALONATE_SEMIALDEHYDE_per', 0))
Initial(met(name = '_2_AMINOMALONATE_SEMIALDEHYDE', loc = 'ex', prot = None), Parameter('t0__2_AMINOMALONATE_SEMIALDEHYDE_ex', 0))
Initial(met(name = '_2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE', loc = 'cyt', prot = None), Parameter('t0__2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE_cyt', 0))
Initial(met(name = '_2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE', loc = 'per', prot = None), Parameter('t0__2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE_per', 0))
Initial(met(name = '_2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE', loc = 'ex', prot = None), Parameter('t0__2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE_ex', 0))
Initial(met(name = '_2_DEHYDROPANTOATE', loc = 'cyt', prot = None), Parameter('t0__2_DEHYDROPANTOATE_cyt', 0))
Initial(met(name = '_2_DEHYDROPANTOATE', loc = 'per', prot = None), Parameter('t0__2_DEHYDROPANTOATE_per', 0))
Initial(met(name = '_2_DEHYDROPANTOATE', loc = 'ex', prot = None), Parameter('t0__2_DEHYDROPANTOATE_ex', 0))
Initial(met(name = '_2_DEOXY_D_GLUCOSE', loc = 'cyt', prot = None), Parameter('t0__2_DEOXY_D_GLUCOSE_cyt', 0))
Initial(met(name = '_2_DEOXY_D_GLUCOSE', loc = 'per', prot = None), Parameter('t0__2_DEOXY_D_GLUCOSE_per', 0))
Initial(met(name = '_2_DEOXY_D_GLUCOSE', loc = 'ex', prot = None), Parameter('t0__2_DEOXY_D_GLUCOSE_ex', 0))
Initial(met(name = '_2_DEOXY_D_GLUCOSE_6_PHOSPHATE', loc = 'cyt', prot = None), Parameter('t0__2_DEOXY_D_GLUCOSE_6_PHOSPHATE_cyt', 0))
Initial(met(name = '_2_DEOXY_D_GLUCOSE_6_PHOSPHATE', loc = 'per', prot = None), Parameter('t0__2_DEOXY_D_GLUCOSE_6_PHOSPHATE_per', 0))
Initial(met(name = '_2_DEOXY_D_GLUCOSE_6_PHOSPHATE', loc = 'ex', prot = None), Parameter('t0__2_DEOXY_D_GLUCOSE_6_PHOSPHATE_ex', 0))
Initial(met(name = '_2_KETO_3_METHYL_VALERATE', loc = 'cyt', prot = None), Parameter('t0__2_KETO_3_METHYL_VALERATE_cyt', 0))
Initial(met(name = '_2_KETO_3_METHYL_VALERATE', loc = 'per', prot = None), Parameter('t0__2_KETO_3_METHYL_VALERATE_per', 0))
Initial(met(name = '_2_KETO_3_METHYL_VALERATE', loc = 'ex', prot = None), Parameter('t0__2_KETO_3_METHYL_VALERATE_ex', 0))
Initial(met(name = '_2_KETO_ISOVALERATE', loc = 'cyt', prot = None), Parameter('t0__2_KETO_ISOVALERATE_cyt', 0))
Initial(met(name = '_2_KETO_ISOVALERATE', loc = 'per', prot = None), Parameter('t0__2_KETO_ISOVALERATE_per', 0))
Initial(met(name = '_2_KETO_ISOVALERATE', loc = 'ex', prot = None), Parameter('t0__2_KETO_ISOVALERATE_ex', 0))
Initial(met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None), Parameter('t0__2_KETOGLUTARATE_cyt', 0))
Initial(met(name = '_2_KETOGLUTARATE', loc = 'per', prot = None), Parameter('t0__2_KETOGLUTARATE_per', 0))
Initial(met(name = '_2_KETOGLUTARATE', loc = 'ex', prot = None), Parameter('t0__2_KETOGLUTARATE_ex', 0))
Initial(met(name = '_2_OXOBUTANOATE', loc = 'cyt', prot = None), Parameter('t0__2_OXOBUTANOATE_cyt', 0))
Initial(met(name = '_2_OXOBUTANOATE', loc = 'per', prot = None), Parameter('t0__2_OXOBUTANOATE_per', 0))
Initial(met(name = '_2_OXOBUTANOATE', loc = 'ex', prot = None), Parameter('t0__2_OXOBUTANOATE_ex', 0))
Initial(met(name = '_2_PG', loc = 'cyt', prot = None), Parameter('t0__2_PG_cyt', 0))
Initial(met(name = '_2_PG', loc = 'per', prot = None), Parameter('t0__2_PG_per', 0))
Initial(met(name = '_2_PG', loc = 'ex', prot = None), Parameter('t0__2_PG_ex', 0))
Initial(met(name = '_2K_4CH3_PENTANOATE', loc = 'cyt', prot = None), Parameter('t0__2K_4CH3_PENTANOATE_cyt', 0))
Initial(met(name = '_2K_4CH3_PENTANOATE', loc = 'per', prot = None), Parameter('t0__2K_4CH3_PENTANOATE_per', 0))
Initial(met(name = '_2K_4CH3_PENTANOATE', loc = 'ex', prot = None), Parameter('t0__2K_4CH3_PENTANOATE_ex', 0))
Initial(met(name = '_3_CARBOXY_3_HYDROXY_ISOCAPROATE', loc = 'cyt', prot = None), Parameter('t0__3_CARBOXY_3_HYDROXY_ISOCAPROATE_cyt', 0))
Initial(met(name = '_3_CARBOXY_3_HYDROXY_ISOCAPROATE', loc = 'per', prot = None), Parameter('t0__3_CARBOXY_3_HYDROXY_ISOCAPROATE_per', 0))
Initial(met(name = '_3_CARBOXY_3_HYDROXY_ISOCAPROATE', loc = 'ex', prot = None), Parameter('t0__3_CARBOXY_3_HYDROXY_ISOCAPROATE_ex', 0))
Initial(met(name = '_3_DEHYDRO_SHIKIMATE', loc = 'cyt', prot = None), Parameter('t0__3_DEHYDRO_SHIKIMATE_cyt', 0))
Initial(met(name = '_3_DEHYDRO_SHIKIMATE', loc = 'per', prot = None), Parameter('t0__3_DEHYDRO_SHIKIMATE_per', 0))
Initial(met(name = '_3_DEHYDRO_SHIKIMATE', loc = 'ex', prot = None), Parameter('t0__3_DEHYDRO_SHIKIMATE_ex', 0))
Initial(met(name = '_3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P', loc = 'cyt', prot = None), Parameter('t0__3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P_cyt', 0))
Initial(met(name = '_3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P', loc = 'per', prot = None), Parameter('t0__3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P_per', 0))
Initial(met(name = '_3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P', loc = 'ex', prot = None), Parameter('t0__3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P_ex', 0))
Initial(met(name = '_3_ENOLPYRUVYL_SHIKIMATE_5P', loc = 'cyt', prot = None), Parameter('t0__3_ENOLPYRUVYL_SHIKIMATE_5P_cyt', 0))
Initial(met(name = '_3_ENOLPYRUVYL_SHIKIMATE_5P', loc = 'per', prot = None), Parameter('t0__3_ENOLPYRUVYL_SHIKIMATE_5P_per', 0))
Initial(met(name = '_3_ENOLPYRUVYL_SHIKIMATE_5P', loc = 'ex', prot = None), Parameter('t0__3_ENOLPYRUVYL_SHIKIMATE_5P_ex', 0))
Initial(met(name = '_3_HYDROXY_PROPIONATE', loc = 'cyt', prot = None), Parameter('t0__3_HYDROXY_PROPIONATE_cyt', 0))
Initial(met(name = '_3_HYDROXY_PROPIONATE', loc = 'per', prot = None), Parameter('t0__3_HYDROXY_PROPIONATE_per', 0))
Initial(met(name = '_3_HYDROXY_PROPIONATE', loc = 'ex', prot = None), Parameter('t0__3_HYDROXY_PROPIONATE_ex', 0))
Initial(met(name = '_3_MERCAPTO_PYRUVATE', loc = 'cyt', prot = None), Parameter('t0__3_MERCAPTO_PYRUVATE_cyt', 0))
Initial(met(name = '_3_MERCAPTO_PYRUVATE', loc = 'per', prot = None), Parameter('t0__3_MERCAPTO_PYRUVATE_per', 0))
Initial(met(name = '_3_MERCAPTO_PYRUVATE', loc = 'ex', prot = None), Parameter('t0__3_MERCAPTO_PYRUVATE_ex', 0))
Initial(met(name = '_3_P_HYDROXYPYRUVATE', loc = 'cyt', prot = None), Parameter('t0__3_P_HYDROXYPYRUVATE_cyt', 0))
Initial(met(name = '_3_P_HYDROXYPYRUVATE', loc = 'per', prot = None), Parameter('t0__3_P_HYDROXYPYRUVATE_per', 0))
Initial(met(name = '_3_P_HYDROXYPYRUVATE', loc = 'ex', prot = None), Parameter('t0__3_P_HYDROXYPYRUVATE_ex', 0))
Initial(met(name = '_3_P_SERINE', loc = 'cyt', prot = None), Parameter('t0__3_P_SERINE_cyt', 0))
Initial(met(name = '_3_P_SERINE', loc = 'per', prot = None), Parameter('t0__3_P_SERINE_per', 0))
Initial(met(name = '_3_P_SERINE', loc = 'ex', prot = None), Parameter('t0__3_P_SERINE_ex', 0))
Initial(met(name = '_3_Phosphomonucleotides', loc = 'cyt', prot = None), Parameter('t0__3_Phosphomonucleotides_cyt', 0))
Initial(met(name = '_3_Phosphomonucleotides', loc = 'per', prot = None), Parameter('t0__3_Phosphomonucleotides_per', 0))
Initial(met(name = '_3_Phosphomonucleotides', loc = 'ex', prot = None), Parameter('t0__3_Phosphomonucleotides_ex', 0))
Initial(met(name = '_3OH_4P_OH_ALPHA_KETOBUTYRATE', loc = 'cyt', prot = None), Parameter('t0__3OH_4P_OH_ALPHA_KETOBUTYRATE_cyt', 0))
Initial(met(name = '_3OH_4P_OH_ALPHA_KETOBUTYRATE', loc = 'per', prot = None), Parameter('t0__3OH_4P_OH_ALPHA_KETOBUTYRATE_per', 0))
Initial(met(name = '_3OH_4P_OH_ALPHA_KETOBUTYRATE', loc = 'ex', prot = None), Parameter('t0__3OH_4P_OH_ALPHA_KETOBUTYRATE_ex', 0))
Initial(met(name = '_4_PHOSPHONOOXY_THREONINE', loc = 'cyt', prot = None), Parameter('t0__4_PHOSPHONOOXY_THREONINE_cyt', 0))
Initial(met(name = '_4_PHOSPHONOOXY_THREONINE', loc = 'per', prot = None), Parameter('t0__4_PHOSPHONOOXY_THREONINE_per', 0))
Initial(met(name = '_4_PHOSPHONOOXY_THREONINE', loc = 'ex', prot = None), Parameter('t0__4_PHOSPHONOOXY_THREONINE_ex', 0))
Initial(met(name = '_5_10_METHENYL_THF_GLU_N', loc = 'cyt', prot = None), Parameter('t0__5_10_METHENYL_THF_GLU_N_cyt', 0))
Initial(met(name = '_5_10_METHENYL_THF_GLU_N', loc = 'per', prot = None), Parameter('t0__5_10_METHENYL_THF_GLU_N_per', 0))
Initial(met(name = '_5_10_METHENYL_THF_GLU_N', loc = 'ex', prot = None), Parameter('t0__5_10_METHENYL_THF_GLU_N_ex', 0))
Initial(met(name = '_5_METHYL_THF_GLU_N', loc = 'cyt', prot = None), Parameter('t0__5_METHYL_THF_GLU_N_cyt', 0))
Initial(met(name = '_5_METHYL_THF_GLU_N', loc = 'per', prot = None), Parameter('t0__5_METHYL_THF_GLU_N_per', 0))
Initial(met(name = '_5_METHYL_THF_GLU_N', loc = 'ex', prot = None), Parameter('t0__5_METHYL_THF_GLU_N_ex', 0))
Initial(met(name = '_5_P_BETA_D_RIBOSYL_AMINE', loc = 'cyt', prot = None), Parameter('t0__5_P_BETA_D_RIBOSYL_AMINE_cyt', 0))
Initial(met(name = '_5_P_BETA_D_RIBOSYL_AMINE', loc = 'per', prot = None), Parameter('t0__5_P_BETA_D_RIBOSYL_AMINE_per', 0))
Initial(met(name = '_5_P_BETA_D_RIBOSYL_AMINE', loc = 'ex', prot = None), Parameter('t0__5_P_BETA_D_RIBOSYL_AMINE_ex', 0))
Initial(met(name = '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', loc = 'cyt', prot = None), Parameter('t0__5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE_cyt', 0))
Initial(met(name = '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', loc = 'per', prot = None), Parameter('t0__5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE_per', 0))
Initial(met(name = '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', loc = 'ex', prot = None), Parameter('t0__5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE_ex', 0))
Initial(met(name = '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', loc = 'cyt', prot = None), Parameter('t0__5_PHOSPHO_RIBOSYL_GLYCINEAMIDE_cyt', 0))
Initial(met(name = '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', loc = 'per', prot = None), Parameter('t0__5_PHOSPHO_RIBOSYL_GLYCINEAMIDE_per', 0))
Initial(met(name = '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', loc = 'ex', prot = None), Parameter('t0__5_PHOSPHO_RIBOSYL_GLYCINEAMIDE_ex', 0))
Initial(met(name = '_5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE', loc = 'cyt', prot = None), Parameter('t0__5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE_cyt', 0))
Initial(met(name = '_5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE', loc = 'per', prot = None), Parameter('t0__5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE_per', 0))
Initial(met(name = '_5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE', loc = 'ex', prot = None), Parameter('t0__5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE_ex', 0))
Initial(met(name = '_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE', loc = 'cyt', prot = None), Parameter('t0__5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE_cyt', 0))
Initial(met(name = '_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE', loc = 'per', prot = None), Parameter('t0__5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE_per', 0))
Initial(met(name = '_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE', loc = 'ex', prot = None), Parameter('t0__5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE_ex', 0))
# Out:
# Initial(met(name='_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE', loc='ex', prot=None), t0__5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE_ex)

# %%
## paste here the results of "Rules from metabolic network"
# section 1: metabolic rules
Rule('_1_1_1_39_RXN',
    prot(name = 'maeA', loc = 'cyt') +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'MAL', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'maeA', loc = 'cyt') +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None), 
    Parameter('fwd__1_1_1_39_RXN', 1), 
    Parameter('rvs__1_1_1_39_RXN', 0))

Rule('_1_1_1_83_RXN',
    prot(name = 'dmlA', loc = 'cyt') +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'CPD_660', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'dmlA', loc = 'cyt') +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None), 
    Parameter('fwd__1_1_1_83_RXN', 1), 
    Parameter('rvs__1_1_1_83_RXN', 0))

Rule('_1_8_1_4_RXN',
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'Dihydro_Lipoyl_Proteins', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'Lipoyl_Protein_N6_lipoyllysine', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd__1_8_1_4_RXN', 1), 
    Parameter('rvs__1_8_1_4_RXN', 0))

Rule('_1TRANSKETO_RXN',
    prot(name = 'tktA', loc = 'cyt') +
    met(name = 'D_SEDOHEPTULOSE_7_P', loc = 'cyt', prot = None) +
    met(name = 'GAP', loc = 'cyt', prot = None) | 
    prot(name = 'tktA', loc = 'cyt') +
    met(name = 'RIBOSE_5P', loc = 'cyt', prot = None) +
    met(name = 'XYLULOSE_5_PHOSPHATE', loc = 'cyt', prot = None), 
    Parameter('fwd__1TRANSKETO_RXN', 1), 
    Parameter('rvs__1TRANSKETO_RXN', 0))

Rule('_2_DEHYDROPANTOATE_REDUCT_RXN',
    prot(name = 'ilvC', loc = 'cyt') +
    met(name = 'L_PANTOATE', loc = 'cyt', prot = None) +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ilvC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = '_2_DEHYDROPANTOATE', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None), 
    Parameter('fwd__2_DEHYDROPANTOATE_REDUCT_RXN', 1), 
    Parameter('rvs__2_DEHYDROPANTOATE_REDUCT_RXN', 0))

Rule('_2_ISOPROPYLMALATESYN_RXN',
    prot(name = 'leuA', loc = 'cyt') +
    met(name = '_2_KETO_ISOVALERATE', loc = 'cyt', prot = None) +
    met(name = 'ACETYL_COA', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'leuA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = '_3_CARBOXY_3_HYDROXY_ISOCAPROATE', loc = 'cyt', prot = None) +
    met(name = 'CO_A', loc = 'cyt', prot = None), 
    Parameter('fwd__2_ISOPROPYLMALATESYN_RXN', 1), 
    Parameter('rvs__2_ISOPROPYLMALATESYN_RXN', 0))

Rule('_2_5_1_19_RXN',
    prot(name = 'aroA', loc = 'cyt') +
    met(name = 'SHIKIMATE_5P', loc = 'cyt', prot = None) +
    met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'cyt', prot = None) | 
    prot(name = 'aroA', loc = 'cyt') +
    met(name = '_3_ENOLPYRUVYL_SHIKIMATE_5P', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd__2_5_1_19_RXN', 1), 
    Parameter('rvs__2_5_1_19_RXN', 0))

Rule('_2_6_1_57_RXN',
    prot(name = 'tyrB', loc = 'cyt') +
    met(name = 'Aromatic_Amino_Acids', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'tyrB', loc = 'cyt') +
    met(name = 'Aromatic_Oxoacids', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd__2_6_1_57_RXN', 1), 
    Parameter('rvs__2_6_1_57_RXN', 0))

Rule('_2_6_1_7_RXN',
    prot(name = 'aspC', loc = 'cyt') +
    met(name = 'CPD_14736', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'aspC', loc = 'cyt') +
    met(name = 'GLT', loc = 'cyt', prot = None) +
    met(name = 'CPD_476', loc = 'cyt', prot = None), 
    Parameter('fwd__2_6_1_7_RXN', 1), 
    Parameter('rvs__2_6_1_7_RXN', 0))

Rule('_2_7_7_1_RXN',
    prot(name = 'nadR', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'NICOTINAMIDE_NUCLEOTIDE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'nadR', loc = 'cyt') +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd__2_7_7_1_RXN', 1), 
    Parameter('rvs__2_7_7_1_RXN', 0))

Rule('_2OXOGLUTDECARB_RXN',
    prot(name = 'sucA', loc = 'cyt') +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) +
    met(name = 'Oxo_glutarate_dehydrogenase_lipoyl', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'sucA', loc = 'cyt') +
    met(name = 'Oxo_glutarate_dehydro_suc_DH_lipoyl', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd__2OXOGLUTDECARB_RXN', 1), 
    Parameter('rvs__2OXOGLUTDECARB_RXN', 0))

Rule('_2PGADEHYDRAT_RXN',
    prot(name = 'eno', loc = 'cyt') +
    met(name = '_2_PG', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'eno', loc = 'cyt') +
    met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd__2PGADEHYDRAT_RXN', 1), 
    Parameter('rvs__2PGADEHYDRAT_RXN', 0))

Rule('_2TRANSKETO_RXN',
    prot(name = 'tktB', loc = 'cyt') +
    met(name = 'ERYTHROSE_4P', loc = 'cyt', prot = None) +
    met(name = 'XYLULOSE_5_PHOSPHATE', loc = 'cyt', prot = None) | 
    prot(name = 'tktB', loc = 'cyt') +
    met(name = 'FRUCTOSE_6P', loc = 'cyt', prot = None) +
    met(name = 'GAP', loc = 'cyt', prot = None), 
    Parameter('fwd__2TRANSKETO_RXN', 1), 
    Parameter('rvs__2TRANSKETO_RXN', 0))

Rule('_3_DEHYDROQUINATE_DEHYDRATASE_RXN',
    prot(name = 'aroD', loc = 'cyt') +
    met(name = 'DEHYDROQUINATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'aroD', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = '_3_DEHYDRO_SHIKIMATE', loc = 'cyt', prot = None), 
    Parameter('fwd__3_DEHYDROQUINATE_DEHYDRATASE_RXN', 1), 
    Parameter('rvs__3_DEHYDROQUINATE_DEHYDRATASE_RXN', 0))

Rule('_3_DEHYDROQUINATE_SYNTHASE_RXN',
    prot(name = 'aroB', loc = 'cyt') +
    met(name = '_3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'aroB', loc = 'cyt') +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'DEHYDROQUINATE', loc = 'cyt', prot = None), 
    Parameter('fwd__3_DEHYDROQUINATE_SYNTHASE_RXN', 1), 
    Parameter('rvs__3_DEHYDROQUINATE_SYNTHASE_RXN', 0))

Rule('_3_NUCLEOTID_RXN',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = '_3_Phosphomonucleotides', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'Ribonucleosides', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd__3_NUCLEOTID_RXN', 1), 
    Parameter('rvs__3_NUCLEOTID_RXN', 0))

Rule('_3_PHOSPHOGLYCERATE_PHOSPHATASE_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'G3P', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'GLYCERATE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd__3_PHOSPHOGLYCERATE_PHOSPHATASE_RXN', 1), 
    Parameter('rvs__3_PHOSPHOGLYCERATE_PHOSPHATASE_RXN', 0))

Rule('_3_1_3_68_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = '_2_DEOXY_D_GLUCOSE_6_PHOSPHATE', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = '_2_DEOXY_D_GLUCOSE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd__3_1_3_68_RXN', 1), 
    Parameter('rvs__3_1_3_68_RXN', 0))

Rule('_3_1_3_74_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'PYRIDOXAL_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'PYRIDOXAL', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd__3_1_3_74_RXN', 1), 
    Parameter('rvs__3_1_3_74_RXN', 0))

Rule('_3_2_2_10_RXN',
    prot(name = 'ppnN', loc = 'cyt') +
    met(name = 'Pyrimidine_ribonucleotides', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'ppnN', loc = 'cyt') +
    met(name = 'RIBOSE_5P', loc = 'cyt', prot = None) +
    met(name = 'Pyrimidine_Bases', loc = 'cyt', prot = None), 
    Parameter('fwd__3_2_2_10_RXN', 1), 
    Parameter('rvs__3_2_2_10_RXN', 0))

Rule('_3PGAREARR_RXN',
    prot(name = 'gpmM', loc = 'cyt') +
    met(name = '_2_PG', loc = 'cyt', prot = None) | 
    prot(name = 'gpmM', loc = 'cyt') +
    met(name = 'G3P', loc = 'cyt', prot = None), 
    Parameter('fwd__3PGAREARR_RXN', 1), 
    Parameter('rvs__3PGAREARR_RXN', 0))

Rule('_4_NITROPHENYLPHOSPHATASE_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_194', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'P_NITROPHENOL', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd__4_NITROPHENYLPHOSPHATASE_RXN', 1), 
    Parameter('rvs__4_NITROPHENYLPHOSPHATASE_RXN', 0))

Rule('_4_2_1_99_RXN',
    prot(name = 'acnB', loc = 'cyt') +
    met(name = 'CPD_618', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'acnB', loc = 'cyt') +
    met(name = 'CPD_1136', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd__4_2_1_99_RXN', 1), 
    Parameter('rvs__4_2_1_99_RXN', 0))

Rule('_5_NUCLEOTID_RXN',
    prot(name = 'umpG', loc = 'cyt') +
    met(name = 'Ribonucleoside_Monophosphates', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'umpG', loc = 'cyt') +
    met(name = 'Ribonucleosides', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd__5_NUCLEOTID_RXN', 1), 
    Parameter('rvs__5_NUCLEOTID_RXN', 0))

Rule('_6PFRUCTPHOS_RXN',
    prot(name = 'pfkB', loc = 'cyt') +
    met(name = 'FRUCTOSE_6P', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'pfkB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'FRUCTOSE_16_DIPHOSPHATE', loc = 'cyt', prot = None), 
    Parameter('fwd__6PFRUCTPHOS_RXN', 1), 
    Parameter('rvs__6PFRUCTPHOS_RXN', 0))

Rule('ACETATEKIN_RXN',
    prot(name = 'purT', loc = 'cyt') +
    met(name = 'ACET', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'purT', loc = 'cyt') +
    met(name = 'ACETYL_P', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_ACETATEKIN_RXN', 1), 
    Parameter('rvs_ACETATEKIN_RXN', 0))

Rule('ACETOLACTREDUCTOISOM_RXN',
    prot(name = 'ilvC', loc = 'cyt') +
    met(name = 'CPD_13357', loc = 'cyt', prot = None) +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ilvC', loc = 'cyt') +
    met(name = '_2_ACETO_LACTATE', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_ACETOLACTREDUCTOISOM_RXN', 1), 
    Parameter('rvs_ACETOLACTREDUCTOISOM_RXN', 0))

Rule('ACETOLACTSYN_RXN',
    prot(name = 'ilvM', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) | 
    prot(name = 'ilvM', loc = 'cyt') +
    met(name = '_2_ACETO_LACTATE', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None), 
    Parameter('fwd_ACETOLACTSYN_RXN', 1), 
    Parameter('rvs_ACETOLACTSYN_RXN', 0))

Rule('ACETOOHBUTREDUCTOISOM_RXN',
    prot(name = 'ilvC', loc = 'cyt') +
    met(name = '_1_KETO_2_METHYLVALERATE', loc = 'cyt', prot = None) +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ilvC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = '_2_ACETO_2_HYDROXY_BUTYRATE', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None), 
    Parameter('fwd_ACETOOHBUTREDUCTOISOM_RXN', 1), 
    Parameter('rvs_ACETOOHBUTREDUCTOISOM_RXN', 0))

Rule('ACETOOHBUTSYN_RXN',
    prot(name = 'ilvI', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = '_2_OXOBUTANOATE', loc = 'cyt', prot = None) | 
    prot(name = 'ilvI', loc = 'cyt') +
    met(name = '_2_ACETO_2_HYDROXY_BUTYRATE', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_ACETOOHBUTSYN_RXN', 1), 
    Parameter('rvs_ACETOOHBUTSYN_RXN', 0))

Rule('ACETYLORNTRANSAM_RXN',
    prot(name = 'argD', loc = 'cyt') +
    met(name = 'N_ALPHA_ACETYLORNITHINE', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'argD', loc = 'cyt') +
    met(name = 'CPD_469', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_ACETYLORNTRANSAM_RXN', 1), 
    Parameter('rvs_ACETYLORNTRANSAM_RXN', 0))

Rule('ACID_PHOSPHATASE_RXN',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'Orthophosphoric_Monoesters', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'Alcohols', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_ACID_PHOSPHATASE_RXN', 1), 
    Parameter('rvs_ACID_PHOSPHATASE_RXN', 0))

Rule('ACONITATEDEHYDR_RXN',
    prot(name = 'acnA', loc = 'cyt') +
    met(name = 'CIT', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'acnA', loc = 'cyt') +
    met(name = 'CIS_ACONITATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_ACONITATEDEHYDR_RXN', 1), 
    Parameter('rvs_ACONITATEDEHYDR_RXN', 0))

Rule('ACONITATEHYDR_RXN',
    prot(name = 'acnB', loc = 'cyt') +
    met(name = 'CIS_ACONITATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'acnB', loc = 'cyt') +
    met(name = 'THREO_DS_ISO_CITRATE', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_ACONITATEHYDR_RXN', 1), 
    Parameter('rvs_ACONITATEHYDR_RXN', 0))

Rule('ADDALT_RXN',
    prot(name = 'add', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'DEOXYADENOSINE', loc = 'cyt', prot = None) | 
    prot(name = 'add', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'DEOXYINOSINE', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_ADDALT_RXN', 1), 
    Parameter('rvs_ADDALT_RXN', 0))

Rule('ADENODEAMIN_RXN',
    prot(name = 'add', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'ADENOSINE', loc = 'cyt', prot = None) | 
    prot(name = 'add', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'INOSINE', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_ADENODEAMIN_RXN', 1), 
    Parameter('rvs_ADENODEAMIN_RXN', 0))

Rule('ADENOSINE_NUCLEOSIDASE_RXN',
    prot(name = 'rihC', loc = 'cyt') +
    met(name = 'ADENOSINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'rihC', loc = 'cyt') +
    met(name = 'D_Ribofuranose', loc = 'cyt', prot = None) +
    met(name = 'ADENINE', loc = 'cyt', prot = None), 
    Parameter('fwd_ADENOSINE_NUCLEOSIDASE_RXN', 1), 
    Parameter('rvs_ADENOSINE_NUCLEOSIDASE_RXN', 0))

Rule('ADENPHOSPHOR_RXN',
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'ADENOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'RIBOSE_1P', loc = 'cyt', prot = None) +
    met(name = 'ADENINE', loc = 'cyt', prot = None), 
    Parameter('fwd_ADENPHOSPHOR_RXN', 1), 
    Parameter('rvs_ADENPHOSPHOR_RXN', 0))

Rule('ADENPRIBOSYLTRAN_RXN',
    prot(name = 'apt', loc = 'cyt') +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None) | 
    prot(name = 'apt', loc = 'cyt') +
    met(name = 'PRPP', loc = 'cyt', prot = None) +
    met(name = 'ADENINE', loc = 'cyt', prot = None), 
    Parameter('fwd_ADENPRIBOSYLTRAN_RXN', 1), 
    Parameter('rvs_ADENPRIBOSYLTRAN_RXN', 0))

Rule('ADENYL_KIN_RXN',
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'AMP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_ADENYL_KIN_RXN', 1), 
    Parameter('rvs_ADENYL_KIN_RXN', 0))

Rule('ADENYLOSUCCINATE_SYNTHASE_RXN',
    prot(name = 'purA', loc = 'cyt') +
    met(name = 'L_ASPARTATE', loc = 'cyt', prot = None) +
    met(name = 'IMP', loc = 'cyt', prot = None) +
    met(name = 'GTP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'purA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADENYLOSUCC', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'GDP', loc = 'cyt', prot = None), 
    Parameter('fwd_ADENYLOSUCCINATE_SYNTHASE_RXN', 1), 
    Parameter('rvs_ADENYLOSUCCINATE_SYNTHASE_RXN', 0))

Rule('AICARSYN_RXN',
    prot(name = 'purB', loc = 'cyt') +
    met(name = 'P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'purB', loc = 'cyt') +
    met(name = 'FUM', loc = 'cyt', prot = None) +
    met(name = 'AICAR', loc = 'cyt', prot = None), 
    Parameter('fwd_AICARSYN_RXN', 1), 
    Parameter('rvs_AICARSYN_RXN', 0))

Rule('AICARTRANSFORM_RXN',
    prot(name = 'purH', loc = 'cyt') +
    met(name = 'FORMYL_THF_GLU_N', loc = 'cyt', prot = None) +
    met(name = 'AICAR', loc = 'cyt', prot = None) | 
    prot(name = 'purH', loc = 'cyt') +
    met(name = 'THF_GLU_N', loc = 'cyt', prot = None) +
    met(name = 'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE', loc = 'cyt', prot = None), 
    Parameter('fwd_AICARTRANSFORM_RXN', 1), 
    Parameter('rvs_AICARTRANSFORM_RXN', 0))

Rule('AIRS_RXN',
    prot(name = 'purM', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = '_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE', loc = 'cyt', prot = None) +
    None +
    None | 
    prot(name = 'purM', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = '_5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE', loc = 'cyt', prot = None), 
    Parameter('fwd_AIRS_RXN', 1), 
    Parameter('rvs_AIRS_RXN', 0))

Rule('ALKAPHOSPHA_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Orthophosphoric_Monoesters', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Alcohols', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_ALKAPHOSPHA_RXN', 1), 
    Parameter('rvs_ALKAPHOSPHA_RXN', 0))

Rule('AMP_DEPHOSPHORYLATION_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'AMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'ADENOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_AMP_DEPHOSPHORYLATION_RXN', 1), 
    Parameter('rvs_AMP_DEPHOSPHORYLATION_RXN', 0))

Rule('AMP_NUCLEOSID_RXN',
    prot(name = 'ppnN', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None) | 
    prot(name = 'ppnN', loc = 'cyt') +
    met(name = 'CPD_15317', loc = 'cyt', prot = None) +
    met(name = 'ADENINE', loc = 'cyt', prot = None), 
    Parameter('fwd_AMP_NUCLEOSID_RXN', 1), 
    Parameter('rvs_AMP_NUCLEOSID_RXN', 0))

Rule('AMPSYN_RXN',
    prot(name = 'purB', loc = 'cyt') +
    met(name = 'ADENYLOSUCC', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'purB', loc = 'cyt') +
    met(name = 'FUM', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None), 
    Parameter('fwd_AMPSYN_RXN', 1), 
    Parameter('rvs_AMPSYN_RXN', 0))

Rule('ANTHRANSYN_RXN',
    prot(name = 'trpD', loc = 'cyt') +
    met(name = 'CHORISMATE', loc = 'cyt', prot = None) +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    None +
    None | 
    prot(name = 'trpD', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ANTHRANILATE', loc = 'cyt', prot = None) +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_ANTHRANSYN_RXN', 1), 
    Parameter('rvs_ANTHRANSYN_RXN', 0))

Rule('ASNSYNA_RXN',
    prot(name = 'asnB', loc = 'cyt') +
    met(name = 'L_ASPARTATE', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'asnB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ASN', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None), 
    Parameter('fwd_ASNSYNA_RXN', 1), 
    Parameter('rvs_ASNSYNA_RXN', 0))

Rule('ASNSYNB_RXN',
    prot(name = 'asnB', loc = 'cyt') +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    met(name = 'L_ASPARTATE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'asnB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None) +
    met(name = 'ASN', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None), 
    Parameter('fwd_ASNSYNB_RXN', 1), 
    Parameter('rvs_ASNSYNB_RXN', 0))

Rule('ASPAMINOTRANS_RXN',
    prot(name = 'aspC', loc = 'cyt') +
    met(name = 'L_ASPARTATE', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'aspC', loc = 'cyt') +
    met(name = 'OXALACETIC_ACID', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_ASPAMINOTRANS_RXN', 1), 
    Parameter('rvs_ASPAMINOTRANS_RXN', 0))

Rule('ASPARAGHYD_RXN',
    prot(name = 'ansA', loc = 'cyt') +
    met(name = 'ASN', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'ansA', loc = 'cyt') +
    met(name = 'L_ASPARTATE', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None), 
    Parameter('fwd_ASPARAGHYD_RXN', 1), 
    Parameter('rvs_ASPARAGHYD_RXN', 0))

Rule('ASPARTASE_RXN',
    prot(name = 'aspA', loc = 'cyt') +
    met(name = 'L_ASPARTATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'aspA', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'FUM', loc = 'cyt', prot = None), 
    Parameter('fwd_ASPARTASE_RXN', 1), 
    Parameter('rvs_ASPARTASE_RXN', 0))

Rule('ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN',
    prot(name = 'asd', loc = 'cyt') +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'L_ASPARTATE_SEMIALDEHYDE', loc = 'cyt', prot = None) | 
    prot(name = 'asd', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None) +
    met(name = 'L_BETA_ASPARTYL_P', loc = 'cyt', prot = None), 
    Parameter('fwd_ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN', 1), 
    Parameter('rvs_ASPARTATE_SEMIALDEHYDE_DEHYDROGENASE_RXN', 0))

Rule('ASPARTATEKIN_RXN',
    prot(name = 'lysC', loc = 'cyt') +
    met(name = 'L_ASPARTATE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'lysC', loc = 'cyt') +
    met(name = 'L_BETA_ASPARTYL_P', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_ASPARTATEKIN_RXN', 1), 
    Parameter('rvs_ASPARTATEKIN_RXN', 0))

Rule('ATPPHOSPHORIBOSYLTRANS_RXN',
    prot(name = 'hisG', loc = 'cyt') +
    met(name = 'PHOSPHORIBOSYL_ATP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'hisG', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'PRPP', loc = 'cyt', prot = None), 
    Parameter('fwd_ATPPHOSPHORIBOSYLTRANS_RXN', 1), 
    Parameter('rvs_ATPPHOSPHORIBOSYLTRANS_RXN', 0))

Rule('BIS5_ADENOSYL_TRIPHOSPHATASE_RXN',
    prot(name = 'ushA', loc = 'cyt') +
    met(name = 'ADENOSINE5TRIPHOSPHO5ADENOSINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ushA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_BIS5_ADENOSYL_TRIPHOSPHATASE_RXN', 1), 
    Parameter('rvs_BIS5_ADENOSYL_TRIPHOSPHATASE_RXN', 0))

Rule('BRANCHED_CHAINAMINOTRANSFERILEU_RXN',
    prot(name = 'ilvE', loc = 'cyt') +
    met(name = 'ILE', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'ilvE', loc = 'cyt') +
    met(name = '_2_KETO_3_METHYL_VALERATE', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_BRANCHED_CHAINAMINOTRANSFERILEU_RXN', 1), 
    Parameter('rvs_BRANCHED_CHAINAMINOTRANSFERILEU_RXN', 0))

Rule('BRANCHED_CHAINAMINOTRANSFERLEU_RXN',
    prot(name = 'tyrB', loc = 'cyt') +
    met(name = 'LEU', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'tyrB', loc = 'cyt') +
    met(name = '_2K_4CH3_PENTANOATE', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_BRANCHED_CHAINAMINOTRANSFERLEU_RXN', 1), 
    Parameter('rvs_BRANCHED_CHAINAMINOTRANSFERLEU_RXN', 0))

Rule('BRANCHED_CHAINAMINOTRANSFERVAL_RXN',
    prot(name = 'ilvE', loc = 'cyt') +
    met(name = 'VAL', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'ilvE', loc = 'cyt') +
    met(name = '_2_KETO_ISOVALERATE', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_BRANCHED_CHAINAMINOTRANSFERVAL_RXN', 1), 
    Parameter('rvs_BRANCHED_CHAINAMINOTRANSFERVAL_RXN', 0))

Rule('CARBPSYN_RXN',
    prot(name = 'carB', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    met(name = 'HCO3', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'carB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CARBAMOYL_P', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_CARBPSYN_RXN', 1), 
    Parameter('rvs_CARBPSYN_RXN', 0))

Rule('CDPKIN_RXN',
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'CDP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'CTP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_CDPKIN_RXN', 1), 
    Parameter('rvs_CDPKIN_RXN', 0))

Rule('CHORISMATE_SYNTHASE_RXN',
    prot(name = 'aroC', loc = 'cyt') +
    met(name = '_3_ENOLPYRUVYL_SHIKIMATE_5P', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'aroC', loc = 'cyt') +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'CHORISMATE', loc = 'cyt', prot = None), 
    Parameter('fwd_CHORISMATE_SYNTHASE_RXN', 1), 
    Parameter('rvs_CHORISMATE_SYNTHASE_RXN', 0))

Rule('CHORISMATEMUT_RXN',
    prot(name = 'tyrA', loc = 'cyt') +
    met(name = 'CHORISMATE', loc = 'cyt', prot = None) | 
    prot(name = 'tyrA', loc = 'cyt') +
    met(name = 'PREPHENATE', loc = 'cyt', prot = None), 
    Parameter('fwd_CHORISMATEMUT_RXN', 1), 
    Parameter('rvs_CHORISMATEMUT_RXN', 0))

Rule('CITSYN_RXN',
    prot(name = 'gltA', loc = 'cyt') +
    met(name = 'OXALACETIC_ACID', loc = 'cyt', prot = None) +
    met(name = 'ACETYL_COA', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'gltA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CIT', loc = 'cyt', prot = None) +
    met(name = 'CO_A', loc = 'cyt', prot = None), 
    Parameter('fwd_CITSYN_RXN', 1), 
    Parameter('rvs_CITSYN_RXN', 0))

Rule('CTPSYN_RXN',
    prot(name = 'pyrG', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'UTP', loc = 'cyt', prot = None) +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'pyrG', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'CTP', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_CTPSYN_RXN', 1), 
    Parameter('rvs_CTPSYN_RXN', 0))

Rule('CYSTATHIONINE_BETA_LYASE_RXN',
    prot(name = 'malY', loc = 'cyt') +
    met(name = 'L_CYSTATHIONINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'malY', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'HOMO_CYS', loc = 'cyt', prot = None), 
    Parameter('fwd_CYSTATHIONINE_BETA_LYASE_RXN', 1), 
    Parameter('rvs_CYSTATHIONINE_BETA_LYASE_RXN', 0))

Rule('CYSTEINE_AMINOTRANSFERASE_RXN',
    prot(name = 'aspC', loc = 'cyt') +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) +
    met(name = 'CYS', loc = 'cyt', prot = None) | 
    prot(name = 'aspC', loc = 'cyt') +
    met(name = 'GLT', loc = 'cyt', prot = None) +
    met(name = '_3_MERCAPTO_PYRUVATE', loc = 'cyt', prot = None), 
    Parameter('fwd_CYSTEINE_AMINOTRANSFERASE_RXN', 1), 
    Parameter('rvs_CYSTEINE_AMINOTRANSFERASE_RXN', 0))

Rule('CYTDEAM_RXN',
    prot(name = 'codA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'CYTOSINE', loc = 'cyt', prot = None) | 
    prot(name = 'codA', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'URACIL', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_CYTDEAM_RXN', 1), 
    Parameter('rvs_CYTDEAM_RXN', 0))

Rule('CYTIDEAM_RXN',
    prot(name = 'cdd', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'DEOXYCYTIDINE', loc = 'cyt', prot = None) | 
    prot(name = 'cdd', loc = 'cyt') +
    met(name = 'DEOXYURIDINE', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_CYTIDEAM_RXN', 1), 
    Parameter('rvs_CYTIDEAM_RXN', 0))

Rule('CYTIDEAM2_RXN',
    prot(name = 'cdd', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None) | 
    prot(name = 'cdd', loc = 'cyt') +
    met(name = 'URIDINE', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_CYTIDEAM2_RXN', 1), 
    Parameter('rvs_CYTIDEAM2_RXN', 0))

Rule('CYTIDINEKIN_RXN',
    prot(name = 'udk', loc = 'cyt') +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None) +
    met(name = 'GTP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'udk', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CMP', loc = 'cyt', prot = None) +
    met(name = 'GDP', loc = 'cyt', prot = None), 
    Parameter('fwd_CYTIDINEKIN_RXN', 1), 
    Parameter('rvs_CYTIDINEKIN_RXN', 0))

Rule('CYTIKIN_RXN',
    prot(name = 'udk', loc = 'cyt') +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'udk', loc = 'cyt') +
    met(name = 'CMP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_CYTIKIN_RXN', 1), 
    Parameter('rvs_CYTIKIN_RXN', 0))

Rule('D__TARTRATE_DEHYDRATASE_RXN',
    prot(name = 'fumB', loc = 'cyt') +
    met(name = 'D_TARTRATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'fumB', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'OXALACETIC_ACID', loc = 'cyt', prot = None), 
    Parameter('fwd_D__TARTRATE_DEHYDRATASE_RXN', 1), 
    Parameter('rvs_D__TARTRATE_DEHYDRATASE_RXN', 0))

Rule('D_PPENTOMUT_RXN',
    prot(name = 'deoB', loc = 'cyt') +
    met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'cyt', prot = None) | 
    prot(name = 'deoB', loc = 'cyt') +
    met(name = 'DEOXY_RIBOSE_5P', loc = 'cyt', prot = None), 
    Parameter('fwd_D_PPENTOMUT_RXN', 1), 
    Parameter('rvs_D_PPENTOMUT_RXN', 0))

Rule('DADPKIN_RXN',
    prot(name = 'ndk', loc = 'cyt') +
    met(name = 'DADP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'ndk', loc = 'cyt') +
    met(name = 'DATP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_DADPKIN_RXN', 1), 
    Parameter('rvs_DADPKIN_RXN', 0))

Rule('DAHPSYN_RXN',
    prot(name = 'aroG', loc = 'cyt') +
    met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'ERYTHROSE_4P', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aroG', loc = 'cyt') +
    met(name = '_3_DEOXY_D_ARABINO_HEPTULOSONATE_7_P', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_DAHPSYN_RXN', 1), 
    Parameter('rvs_DAHPSYN_RXN', 0))

Rule('DCDPKIN_RXN',
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'DCDP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'DCTP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_DCDPKIN_RXN', 1), 
    Parameter('rvs_DCDPKIN_RXN', 0))

Rule('DCTP_DEAM_RXN',
    prot(name = 'dcd', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'DCTP', loc = 'cyt', prot = None) | 
    prot(name = 'dcd', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'DUTP', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_DCTP_DEAM_RXN', 1), 
    Parameter('rvs_DCTP_DEAM_RXN', 0))

Rule('DCTP_PYROPHOSPHATASE_RXN',
    prot(name = 'nudI', loc = 'cyt') +
    met(name = 'DCTP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'nudI', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DCMP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None), 
    Parameter('fwd_DCTP_PYROPHOSPHATASE_RXN', 1), 
    Parameter('rvs_DCTP_PYROPHOSPHATASE_RXN', 0))

Rule('DEOXYADENPHOSPHOR_RXN',
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'DEOXYADENOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'ADENINE', loc = 'cyt', prot = None) +
    met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'cyt', prot = None), 
    Parameter('fwd_DEOXYADENPHOSPHOR_RXN', 1), 
    Parameter('rvs_DEOXYADENPHOSPHOR_RXN', 0))

Rule('DEOXYGUANPHOSPHOR_RXN',
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'DEOXYGUANOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'GUANINE', loc = 'cyt', prot = None) +
    met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'cyt', prot = None), 
    Parameter('fwd_DEOXYGUANPHOSPHOR_RXN', 1), 
    Parameter('rvs_DEOXYGUANPHOSPHOR_RXN', 0))

Rule('DEOXYINOPHOSPHOR_RXN',
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'DEOXYINOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'HYPOXANTHINE', loc = 'cyt', prot = None) +
    met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'cyt', prot = None), 
    Parameter('fwd_DEOXYINOPHOSPHOR_RXN', 1), 
    Parameter('rvs_DEOXYINOPHOSPHOR_RXN', 0))

Rule('DEOXYNUCLEOTIDE_3_PHOSPHATASE_RXN',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'Deoxy_Ribonucleoside_3P', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'Deoxy_Ribonucleosides', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_DEOXYNUCLEOTIDE_3_PHOSPHATASE_RXN', 1), 
    Parameter('rvs_DEOXYNUCLEOTIDE_3_PHOSPHATASE_RXN', 0))

Rule('DGDPKIN_RXN',
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'DGDP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'DGTP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_DGDPKIN_RXN', 1), 
    Parameter('rvs_DGDPKIN_RXN', 0))

Rule('DIAMINOPIMDECARB_RXN',
    prot(name = 'lysA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'MESO_DIAMINOPIMELATE', loc = 'cyt', prot = None) | 
    prot(name = 'lysA', loc = 'cyt') +
    met(name = 'LYS', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None), 
    Parameter('fwd_DIAMINOPIMDECARB_RXN', 1), 
    Parameter('rvs_DIAMINOPIMDECARB_RXN', 0))

Rule('DIAMINOPIMEPIM_RXN',
    prot(name = 'dapF', loc = 'cyt') +
    met(name = 'LL_DIAMINOPIMELATE', loc = 'cyt', prot = None) | 
    prot(name = 'dapF', loc = 'cyt') +
    met(name = 'MESO_DIAMINOPIMELATE', loc = 'cyt', prot = None), 
    Parameter('fwd_DIAMINOPIMEPIM_RXN', 1), 
    Parameter('rvs_DIAMINOPIMEPIM_RXN', 0))

Rule('DIHYDRODIPICSYN_RXN',
    prot(name = 'dapA', loc = 'cyt') +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'L_ASPARTATE_SEMIALDEHYDE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'dapA', loc = 'cyt') +
    met(name = 'CPD_14443', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_DIHYDRODIPICSYN_RXN', 1), 
    Parameter('rvs_DIHYDRODIPICSYN_RXN', 0))

Rule('DIHYDROOROT_RXN',
    prot(name = 'pyrC', loc = 'cyt') +
    met(name = 'DI_H_OROTATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'pyrC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CARBAMYUL_L_ASPARTATE', loc = 'cyt', prot = None), 
    Parameter('fwd_DIHYDROOROT_RXN', 1), 
    Parameter('rvs_DIHYDROOROT_RXN', 0))

Rule('DIHYDROOROTATE_DEHYDROGENASE_RXN',
    prot(name = 'pyrD', loc = 'cyt') +
    met(name = 'ETR_Quinones', loc = 'cyt', prot = None) +
    met(name = 'DI_H_OROTATE', loc = 'cyt', prot = None) | 
    prot(name = 'pyrD', loc = 'cyt') +
    met(name = 'ETR_Quinols', loc = 'cyt', prot = None) +
    met(name = 'OROTATE', loc = 'cyt', prot = None), 
    Parameter('fwd_DIHYDROOROTATE_DEHYDROGENASE_RXN', 1), 
    Parameter('rvs_DIHYDROOROTATE_DEHYDROGENASE_RXN', 0))

Rule('DIHYDROXYISOVALDEHYDRAT_RXN',
    prot(name = 'ilvD', loc = 'cyt') +
    met(name = 'CPD_13357', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ilvD', loc = 'cyt') +
    met(name = '_2_KETO_ISOVALERATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_DIHYDROXYISOVALDEHYDRAT_RXN', 1), 
    Parameter('rvs_DIHYDROXYISOVALDEHYDRAT_RXN', 0))

Rule('DIHYDROXYMETVALDEHYDRAT_RXN',
    prot(name = 'ilvD', loc = 'cyt') +
    met(name = '_1_KETO_2_METHYLVALERATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ilvD', loc = 'cyt') +
    met(name = '_2_KETO_3_METHYL_VALERATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_DIHYDROXYMETVALDEHYDRAT_RXN', 1), 
    Parameter('rvs_DIHYDROXYMETVALDEHYDRAT_RXN', 0))

Rule('DTDPKIN_RXN',
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'TDP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'TTP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_DTDPKIN_RXN', 1), 
    Parameter('rvs_DTDPKIN_RXN', 0))

Rule('DTMPKI_RXN',
    prot(name = 'tmk', loc = 'cyt') +
    met(name = 'TMP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'tmk', loc = 'cyt') +
    met(name = 'TDP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_DTMPKI_RXN', 1), 
    Parameter('rvs_DTMPKI_RXN', 0))

Rule('DUDPKIN_RXN',
    prot(name = 'ndk', loc = 'cyt') +
    met(name = 'DUDP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'ndk', loc = 'cyt') +
    met(name = 'DUTP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_DUDPKIN_RXN', 1), 
    Parameter('rvs_DUDPKIN_RXN', 0))

Rule('DURIDKI_RXN',
    prot(name = 'tdk', loc = 'cyt') +
    met(name = 'DEOXYURIDINE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'tdk', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DUMP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_DURIDKI_RXN', 1), 
    Parameter('rvs_DURIDKI_RXN', 0))

Rule('DUTP_PYROP_RXN',
    prot(name = 'dut', loc = 'cyt') +
    met(name = 'DUTP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'dut', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DUMP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None), 
    Parameter('fwd_DUTP_PYROP_RXN', 1), 
    Parameter('rvs_DUTP_PYROP_RXN', 0))

Rule('F16ALDOLASE_RXN',
    prot(name = 'fbaA', loc = 'cyt') +
    met(name = 'FRUCTOSE_16_DIPHOSPHATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'fbaA', loc = 'cyt') +
    met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'GAP', loc = 'cyt', prot = None), 
    Parameter('fwd_F16ALDOLASE_RXN', 1), 
    Parameter('rvs_F16ALDOLASE_RXN', 0))

Rule('F16BDEPHOS_RXN',
    prot(name = 'fbp', loc = 'cyt') +
    met(name = 'FRUCTOSE_16_DIPHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'fbp', loc = 'cyt') +
    met(name = 'FRUCTOSE_6P', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_F16BDEPHOS_RXN', 1), 
    Parameter('rvs_F16BDEPHOS_RXN', 0))

Rule('FGAMSYN_RXN',
    prot(name = 'purL', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', loc = 'cyt', prot = None) +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'purL', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = '_5_PHOSPHORIBOSYL_N_FORMYLGLYCINEAMIDINE', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_FGAMSYN_RXN', 1), 
    Parameter('rvs_FGAMSYN_RXN', 0))

Rule('FUMHYDR_RXN',
    prot(name = 'fumB', loc = 'cyt') +
    met(name = 'MAL', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'fumB', loc = 'cyt') +
    met(name = 'FUM', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_FUMHYDR_RXN', 1), 
    Parameter('rvs_FUMHYDR_RXN', 0))

Rule('GAPOXNPHOSPHN_RXN',
    prot(name = 'gapA', loc = 'cyt') +
    met(name = 'GAP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) | 
    prot(name = 'gapA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DPG', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None), 
    Parameter('fwd_GAPOXNPHOSPHN_RXN', 1), 
    Parameter('rvs_GAPOXNPHOSPHN_RXN', 0))

Rule('GART_RXN',
    prot(name = 'purN', loc = 'cyt') +
    met(name = 'FORMYL_THF_GLU_N', loc = 'cyt', prot = None) +
    met(name = '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'purN', loc = 'cyt') +
    met(name = 'THF_GLU_N', loc = 'cyt', prot = None) +
    met(name = '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_GART_RXN', 1), 
    Parameter('rvs_GART_RXN', 0))

Rule('GARTRANSFORMYL2_RXN',
    prot(name = 'purT', loc = 'cyt') +
    met(name = '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', loc = 'cyt', prot = None) +
    met(name = 'FORMATE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'purT', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = '_5_P_RIBOSYL_N_FORMYLGLYCINEAMIDE', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_GARTRANSFORMYL2_RXN', 1), 
    Parameter('rvs_GARTRANSFORMYL2_RXN', 0))

Rule('GDPKIN_RXN',
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'GDP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'GTP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_GDPKIN_RXN', 1), 
    Parameter('rvs_GDPKIN_RXN', 0))

Rule('GLU6PDEHYDROG_RXN',
    prot(name = 'zwf', loc = 'cyt') +
    met(name = 'D_glucopyranose_6_phosphate', loc = 'cyt', prot = None) +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'zwf', loc = 'cyt') +
    met(name = 'D_6_P_GLUCONO_DELTA_LACTONE', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_GLU6PDEHYDROG_RXN', 1), 
    Parameter('rvs_GLU6PDEHYDROG_RXN', 0))

Rule('GLUTAMIDOTRANS_RXN',
    prot(name = 'hisH', loc = 'cyt') +
    met(name = 'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P', loc = 'cyt', prot = None) +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    None +
    None | 
    prot(name = 'hisH', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None) +
    met(name = 'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P', loc = 'cyt', prot = None) +
    met(name = 'AICAR', loc = 'cyt', prot = None), 
    Parameter('fwd_GLUTAMIDOTRANS_RXN', 1), 
    Parameter('rvs_GLUTAMIDOTRANS_RXN', 0))

Rule('GLUTAMIN_RXN',
    prot(name = 'asnB', loc = 'cyt') +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'asnB', loc = 'cyt') +
    met(name = 'GLT', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None), 
    Parameter('fwd_GLUTAMIN_RXN', 1), 
    Parameter('rvs_GLUTAMIN_RXN', 0))

Rule('GLYCEROL_2_PHOSPHATASE_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'CPD_536', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'GLYCEROL', loc = 'cyt', prot = None), 
    Parameter('fwd_GLYCEROL_2_PHOSPHATASE_RXN', 1), 
    Parameter('rvs_GLYCEROL_2_PHOSPHATASE_RXN', 0))

Rule('GLYOHMETRANS_RXN',
    prot(name = 'glyA', loc = 'cyt') +
    met(name = 'SER', loc = 'cyt', prot = None) +
    met(name = 'THF_GLU_N', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'glyA', loc = 'cyt') +
    met(name = 'GLY', loc = 'cyt', prot = None) +
    met(name = 'METHYLENE_THF_GLU_N', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_GLYOHMETRANS_RXN', 1), 
    Parameter('rvs_GLYOHMETRANS_RXN', 0))

Rule('GLYRIBONUCSYN_RXN',
    prot(name = 'purD', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = '_5_P_BETA_D_RIBOSYL_AMINE', loc = 'cyt', prot = None) +
    met(name = 'GLY', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'purD', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = '_5_PHOSPHO_RIBOSYL_GLYCINEAMIDE', loc = 'cyt', prot = None), 
    Parameter('fwd_GLYRIBONUCSYN_RXN', 1), 
    Parameter('rvs_GLYRIBONUCSYN_RXN', 0))

Rule('GMKALT_RXN',
    prot(name = 'gmk', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'DGMP', loc = 'cyt', prot = None) | 
    prot(name = 'gmk', loc = 'cyt') +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'DGDP', loc = 'cyt', prot = None), 
    Parameter('fwd_GMKALT_RXN', 1), 
    Parameter('rvs_GMKALT_RXN', 0))

Rule('GMP_SYN_GLUT_RXN',
    prot(name = 'guaA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'guaA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None) +
    met(name = 'GMP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None), 
    Parameter('fwd_GMP_SYN_GLUT_RXN', 1), 
    Parameter('rvs_GMP_SYN_GLUT_RXN', 0))

Rule('GMP_SYN_NH3_RXN',
    prot(name = 'guaA', loc = 'cyt') +
    met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'guaA', loc = 'cyt') +
    met(name = 'GMP', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_GMP_SYN_NH3_RXN', 1), 
    Parameter('rvs_GMP_SYN_NH3_RXN', 0))

Rule('GPH_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'CPD_67', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'GLYCOLLATE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_GPH_RXN', 1), 
    Parameter('rvs_GPH_RXN', 0))

Rule('GUANINE_DEAMINASE_RXN',
    prot(name = 'guaD', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'GUANINE', loc = 'cyt', prot = None) | 
    prot(name = 'guaD', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'XANTHINE', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_GUANINE_DEAMINASE_RXN', 1), 
    Parameter('rvs_GUANINE_DEAMINASE_RXN', 0))

Rule('GUANOSINEKIN_RXN',
    prot(name = 'gsk', loc = 'cyt') +
    met(name = 'GUANOSINE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'gsk', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'GMP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_GUANOSINEKIN_RXN', 1), 
    Parameter('rvs_GUANOSINEKIN_RXN', 0))

Rule('GUANPRIBOSYLTRAN_RXN',
    prot(name = 'gpt', loc = 'cyt') +
    met(name = 'GMP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) | 
    prot(name = 'gpt', loc = 'cyt') +
    met(name = 'GUANINE', loc = 'cyt', prot = None) +
    met(name = 'PRPP', loc = 'cyt', prot = None), 
    Parameter('fwd_GUANPRIBOSYLTRAN_RXN', 1), 
    Parameter('rvs_GUANPRIBOSYLTRAN_RXN', 0))

Rule('GUANYL_KIN_RXN',
    prot(name = 'gmk', loc = 'cyt') +
    met(name = 'GMP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'gmk', loc = 'cyt') +
    met(name = 'GDP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_GUANYL_KIN_RXN', 1), 
    Parameter('rvs_GUANYL_KIN_RXN', 0))

Rule('HISTALDEHYD_RXN',
    prot(name = 'hisD', loc = 'cyt') +
    met(name = 'HISTIDINAL', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'hisD', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'HIS', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None), 
    Parameter('fwd_HISTALDEHYD_RXN', 1), 
    Parameter('rvs_HISTALDEHYD_RXN', 0))

Rule('HISTAMINOTRANS_RXN',
    prot(name = 'hisC', loc = 'cyt') +
    met(name = 'L_HISTIDINOL_P', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'hisC', loc = 'cyt') +
    met(name = 'IMIDAZOLE_ACETOL_P', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_HISTAMINOTRANS_RXN', 1), 
    Parameter('rvs_HISTAMINOTRANS_RXN', 0))

Rule('HISTCYCLOHYD_RXN',
    prot(name = 'hisI', loc = 'cyt') +
    met(name = 'PHOSPHORIBOSYL_AMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'hisI', loc = 'cyt') +
    met(name = 'PHOSPHORIBOSYL_FORMIMINO_AICAR_P', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_HISTCYCLOHYD_RXN', 1), 
    Parameter('rvs_HISTCYCLOHYD_RXN', 0))

Rule('HISTIDPHOS_RXN',
    prot(name = 'hisB', loc = 'cyt') +
    met(name = 'L_HISTIDINOL_P', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'hisB', loc = 'cyt') +
    met(name = 'HISTIDINOL', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_HISTIDPHOS_RXN', 1), 
    Parameter('rvs_HISTIDPHOS_RXN', 0))

Rule('HISTOLDEHYD_RXN',
    prot(name = 'hisD', loc = 'cyt') +
    met(name = 'HISTIDINOL', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'hisD', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'HISTIDINAL', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None), 
    Parameter('fwd_HISTOLDEHYD_RXN', 1), 
    Parameter('rvs_HISTOLDEHYD_RXN', 0))

Rule('HISTPRATPHYD_RXN',
    prot(name = 'hisI', loc = 'cyt') +
    met(name = 'PHOSPHORIBOSYL_ATP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'hisI', loc = 'cyt') +
    met(name = 'PHOSPHORIBOSYL_AMP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_HISTPRATPHYD_RXN', 1), 
    Parameter('rvs_HISTPRATPHYD_RXN', 0))

Rule('HOMOCYSMET_RXN',
    prot(name = 'metE', loc = 'cyt') +
    met(name = 'CPD_1302', loc = 'cyt', prot = None) +
    met(name = 'HOMO_CYS', loc = 'cyt', prot = None) | 
    prot(name = 'metE', loc = 'cyt') +
    met(name = 'MET', loc = 'cyt', prot = None) +
    met(name = 'CPD_1301', loc = 'cyt', prot = None), 
    Parameter('fwd_HOMOCYSMET_RXN', 1), 
    Parameter('rvs_HOMOCYSMET_RXN', 0))

Rule('HOMOCYSMETB12_RXN',
    prot(name = 'metH', loc = 'cyt') +
    met(name = 'HOMO_CYS', loc = 'cyt', prot = None) +
    met(name = '_5_METHYL_THF_GLU_N', loc = 'cyt', prot = None) | 
    prot(name = 'metH', loc = 'cyt') +
    met(name = 'MET', loc = 'cyt', prot = None) +
    met(name = 'THF_GLU_N', loc = 'cyt', prot = None), 
    Parameter('fwd_HOMOCYSMETB12_RXN', 1), 
    Parameter('rvs_HOMOCYSMETB12_RXN', 0))

Rule('HOMOSERDEHYDROG_RXN',
    prot(name = 'thrA', loc = 'cyt') +
    met(name = 'NAD_P_OR_NOP', loc = 'cyt', prot = None) +
    met(name = 'HOMO_SER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'thrA', loc = 'cyt') +
    met(name = 'NADH_P_OR_NOP', loc = 'cyt', prot = None) +
    met(name = 'L_ASPARTATE_SEMIALDEHYDE', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_HOMOSERDEHYDROG_RXN', 1), 
    Parameter('rvs_HOMOSERDEHYDROG_RXN', 0))

Rule('HOMOSERKIN_RXN',
    prot(name = 'thrB', loc = 'cyt') +
    met(name = 'HOMO_SER', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'thrB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'O_PHOSPHO_L_HOMOSERINE', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_HOMOSERKIN_RXN', 1), 
    Parameter('rvs_HOMOSERKIN_RXN', 0))

Rule('HOMSUCTRAN_RXN',
    prot(name = 'metA', loc = 'cyt') +
    met(name = 'HOMO_SER', loc = 'cyt', prot = None) +
    met(name = 'SUC_COA', loc = 'cyt', prot = None) | 
    prot(name = 'metA', loc = 'cyt') +
    met(name = 'O_SUCCINYL_L_HOMOSERINE', loc = 'cyt', prot = None) +
    met(name = 'CO_A', loc = 'cyt', prot = None), 
    Parameter('fwd_HOMSUCTRAN_RXN', 1), 
    Parameter('rvs_HOMSUCTRAN_RXN', 0))

Rule('HYPOXANPRIBOSYLTRAN_RXN',
    prot(name = 'hpt', loc = 'cyt') +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'IMP', loc = 'cyt', prot = None) | 
    prot(name = 'hpt', loc = 'cyt') +
    met(name = 'PRPP', loc = 'cyt', prot = None) +
    met(name = 'HYPOXANTHINE', loc = 'cyt', prot = None), 
    Parameter('fwd_HYPOXANPRIBOSYLTRAN_RXN', 1), 
    Parameter('rvs_HYPOXANPRIBOSYLTRAN_RXN', 0))

Rule('IGPSYN_RXN',
    prot(name = 'trpC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'trpC', loc = 'cyt') +
    met(name = 'INDOLE_3_GLYCEROL_P', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_IGPSYN_RXN', 1), 
    Parameter('rvs_IGPSYN_RXN', 0))

Rule('IMIDPHOSDEHYD_RXN',
    prot(name = 'hisB', loc = 'cyt') +
    met(name = 'D_ERYTHRO_IMIDAZOLE_GLYCEROL_P', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'hisB', loc = 'cyt') +
    met(name = 'IMIDAZOLE_ACETOL_P', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_IMIDPHOSDEHYD_RXN', 1), 
    Parameter('rvs_IMIDPHOSDEHYD_RXN', 0))

Rule('IMP_DEHYDROG_RXN',
    prot(name = 'guaB', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'IMP', loc = 'cyt', prot = None) | 
    prot(name = 'guaB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'cyt', prot = None), 
    Parameter('fwd_IMP_DEHYDROG_RXN', 1), 
    Parameter('rvs_IMP_DEHYDROG_RXN', 0))

Rule('IMPCYCLOHYDROLASE_RXN',
    prot(name = 'purH', loc = 'cyt') +
    met(name = 'IMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'purH', loc = 'cyt') +
    met(name = 'PHOSPHORIBOSYL_FORMAMIDO_CARBOXAMIDE', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_IMPCYCLOHYDROLASE_RXN', 1), 
    Parameter('rvs_IMPCYCLOHYDROLASE_RXN', 0))

Rule('INOPHOSPHOR_RXN',
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'INOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'RIBOSE_1P', loc = 'cyt', prot = None) +
    met(name = 'HYPOXANTHINE', loc = 'cyt', prot = None), 
    Parameter('fwd_INOPHOSPHOR_RXN', 1), 
    Parameter('rvs_INOPHOSPHOR_RXN', 0))

Rule('INORGPYROPHOSPHAT_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_INORGPYROPHOSPHAT_RXN', 1), 
    Parameter('rvs_INORGPYROPHOSPHAT_RXN', 0))

Rule('INOSINATE_NUCLEOSIDASE_RXN',
    prot(name = 'ppnN', loc = 'cyt') +
    met(name = 'IMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'ppnN', loc = 'cyt') +
    met(name = 'HYPOXANTHINE', loc = 'cyt', prot = None) +
    met(name = 'CPD_15317', loc = 'cyt', prot = None), 
    Parameter('fwd_INOSINATE_NUCLEOSIDASE_RXN', 1), 
    Parameter('rvs_INOSINATE_NUCLEOSIDASE_RXN', 0))

Rule('INOSINE_NUCLEOSIDASE_RXN',
    prot(name = 'rihC', loc = 'cyt') +
    met(name = 'INOSINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'rihC', loc = 'cyt') +
    met(name = 'D_Ribofuranose', loc = 'cyt', prot = None) +
    met(name = 'HYPOXANTHINE', loc = 'cyt', prot = None), 
    Parameter('fwd_INOSINE_NUCLEOSIDASE_RXN', 1), 
    Parameter('rvs_INOSINE_NUCLEOSIDASE_RXN', 0))

Rule('INOSINEKIN_RXN',
    prot(name = 'gsk', loc = 'cyt') +
    met(name = 'INOSINE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'gsk', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'IMP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_INOSINEKIN_RXN', 1), 
    Parameter('rvs_INOSINEKIN_RXN', 0))

Rule('ISOCIT_CLEAV_RXN',
    prot(name = 'aceA', loc = 'cyt') +
    met(name = 'THREO_DS_ISO_CITRATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'aceA', loc = 'cyt') +
    met(name = 'GLYOX', loc = 'cyt', prot = None) +
    met(name = 'SUC', loc = 'cyt', prot = None), 
    Parameter('fwd_ISOCIT_CLEAV_RXN', 1), 
    Parameter('rvs_ISOCIT_CLEAV_RXN', 0))

Rule('ISOCITDEH_RXN',
    prot(name = 'icd', loc = 'cyt') +
    met(name = 'THREO_DS_ISO_CITRATE', loc = 'cyt', prot = None) +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'icd', loc = 'cyt') +
    met(name = 'NADPH', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None), 
    Parameter('fwd_ISOCITDEH_RXN', 1), 
    Parameter('rvs_ISOCITDEH_RXN', 0))

Rule('KETOGLUTREDUCT_RXN',
    prot(name = 'serA', loc = 'cyt') +
    met(name = 'R_2_HYDROXYGLUTARATE', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'serA', loc = 'cyt') +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_KETOGLUTREDUCT_RXN', 1), 
    Parameter('rvs_KETOGLUTREDUCT_RXN', 0))

Rule('LCYSDESULF_RXN',
    prot(name = 'metC', loc = 'cyt') +
    met(name = 'CYS', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'metC', loc = 'cyt') +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'HS', loc = 'cyt', prot = None), 
    Parameter('fwd_LCYSDESULF_RXN', 1), 
    Parameter('rvs_LCYSDESULF_RXN', 0))

Rule('MALATE_DEH_RXN',
    prot(name = 'mdh', loc = 'cyt') +
    met(name = 'MAL', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'mdh', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'OXALACETIC_ACID', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None), 
    Parameter('fwd_MALATE_DEH_RXN', 1), 
    Parameter('rvs_MALATE_DEH_RXN', 0))

Rule('MALATE_DEHYDROGENASE_ACCEPTOR_RXN',
    prot(name = 'mqo', loc = 'cyt') +
    met(name = 'ETR_Quinones', loc = 'cyt', prot = None) +
    met(name = 'MAL', loc = 'cyt', prot = None) | 
    prot(name = 'mqo', loc = 'cyt') +
    met(name = 'ETR_Quinols', loc = 'cyt', prot = None) +
    met(name = 'OXALACETIC_ACID', loc = 'cyt', prot = None), 
    Parameter('fwd_MALATE_DEHYDROGENASE_ACCEPTOR_RXN', 1), 
    Parameter('rvs_MALATE_DEHYDROGENASE_ACCEPTOR_RXN', 0))

Rule('MALIC_NADP_RXN',
    prot(name = 'maeB', loc = 'cyt') +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    met(name = 'MAL', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'maeB', loc = 'cyt') +
    met(name = 'NADPH', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None), 
    Parameter('fwd_MALIC_NADP_RXN', 1), 
    Parameter('rvs_MALIC_NADP_RXN', 0))

Rule('MALSYN_RXN',
    prot(name = 'aceB', loc = 'cyt') +
    met(name = 'ACETYL_COA', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'GLYOX', loc = 'cyt', prot = None) | 
    prot(name = 'aceB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'MAL', loc = 'cyt', prot = None) +
    met(name = 'CO_A', loc = 'cyt', prot = None), 
    Parameter('fwd_MALSYN_RXN', 1), 
    Parameter('rvs_MALSYN_RXN', 0))

Rule('METBALT_RXN',
    prot(name = 'metB', loc = 'cyt') +
    met(name = 'O_SUCCINYL_L_HOMOSERINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None +
    None | 
    prot(name = 'metB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = '_2_OXOBUTANOATE', loc = 'cyt', prot = None) +
    met(name = 'SUC', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None), 
    Parameter('fwd_METBALT_RXN', 1), 
    Parameter('rvs_METBALT_RXN', 0))

Rule('NAD_SYNTH_GLN_RXN',
    prot(name = 'nadE', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'DEAMIDO_NAD', loc = 'cyt', prot = None) +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'nadE', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_NAD_SYNTH_GLN_RXN', 1), 
    Parameter('rvs_NAD_SYNTH_GLN_RXN', 0))

Rule('NAD_SYNTH_NH3_RXN',
    prot(name = 'nadE', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'DEAMIDO_NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'nadE', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None), 
    Parameter('fwd_NAD_SYNTH_NH3_RXN', 1), 
    Parameter('rvs_NAD_SYNTH_NH3_RXN', 0))

Rule('NICONUCADENYLYLTRAN_RXN',
    prot(name = 'nadD', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'NICOTINATE_NUCLEOTIDE', loc = 'cyt', prot = None) | 
    prot(name = 'nadD', loc = 'cyt') +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'DEAMIDO_NAD', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_NICONUCADENYLYLTRAN_RXN', 1), 
    Parameter('rvs_NICONUCADENYLYLTRAN_RXN', 0))

Rule('NICOTINAMID_RXN',
    prot(name = 'pncA', loc = 'cyt') +
    met(name = 'NIACINAMIDE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'pncA', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'NIACINE', loc = 'cyt', prot = None), 
    Parameter('fwd_NICOTINAMID_RXN', 1), 
    Parameter('rvs_NICOTINAMID_RXN', 0))

Rule('NICOTINATEPRIBOSYLTRANS_RXN',
    prot(name = 'pncB', loc = 'cyt') +
    met(name = 'NIACINE', loc = 'cyt', prot = None) +
    met(name = 'PRPP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'pncB', loc = 'cyt') +
    met(name = 'NICOTINATE_NUCLEOTIDE', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_NICOTINATEPRIBOSYLTRANS_RXN', 1), 
    Parameter('rvs_NICOTINATEPRIBOSYLTRANS_RXN', 0))

Rule('NUCLEOSIDE_DIP_KIN_RXN',
    prot(name = 'ndk', loc = 'cyt') +
    met(name = 'Nucleoside_Diphosphates', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'ndk', loc = 'cyt') +
    met(name = 'Nucleoside_Triphosphates', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_NUCLEOSIDE_DIP_KIN_RXN', 1), 
    Parameter('rvs_NUCLEOSIDE_DIP_KIN_RXN', 0))

Rule('NUCLEOTIDE_PYROPHOSPHATASE_RXN',
    prot(name = 'mazG', loc = 'cyt') +
    met(name = 'Nucleoside_Triphosphates', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'mazG', loc = 'cyt') +
    met(name = 'Nucleoside_Monophosphates', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_NUCLEOTIDE_PYROPHOSPHATASE_RXN', 1), 
    Parameter('rvs_NUCLEOTIDE_PYROPHOSPHATASE_RXN', 0))

Rule('O_SUCCHOMOSERLYASE_RXN',
    prot(name = 'metB', loc = 'cyt') +
    met(name = 'CYS', loc = 'cyt', prot = None) +
    met(name = 'O_SUCCINYL_L_HOMOSERINE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'metB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'SUC', loc = 'cyt', prot = None) +
    met(name = 'L_CYSTATHIONINE', loc = 'cyt', prot = None), 
    Parameter('fwd_O_SUCCHOMOSERLYASE_RXN', 1), 
    Parameter('rvs_O_SUCCHOMOSERLYASE_RXN', 0))

Rule('OROPRIBTRANS_RXN',
    prot(name = 'pyrE', loc = 'cyt') +
    met(name = 'OROTIDINE_5_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) | 
    prot(name = 'pyrE', loc = 'cyt') +
    met(name = 'PRPP', loc = 'cyt', prot = None) +
    met(name = 'OROTATE', loc = 'cyt', prot = None), 
    Parameter('fwd_OROPRIBTRANS_RXN', 1), 
    Parameter('rvs_OROPRIBTRANS_RXN', 0))

Rule('OROTPDECARB_RXN',
    prot(name = 'pyrF', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'OROTIDINE_5_PHOSPHATE', loc = 'cyt', prot = None) | 
    prot(name = 'pyrF', loc = 'cyt') +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'UMP', loc = 'cyt', prot = None), 
    Parameter('fwd_OROTPDECARB_RXN', 1), 
    Parameter('rvs_OROTPDECARB_RXN', 0))

Rule('OXALOACETATE_TAUTOMERASE_RXN',
    prot(name = 'fumA', loc = 'cyt') +
    met(name = 'OXALACETIC_ACID', loc = 'cyt', prot = None) | 
    prot(name = 'fumA', loc = 'cyt') +
    met(name = 'ENOL_OXALOACETATE', loc = 'cyt', prot = None), 
    Parameter('fwd_OXALOACETATE_TAUTOMERASE_RXN', 1), 
    Parameter('rvs_OXALOACETATE_TAUTOMERASE_RXN', 0))

Rule('PEPCARBOXYKIN_RXN',
    prot(name = 'pck', loc = 'cyt') +
    met(name = 'OXALACETIC_ACID', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'pck', loc = 'cyt') +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_PEPCARBOXYKIN_RXN', 1), 
    Parameter('rvs_PEPCARBOXYKIN_RXN', 0))

Rule('PEPDEPHOS_RXN',
    prot(name = 'pykA', loc = 'cyt') +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'pykA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'cyt', prot = None), 
    Parameter('fwd_PEPDEPHOS_RXN', 1), 
    Parameter('rvs_PEPDEPHOS_RXN', 0))

Rule('PEPSYNTH_RXN',
    prot(name = 'ppsA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ppsA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None), 
    Parameter('fwd_PEPSYNTH_RXN', 1), 
    Parameter('rvs_PEPSYNTH_RXN', 0))

Rule('PGLUCISOM_RXN',
    prot(name = 'pgi', loc = 'cyt') +
    met(name = 'D_glucopyranose_6_phosphate', loc = 'cyt', prot = None) | 
    prot(name = 'pgi', loc = 'cyt') +
    met(name = 'FRUCTOSE_6P', loc = 'cyt', prot = None), 
    Parameter('fwd_PGLUCISOM_RXN', 1), 
    Parameter('rvs_PGLUCISOM_RXN', 0))

Rule('PGLYCDEHYDROG_RXN',
    prot(name = 'serA', loc = 'cyt') +
    met(name = 'G3P', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'serA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = '_3_P_HYDROXYPYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None), 
    Parameter('fwd_PGLYCDEHYDROG_RXN', 1), 
    Parameter('rvs_PGLYCDEHYDROG_RXN', 0))

Rule('PHOSGLYPHOS_RXN',
    prot(name = 'pgk', loc = 'cyt') +
    met(name = 'G3P', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'pgk', loc = 'cyt') +
    met(name = 'DPG', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_PHOSGLYPHOS_RXN', 1), 
    Parameter('rvs_PHOSGLYPHOS_RXN', 0))

Rule('PHOSPHOAMIDASE_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'CREATINE_P', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'CREATINE', loc = 'cyt', prot = None), 
    Parameter('fwd_PHOSPHOAMIDASE_RXN', 1), 
    Parameter('rvs_PHOSPHOAMIDASE_RXN', 0))

Rule('PHOSPHOENOLPYRUVATE_PHOSPHATASE_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'PHOSPHO_ENOL_PYRUVATE', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_PHOSPHOENOLPYRUVATE_PHOSPHATASE_RXN', 1), 
    Parameter('rvs_PHOSPHOENOLPYRUVATE_PHOSPHATASE_RXN', 0))

Rule('PHOSPHOGLYCERATE_PHOSPHATASE_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = '_2_PG', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'GLYCERATE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_PHOSPHOGLYCERATE_PHOSPHATASE_RXN', 1), 
    Parameter('rvs_PHOSPHOGLYCERATE_PHOSPHATASE_RXN', 0))

Rule('PNP_RXN',
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'Purine_Ribonucleosides', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'Purine_Bases', loc = 'cyt', prot = None) +
    met(name = 'RIBOSE_1P', loc = 'cyt', prot = None), 
    Parameter('fwd_PNP_RXN', 1), 
    Parameter('rvs_PNP_RXN', 0))

Rule('PPENTOMUT_RXN',
    prot(name = 'deoB', loc = 'cyt') +
    met(name = 'RIBOSE_1P', loc = 'cyt', prot = None) | 
    prot(name = 'deoB', loc = 'cyt') +
    met(name = 'RIBOSE_5P', loc = 'cyt', prot = None), 
    Parameter('fwd_PPENTOMUT_RXN', 1), 
    Parameter('rvs_PPENTOMUT_RXN', 0))

Rule('PRAISOM_RXN',
    prot(name = 'trpC', loc = 'cyt') +
    met(name = 'N_5_PHOSPHORIBOSYL_ANTHRANILATE', loc = 'cyt', prot = None) | 
    prot(name = 'trpC', loc = 'cyt') +
    met(name = 'CARBOXYPHENYLAMINO_DEOXYRIBULOSE_P', loc = 'cyt', prot = None), 
    Parameter('fwd_PRAISOM_RXN', 1), 
    Parameter('rvs_PRAISOM_RXN', 0))

Rule('PREPHENATEDEHYDRAT_RXN',
    prot(name = 'pheA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'PREPHENATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'pheA', loc = 'cyt') +
    met(name = 'PHENYL_PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None), 
    Parameter('fwd_PREPHENATEDEHYDRAT_RXN', 1), 
    Parameter('rvs_PREPHENATEDEHYDRAT_RXN', 0))

Rule('PREPHENATEDEHYDROG_RXN',
    prot(name = 'tyrA', loc = 'cyt') +
    met(name = 'PREPHENATE', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'tyrA', loc = 'cyt') +
    met(name = 'P_HYDROXY_PHENYLPYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None), 
    Parameter('fwd_PREPHENATEDEHYDROG_RXN', 1), 
    Parameter('rvs_PREPHENATEDEHYDROG_RXN', 0))

Rule('PRIBFAICARPISOM_RXN',
    prot(name = 'hisA', loc = 'cyt') +
    met(name = 'PHOSPHORIBOSYL_FORMIMINO_AICAR_P', loc = 'cyt', prot = None) | 
    prot(name = 'hisA', loc = 'cyt') +
    met(name = 'PHOSPHORIBULOSYL_FORMIMINO_AICAR_P', loc = 'cyt', prot = None), 
    Parameter('fwd_PRIBFAICARPISOM_RXN', 1), 
    Parameter('rvs_PRIBFAICARPISOM_RXN', 0))

Rule('PRPPAMIDOTRANS_RXN',
    prot(name = 'purF', loc = 'cyt') +
    met(name = '_5_P_BETA_D_RIBOSYL_AMINE', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None) | 
    prot(name = 'purF', loc = 'cyt') +
    met(name = 'PRPP', loc = 'cyt', prot = None) +
    met(name = 'GLN', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_PRPPAMIDOTRANS_RXN', 1), 
    Parameter('rvs_PRPPAMIDOTRANS_RXN', 0))

Rule('PRPPSYN_RXN',
    prot(name = 'prs', loc = 'cyt') +
    met(name = 'RIBOSE_5P', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'prs', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'PRPP', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None), 
    Parameter('fwd_PRPPSYN_RXN', 1), 
    Parameter('rvs_PRPPSYN_RXN', 0))

Rule('PRTRANS_RXN',
    prot(name = 'trpD', loc = 'cyt') +
    met(name = 'N_5_PHOSPHORIBOSYL_ANTHRANILATE', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) | 
    prot(name = 'trpD', loc = 'cyt') +
    met(name = 'ANTHRANILATE', loc = 'cyt', prot = None) +
    met(name = 'PRPP', loc = 'cyt', prot = None), 
    Parameter('fwd_PRTRANS_RXN', 1), 
    Parameter('rvs_PRTRANS_RXN', 0))

Rule('PSERTRANSAM_RXN',
    prot(name = 'serC', loc = 'cyt') +
    met(name = '_3_P_SERINE', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'serC', loc = 'cyt') +
    met(name = '_3_P_HYDROXYPYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_PSERTRANSAM_RXN', 1), 
    Parameter('rvs_PSERTRANSAM_RXN', 0))

Rule('PSERTRANSAMPYR_RXN',
    prot(name = 'serC', loc = 'cyt') +
    met(name = '_3OH_4P_OH_ALPHA_KETOBUTYRATE', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None) | 
    prot(name = 'serC', loc = 'cyt') +
    met(name = '_4_PHOSPHONOOXY_THREONINE', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None), 
    Parameter('fwd_PSERTRANSAMPYR_RXN', 1), 
    Parameter('rvs_PSERTRANSAMPYR_RXN', 0))

Rule('PYRAZIN_RXN',
    prot(name = 'pncA', loc = 'cyt') +
    met(name = 'PYRAZINAMIDE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'pncA', loc = 'cyt') +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    met(name = 'PYRAZINOIC_ACID', loc = 'cyt', prot = None), 
    Parameter('fwd_PYRAZIN_RXN', 1), 
    Parameter('rvs_PYRAZIN_RXN', 0))

Rule('PYRUVDEH_RXN',
    prot(name = 'aceF', loc = 'cyt') +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'CO_A', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) | 
    prot(name = 'aceF', loc = 'cyt') +
    met(name = 'ACETYL_COA', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None), 
    Parameter('fwd_PYRUVDEH_RXN', 1), 
    Parameter('rvs_PYRUVDEH_RXN', 0))

Rule('RIB5PISOM_RXN',
    prot(name = 'rpiA', loc = 'cyt') +
    met(name = 'RIBOSE_5P', loc = 'cyt', prot = None) | 
    prot(name = 'rpiA', loc = 'cyt') +
    met(name = 'RIBULOSE_5P', loc = 'cyt', prot = None), 
    Parameter('fwd_RIB5PISOM_RXN', 1), 
    Parameter('rvs_RIB5PISOM_RXN', 0))

Rule('RIBONUCLEOSIDE_TRIP_REDUCT_RXN',
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'FORMATE', loc = 'cyt', prot = None) +
    met(name = 'Ribonucleoside_Triphosphates', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'Deoxy_Ribonucleoside_Triphosphates', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_RIBONUCLEOSIDE_TRIP_REDUCT_RXN', 1), 
    Parameter('rvs_RIBONUCLEOSIDE_TRIP_REDUCT_RXN', 0))

Rule('RIBOSYLNICOTINAMIDE_KINASE_RXN',
    prot(name = 'nadR', loc = 'cyt') +
    met(name = 'NICOTINAMIDE_RIBOSE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'nadR', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'NICOTINAMIDE_NUCLEOTIDE', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_RIBOSYLNICOTINAMIDE_KINASE_RXN', 1), 
    Parameter('rvs_RIBOSYLNICOTINAMIDE_KINASE_RXN', 0))

Rule('RIBOSYLPYRIMIDINE_NUCLEOSIDASE_RXN',
    prot(name = 'rihB', loc = 'cyt') +
    met(name = 'Pyrimidine_Nucleosides', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'rihB', loc = 'cyt') +
    met(name = 'Pyrimidine_Bases', loc = 'cyt', prot = None) +
    met(name = 'D_Ribofuranose', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_RIBOSYLPYRIMIDINE_NUCLEOSIDASE_RXN', 1), 
    Parameter('rvs_RIBOSYLPYRIMIDINE_NUCLEOSIDASE_RXN', 0))

Rule('RIBULP3EPIM_RXN',
    prot(name = 'rpe', loc = 'cyt') +
    met(name = 'RIBULOSE_5P', loc = 'cyt', prot = None) | 
    prot(name = 'rpe', loc = 'cyt') +
    met(name = 'XYLULOSE_5_PHOSPHATE', loc = 'cyt', prot = None), 
    Parameter('fwd_RIBULP3EPIM_RXN', 1), 
    Parameter('rvs_RIBULP3EPIM_RXN', 0))

Rule('RXN_10814',
    prot(name = 'ilvE', loc = 'cyt') +
    met(name = 'PHE', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'ilvE', loc = 'cyt') +
    met(name = 'PHENYL_PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_10814', 1), 
    Parameter('rvs_RXN_10814', 0))

Rule('RXN_11832',
    prot(name = 'cmk', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'CMP', loc = 'cyt', prot = None) | 
    prot(name = 'cmk', loc = 'cyt') +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'CDP', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_11832', 1), 
    Parameter('rvs_RXN_11832', 0))

Rule('RXN_12002',
    prot(name = 'pyrH', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'UMP', loc = 'cyt', prot = None) | 
    prot(name = 'pyrH', loc = 'cyt') +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'UDP', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_12002', 1), 
    Parameter('rvs_RXN_12002', 0))

Rule('RXN_12886',
    prot(name = 'rutA', loc = 'cyt') +
    met(name = 'THYMINE', loc = 'cyt', prot = None) +
    met(name = 'OXYGEN_MOLECULE', loc = 'cyt', prot = None) +
    met(name = 'FMNH2', loc = 'cyt', prot = None) | 
    prot(name = 'rutA', loc = 'cyt') +
    met(name = 'CPD_13927', loc = 'cyt', prot = None) +
    met(name = 'FMN', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_12886', 1), 
    Parameter('rvs_RXN_12886', 0))

Rule('RXN_12896',
    prot(name = 'rutB', loc = 'cyt') +
    met(name = 'CPD_13927', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'rutB', loc = 'cyt') +
    met(name = 'CPD_13930', loc = 'cyt', prot = None) +
    met(name = 'CARBAMATE', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_12896', 1), 
    Parameter('rvs_RXN_12896', 0))

Rule('RXN_13158',
    prot(name = 'leuB', loc = 'cyt') +
    met(name = '_2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'leuB', loc = 'cyt') +
    met(name = '_2K_4CH3_PENTANOATE', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_13158', 1), 
    Parameter('rvs_RXN_13158', 0))

Rule('RXN_13163',
    prot(name = 'leuC', loc = 'cyt') +
    met(name = '_2_D_THREO_HYDROXY_3_CARBOXY_ISOCAPROATE', loc = 'cyt', prot = None) | 
    prot(name = 'leuC', loc = 'cyt') +
    met(name = '_3_CARBOXY_3_HYDROXY_ISOCAPROATE', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_13163', 1), 
    Parameter('rvs_RXN_13163', 0))

Rule('RXN_14014',
    prot(name = 'dapB', loc = 'cyt') +
    met(name = 'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE', loc = 'per', prot = None) +
    met(name = 'NAD_P_OR_NOP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'dapB', loc = 'cyt') +
    met(name = 'CPD_14443', loc = 'cyt', prot = None) +
    met(name = 'NADH_P_OR_NOP', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14014', 1), 
    Parameter('rvs_RXN_14014', 0))

Rule('RXN_14025',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'UMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'URIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14025', 1), 
    Parameter('rvs_RXN_14025', 0))

Rule('RXN_14026',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14026', 1), 
    Parameter('rvs_RXN_14026', 0))

Rule('RXN_14074',
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'GTP', loc = 'cyt', prot = None) +
    met(name = 'AMP', loc = 'cyt', prot = None) | 
    prot(name = 'adk', loc = 'cyt') +
    met(name = 'GDP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14074', 1), 
    Parameter('rvs_RXN_14074', 0))

Rule('RXN_14090',
    prot(name = 'umpG', loc = 'cyt') +
    met(name = 'CPD_3711', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'umpG', loc = 'cyt') +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14090', 1), 
    Parameter('rvs_RXN_14090', 0))

Rule('RXN_14115',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_3724', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'URIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14115', 1), 
    Parameter('rvs_RXN_14115', 0))

Rule('RXN_14126',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_3706', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'ADENOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14126', 1), 
    Parameter('rvs_RXN_14126', 0))

Rule('RXN_14142',
    prot(name = 'umpG', loc = 'cyt') +
    met(name = 'DGMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'umpG', loc = 'cyt') +
    met(name = 'DEOXYGUANOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14142', 1), 
    Parameter('rvs_RXN_14142', 0))

Rule('RXN_14161',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'DAMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'DEOXYADENOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14161', 1), 
    Parameter('rvs_RXN_14161', 0))

Rule('RXN_14181',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'PYRIDOXINE_5P', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'PYRIDOXINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14181', 1), 
    Parameter('rvs_RXN_14181', 0))

Rule('RXN_14473',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'Nucleoside_Monophosphates', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'Nucleosides', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14473', 1), 
    Parameter('rvs_RXN_14473', 0))

Rule('RXN_14505',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'L_THREONINE_O_3_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'THR', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14505', 1), 
    Parameter('rvs_RXN_14505', 0))

Rule('RXN_14509',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'RIBOSE_5P', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_15818', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14509', 1), 
    Parameter('rvs_RXN_14509', 0))

Rule('RXN_14510',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_3723', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'URIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14510', 1), 
    Parameter('rvs_RXN_14510', 0))

Rule('RXN_14511',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_3710', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14511', 1), 
    Parameter('rvs_RXN_14511', 0))

Rule('RXN_14512',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_13025', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'GUANOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14512', 1), 
    Parameter('rvs_RXN_14512', 0))

Rule('RXN_14513',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_3705', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'ADENOSINE', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14513', 1), 
    Parameter('rvs_RXN_14513', 0))

Rule('RXN_14514',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_3721', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_239', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14514', 1), 
    Parameter('rvs_RXN_14514', 0))

Rule('RXN_14522',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'CPD_15392', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'DEOXYCYTIDINE', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14522', 1), 
    Parameter('rvs_RXN_14522', 0))

Rule('RXN_14523',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'CPD_15393', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'DEOXYURIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14523', 1), 
    Parameter('rvs_RXN_14523', 0))

Rule('RXN_14524',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'CPD_15391', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'DEOXYADENOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14524', 1), 
    Parameter('rvs_RXN_14524', 0))

Rule('RXN_14525',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'CPD_15390', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'DEOXYGUANOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14525', 1), 
    Parameter('rvs_RXN_14525', 0))

Rule('RXN_14534',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'CPD_3728', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'TYR', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_14534', 1), 
    Parameter('rvs_RXN_14534', 0))

Rule('RXN_15119',
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'CPD_4544', loc = 'cyt', prot = None) +
    met(name = 'Donor_H2', loc = 'cyt', prot = None) | 
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'CPD_16009', loc = 'cyt', prot = None) +
    met(name = 'Acceptor', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_15119', 1), 
    Parameter('rvs_RXN_15119', 0))

Rule('RXN_15513',
    prot(name = 'gpmA', loc = 'cyt') +
    met(name = '_2_PG', loc = 'cyt', prot = None) | 
    prot(name = 'gpmA', loc = 'cyt') +
    met(name = 'G3P', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_15513', 1), 
    Parameter('rvs_RXN_15513', 0))

Rule('RXN_16000',
    prot(name = 'ydfG', loc = 'cyt') +
    met(name = 'L_ALLO_THREONINE', loc = 'cyt', prot = None) +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ydfG', loc = 'cyt') +
    met(name = 'AMINO_OXOBUT', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_16000', 1), 
    Parameter('rvs_RXN_16000', 0))

Rule('RXN_16701',
    prot(name = 'serA', loc = 'cyt') +
    met(name = 'CPD_381', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'serA', loc = 'cyt') +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_16701', 1), 
    Parameter('rvs_RXN_16701', 0))

Rule('RXN_17330',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'D_glucose_1_phosphates', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Glucopyranose', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_17330', 1), 
    Parameter('rvs_RXN_17330', 0))

Rule('RXN_17724',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Mannose_6_phosphate', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'MANNOSE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_17724', 1), 
    Parameter('rvs_RXN_17724', 0))

Rule('RXN_17725',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'MANNOSE_1P', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'MANNOSE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_17725', 1), 
    Parameter('rvs_RXN_17725', 0))

Rule('RXN_17745',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'D_GLUCOSAMINE_6_P', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'GLUCOSAMINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_17745', 1), 
    Parameter('rvs_RXN_17745', 0))

Rule('RXN_18241',
    prot(name = 'ushA', loc = 'cyt') +
    met(name = 'CPD_606', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None +
    None | 
    prot(name = 'ushA', loc = 'cyt') +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'GLYCEROL_3P', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_18241', 1), 
    Parameter('rvs_RXN_18241', 0))

Rule('RXN_5076',
    prot(name = 'rutG', loc = 'cyt') +
    met(name = 'XANTHINE', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'rutG', loc = 'cyt') +
    met(name = 'XANTHINE', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_5076', 1), 
    Parameter('rvs_RXN_5076', 0))

Rule('RXN_5647',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'PHOSPHORYL_CHOLINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CHOLINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_5647', 1), 
    Parameter('rvs_RXN_5647', 0))

Rule('RXN_5822',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_5822', 1), 
    Parameter('rvs_RXN_5822', 0))

Rule('RXN_6321',
    prot(name = 'glyA', loc = 'cyt') +
    met(name = '_5_10_METHENYL_THF_GLU_N', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'glyA', loc = 'cyt') +
    met(name = 'N5_Formyl_THF_Glu_N', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_6321', 1), 
    Parameter('rvs_RXN_6321', 0))

Rule('RXN_7607',
    prot(name = 'yrfG', loc = 'cyt') +
    met(name = 'IMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'yrfG', loc = 'cyt') +
    met(name = 'INOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_7607', 1), 
    Parameter('rvs_RXN_7607', 0))

Rule('RXN_7609',
    prot(name = 'yrfG', loc = 'cyt') +
    met(name = 'GMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'yrfG', loc = 'cyt') +
    met(name = 'GUANOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_7609', 1), 
    Parameter('rvs_RXN_7609', 0))

Rule('RXN_7682',
    prot(name = 'xdhC', loc = 'cyt') +
    met(name = 'HYPOXANTHINE', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'xdhC', loc = 'cyt') +
    met(name = 'XANTHINE', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_7682', 1), 
    Parameter('rvs_RXN_7682', 0))

Rule('RXN_7716',
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'Oxo_glutarate_dehydrogenase_DH_lipoyl', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'Oxo_glutarate_dehydrogenase_lipoyl', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_7716', 1), 
    Parameter('rvs_RXN_7716', 0))

Rule('RXN_7913',
    prot(name = 'cmk', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'DCMP', loc = 'cyt', prot = None) | 
    prot(name = 'cmk', loc = 'cyt') +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'DCDP', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_7913', 1), 
    Parameter('rvs_RXN_7913', 0))

Rule('RXN_7948',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'PHOSPHORYL_ETHANOLAMINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'ETHANOL_AMINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_7948', 1), 
    Parameter('rvs_RXN_7948', 0))

Rule('RXN_8629',
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'DIHYDROLIPOYL_GCVH', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'PROTEIN_LIPOYLLYSINE', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_8629', 1), 
    Parameter('rvs_RXN_8629', 0))

Rule('RXN_8974',
    prot(name = 'rutE', loc = 'cyt') +
    met(name = '_3_HYDROXY_PROPIONATE', loc = 'cyt', prot = None) +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'rutE', loc = 'cyt') +
    met(name = 'MALONATE_S_ALD', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_8974', 1), 
    Parameter('rvs_RXN_8974', 0))

Rule('RXN_9952',
    prot(name = 'gnd', loc = 'cyt') +
    met(name = 'CPD_2961', loc = 'cyt', prot = None) +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'gnd', loc = 'cyt') +
    met(name = 'RIBULOSE_5P', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN_9952', 1), 
    Parameter('rvs_RXN_9952', 0))

Rule('RXN0_1132',
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'Pyruvate_dehydrogenase_dihydrolipoate', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'lpd', loc = 'cyt') +
    met(name = 'Pyruvate_dehydrogenase_lipoate', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_1132', 1), 
    Parameter('rvs_RXN0_1132', 0))

Rule('RXN0_1133',
    prot(name = 'aceF', loc = 'cyt') +
    met(name = 'ACETYL_COA', loc = 'cyt', prot = None) +
    met(name = 'Pyruvate_dehydrogenase_dihydrolipoate', loc = 'cyt', prot = None) | 
    prot(name = 'aceF', loc = 'cyt') +
    met(name = 'CO_A', loc = 'cyt', prot = None) +
    met(name = 'Pyruvate_dehydrogenase_acetylDHlipoyl', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_1133', 1), 
    Parameter('rvs_RXN0_1133', 0))

Rule('RXN0_1134',
    prot(name = 'aceE', loc = 'cyt') +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'Pyruvate_dehydrogenase_lipoate', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'aceE', loc = 'cyt') +
    met(name = 'Pyruvate_dehydrogenase_acetylDHlipoyl', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_RXN0_1134', 1), 
    Parameter('rvs_RXN0_1134', 0))

Rule('RXN0_1147',
    prot(name = 'sucB', loc = 'cyt') +
    met(name = 'SUC_COA', loc = 'cyt', prot = None) +
    met(name = 'Oxo_glutarate_dehydrogenase_DH_lipoyl', loc = 'cyt', prot = None) | 
    prot(name = 'sucB', loc = 'cyt') +
    met(name = 'CO_A', loc = 'cyt', prot = None) +
    met(name = 'Oxo_glutarate_dehydro_suc_DH_lipoyl', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_1147', 1), 
    Parameter('rvs_RXN0_1147', 0))

Rule('RXN0_17',
    prot(name = 'crr', loc = 'cyt') +
    met(name = 'NACMUR', loc = 'cyt', prot = None) +
    met(name = 'PTSH_PHOSPHORYLATED', loc = 'cyt', prot = None) | 
    prot(name = 'crr', loc = 'cyt') +
    met(name = 'CPD0_881', loc = 'cyt', prot = None) +
    met(name = 'PTSH_MONOMER', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_17', 1), 
    Parameter('rvs_RXN0_17', 0))

Rule('RXN0_2201',
    prot(name = 'ydfG', loc = 'cyt') +
    met(name = 'SER', loc = 'cyt', prot = None) +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ydfG', loc = 'cyt') +
    met(name = '_2_AMINOMALONATE_SEMIALDEHYDE', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_2201', 1), 
    Parameter('rvs_RXN0_2201', 0))

Rule('RXN0_2381',
    prot(name = 'trpA', loc = 'cyt') +
    met(name = 'INDOLE_3_GLYCEROL_P', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'trpA', loc = 'cyt') +
    met(name = 'INDOLE', loc = 'cyt', prot = None) +
    met(name = 'GAP', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_2381', 1), 
    Parameter('rvs_RXN0_2381', 0))

Rule('RXN0_2382',
    prot(name = 'trpB', loc = 'cyt') +
    met(name = 'INDOLE', loc = 'cyt', prot = None) +
    met(name = 'SER', loc = 'cyt', prot = None) | 
    prot(name = 'trpB', loc = 'cyt') +
    met(name = 'TRP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_2382', 1), 
    Parameter('rvs_RXN0_2382', 0))

Rule('RXN0_303',
    prot(name = 'rpiB', loc = 'cyt') +
    met(name = 'D_ALLOSE_6_PHOSPHATE', loc = 'cyt', prot = None) | 
    prot(name = 'rpiB', loc = 'cyt') +
    met(name = 'D_ALLULOSE_6_PHOSPHATE', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_303', 1), 
    Parameter('rvs_RXN0_303', 0))

Rule('RXN0_3241',
    prot(name = 'iaaA', loc = 'cyt') +
    met(name = 'CPD_12991', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'iaaA', loc = 'cyt') +
    met(name = 'L_ASPARTATE', loc = 'cyt', prot = None) +
    met(name = 'Amino_Acids_20', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_3241', 1), 
    Parameter('rvs_RXN0_3241', 0))

Rule('RXN0_361',
    prot(name = 'rihB', loc = 'cyt') +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'rihB', loc = 'cyt') +
    met(name = 'D_Ribofuranose', loc = 'cyt', prot = None) +
    met(name = 'CYTOSINE', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_361', 1), 
    Parameter('rvs_RXN0_361', 0))

Rule('RXN0_363',
    prot(name = 'rihC', loc = 'cyt') +
    met(name = 'XANTHOSINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'rihC', loc = 'cyt') +
    met(name = 'D_Ribofuranose', loc = 'cyt', prot = None) +
    met(name = 'XANTHINE', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_363', 1), 
    Parameter('rvs_RXN0_363', 0))

Rule('RXN0_3741',
    prot(name = 'ushA', loc = 'cyt') +
    met(name = 'Deoxy_Ribonucleoside_Monophosphates', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'ushA', loc = 'cyt') +
    met(name = 'Deoxy_Ribonucleosides', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_3741', 1), 
    Parameter('rvs_RXN0_3741', 0))

Rule('RXN0_5107',
    prot(name = 'nudI', loc = 'cyt') +
    met(name = 'TTP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'nudI', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'TMP', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_5107', 1), 
    Parameter('rvs_RXN0_5107', 0))

Rule('RXN0_5114',
    prot(name = 'aphA', loc = 'cyt') +
    met(name = '_3_P_SERINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'aphA', loc = 'cyt') +
    met(name = 'SER', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_5114', 1), 
    Parameter('rvs_RXN0_5114', 0))

Rule('RXN0_5185',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'CPD_2961', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'GLUCONATE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_5185', 1), 
    Parameter('rvs_RXN0_5185', 0))

Rule('RXN0_5187',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'FMN', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'RIBOFLAVIN', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_5187', 1), 
    Parameter('rvs_RXN0_5187', 0))

Rule('RXN0_5199',
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'GUANOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'deoD', loc = 'cyt') +
    met(name = 'RIBOSE_1P', loc = 'cyt', prot = None) +
    met(name = 'GUANINE', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_5199', 1), 
    Parameter('rvs_RXN0_5199', 0))

Rule('RXN0_5234',
    prot(name = 'glyA', loc = 'cyt') +
    met(name = 'ALLO_THR', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'glyA', loc = 'cyt') +
    met(name = 'ACETALD', loc = 'cyt', prot = None) +
    met(name = 'GLY', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_5234', 1), 
    Parameter('rvs_RXN0_5234', 0))

Rule('RXN0_5240',
    prot(name = 'glyA', loc = 'cyt') +
    met(name = 'D_ALANINE', loc = 'cyt', prot = None) +
    met(name = 'PYRIDOXAL_PHOSPHATE', loc = 'cyt', prot = None) | 
    prot(name = 'glyA', loc = 'cyt') +
    met(name = 'PYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'PYRIDOXAMINE_5P', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_5240', 1), 
    Parameter('rvs_RXN0_5240', 0))

Rule('RXN0_5292',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'DCMP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'DEOXYCYTIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_5292', 1), 
    Parameter('rvs_RXN0_5292', 0))

Rule('RXN0_6444',
    prot(name = 'rutA', loc = 'cyt') +
    met(name = 'URACIL', loc = 'cyt', prot = None) +
    met(name = 'OXYGEN_MOLECULE', loc = 'cyt', prot = None) +
    met(name = 'FMNH2', loc = 'cyt', prot = None) | 
    prot(name = 'rutA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CPD0_2338', loc = 'cyt', prot = None) +
    met(name = 'FMN', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_6444', 1), 
    Parameter('rvs_RXN0_6444', 0))

Rule('RXN0_6451',
    prot(name = 'rutB', loc = 'cyt') +
    met(name = 'CPD0_2331', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'rutB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CARBAMATE', loc = 'cyt', prot = None) +
    met(name = 'CPD0_2339', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_6451', 1), 
    Parameter('rvs_RXN0_6451', 0))

Rule('RXN0_6452',
    prot(name = 'rutD', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CPD0_2339', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'rutD', loc = 'cyt') +
    met(name = 'MALONATE_S_ALD', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_RXN0_6452', 1), 
    Parameter('rvs_RXN0_6452', 0))

Rule('RXN0_6460',
    prot(name = 'rutB', loc = 'cyt') +
    met(name = 'CPD0_2338', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'rutB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CARBAMATE', loc = 'cyt', prot = None) +
    met(name = 'CPD0_2340', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_6460', 1), 
    Parameter('rvs_RXN0_6460', 0))

Rule('RXN0_6491',
    prot(name = 'pyrD', loc = 'cyt') +
    met(name = 'DI_H_OROTATE', loc = 'cyt', prot = None) +
    met(name = 'Ubiquinones', loc = 'cyt', prot = None) | 
    prot(name = 'pyrD', loc = 'cyt') +
    met(name = 'OROTATE', loc = 'cyt', prot = None) +
    met(name = 'Ubiquinols', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_6491', 1), 
    Parameter('rvs_RXN0_6491', 0))

Rule('RXN0_6541',
    prot(name = 'pfkA', loc = 'cyt') +
    met(name = 'D_SEDOHEPTULOSE_7_P', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'pfkA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'D_SEDOHEPTULOSE_1_7_P2', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_6541', 1), 
    Parameter('rvs_RXN0_6541', 0))

Rule('RXN0_6554',
    prot(name = 'pyrD', loc = 'cyt') +
    met(name = 'DI_H_OROTATE', loc = 'cyt', prot = None) +
    met(name = 'Menaquinones', loc = 'cyt', prot = None) | 
    prot(name = 'pyrD', loc = 'cyt') +
    met(name = 'OROTATE', loc = 'cyt', prot = None) +
    met(name = 'Menaquinols', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_6554', 1), 
    Parameter('rvs_RXN0_6554', 0))

Rule('RXN0_6564',
    prot(name = 'thrB', loc = 'cyt') +
    met(name = 'CPD0_2189', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'thrB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = '_4_PHOSPHONOOXY_THREONINE', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_6564', 1), 
    Parameter('rvs_RXN0_6564', 0))

Rule('RXN0_6708',
    prot(name = 'codA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CPD0_2461', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'codA', loc = 'cyt') +
    met(name = 'XANTHINE', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_RXN0_6708', 1), 
    Parameter('rvs_RXN0_6708', 0))

Rule('RXN0_7092',
    prot(name = 'xapA', loc = 'cyt') +
    met(name = 'NIACINAMIDE', loc = 'cyt', prot = None) +
    met(name = 'RIBOSE_1P', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'xapA', loc = 'cyt') +
    met(name = 'NICOTINAMIDE_RIBOSE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_RXN0_7092', 1), 
    Parameter('rvs_RXN0_7092', 0))

Rule('RXN0_723',
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'FORMATE', loc = 'cyt', prot = None) +
    met(name = 'CTP', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'DCTP', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_723', 1), 
    Parameter('rvs_RXN0_723', 0))

Rule('RXN0_724',
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'FORMATE', loc = 'cyt', prot = None) +
    met(name = 'UTP', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'DUTP', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_724', 1), 
    Parameter('rvs_RXN0_724', 0))

Rule('RXN0_7249',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'DIHYDROXYACETONE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_7249', 1), 
    Parameter('rvs_RXN0_7249', 0))

Rule('RXN0_7250',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'GAP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'GLYCERALD', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_7250', 1), 
    Parameter('rvs_RXN0_7250', 0))

Rule('RXN0_7251',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'L_GLYCERALDEHYDE_3_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'L_GLYCERALDEHYDE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_7251', 1), 
    Parameter('rvs_RXN0_7251', 0))

Rule('RXN0_742',
    prot(name = 'purK', loc = 'cyt') +
    met(name = '_5_PHOSPHORIBOSYL_5_AMINOIMIDAZOLE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'HCO3', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'purK', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CPD0_181', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_742', 1), 
    Parameter('rvs_RXN0_742', 0))

Rule('RXN0_743',
    prot(name = 'purE', loc = 'cyt') +
    met(name = 'CPD0_181', loc = 'cyt', prot = None) | 
    prot(name = 'purE', loc = 'cyt') +
    met(name = 'PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_743', 1), 
    Parameter('rvs_RXN0_743', 0))

Rule('RXN0_745',
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'FORMATE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'DATP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_745', 1), 
    Parameter('rvs_RXN0_745', 0))

Rule('RXN0_746',
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'FORMATE', loc = 'cyt', prot = None) +
    met(name = 'GTP', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'nrdD', loc = 'cyt') +
    met(name = 'DGTP', loc = 'cyt', prot = None) +
    met(name = 'CARBON_DIOXIDE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_746', 1), 
    Parameter('rvs_RXN0_746', 0))

Rule('RXN0_901',
    prot(name = 'xdhC', loc = 'cyt') +
    met(name = 'XANTHINE', loc = 'cyt', prot = None) +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'xdhC', loc = 'cyt') +
    met(name = 'URATE', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN0_901', 1), 
    Parameter('rvs_RXN0_901', 0))

Rule('RXN66_526',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'D_glucopyranose_6_phosphate', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Glucopyranose', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_RXN66_526', 1), 
    Parameter('rvs_RXN66_526', 0))

Rule('SAICARSYN_RXN',
    prot(name = 'purC', loc = 'cyt') +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    met(name = 'PHOSPHORIBOSYL_CARBOXY_AMINOIMIDAZOLE', loc = 'cyt', prot = None) +
    met(name = 'L_ASPARTATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'purC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'P_RIBOSYL_4_SUCCCARB_AMINOIMIDAZOLE', loc = 'cyt', prot = None), 
    Parameter('fwd_SAICARSYN_RXN', 1), 
    Parameter('rvs_SAICARSYN_RXN', 0))

Rule('SEDOBISALDOL_RXN',
    prot(name = 'fbaA', loc = 'cyt') +
    met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'ERYTHROSE_4P', loc = 'cyt', prot = None) | 
    prot(name = 'fbaA', loc = 'cyt') +
    met(name = 'D_SEDOHEPTULOSE_1_7_P2', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_SEDOBISALDOL_RXN', 1), 
    Parameter('rvs_SEDOBISALDOL_RXN', 0))

Rule('SHIKIMATE_5_DEHYDROGENASE_RXN',
    prot(name = 'aroE', loc = 'cyt') +
    met(name = 'NADP', loc = 'cyt', prot = None) +
    met(name = 'SHIKIMATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'aroE', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'NADPH', loc = 'cyt', prot = None) +
    met(name = '_3_DEHYDRO_SHIKIMATE', loc = 'cyt', prot = None), 
    Parameter('fwd_SHIKIMATE_5_DEHYDROGENASE_RXN', 1), 
    Parameter('rvs_SHIKIMATE_5_DEHYDROGENASE_RXN', 0))

Rule('SHIKIMATE_KINASE_RXN',
    prot(name = 'aroL', loc = 'cyt') +
    met(name = 'SHIKIMATE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'aroL', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'SHIKIMATE_5P', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_SHIKIMATE_KINASE_RXN', 1), 
    Parameter('rvs_SHIKIMATE_KINASE_RXN', 0))

Rule('SUCCCOASYN_RXN',
    prot(name = 'sucC', loc = 'cyt') +
    met(name = 'SUC', loc = 'cyt', prot = None) +
    met(name = 'CO_A', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'sucC', loc = 'cyt') +
    met(name = 'SUC_COA', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_SUCCCOASYN_RXN', 1), 
    Parameter('rvs_SUCCCOASYN_RXN', 0))

Rule('SUCCDIAMINOPIMDESUCC_RXN',
    prot(name = 'dapE', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'N_SUCCINYLLL_2_6_DIAMINOPIMELATE', loc = 'cyt', prot = None) | 
    prot(name = 'dapE', loc = 'cyt') +
    met(name = 'LL_DIAMINOPIMELATE', loc = 'cyt', prot = None) +
    met(name = 'SUC', loc = 'cyt', prot = None), 
    Parameter('fwd_SUCCDIAMINOPIMDESUCC_RXN', 1), 
    Parameter('rvs_SUCCDIAMINOPIMDESUCC_RXN', 0))

Rule('SUCCINYLDIAMINOPIMTRANS_RXN',
    prot(name = 'argD', loc = 'cyt') +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) +
    met(name = 'N_SUCCINYLLL_2_6_DIAMINOPIMELATE', loc = 'cyt', prot = None) | 
    prot(name = 'argD', loc = 'cyt') +
    met(name = 'GLT', loc = 'cyt', prot = None) +
    met(name = 'N_SUCCINYL_2_AMINO_6_KETOPIMELATE', loc = 'cyt', prot = None), 
    Parameter('fwd_SUCCINYLDIAMINOPIMTRANS_RXN', 1), 
    Parameter('rvs_SUCCINYLDIAMINOPIMTRANS_RXN', 0))

Rule('SUGAR_PHOSPHATASE_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'Sugar_Phosphate', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Sugar', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None), 
    Parameter('fwd_SUGAR_PHOSPHATASE_RXN', 1), 
    Parameter('rvs_SUGAR_PHOSPHATASE_RXN', 0))

Rule('TAGAKIN_RXN',
    prot(name = 'pfkB', loc = 'cyt') +
    met(name = 'TAGATOSE_6_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'pfkB', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'TAGATOSE_1_6_DIPHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_TAGAKIN_RXN', 1), 
    Parameter('rvs_TAGAKIN_RXN', 0))

Rule('TARTRATE_DEHYDROGENASE_RXN',
    prot(name = 'dmlA', loc = 'cyt') +
    met(name = 'NAD', loc = 'cyt', prot = None) +
    met(name = 'TARTRATE', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'dmlA', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'NADH', loc = 'cyt', prot = None) +
    met(name = 'CPD_66', loc = 'cyt', prot = None), 
    Parameter('fwd_TARTRATE_DEHYDROGENASE_RXN', 1), 
    Parameter('rvs_TARTRATE_DEHYDROGENASE_RXN', 0))

Rule('TETHYDPICSUCC_RXN',
    prot(name = 'dapD', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'DELTA1_PIPERIDEINE_2_6_DICARBOXYLATE', loc = 'per', prot = None) +
    met(name = 'SUC_COA', loc = 'cyt', prot = None) | 
    prot(name = 'dapD', loc = 'cyt') +
    met(name = 'N_SUCCINYL_2_AMINO_6_KETOPIMELATE', loc = 'cyt', prot = None) +
    met(name = 'CO_A', loc = 'cyt', prot = None) +
    None, 
    Parameter('fwd_TETHYDPICSUCC_RXN', 1), 
    Parameter('rvs_TETHYDPICSUCC_RXN', 0))

Rule('THREDEHYD_RXN',
    prot(name = 'ilvA', loc = 'cyt') +
    met(name = 'THR', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ilvA', loc = 'cyt') +
    met(name = '_2_OXOBUTANOATE', loc = 'cyt', prot = None) +
    met(name = 'AMMONIUM', loc = 'cyt', prot = None), 
    Parameter('fwd_THREDEHYD_RXN', 1), 
    Parameter('rvs_THREDEHYD_RXN', 0))

Rule('THRESYN_RXN',
    prot(name = 'thrC', loc = 'cyt') +
    met(name = 'O_PHOSPHO_L_HOMOSERINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'thrC', loc = 'cyt') +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'THR', loc = 'cyt', prot = None), 
    Parameter('fwd_THRESYN_RXN', 1), 
    Parameter('rvs_THRESYN_RXN', 0))

Rule('THYKI_RXN',
    prot(name = 'tdk', loc = 'cyt') +
    met(name = 'THYMIDINE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'tdk', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'TMP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_THYKI_RXN', 1), 
    Parameter('rvs_THYKI_RXN', 0))

Rule('THYM_PHOSPH_RXN',
    prot(name = 'deoA', loc = 'cyt') +
    met(name = 'THYMIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'deoA', loc = 'cyt') +
    met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'THYMINE', loc = 'cyt', prot = None), 
    Parameter('fwd_THYM_PHOSPH_RXN', 1), 
    Parameter('rvs_THYM_PHOSPH_RXN', 0))

Rule('THYMIDYLATESYN_RXN',
    prot(name = 'thyA', loc = 'cyt') +
    met(name = 'METHYLENE_THF_GLU_N', loc = 'cyt', prot = None) +
    met(name = 'DUMP', loc = 'cyt', prot = None) | 
    prot(name = 'thyA', loc = 'cyt') +
    met(name = 'TMP', loc = 'cyt', prot = None) +
    met(name = 'DIHYDROFOLATE_GLU_N', loc = 'cyt', prot = None), 
    Parameter('fwd_THYMIDYLATESYN_RXN', 1), 
    Parameter('rvs_THYMIDYLATESYN_RXN', 0))

Rule('TRANS_RXN_108',
    prot(name = 'nupG', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'Nucleosides', loc = 'cyt', prot = None) | 
    prot(name = 'nupG', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'Nucleosides', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108', 1), 
    Parameter('rvs_TRANS_RXN_108', 0))

Rule('TRANS_RXN_108A',
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADENOSINE', loc = 'cyt', prot = None) | 
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'ADENOSINE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108A', 1), 
    Parameter('rvs_TRANS_RXN_108A', 0))

Rule('TRANS_RXN_108B',
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None) | 
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'CYTIDINE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108B', 1), 
    Parameter('rvs_TRANS_RXN_108B', 0))

Rule('TRANS_RXN_108C',
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DEOXYADENOSINE', loc = 'cyt', prot = None) | 
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DEOXYADENOSINE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108C', 1), 
    Parameter('rvs_TRANS_RXN_108C', 0))

Rule('TRANS_RXN_108D',
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DEOXYCYTIDINE', loc = 'cyt', prot = None) | 
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DEOXYCYTIDINE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108D', 1), 
    Parameter('rvs_TRANS_RXN_108D', 0))

Rule('TRANS_RXN_108E',
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DEOXYINOSINE', loc = 'cyt', prot = None) | 
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DEOXYINOSINE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108E', 1), 
    Parameter('rvs_TRANS_RXN_108E', 0))

Rule('TRANS_RXN_108F',
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DEOXYURIDINE', loc = 'cyt', prot = None) | 
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'DEOXYURIDINE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108F', 1), 
    Parameter('rvs_TRANS_RXN_108F', 0))

Rule('TRANS_RXN_108G',
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'INOSINE', loc = 'cyt', prot = None) | 
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'INOSINE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108G', 1), 
    Parameter('rvs_TRANS_RXN_108G', 0))

Rule('TRANS_RXN_108H',
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'THYMIDINE', loc = 'cyt', prot = None) | 
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'THYMIDINE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108H', 1), 
    Parameter('rvs_TRANS_RXN_108H', 0))

Rule('TRANS_RXN_108I',
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'URIDINE', loc = 'cyt', prot = None) | 
    prot(name = 'nupC', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'URIDINE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_108I', 1), 
    Parameter('rvs_TRANS_RXN_108I', 0))

Rule('TRANS_RXN_132',
    prot(name = 'rutG', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'URACIL', loc = 'cyt', prot = None) | 
    prot(name = 'rutG', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'URACIL', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_132', 1), 
    Parameter('rvs_TRANS_RXN_132', 0))

Rule('TRANS_RXN_157',
    prot(name = 'crr', loc = 'cyt') +
    met(name = 'PTSH_PHOSPHORYLATED', loc = 'cyt', prot = None) +
    met(name = 'Glucopyranose', loc = 'cyt', prot = None) | 
    prot(name = 'crr', loc = 'cyt') +
    met(name = 'D_glucopyranose_6_phosphate', loc = 'cyt', prot = None) +
    met(name = 'PTSH_MONOMER', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_157', 1), 
    Parameter('rvs_TRANS_RXN_157', 0))

Rule('TRANS_RXN_168',
    prot(name = 'crr', loc = 'cyt') +
    met(name = 'PTSH_PHOSPHORYLATED', loc = 'cyt', prot = None) +
    met(name = 'TREHALOSE', loc = 'cyt', prot = None) | 
    prot(name = 'crr', loc = 'cyt') +
    met(name = 'TREHALOSE_6P', loc = 'cyt', prot = None) +
    met(name = 'PTSH_MONOMER', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_168', 1), 
    Parameter('rvs_TRANS_RXN_168', 0))

Rule('TRANS_RXN_362',
    prot(name = 'rutG', loc = 'cyt') +
    met(name = 'THYMINE', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None) | 
    prot(name = 'rutG', loc = 'cyt') +
    met(name = 'THYMINE', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN_362', 1), 
    Parameter('rvs_TRANS_RXN_362', 0))

Rule('TRANS_RXN0_583',
    prot(name = 'ptsG', loc = 'cyt') +
    met(name = 'CPD_3582', loc = 'cyt', prot = None) +
    met(name = 'PTSH_PHOSPHORYLATED', loc = 'cyt', prot = None) | 
    prot(name = 'ptsG', loc = 'cyt') +
    met(name = 'PTSH_MONOMER', loc = 'cyt', prot = None) +
    met(name = 'CPD_16619', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANS_RXN0_583', 1), 
    Parameter('rvs_TRANS_RXN0_583', 0))

Rule('TRANSALDOL_RXN',
    prot(name = 'talA', loc = 'cyt') +
    met(name = 'D_SEDOHEPTULOSE_7_P', loc = 'cyt', prot = None) +
    met(name = 'GAP', loc = 'cyt', prot = None) | 
    prot(name = 'talA', loc = 'cyt') +
    met(name = 'FRUCTOSE_6P', loc = 'cyt', prot = None) +
    met(name = 'ERYTHROSE_4P', loc = 'cyt', prot = None), 
    Parameter('fwd_TRANSALDOL_RXN', 1), 
    Parameter('rvs_TRANSALDOL_RXN', 0))

Rule('TRIOSEPISOMERIZATION_RXN',
    prot(name = 'tpiA', loc = 'cyt') +
    met(name = 'GAP', loc = 'cyt', prot = None) | 
    prot(name = 'tpiA', loc = 'cyt') +
    met(name = 'DIHYDROXY_ACETONE_PHOSPHATE', loc = 'cyt', prot = None), 
    Parameter('fwd_TRIOSEPISOMERIZATION_RXN', 1), 
    Parameter('rvs_TRIOSEPISOMERIZATION_RXN', 0))

Rule('TRIPHOSPHATASE_RXN',
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'P3I', loc = 'cyt', prot = None) | 
    prot(name = 'phoA', loc = 'cyt') +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None), 
    Parameter('fwd_TRIPHOSPHATASE_RXN', 1), 
    Parameter('rvs_TRIPHOSPHATASE_RXN', 0))

Rule('TRYPSYN_RXN',
    prot(name = 'trpA', loc = 'cyt') +
    met(name = 'INDOLE_3_GLYCEROL_P', loc = 'cyt', prot = None) +
    met(name = 'SER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'trpA', loc = 'cyt') +
    met(name = 'TRP', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    met(name = 'GAP', loc = 'cyt', prot = None), 
    Parameter('fwd_TRYPSYN_RXN', 1), 
    Parameter('rvs_TRYPSYN_RXN', 0))

Rule('TYROSINE_AMINOTRANSFERASE_RXN',
    prot(name = 'aspC', loc = 'cyt') +
    met(name = 'TYR', loc = 'cyt', prot = None) +
    met(name = '_2_KETOGLUTARATE', loc = 'cyt', prot = None) | 
    prot(name = 'aspC', loc = 'cyt') +
    met(name = 'P_HYDROXY_PHENYLPYRUVATE', loc = 'cyt', prot = None) +
    met(name = 'GLT', loc = 'cyt', prot = None), 
    Parameter('fwd_TYROSINE_AMINOTRANSFERASE_RXN', 1), 
    Parameter('rvs_TYROSINE_AMINOTRANSFERASE_RXN', 0))

Rule('UDPKIN_RXN',
    prot(name = 'ndk', loc = 'cyt') +
    met(name = 'UDP', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) | 
    prot(name = 'ndk', loc = 'cyt') +
    met(name = 'UTP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_UDPKIN_RXN', 1), 
    Parameter('rvs_UDPKIN_RXN', 0))

Rule('UDPSUGARHYDRO_RXN',
    prot(name = 'ushA', loc = 'cyt') +
    met(name = 'UDP_sugar', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'ushA', loc = 'cyt') +
    met(name = 'UMP', loc = 'cyt', prot = None) +
    met(name = 'Alpha_D_aldose_1_phosphates', loc = 'cyt', prot = None) +
    met(name = 'PROTON', loc = 'cyt', prot = None), 
    Parameter('fwd_UDPSUGARHYDRO_RXN', 1), 
    Parameter('rvs_UDPSUGARHYDRO_RXN', 0))

Rule('URA_PHOSPH_RXN',
    prot(name = 'deoA', loc = 'cyt') +
    met(name = 'DEOXYURIDINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'deoA', loc = 'cyt') +
    met(name = 'DEOXY_D_RIBOSE_1_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'URACIL', loc = 'cyt', prot = None), 
    Parameter('fwd_URA_PHOSPH_RXN', 1), 
    Parameter('rvs_URA_PHOSPH_RXN', 0))

Rule('URACIL_PRIBOSYLTRANS_RXN',
    prot(name = 'upp', loc = 'cyt') +
    met(name = 'PPI', loc = 'cyt', prot = None) +
    met(name = 'UMP', loc = 'cyt', prot = None) | 
    prot(name = 'upp', loc = 'cyt') +
    met(name = 'PRPP', loc = 'cyt', prot = None) +
    met(name = 'URACIL', loc = 'cyt', prot = None), 
    Parameter('fwd_URACIL_PRIBOSYLTRANS_RXN', 1), 
    Parameter('rvs_URACIL_PRIBOSYLTRANS_RXN', 0))

Rule('URIDINE_NUCLEOSIDASE_RXN',
    prot(name = 'rihC', loc = 'cyt') +
    met(name = 'URIDINE', loc = 'cyt', prot = None) +
    met(name = 'WATER', loc = 'cyt', prot = None) | 
    prot(name = 'rihC', loc = 'cyt') +
    met(name = 'D_Ribofuranose', loc = 'cyt', prot = None) +
    met(name = 'URACIL', loc = 'cyt', prot = None), 
    Parameter('fwd_URIDINE_NUCLEOSIDASE_RXN', 1), 
    Parameter('rvs_URIDINE_NUCLEOSIDASE_RXN', 0))

Rule('URIDINEKIN_RXN',
    prot(name = 'udk', loc = 'cyt') +
    met(name = 'URIDINE', loc = 'cyt', prot = None) +
    met(name = 'ATP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'udk', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'UMP', loc = 'cyt', prot = None) +
    met(name = 'ADP', loc = 'cyt', prot = None), 
    Parameter('fwd_URIDINEKIN_RXN', 1), 
    Parameter('rvs_URIDINEKIN_RXN', 0))

Rule('URKI_RXN',
    prot(name = 'udk', loc = 'cyt') +
    met(name = 'URIDINE', loc = 'cyt', prot = None) +
    met(name = 'GTP', loc = 'cyt', prot = None) +
    None | 
    prot(name = 'udk', loc = 'cyt') +
    met(name = 'PROTON', loc = 'cyt', prot = None) +
    met(name = 'UMP', loc = 'cyt', prot = None) +
    met(name = 'GDP', loc = 'cyt', prot = None), 
    Parameter('fwd_URKI_RXN', 1), 
    Parameter('rvs_URKI_RXN', 0))

Rule('URPHOS_RXN',
    prot(name = 'udp', loc = 'cyt') +
    met(name = 'Pi', loc = 'cyt', prot = None) +
    met(name = 'URIDINE', loc = 'cyt', prot = None) | 
    prot(name = 'udp', loc = 'cyt') +
    met(name = 'RIBOSE_1P', loc = 'cyt', prot = None) +
    met(name = 'URACIL', loc = 'cyt', prot = None), 
    Parameter('fwd_URPHOS_RXN', 1), 
    Parameter('rvs_URPHOS_RXN', 0))

Rule('XANPRIBOSYLTRAN_RXN',
    prot(name = 'gpt', loc = 'cyt') +
    met(name = 'XANTHOSINE_5_PHOSPHATE', loc = 'cyt', prot = None) +
    met(name = 'PPI', loc = 'cyt', prot = None) | 
    prot(name = 'gpt', loc = 'cyt') +
    met(name = 'XANTHINE', loc = 'cyt', prot = None) +
    met(name = 'PRPP', loc = 'cyt', prot = None), 
    Parameter('fwd_XANPRIBOSYLTRAN_RXN', 1), 
    Parameter('rvs_XANPRIBOSYLTRAN_RXN', 0))

Rule('XANTHOSINEPHOSPHORY_RXN',
    prot(name = 'xapA', loc = 'cyt') +
    met(name = 'XANTHOSINE', loc = 'cyt', prot = None) +
    met(name = 'Pi', loc = 'cyt', prot = None) | 
    prot(name = 'xapA', loc = 'cyt') +
    met(name = 'RIBOSE_1P', loc = 'cyt', prot = None) +
    met(name = 'XANTHINE', loc = 'cyt', prot = None), 
    Parameter('fwd_XANTHOSINEPHOSPHORY_RXN', 1), 
    Parameter('rvs_XANTHOSINEPHOSPHORY_RXN', 0))
# Out:
# Rule('XANTHOSINEPHOSPHORY_RXN', prot(name='xapA', loc='cyt') + met(name='XANTHOSINE', loc='cyt', prot=None) + met(name='Pi', loc='cyt', prot=None) | prot(name='xapA', loc='cyt') + met(name='RIBOSE_1P', loc='cyt', prot=None) + met(name='XANTHINE', loc='cyt', prot=None), fwd_XANTHOSINEPHOSPHORY_RXN, rvs_XANTHOSINEPHOSPHORY_RXN)

# %%
## paste here the results of "Rules from protein-protein"
# section 2: protein-protein interactions

# %%
## paste here the result of either "Rules from SigmaFactors x Architecture" or "Rules from genome architecture"
## the later do not consider sigma specificity and requires the declaration of an ad-hoc agent for RNAP:
## Initial(cplx(name = 'RNAP', loc = 'cyt', dna = None, prot = None, rna = None), Parameter('t0_RNAP', 10))
# section 3a: rna synthesis

# section 3b: protein synthesis

# %%
## write dna parts. TODO automatization
# section 3c: initialize dna and others

# %%
## paste here the result of "Rules from tf-tfbs"
# section 4: regulation of gene expression

# %%
## paste here the result of "Rules from protein-small compounds"
# section 5: protein and small compounds interactions

# %%
## write here ad-hoc rules.
# section 6: ad-hoc rules

# %% [markdown]
# ### Section 3: SImulation

# %%
## save model to kappa and bngl
with open('model_central_carbon.kappa', 'w') as outfile:
    outfile.write(export(model, 'kappa'))
    
with open('model_central_carbon.bngl', 'w') as outfile:
    outfile.write(export(model, 'bngl'))

# %%
runs = 20
data2 = BngSimulator(model, linspace(0, 200, 201)).run(method = 'nf', n_runs = runs).dataframe
data2 = KappaSimulator(model, linspace(0, 200, 201)).run(n_runs = runs).dataframe

data = []
for i in range(runs):
    data.append(data2.xs(i))

avrg = 0
for i in range(runs):
    avrg += data[i]
avrg = avrg / runs

stdv = []
for i in range(runs):
    stdv = (data[i] - avrg)**2
stdv = (stdv / (runs-1))**0.5

# %%
fig, ax = plt.subplots(1, 2, figsize = (4*2, 3*1), dpi = 100)

label = r'Glucopyranose' # use $$ for latex rendering
observable = 'obs_Glucopyranose_per'
ax[0].fill_between(avrg.index, 
                   avrg[observable] + stdv[observable], 
                   avrg[observable] - stdv[observable], 
                   label = label, **{'color' : palette[2], 'alpha' : 0.5})

label = r'D-glucopyranose 6-phosphate'
observable = 'obs_D_glucopyranose_6_phosphate_cyt'
ax[1].fill_between(avrg.index, 
                   avrg[observable] + stdv[observable], 
                   avrg[observable] - stdv[observable], 
                   label = label, **{'color' : palette[2], 'alpha' : 0.5})

ax[0].set_xlabel('Time [A.U.]')
ax[0].set_ylabel('Concentration [A.U.]')
ax[0].set_title('Cytolasm')
ax[0].set_ylim(top = 200, bottom = 0)

ax[1].set_xlabel('Time [A.U.]')
ax[1].set_title('Cytoplasm')
ax[1].set_ylim(top = 200, bottom = 0)

ax[0].legend(frameon = False)
ax[1].legend(frameon = False)

seaborn.despine()
plt.savefig('model.png', format = 'png', bbox_inches = 'tight', dpi = 300)
plt.show()
