# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width: 95% !important; }</style>"))
# Out:
# <style>.container { width: 95% !important; }</style>

# %%
import pandas

# %%
with open('./architecture_final.txt', 'r') as infile:
    data = pandas.read_csv(infile, delimiter = '\t')
# data

# %%
c = list(zip(list(data.SOURCE), list(data.TARGET)))
c = [elt for sublist in c for elt in sublist]

architecture = list(dict.fromkeys(c).keys())
# architecture

# %%
for dna_part in architecture:
    Rule = ''

    if 'pro' in dna_part: # docking rules
        name = dna_part.split('-')[0]
        type = dna_part.split('-')[1]
            
        # we write specific rules following the sigma specificity for promoters
        # (i.e. we assume each promoter has different affinity for their sigma factors) in the sigma factor-DNA binding notebook
#         Rule = 'Rule(\'docking_{:s}\',\n'\
#                '    cplx(name = \'RNAP\', dna = None) + dna(name = \'{:s}\', type = \'{:s}\', prot = None, free = \'True\') |\n' \
#                '    cplx(name = \'RNAP\', dna = 1) % dna(name = \'{:s}\', type = \'{:s}\', prot = 1, free = \'False\'),\n' \
#                '    Parameter(\'fwd_docking_{:s}\', 0), Parameter(\'rvs_docking_{:s}\', 0))' \
#                .format(dna_part, name, type, name, type, dna_part, dna_part)
        
        print(Rule.replace('-', '_'))
        print()
        
    elif 'ter' in dna_part: # falloff rules
        name = dna_part.split('-')[0]
        type = dna_part.split('-')[1]
            
        Rule = 'Rule(\'falloff_{:s}\',\n'\
               '    cplx(name = \'RNAP\', dna = 1) % dna(name = \'{:s}\', type = \'{:s}\', prot = 1, free = \'False\') >>\n' \
               '    cplx(name = \'RNAP\', dna = None) + dna(name = \'{:s}\', type = \'{:s}\', prot = None, free = \'True\'),\n' \
               '    Parameter(\'fwd_falloff_{:s}\', 0))' \
               .format(dna_part, name, type, name, type, dna_part)
        
        print(Rule.replace('-', '_'))
        print()
# Out:
# Rule('docking_rpoA_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoA', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoA', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_rpoA_pro1', 0), Parameter('rvs_docking_rpoA_pro1', 0))
#
# Rule('falloff_rpoA_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoA', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoA', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_rpoA_ter1', 0))
#
# Rule('docking_rpoB_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoB', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoB', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_rpoB_pro1', 0), Parameter('rvs_docking_rpoB_pro1', 0))
#
# Rule('falloff_rpoC_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoC', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoC', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_rpoC_ter1', 0))
#
# Rule('docking_rpoD_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoD', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoD', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_rpoD_pro1', 0), Parameter('rvs_docking_rpoD_pro1', 0))
#
# Rule('falloff_rpoD_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoD', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoD', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_rpoD_ter1', 0))
#
# Rule('docking_rpoE_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoE', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoE', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_rpoE_pro1', 0), Parameter('rvs_docking_rpoE_pro1', 0))
#
# Rule('falloff_rpoE_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoE', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoE', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_rpoE_ter1', 0))
#
# Rule('docking_rpoH_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoH', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoH', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_rpoH_pro1', 0), Parameter('rvs_docking_rpoH_pro1', 0))
#
# Rule('falloff_rpoH_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoH', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoH', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_rpoH_ter1', 0))
#
# Rule('docking_rpoN_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoN', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoN', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_rpoN_pro1', 0), Parameter('rvs_docking_rpoN_pro1', 0))
#
# Rule('falloff_rpoN_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoN', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoN', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_rpoN_ter1', 0))
#
# Rule('docking_rpoS_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoS', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoS', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_rpoS_pro1', 0), Parameter('rvs_docking_rpoS_pro1', 0))
#
# Rule('falloff_rpoS_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoS', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'rpoS', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_rpoS_ter1', 0))
#
# Rule('docking_fliA_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fliA', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fliA', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_fliA_pro1', 0), Parameter('rvs_docking_fliA_pro1', 0))
#
# Rule('falloff_fliA_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fliA', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fliA', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_fliA_ter1', 0))
#
# Rule('docking_fecI_pro1',
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fecI', type = 'pro1', prot = None, free = 'True') |
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fecI', type = 'pro1', prot = 1, free = 'False'),
#     Parameter('fwd_docking_fecI_pro1', 0), Parameter('rvs_docking_fecI_pro1', 0))
#
# Rule('falloff_fecI_ter1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fecI', type = 'ter1', prot = 1, free = 'False') >>
#     cplx(name = 'RNAP', dna = None) + dna(name = 'fecI', type = 'ter1', prot = None, free = 'True'),
#     Parameter('fwd_falloff_fecI_ter1', 0))

# %%
for dna_part1, dna_part2 in zip(data.SOURCE, data.TARGET):
    name1 = dna_part1.split('-')[0]
    type1 = dna_part1.split('-')[1]
    name2 = dna_part2.split('-')[0]
    type2 = dna_part2.split('-')[1]
    
    if 'BS' in dna_part1:  # catch binding sites to add to sliding rules
        name1 = '_'.join(dna_part1.split('-')[1:])
        type1 = dna_part1.split('-')[1]
    elif 'BS' in dna_part2:
        name2 = '_'.join(dna_part2.split('-')[1:])
        type2 = dna_part2.split('-')[1]
        
    Rule = 'Rule(\'sliding_{:s}\',\n'\
           '    cplx(name = \'RNAP\', dna = 1) % dna(name = \'{:s}\', type = \'{:s}\', prot = 1, free = \'False\') + None + dna(name = \'{:s}\', type = \'{:s}\', prot = None, free = \'True\') >>\n' \
           '    cplx(name = \'RNAP\', dna = 1) % dna(name = \'{:s}\', type = \'{:s}\', prot = 1, free = \'False\') + rna(name = \'{:s}\', type = \'{:s}\', dna = None, prot = None) + dna(name = \'{:s}\', type = \'{:s}\', prot = None, free = \'True\'),\n' \
           '    Parameter(\'fwd_sliding_{:s}\', 0))' \
           .format(dna_part1, name1, type1, name2, type2, name2, type2, name2, type2, name1, type1, dna_part1)
    
    print(Rule.replace('-', '_'))
    print()
# Out:
# Rule('sliding_rpoA_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoA', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'rpoA', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoA', type = 'rbs', prot = 1, free = 'False') + rna(name = 'rpoA', type = 'rbs', dna = None, prot = None) + dna(name = 'rpoA', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoA_pro1', 0))
#
# Rule('sliding_rpoA_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoA', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'rpoA', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoA', type = 'cds', prot = 1, free = 'False') + rna(name = 'rpoA', type = 'cds', dna = None, prot = None) + dna(name = 'rpoA', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoA_rbs', 0))
#
# Rule('sliding_rpoA_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoA', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'rpoA', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoA', type = 'ter1', prot = 1, free = 'False') + rna(name = 'rpoA', type = 'ter1', dna = None, prot = None) + dna(name = 'rpoA', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoA_cds', 0))
#
# Rule('sliding_rpoB_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoB', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'rpoB', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoB', type = 'rbs', prot = 1, free = 'False') + rna(name = 'rpoB', type = 'rbs', dna = None, prot = None) + dna(name = 'rpoB', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoB_pro1', 0))
#
# Rule('sliding_rpoB_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoB', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'rpoB', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoB', type = 'cds', prot = 1, free = 'False') + rna(name = 'rpoB', type = 'cds', dna = None, prot = None) + dna(name = 'rpoB', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoB_rbs', 0))
#
# Rule('sliding_rpoB_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoB', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'rpoC', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoC', type = 'rbs', prot = 1, free = 'False') + rna(name = 'rpoC', type = 'rbs', dna = None, prot = None) + dna(name = 'rpoB', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoB_cds', 0))
#
# Rule('sliding_rpoC_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoC', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'rpoC', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoC', type = 'cds', prot = 1, free = 'False') + rna(name = 'rpoC', type = 'cds', dna = None, prot = None) + dna(name = 'rpoC', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoC_rbs', 0))
#
# Rule('sliding_rpoC_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoC', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'rpoC', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoC', type = 'ter1', prot = 1, free = 'False') + rna(name = 'rpoC', type = 'ter1', dna = None, prot = None) + dna(name = 'rpoC', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoC_cds', 0))
#
# Rule('sliding_rpoD_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoD', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'rpoD', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoD', type = 'rbs', prot = 1, free = 'False') + rna(name = 'rpoD', type = 'rbs', dna = None, prot = None) + dna(name = 'rpoD', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoD_pro1', 0))
#
# Rule('sliding_rpoD_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoD', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'rpoD', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoD', type = 'cds', prot = 1, free = 'False') + rna(name = 'rpoD', type = 'cds', dna = None, prot = None) + dna(name = 'rpoD', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoD_rbs', 0))
#
# Rule('sliding_rpoD_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoD', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'rpoD', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoD', type = 'ter1', prot = 1, free = 'False') + rna(name = 'rpoD', type = 'ter1', dna = None, prot = None) + dna(name = 'rpoD', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoD_cds', 0))
#
# Rule('sliding_rpoE_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoE', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'rpoE', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoE', type = 'rbs', prot = 1, free = 'False') + rna(name = 'rpoE', type = 'rbs', dna = None, prot = None) + dna(name = 'rpoE', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoE_pro1', 0))
#
# Rule('sliding_rpoE_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoE', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'rpoE', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoE', type = 'cds', prot = 1, free = 'False') + rna(name = 'rpoE', type = 'cds', dna = None, prot = None) + dna(name = 'rpoE', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoE_rbs', 0))
#
# Rule('sliding_rpoE_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoE', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'rpoE', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoE', type = 'ter1', prot = 1, free = 'False') + rna(name = 'rpoE', type = 'ter1', dna = None, prot = None) + dna(name = 'rpoE', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoE_cds', 0))
#
# Rule('sliding_rpoH_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoH', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'rpoH', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoH', type = 'rbs', prot = 1, free = 'False') + rna(name = 'rpoH', type = 'rbs', dna = None, prot = None) + dna(name = 'rpoH', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoH_pro1', 0))
#
# Rule('sliding_rpoH_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoH', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'rpoH', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoH', type = 'cds', prot = 1, free = 'False') + rna(name = 'rpoH', type = 'cds', dna = None, prot = None) + dna(name = 'rpoH', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoH_rbs', 0))
#
# Rule('sliding_rpoH_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoH', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'rpoH', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoH', type = 'ter1', prot = 1, free = 'False') + rna(name = 'rpoH', type = 'ter1', dna = None, prot = None) + dna(name = 'rpoH', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoH_cds', 0))
#
# Rule('sliding_rpoN_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoN', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'rpoN', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoN', type = 'rbs', prot = 1, free = 'False') + rna(name = 'rpoN', type = 'rbs', dna = None, prot = None) + dna(name = 'rpoN', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoN_pro1', 0))
#
# Rule('sliding_rpoN_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoN', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'rpoN', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoN', type = 'cds', prot = 1, free = 'False') + rna(name = 'rpoN', type = 'cds', dna = None, prot = None) + dna(name = 'rpoN', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoN_rbs', 0))
#
# Rule('sliding_rpoN_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoN', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'rpoN', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoN', type = 'ter1', prot = 1, free = 'False') + rna(name = 'rpoN', type = 'ter1', dna = None, prot = None) + dna(name = 'rpoN', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoN_cds', 0))
#
# Rule('sliding_rpoS_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoS', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'rpoS', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoS', type = 'rbs', prot = 1, free = 'False') + rna(name = 'rpoS', type = 'rbs', dna = None, prot = None) + dna(name = 'rpoS', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoS_pro1', 0))
#
# Rule('sliding_rpoS_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoS', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'rpoS', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoS', type = 'cds', prot = 1, free = 'False') + rna(name = 'rpoS', type = 'cds', dna = None, prot = None) + dna(name = 'rpoS', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoS_rbs', 0))
#
# Rule('sliding_rpoS_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoS', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'rpoS', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'rpoS', type = 'ter1', prot = 1, free = 'False') + rna(name = 'rpoS', type = 'ter1', dna = None, prot = None) + dna(name = 'rpoS', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_rpoS_cds', 0))
#
# Rule('sliding_fliA_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fliA', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'fliA', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fliA', type = 'rbs', prot = 1, free = 'False') + rna(name = 'fliA', type = 'rbs', dna = None, prot = None) + dna(name = 'fliA', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fliA_pro1', 0))
#
# Rule('sliding_fliA_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fliA', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'fliA', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fliA', type = 'cds', prot = 1, free = 'False') + rna(name = 'fliA', type = 'cds', dna = None, prot = None) + dna(name = 'fliA', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fliA_rbs', 0))
#
# Rule('sliding_fliA_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fliA', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'fliA', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fliA', type = 'ter1', prot = 1, free = 'False') + rna(name = 'fliA', type = 'ter1', dna = None, prot = None) + dna(name = 'fliA', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fliA_cds', 0))
#
# Rule('sliding_fecI_pro1',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fecI', type = 'pro1', prot = 1, free = 'False') + None + dna(name = 'fecI', type = 'rbs', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fecI', type = 'rbs', prot = 1, free = 'False') + rna(name = 'fecI', type = 'rbs', dna = None, prot = None) + dna(name = 'fecI', type = 'pro1', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fecI_pro1', 0))
#
# Rule('sliding_fecI_rbs',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fecI', type = 'rbs', prot = 1, free = 'False') + None + dna(name = 'fecI', type = 'cds', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fecI', type = 'cds', prot = 1, free = 'False') + rna(name = 'fecI', type = 'cds', dna = None, prot = None) + dna(name = 'fecI', type = 'rbs', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fecI_rbs', 0))
#
# Rule('sliding_fecI_cds',
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fecI', type = 'cds', prot = 1, free = 'False') + None + dna(name = 'fecI', type = 'ter1', prot = None, free = 'True') >>
#     cplx(name = 'RNAP', dna = 1) % dna(name = 'fecI', type = 'ter1', prot = 1, free = 'False') + rna(name = 'fecI', type = 'ter1', dna = None, prot = None) + dna(name = 'fecI', type = 'cds', prot = None, free = 'True'),
#     Parameter('fwd_sliding_fecI_cds', 0))

# %%
for dna_part in architecture:
    Rule = ''

    if 'rbs' in dna_part: # docking rules
        name = dna_part.split('-')[0]
        type = dna_part.split('-')[1]
            
        Rule = 'Rule(\'dr_{:s}\', cplx(name = \'Ribosome\', rna = None) + rna(name = \'{:s}\', type = \'{:s}\', prot = None) |\n' \
               '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1),\n' \
               '    Parameter(\'fwd_dr_{:s}\', 0), Parameter(\'rvs_dr_{:s}\', 0))' \
               .format(dna_part, name, type, name, type, dna_part, dna_part)
        
        print(Rule.replace('-', '_'))
        print()
        
    elif 'ter' in dna_part: # falloff rules
        name = dna_part.split('-')[0]
        type = dna_part.split('-')[1]
            
        Rule = 'Rule(\'fr_{:s}\', cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) >>\n' \
               '    cplx(name = \'Ribosome\', rna = None) + rna(name = \'{:s}\', type = \'{:s}\', prot = None),\n' \
               '    Parameter(\'fwd_fr_{:s}\', 0))' \
               .format(dna_part, name, type, name, type, dna_part)
        
        print(Rule.replace('-', '_'))
        print()
# Out:
# Rule('dr_rpoA_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoA', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoA', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_rpoA_rbs', 0), Parameter('rvs_dr_rpoA_rbs', 0))
#
# Rule('fr_rpoA_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoA', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoA', type = 'ter1', prot = None),
#     Parameter('fwd_fr_rpoA_ter1', 0))
#
# Rule('dr_rpoB_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoB', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoB', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_rpoB_rbs', 0), Parameter('rvs_dr_rpoB_rbs', 0))
#
# Rule('dr_rpoC_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoC', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoC', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_rpoC_rbs', 0), Parameter('rvs_dr_rpoC_rbs', 0))
#
# Rule('fr_rpoC_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoC', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoC', type = 'ter1', prot = None),
#     Parameter('fwd_fr_rpoC_ter1', 0))
#
# Rule('dr_rpoD_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoD', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoD', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_rpoD_rbs', 0), Parameter('rvs_dr_rpoD_rbs', 0))
#
# Rule('fr_rpoD_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoD', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoD', type = 'ter1', prot = None),
#     Parameter('fwd_fr_rpoD_ter1', 0))
#
# Rule('dr_rpoE_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoE', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoE', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_rpoE_rbs', 0), Parameter('rvs_dr_rpoE_rbs', 0))
#
# Rule('fr_rpoE_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoE', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoE', type = 'ter1', prot = None),
#     Parameter('fwd_fr_rpoE_ter1', 0))
#
# Rule('dr_rpoH_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoH', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoH', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_rpoH_rbs', 0), Parameter('rvs_dr_rpoH_rbs', 0))
#
# Rule('fr_rpoH_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoH', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoH', type = 'ter1', prot = None),
#     Parameter('fwd_fr_rpoH_ter1', 0))
#
# Rule('dr_rpoN_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoN', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoN', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_rpoN_rbs', 0), Parameter('rvs_dr_rpoN_rbs', 0))
#
# Rule('fr_rpoN_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoN', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoN', type = 'ter1', prot = None),
#     Parameter('fwd_fr_rpoN_ter1', 0))
#
# Rule('dr_rpoS_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoS', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoS', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_rpoS_rbs', 0), Parameter('rvs_dr_rpoS_rbs', 0))
#
# Rule('fr_rpoS_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoS', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'rpoS', type = 'ter1', prot = None),
#     Parameter('fwd_fr_rpoS_ter1', 0))
#
# Rule('dr_fliA_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'fliA', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fliA', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_fliA_rbs', 0), Parameter('rvs_dr_fliA_rbs', 0))
#
# Rule('fr_fliA_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'fliA', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'fliA', type = 'ter1', prot = None),
#     Parameter('fwd_fr_fliA_ter1', 0))
#
# Rule('dr_fecI_rbs', cplx(name = 'Ribosome', rna = None) + rna(name = 'fecI', type = 'rbs', prot = None) |
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fecI', type = 'rbs', prot = 1),
#     Parameter('fwd_dr_fecI_rbs', 0), Parameter('rvs_dr_fecI_rbs', 0))
#
# Rule('fr_fecI_ter1', cplx(name = 'Ribosome', rna = 1) % rna(name = 'fecI', type = 'ter1', prot = 1) >>
#     cplx(name = 'Ribosome', rna = None) + rna(name = 'fecI', type = 'ter1', prot = None),
#     Parameter('fwd_fr_fecI_ter1', 0))

# %%
forward = False
for dna_part1, dna_part2 in zip(data.SOURCE, data.TARGET):
    name1 = dna_part1.split('-')[0]
    type1 = dna_part1.split('-')[1]
    name2 = dna_part2.split('-')[0]
    type2 = dna_part2.split('-')[1]

    if 'rbs' in type1:
        forward = True
        
    if forward:
        if 'cds' in type2:
            Rule = 'Rule(\'sr_{:s}\',\n'\
                   '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) + None + rna(name = \'{:s}\', type = \'{:s}\', prot = None) >>\n' \
                   '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) + prot(name = \'{:s}\', loc = \'cyt\', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = \'{:s}\', type = \'{:s}\', prot = None),\n' \
                   '    Parameter(\'fwd_sr_{:s}\', 0))' \
                   .format(dna_part1, name1, type1, name2, type2, name2, type2, name2, name2, type2, dna_part1)

        else: # just sliding
            Rule = 'Rule(\'sr_{:s}\',\n'\
                   '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) + rna(name = \'{:s}\', type = \'{:s}\', prot = None) >>\n' \
                   '    cplx(name = \'Ribosome\', rna = 1) % rna(name = \'{:s}\', type = \'{:s}\', prot = 1) + rna(name = \'{:s}\', type = \'{:s}\', prot = None),\n' \
                   '    Parameter(\'fwd_sr_{:s}\', 0))' \
                   .format(dna_part1, name1, type1, name2, type2, name2, type2, name1, type1, dna_part1)
            
        print(Rule.replace('-', '_'))
        print()
# Out:
# Rule('sr_rpoA_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoA', type = 'rbs', prot = 1) + None + rna(name = 'rpoA', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoA', type = 'cds', prot = 1) + prot(name = 'rpoA', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'rpoA', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoA_rbs', 0))
#
# Rule('sr_rpoA_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoA', type = 'cds', prot = 1) + rna(name = 'rpoA', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoA', type = 'ter1', prot = 1) + rna(name = 'rpoA', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoA_cds', 0))
#
# Rule('sr_rpoB_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoB', type = 'pro1', prot = 1) + rna(name = 'rpoB', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoB', type = 'rbs', prot = 1) + rna(name = 'rpoB', type = 'pro1', prot = None),
#     Parameter('fwd_sr_rpoB_pro1', 0))
#
# Rule('sr_rpoB_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoB', type = 'rbs', prot = 1) + None + rna(name = 'rpoB', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoB', type = 'cds', prot = 1) + prot(name = 'rpoB', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'rpoB', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoB_rbs', 0))
#
# Rule('sr_rpoB_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoB', type = 'cds', prot = 1) + rna(name = 'rpoC', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoC', type = 'rbs', prot = 1) + rna(name = 'rpoB', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoB_cds', 0))
#
# Rule('sr_rpoC_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoC', type = 'rbs', prot = 1) + None + rna(name = 'rpoC', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoC', type = 'cds', prot = 1) + prot(name = 'rpoC', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'rpoC', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoC_rbs', 0))
#
# Rule('sr_rpoC_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoC', type = 'cds', prot = 1) + rna(name = 'rpoC', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoC', type = 'ter1', prot = 1) + rna(name = 'rpoC', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoC_cds', 0))
#
# Rule('sr_rpoD_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoD', type = 'pro1', prot = 1) + rna(name = 'rpoD', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoD', type = 'rbs', prot = 1) + rna(name = 'rpoD', type = 'pro1', prot = None),
#     Parameter('fwd_sr_rpoD_pro1', 0))
#
# Rule('sr_rpoD_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoD', type = 'rbs', prot = 1) + None + rna(name = 'rpoD', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoD', type = 'cds', prot = 1) + prot(name = 'rpoD', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'rpoD', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoD_rbs', 0))
#
# Rule('sr_rpoD_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoD', type = 'cds', prot = 1) + rna(name = 'rpoD', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoD', type = 'ter1', prot = 1) + rna(name = 'rpoD', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoD_cds', 0))
#
# Rule('sr_rpoE_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoE', type = 'pro1', prot = 1) + rna(name = 'rpoE', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoE', type = 'rbs', prot = 1) + rna(name = 'rpoE', type = 'pro1', prot = None),
#     Parameter('fwd_sr_rpoE_pro1', 0))
#
# Rule('sr_rpoE_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoE', type = 'rbs', prot = 1) + None + rna(name = 'rpoE', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoE', type = 'cds', prot = 1) + prot(name = 'rpoE', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'rpoE', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoE_rbs', 0))
#
# Rule('sr_rpoE_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoE', type = 'cds', prot = 1) + rna(name = 'rpoE', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoE', type = 'ter1', prot = 1) + rna(name = 'rpoE', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoE_cds', 0))
#
# Rule('sr_rpoH_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoH', type = 'pro1', prot = 1) + rna(name = 'rpoH', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoH', type = 'rbs', prot = 1) + rna(name = 'rpoH', type = 'pro1', prot = None),
#     Parameter('fwd_sr_rpoH_pro1', 0))
#
# Rule('sr_rpoH_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoH', type = 'rbs', prot = 1) + None + rna(name = 'rpoH', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoH', type = 'cds', prot = 1) + prot(name = 'rpoH', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'rpoH', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoH_rbs', 0))
#
# Rule('sr_rpoH_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoH', type = 'cds', prot = 1) + rna(name = 'rpoH', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoH', type = 'ter1', prot = 1) + rna(name = 'rpoH', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoH_cds', 0))
#
# Rule('sr_rpoN_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoN', type = 'pro1', prot = 1) + rna(name = 'rpoN', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoN', type = 'rbs', prot = 1) + rna(name = 'rpoN', type = 'pro1', prot = None),
#     Parameter('fwd_sr_rpoN_pro1', 0))
#
# Rule('sr_rpoN_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoN', type = 'rbs', prot = 1) + None + rna(name = 'rpoN', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoN', type = 'cds', prot = 1) + prot(name = 'rpoN', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'rpoN', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoN_rbs', 0))
#
# Rule('sr_rpoN_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoN', type = 'cds', prot = 1) + rna(name = 'rpoN', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoN', type = 'ter1', prot = 1) + rna(name = 'rpoN', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoN_cds', 0))
#
# Rule('sr_rpoS_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoS', type = 'pro1', prot = 1) + rna(name = 'rpoS', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoS', type = 'rbs', prot = 1) + rna(name = 'rpoS', type = 'pro1', prot = None),
#     Parameter('fwd_sr_rpoS_pro1', 0))
#
# Rule('sr_rpoS_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoS', type = 'rbs', prot = 1) + None + rna(name = 'rpoS', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoS', type = 'cds', prot = 1) + prot(name = 'rpoS', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'rpoS', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoS_rbs', 0))
#
# Rule('sr_rpoS_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoS', type = 'cds', prot = 1) + rna(name = 'rpoS', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'rpoS', type = 'ter1', prot = 1) + rna(name = 'rpoS', type = 'cds', prot = None),
#     Parameter('fwd_sr_rpoS_cds', 0))
#
# Rule('sr_fliA_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fliA', type = 'pro1', prot = 1) + rna(name = 'fliA', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fliA', type = 'rbs', prot = 1) + rna(name = 'fliA', type = 'pro1', prot = None),
#     Parameter('fwd_sr_fliA_pro1', 0))
#
# Rule('sr_fliA_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fliA', type = 'rbs', prot = 1) + None + rna(name = 'fliA', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fliA', type = 'cds', prot = 1) + prot(name = 'fliA', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'fliA', type = 'cds', prot = None),
#     Parameter('fwd_sr_fliA_rbs', 0))
#
# Rule('sr_fliA_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fliA', type = 'cds', prot = 1) + rna(name = 'fliA', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fliA', type = 'ter1', prot = 1) + rna(name = 'fliA', type = 'cds', prot = None),
#     Parameter('fwd_sr_fliA_cds', 0))
#
# Rule('sr_fecI_pro1',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fecI', type = 'pro1', prot = 1) + rna(name = 'fecI', type = 'rbs', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fecI', type = 'rbs', prot = 1) + rna(name = 'fecI', type = 'pro1', prot = None),
#     Parameter('fwd_sr_fecI_pro1', 0))
#
# Rule('sr_fecI_rbs',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fecI', type = 'rbs', prot = 1) + None + rna(name = 'fecI', type = 'cds', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fecI', type = 'cds', prot = 1) + prot(name = 'fecI', loc = 'cyt', dna = None, met = None, rna = None, up = None, dw = None) + rna(name = 'fecI', type = 'cds', prot = None),
#     Parameter('fwd_sr_fecI_rbs', 0))
#
# Rule('sr_fecI_cds',
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fecI', type = 'cds', prot = 1) + rna(name = 'fecI', type = 'ter1', prot = None) >>
#     cplx(name = 'Ribosome', rna = 1) % rna(name = 'fecI', type = 'ter1', prot = 1) + rna(name = 'fecI', type = 'cds', prot = None),
#     Parameter('fwd_sr_fecI_cds', 0))

# %%
Initials = []

c = list(zip(list(data.SOURCE), list(data.TARGET)))
c = [elt for sublist in c for elt in sublist]

for dna_part in list(dict.fromkeys(c).keys()):
    name = dna_part.split('-')[0]
    type = dna_part.split('-')[1]
    
    print('Initial(dna(name = \'{:s}\', type = \'{:s}\', prot = None, rna = None, up = None, dw = None), Parameter(\'t0_{:s}_{:s}_dna\', 1))'.format(name, type, name, type))
# Out:
# Initial(dna(name = 'rpoA', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoA_pro1_dna', 1))
# Initial(dna(name = 'rpoA', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoA_rbs_dna', 1))
# Initial(dna(name = 'rpoA', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoA_cds_dna', 1))
# Initial(dna(name = 'rpoA', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoA_ter1_dna', 1))
# Initial(dna(name = 'rpoB', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoB_pro1_dna', 1))
# Initial(dna(name = 'rpoB', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoB_rbs_dna', 1))
# Initial(dna(name = 'rpoB', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoB_cds_dna', 1))
# Initial(dna(name = 'rpoC', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoC_rbs_dna', 1))
# Initial(dna(name = 'rpoC', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoC_cds_dna', 1))
# Initial(dna(name = 'rpoC', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoC_ter1_dna', 1))
# Initial(dna(name = 'rpoD', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoD_pro1_dna', 1))
# Initial(dna(name = 'rpoD', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoD_rbs_dna', 1))
# Initial(dna(name = 'rpoD', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoD_cds_dna', 1))
# Initial(dna(name = 'rpoD', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoD_ter1_dna', 1))
# Initial(dna(name = 'rpoE', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoE_pro1_dna', 1))
# Initial(dna(name = 'rpoE', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoE_rbs_dna', 1))
# Initial(dna(name = 'rpoE', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoE_cds_dna', 1))
# Initial(dna(name = 'rpoE', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoE_ter1_dna', 1))
# Initial(dna(name = 'rpoH', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoH_pro1_dna', 1))
# Initial(dna(name = 'rpoH', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoH_rbs_dna', 1))
# Initial(dna(name = 'rpoH', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoH_cds_dna', 1))
# Initial(dna(name = 'rpoH', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoH_ter1_dna', 1))
# Initial(dna(name = 'rpoN', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoN_pro1_dna', 1))
# Initial(dna(name = 'rpoN', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoN_rbs_dna', 1))
# Initial(dna(name = 'rpoN', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoN_cds_dna', 1))
# Initial(dna(name = 'rpoN', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoN_ter1_dna', 1))
# Initial(dna(name = 'rpoS', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoS_pro1_dna', 1))
# Initial(dna(name = 'rpoS', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoS_rbs_dna', 1))
# Initial(dna(name = 'rpoS', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoS_cds_dna', 1))
# Initial(dna(name = 'rpoS', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_rpoS_ter1_dna', 1))
# Initial(dna(name = 'fliA', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fliA_pro1_dna', 1))
# Initial(dna(name = 'fliA', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_fliA_rbs_dna', 1))
# Initial(dna(name = 'fliA', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_fliA_cds_dna', 1))
# Initial(dna(name = 'fliA', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fliA_ter1_dna', 1))
# Initial(dna(name = 'fecI', type = 'pro1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fecI_pro1_dna', 1))
# Initial(dna(name = 'fecI', type = 'rbs', prot = None, rna = None, up = None, dw = None), Parameter('t0_fecI_rbs_dna', 1))
# Initial(dna(name = 'fecI', type = 'cds', prot = None, rna = None, up = None, dw = None), Parameter('t0_fecI_cds_dna', 1))
# Initial(dna(name = 'fecI', type = 'ter1', prot = None, rna = None, up = None, dw = None), Parameter('t0_fecI_ter1_dna', 1))
