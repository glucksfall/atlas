# %%
import pandas

# %%
data = pandas.read_csv('./metabolic_network_v2.txt', header = None, delimiter = '\t')
data
# Out:
#                   0                      1  \
# 0      ARAE-MONOMER  TRANS-RXN-10-alpha-af
# 1      ARAE-MONOMER   TRANS-RXN-10-beta-af
# 2      ARAE-MONOMER  TRANS-RXN-10-alpha-ap
# 3      ARAE-MONOMER   TRANS-RXN-10-beta-ap
# 4        ABC-2-CPLX     ABC-2-RXN-alpha-af
# 5        ABC-2-CPLX      ABC-2-RXN-beta-af
# 6        ABC-2-CPLX     ABC-2-RXN-alpha-ap
# 7        ABC-2-CPLX      ABC-2-RXN-beta-ap
# 8     ARABISOM-CPLX  ARABISOM-RXN-alpha-ap
# 9     ARABISOM-CPLX   ARABISOM-RXN-beta-ap
# 10   RIBULOKIN-CPLX              RXN0-5116
# 11  RIBULPEPIM-CPLX         RIBULPEPIM-RXN
#
#                                           2  \
# 0   PER-PROTON, PER-alpha-L-arabinofuranose
# 1    PER-PROTON, PER-beta-L-arabinofuranose
# 2   PER-PROTON, PER-alpha-L-arabinopyranose
# 3    PER-PROTON, PER-beta-L-arabinopyranose
# 4   WATER, ATP, PER-alpha-L-arabinofuranose
# 5    WATER, ATP, PER-beta-L-arabinofuranose
# 6   WATER, ATP, PER-alpha-L-arabinopyranose
# 7    WATER, ATP, PER-beta-L-arabinopyranose
# 8                   alpha-L-arabinopyranose
# 9                    beta-L-arabinopyranose
# 10                          L-RIBULOSE, ATP
# 11                           L-RIBULOSE-5-P
#
#                                            3
# 0            PROTON, alpha-L-arabinofuranose
# 1             PROTON, beta-L-arabinofuranose
# 2            PROTON, alpha-L-arabinopyranose
# 3             PROTON, beta-L-arabinopyranose
# 4   Pi, ADP, PROTON, alpha-L-arabinofuranose
# 5    Pi, ADP, PROTON, beta-L-arabinofuranose
# 6   Pi, ADP, PROTON, alpha-L-arabinopyranose
# 7    Pi, ADP, PROTON, beta-L-arabinopyranose
# 8                                 L-RIBULOSE
# 9                                 L-RIBULOSE
# 10               PROTON, L-RIBULOSE-5-P, ADP
# 11                      XYLULOSE-5-PHOSPHATE

# %%
print('SOURCE	SOURCE_ATTRIBUTE	TARGET	TARGET_ATTRIBUTE')
for enzyme, reaction in zip(data.loc[:,0], data.loc[:,1]):
    print('{:s}\tGENE_PROD\t{:s}\tRXN'.format(enzyme, reaction))
print()
    
for reaction, substrates in zip(data.loc[:,1], data.loc[:,2]):
    for subtrate in substrates.split(', '):
        print('{:s}\tMET\t{:s}\tRXN'.format(subtrate, reaction))
print()
        
for reaction, products in zip(data.loc[:,1], data.loc[:,3]):
    for product in products.split(', '):
        print('{:s}\tRXN\t{:s}\tMET'.format(reaction, product))
# Out:
# SOURCE	SOURCE_ATTRIBUTE	TARGET	TARGET_ATTRIBUTE
# ARAE-MONOMER	GENE_PROD	TRANS-RXN-10-alpha-af	RXN
# ARAE-MONOMER	GENE_PROD	TRANS-RXN-10-beta-af	RXN
# ARAE-MONOMER	GENE_PROD	TRANS-RXN-10-alpha-ap	RXN
# ARAE-MONOMER	GENE_PROD	TRANS-RXN-10-beta-ap	RXN
# ABC-2-CPLX	GENE_PROD	ABC-2-RXN-alpha-af	RXN
# ABC-2-CPLX	GENE_PROD	ABC-2-RXN-beta-af	RXN
# ABC-2-CPLX	GENE_PROD	ABC-2-RXN-alpha-ap	RXN
# ABC-2-CPLX	GENE_PROD	ABC-2-RXN-beta-ap	RXN
# ARABISOM-CPLX	GENE_PROD	ARABISOM-RXN-alpha-ap	RXN
# ARABISOM-CPLX	GENE_PROD	ARABISOM-RXN-beta-ap	RXN
# RIBULOKIN-CPLX	GENE_PROD	RXN0-5116	RXN
# RIBULPEPIM-CPLX	GENE_PROD	RIBULPEPIM-RXN	RXN
#
# PER-PROTON	MET	TRANS-RXN-10-alpha-af	RXN
# PER-alpha-L-arabinofuranose	MET	TRANS-RXN-10-alpha-af	RXN
# PER-PROTON	MET	TRANS-RXN-10-beta-af	RXN
# PER-beta-L-arabinofuranose	MET	TRANS-RXN-10-beta-af	RXN
# PER-PROTON	MET	TRANS-RXN-10-alpha-ap	RXN
# PER-alpha-L-arabinopyranose	MET	TRANS-RXN-10-alpha-ap	RXN
# PER-PROTON	MET	TRANS-RXN-10-beta-ap	RXN
# PER-beta-L-arabinopyranose	MET	TRANS-RXN-10-beta-ap	RXN
# WATER	MET	ABC-2-RXN-alpha-af	RXN
# ATP	MET	ABC-2-RXN-alpha-af	RXN
# PER-alpha-L-arabinofuranose	MET	ABC-2-RXN-alpha-af	RXN
# WATER	MET	ABC-2-RXN-beta-af	RXN
# ATP	MET	ABC-2-RXN-beta-af	RXN
# PER-beta-L-arabinofuranose	MET	ABC-2-RXN-beta-af	RXN
# WATER	MET	ABC-2-RXN-alpha-ap	RXN
# ATP	MET	ABC-2-RXN-alpha-ap	RXN
# PER-alpha-L-arabinopyranose	MET	ABC-2-RXN-alpha-ap	RXN
# WATER	MET	ABC-2-RXN-beta-ap	RXN
# ATP	MET	ABC-2-RXN-beta-ap	RXN
# PER-beta-L-arabinopyranose	MET	ABC-2-RXN-beta-ap	RXN
# alpha-L-arabinopyranose	MET	ARABISOM-RXN-alpha-ap	RXN
# beta-L-arabinopyranose	MET	ARABISOM-RXN-beta-ap	RXN
# L-RIBULOSE	MET	RXN0-5116	RXN
# ATP	MET	RXN0-5116	RXN
# L-RIBULOSE-5-P	MET	RIBULPEPIM-RXN	RXN
#
# TRANS-RXN-10-alpha-af	RXN	PROTON	MET
# TRANS-RXN-10-alpha-af	RXN	alpha-L-arabinofuranose	MET
# TRANS-RXN-10-beta-af	RXN	PROTON	MET
# TRANS-RXN-10-beta-af	RXN	beta-L-arabinofuranose	MET
# TRANS-RXN-10-alpha-ap	RXN	PROTON	MET
# TRANS-RXN-10-alpha-ap	RXN	alpha-L-arabinopyranose	MET
# TRANS-RXN-10-beta-ap	RXN	PROTON	MET
# TRANS-RXN-10-beta-ap	RXN	beta-L-arabinopyranose	MET
# ABC-2-RXN-alpha-af	RXN	Pi	MET
# ABC-2-RXN-alpha-af	RXN	ADP	MET
# ABC-2-RXN-alpha-af	RXN	PROTON	MET
# ABC-2-RXN-alpha-af	RXN	alpha-L-arabinofuranose	MET
# ABC-2-RXN-beta-af	RXN	Pi	MET
# ABC-2-RXN-beta-af	RXN	ADP	MET
# ABC-2-RXN-beta-af	RXN	PROTON	MET
# ABC-2-RXN-beta-af	RXN	beta-L-arabinofuranose	MET
# ABC-2-RXN-alpha-ap	RXN	Pi	MET
# ABC-2-RXN-alpha-ap	RXN	ADP	MET
# ABC-2-RXN-alpha-ap	RXN	PROTON	MET
# ABC-2-RXN-alpha-ap	RXN	alpha-L-arabinopyranose	MET
# ABC-2-RXN-beta-ap	RXN	Pi	MET
# ABC-2-RXN-beta-ap	RXN	ADP	MET
# ABC-2-RXN-beta-ap	RXN	PROTON	MET
# ABC-2-RXN-beta-ap	RXN	beta-L-arabinopyranose	MET
# ARABISOM-RXN-alpha-ap	RXN	L-RIBULOSE	MET
# ARABISOM-RXN-beta-ap	RXN	L-RIBULOSE	MET
# RXN0-5116	RXN	PROTON	MET
# RXN0-5116	RXN	L-RIBULOSE-5-P	MET
# RXN0-5116	RXN	ADP	MET
# RIBULPEPIM-RXN	RXN	XYLULOSE-5-PHOSPHATE	MET
